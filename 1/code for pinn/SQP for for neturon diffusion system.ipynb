# %%
# FIXED-BATCH + JITTERED-NOISE STOCHASTIC SQP-PINN (JAX)
# FOR REDUCED COUPLED NEUTRON / FUEL-HEAT / COOLANT-HEAT
#
# Network outputs: [phi, Ts, Tf]
#
#   phi : neutron flux in fuel
#   Ts  : fuel temperature in fuel
#   Tf  : coolant temperature in coolant
#
# No Navier-Stokes. No pressure.
# Coolant advection is prescribed by constant upward velocity vy.
#
# IMPORTANT:
#   - base collocation/boundary/interface/IC point sets are sampled ONCE
#   - each iteration uses fresh jittered versions of those fixed sets
#   - no resampling during training
#
# Objective:
#   PDE residuals on large fixed base sets (with fresh jitter each iter)
#
# Hard constraints:
#   PDE anchors on smaller fixed base sets (with fresh jitter each iter)
#   BC / IC / interface constraints
#
# This follows your Burgers / test style:
#   - train_sqp(...) has the knobs in main()
#   - jitter/noise magnitudes chosen in main()
#   - weights chosen in main()
#   - gamma, L_lip, Gamma_lip etc. chosen in main()
# ============================================================

import os
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "1")
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_FLAGS"] = "--xla_gpu_enable_command_buffer="

import time
import math
from functools import partial
import numpy as np

import jax
import jax.numpy as jnp
from jax import random, vmap, jacrev, hessian

# ============================================================
# Precision / dtype
# ============================================================
USE_X64 = True
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = DTYPE(1e-12)

# ============================================================
# GEOMETRY
# ============================================================
Ls = DTYPE(0.4)
Lf = DTYPE(0.6)
Ly = DTYPE(1.0)
T_end = DTYPE(1.0)

x_min = DTYPE(0.0)
x_max = DTYPE(Ls + Lf)
y_min = DTYPE(0.0)
y_max = DTYPE(Ly)
t_min = DTYPE(0.0)
t_max = DTYPE(T_end)

# ============================================================
# SAMPLE COUNTS (edit here if you want different set sizes)
# ============================================================
# Objective PDE sets (large, soft)
NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI = 15, 15, 10
NX_OBJ_TS,  NY_OBJ_TS,  NT_OBJ_TS  = 15, 15, 10
NX_OBJ_TF,  NY_OBJ_TF,  NT_OBJ_TF  = 15, 15, 10

# PDE anchor sets (smaller, hard)
NX_CON_PHI, NY_CON_PHI, NT_CON_PHI = 6 ,6, 6 
NX_CON_TS,  NY_CON_TS,  NT_CON_TS  = 7, 7, 7
NX_CON_TF,  NY_CON_TF,  NT_CON_TF  = 7, 7, 7

K_CON_PHI = NX_CON_PHI * NY_CON_PHI * NT_CON_PHI
K_CON_TS  = NX_CON_TS  * NY_CON_TS  * NT_CON_TS
K_CON_TF  = NX_CON_TF  * NY_CON_TF  * NT_CON_TF

N_PER_CELL = 1
N_BC_PER_BIN = 1
N_IC_PER_BIN = 1
N_IF_PER_BIN = 1

# BC counts
K_BC_PHI_LEFT = 60
K_BC_PHI_Y0   = 60
K_BC_PHI_Y1   = 60
K_BC_PHI_IF   = 60

K_BC_TS_X0    = 60
K_BC_TS_Y0    = 60
K_BC_TS_Y1    = 60

K_BC_TF_Y0    = 60  # coolant bottom Dirichlet Tf=0
K_BC_TF_Y1    = 60   # coolant top zero diffusive flux
K_BC_TF_X1    = 60   # coolant right zero diffusive flux
# IC counts: separate point sets for phi, Ts, Tf
NX_IC, NY_IC = 10, 10
K_IC_PHI = NX_IC * NY_IC
K_IC_TS  = NX_IC * NY_IC
K_IC_TF  = NX_IC * NY_IC

# Interface points
NY_IF, NT_IF = 10, 10
K_IF = NY_IF * NT_IF

# ============================================================
# BLOCK SIZES
# ============================================================
N_PDE_PHI = K_CON_PHI
N_PDE_TS  = K_CON_TS
N_PDE_TF  = K_CON_TF

N_BC_PHI = K_BC_PHI_LEFT + K_BC_PHI_Y0 + K_BC_PHI_Y1 + K_BC_PHI_IF
N_BC_TS  = K_BC_TS_X0 + K_BC_TS_Y0 + K_BC_TS_Y1
N_BC_TF  = K_BC_TF_Y0 + K_BC_TF_Y1 + K_BC_TF_X1
N_IF     = 2 * K_IF
N_IC     = K_IC_PHI + K_IC_TS + K_IC_TF

M_CON = N_PDE_PHI + N_PDE_TS + N_PDE_TF + N_BC_PHI + N_BC_TS + N_BC_TF + N_IF + N_IC

# ============================================================
# TARGETS / BCs / ICs
# ============================================================
@jax.jit
def phi_left_source(y, t):
    return (DTYPE(1.0) - jnp.exp(-DTYPE(5.0) * t)) * (
        DTYPE(1.0) + DTYPE(0.2) * jnp.sin(jnp.pi * y) * jnp.sin(jnp.pi * y)
    )

@jax.jit
def phi_ic_target(y):
    return jnp.zeros_like(y)

@jax.jit
def Ts_ic_target(x, y):
    return jnp.zeros_like(x)

@jax.jit
def Tf_ic_target(x, y):
    return jnp.zeros_like(x)

# ============================================================
# NETWORK
# ============================================================
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params

def normalize_xyt(X):
    x = X[:, 0:1]
    y = X[:, 1:2]
    t = X[:, 2:3]

    x_n = DTYPE(2.0) * (x - x_min) / (x_max - x_min + EPS) - DTYPE(1.0)
    y_n = DTYPE(2.0) * (y - y_min) / (y_max - y_min + EPS) - DTYPE(1.0)
    t_n = DTYPE(2.0) * (t - t_min) / (t_max - t_min + EPS) - DTYPE(1.0)
    return jnp.concatenate([x_n, y_n, t_n], axis=1)

def mlp_apply(params, X):
    h = normalize_xyt(X)
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)
    # outputs = [phi, Ts, Tf]
    return h

def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)

def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape)
        idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape)
        idx += b_size
        params.append({"W": W, "b": b})
    return params

# ============================================================
# UTILITIES
# ============================================================
def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)

# ============================================================
# STRATIFIED SAMPLING
# ============================================================
def sample_stratified_3d(key, x0, x1, y0, y1, t0, t1, NX, NY, NT):
    dx = (DTYPE(x1) - DTYPE(x0)) / DTYPE(NX)
    dy = (DTYPE(y1) - DTYPE(y0)) / DTYPE(NY)
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(NT)

    it, iy, ix = jnp.meshgrid(jnp.arange(NT), jnp.arange(NY), jnp.arange(NX), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids = (it * (NY * NX) + iy * NX + ix).astype(jnp.int32)

    xb = DTYPE(x0) + DTYPE(ix) * dx
    yb = DTYPE(y0) + DTYPE(iy) * dy
    tb = DTYPE(t0) + DTYPE(it) * dt

    K = NX * NY * NT
    u = random.uniform(key, (K, 3), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = xb + u[:, 0] * dx
    ys = yb + u[:, 1] * dy
    ts = tb + u[:, 2] * dt
    X = jnp.stack([xs, ys, ts], axis=1)
    return X, ids

def sample_bc_time_binned(key, K, *, x_fixed=None, y_fixed=None, t0=t_min, t1=t_max,
                          x_lo=None, x_hi=None, y_lo=None, y_hi=None):
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(K)
    j = jnp.arange(K, dtype=jnp.int32)
    tb = DTYPE(t0) + DTYPE(j) * dt

    key, kt, kr = random.split(key, 3)
    u_t = random.uniform(kt, (K, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (tb[:, None] + u_t * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    if x_fixed is not None:
        lo = DTYPE(y_min if y_lo is None else y_lo)
        hi = DTYPE(y_max if y_hi is None else y_hi)
        y = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        x = DTYPE(x_fixed) * jnp.ones_like(y)
        return jnp.concatenate([x, y, ts], axis=1), ids

    if y_fixed is not None:
        lo = DTYPE(x_min if x_lo is None else x_lo)
        hi = DTYPE(x_max if x_hi is None else x_hi)
        x = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        y = DTYPE(y_fixed) * jnp.ones_like(x)
        return jnp.concatenate([x, y, ts], axis=1), ids

    raise ValueError("Provide x_fixed or y_fixed")

def sample_ic_xy(key, x0, x1, y0, y1, NX, NY):
    dx = (DTYPE(x1) - DTYPE(x0)) / DTYPE(NX)
    dy = (DTYPE(y1) - DTYPE(y0)) / DTYPE(NY)

    iy, ix = jnp.meshgrid(jnp.arange(NY), jnp.arange(NX), indexing="ij")
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids0 = (iy * NX + ix).astype(jnp.int32)

    xb = DTYPE(x0) + DTYPE(ix) * dx
    yb = DTYPE(y0) + DTYPE(iy) * dy

    u = random.uniform(key, (NX * NY, N_IC_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (xb[:, None] + u[:, :, 0] * dx).reshape(-1, 1)
    ys = (yb[:, None] + u[:, :, 1] * dy).reshape(-1, 1)
    ts = t_min * jnp.ones_like(xs)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IC_PER_BIN)
    return X, ids

def sample_interface_yt(key):
    dy = (y_max - y_min) / DTYPE(NY_IF)
    dt = (t_max - t_min) / DTYPE(NT_IF)

    it, iy = jnp.meshgrid(jnp.arange(NT_IF), jnp.arange(NY_IF), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ids0 = (it * NY_IF + iy).astype(jnp.int32)

    yb = y_min + DTYPE(iy) * dy
    tb = t_min + DTYPE(it) * dt

    u = random.uniform(key, (NY_IF * NT_IF, N_IF_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    ys = (yb[:, None] + u[:, :, 0] * dy).reshape(-1, 1)
    ts = (tb[:, None] + u[:, :, 1] * dt).reshape(-1, 1)
    xs = DTYPE(Ls) * jnp.ones_like(ys)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IF_PER_BIN)
    return X, ids

# ============================================================
# JITTER + PROJECTIONS
# ============================================================
def jitter_xyt(key, X, sx, sy, st, clip_k=2.0):
    if X.shape[0] == 0 or ((sx <= 0) and (sy <= 0) and (st <= 0)):
        return X

    key, kx, ky, kt = random.split(key, 4)
    dx = DTYPE(sx) * random.normal(kx, (X.shape[0],), dtype=DTYPE)
    dy = DTYPE(sy) * random.normal(ky, (X.shape[0],), dtype=DTYPE)
    dt = DTYPE(st) * random.normal(kt, (X.shape[0],), dtype=DTYPE)

    k = DTYPE(clip_k)
    dx = jnp.clip(dx, -k * DTYPE(sx), k * DTYPE(sx))
    dy = jnp.clip(dy, -k * DTYPE(sy), k * DTYPE(sy))
    dt = jnp.clip(dt, -k * DTYPE(st), k * DTYPE(st))

    x = jnp.clip(X[:, 0] + dx, x_min, x_max)
    y = jnp.clip(X[:, 1] + dy, y_min, y_max)
    t = jnp.clip(X[:, 2] + dt, t_min, t_max)
    return jnp.stack([x, y, t], axis=1)

def project_x_fixed(X, x_fixed):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        DTYPE(x_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE),
        X[:, 1],
        X[:, 2],
    ], axis=1)

def project_y_fixed(X, y_fixed, *, x_lo=None, x_hi=None):
    if X.shape[0] == 0:
        return X
    x = X[:, 0]
    if (x_lo is not None) or (x_hi is not None):
        lo = DTYPE(x_lo if x_lo is not None else x_min)
        hi = DTYPE(x_hi if x_hi is not None else x_max)
        x = jnp.clip(x, lo, hi)
    y = DTYPE(y_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE)
    return jnp.stack([x, y, X[:, 2]], axis=1)

def project_t0(X):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        X[:, 0],
        X[:, 1],
        t_min * jnp.ones((X.shape[0],), dtype=DTYPE),
    ], axis=1)

def project_interface(X):
    return project_x_fixed(X, Ls)

# ============================================================
# PDE RESIDUALS
# ============================================================
def forward3(params, xyt):
    return mlp_apply(params, xyt[None, :])[0, :]

def eval_fields_and_derivs(params, X):
    out = vmap(lambda z: forward3(params, z))(X)
    J   = vmap(jacrev(lambda z: forward3(params, z)))(X)
    H   = vmap(hessian(lambda z: forward3(params, z)))(X)
    return out, J, H

def residual_phi(params, X, D_phi, Sigma_a):
    out, J, H = eval_fields_and_derivs(params, X)
    phi = out[:, 0]
    phi_t = J[:, 0, 2]
    phi_xx = H[:, 0, 0, 0]
    phi_yy = H[:, 0, 1, 1]
    lap_phi = phi_xx + phi_yy
    return phi_t - DTYPE(D_phi) * lap_phi + DTYPE(Sigma_a) * phi

def residual_Ts(params, X, rho_s_cp_s, k_s, gamma):
    out, J, H = eval_fields_and_derivs(params, X)
    phi = out[:, 0]
    Ts  = out[:, 1]
    Ts_t  = J[:, 1, 2]
    Ts_xx = H[:, 1, 0, 0]
    Ts_yy = H[:, 1, 1, 1]
    lap_Ts = Ts_xx + Ts_yy
    return DTYPE(rho_s_cp_s) * Ts_t - DTYPE(k_s) * lap_Ts - DTYPE(gamma) * phi

def residual_Tf(params, X, rho_f_cp_f, k_f, vy):
    out, J, H = eval_fields_and_derivs(params, X)
    Tf = out[:, 2]
    Tf_t = J[:, 2, 2]
    Tf_y = J[:, 2, 1]
    Tf_xx = H[:, 2, 0, 0]
    Tf_yy = H[:, 2, 1, 1]
    lap_Tf = Tf_xx + Tf_yy
    return DTYPE(rho_f_cp_f) * Tf_t + DTYPE(vy) * Tf_y - DTYPE(k_f) * lap_Tf

# ============================================================
# OBJECTIVE
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_obj(theta, shapes, X_obj_phi, X_obj_Ts, X_obj_Tf,
                w_obj_phi, w_obj_Ts, w_obj_Tf,
                D_phi, Sigma_a, rho_s_cp_s, k_s, gamma, rho_f_cp_f, k_f, vy):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        r_phi = residual_phi(params, X_obj_phi, D_phi, Sigma_a)
        r_Ts  = residual_Ts(params, X_obj_Ts, rho_s_cp_s, k_s, gamma)
        r_Tf  = residual_Tf(params, X_obj_Tf, rho_f_cp_f, k_f, vy)
        return (
            DTYPE(w_obj_phi) * jnp.mean(r_phi ** 2)
            + DTYPE(w_obj_Ts) * jnp.mean(r_Ts ** 2)
            + DTYPE(w_obj_Tf) * jnp.mean(r_Tf ** 2)
        )

    val, g = jax.value_and_grad(obj_theta)(theta)
    return val, g

# ============================================================
# CONSTRAINT VECTOR
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector(theta, shapes,
                      X_con_phi, ids_con_phi,
                      X_con_Ts, ids_con_Ts,
                      X_con_Tf, ids_con_Tf,
                      X_phi_left, ids_phi_left,
                      X_phi_y0, ids_phi_y0,
                      X_phi_y1, ids_phi_y1,
                      X_phi_if, ids_phi_if,
                      X_Ts_x0, ids_Ts_x0,
                      X_Ts_y0, ids_Ts_y0,
                      X_Ts_y1, ids_Ts_y1,
                      X_Tf_y0, ids_Tf_y0,
                      X_Tf_y1, ids_Tf_y1,
                      X_Tf_x1, ids_Tf_x1,
                      X_if, ids_if,
                      X_ic_phi, ids_ic_phi,
                      X_ic_Ts, ids_ic_Ts,
                      X_ic_Tf, ids_ic_Tf,
                      D_phi, Sigma_a, rho_s_cp_s, k_s, gamma, rho_f_cp_f, k_f, vy):
    params = unflatten_params(theta, shapes)

    # PDE anchors
    r_phi = residual_phi(params, X_con_phi, D_phi, Sigma_a)
    r_Ts  = residual_Ts(params, X_con_Ts, rho_s_cp_s, k_s, gamma)
    r_Tf  = residual_Tf(params, X_con_Tf, rho_f_cp_f, k_f, vy)

    c_pde_phi = segment_sum(r_phi, ids_con_phi, K_CON_PHI) / DTYPE(N_PER_CELL)
    c_pde_Ts  = segment_sum(r_Ts,  ids_con_Ts,  K_CON_TS)  / DTYPE(N_PER_CELL)
    c_pde_Tf  = segment_sum(r_Tf,  ids_con_Tf,  K_CON_TF)  / DTYPE(N_PER_CELL)

    # scalar helpers
    def phi_fun(z):
        return forward3(params, z)[0]
    def Ts_fun(z):
        return forward3(params, z)[1]
    def Tf_fun(z):
        return forward3(params, z)[2]

    # Neutron BCs
    phiL = mlp_apply(params, X_phi_left)[:, 0]
    yL, tL = X_phi_left[:, 1], X_phi_left[:, 2]
    c_phi_left = segment_sum(phiL - phi_left_source(yL, tL), ids_phi_left, K_BC_PHI_LEFT) / DTYPE(N_BC_PER_BIN)

    phi_y0 = vmap(lambda z: jacrev(phi_fun)(z)[1])(X_phi_y0)
    c_phi_y0 = segment_sum(phi_y0, ids_phi_y0, K_BC_PHI_Y0) / DTYPE(N_BC_PER_BIN)

    phi_y1 = vmap(lambda z: jacrev(phi_fun)(z)[1])(X_phi_y1)
    c_phi_y1 = segment_sum(phi_y1, ids_phi_y1, K_BC_PHI_Y1) / DTYPE(N_BC_PER_BIN)

    phi_x_if = vmap(lambda z: jacrev(phi_fun)(z)[0])(X_phi_if)
    c_phi_if = segment_sum(phi_x_if, ids_phi_if, K_BC_PHI_IF) / DTYPE(N_BC_PER_BIN)

    c_bc_phi = jnp.concatenate([c_phi_left, c_phi_y0, c_phi_y1, c_phi_if], axis=0)

    # Fuel thermal BCs
    Ts_x0 = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_Ts_x0)
    c_Ts_x0 = segment_sum(Ts_x0, ids_Ts_x0, K_BC_TS_X0) / DTYPE(N_BC_PER_BIN)

    Ts_y0 = vmap(lambda z: jacrev(Ts_fun)(z)[1])(X_Ts_y0)
    c_Ts_y0 = segment_sum(Ts_y0, ids_Ts_y0, K_BC_TS_Y0) / DTYPE(N_BC_PER_BIN)

    Ts_y1 = vmap(lambda z: jacrev(Ts_fun)(z)[1])(X_Ts_y1)
    c_Ts_y1 = segment_sum(Ts_y1, ids_Ts_y1, K_BC_TS_Y1) / DTYPE(N_BC_PER_BIN)

    c_bc_Ts = jnp.concatenate([c_Ts_x0, c_Ts_y0, c_Ts_y1], axis=0)

    # Coolant thermal BCs
    Tf_bottom = mlp_apply(params, X_Tf_y0)[:, 2]
    c_Tf_y0 = segment_sum(Tf_bottom, ids_Tf_y0, K_BC_TF_Y0) / DTYPE(N_BC_PER_BIN)

    Tf_y1 = vmap(lambda z: jacrev(Tf_fun)(z)[1])(X_Tf_y1)
    c_Tf_y1 = segment_sum(Tf_y1, ids_Tf_y1, K_BC_TF_Y1) / DTYPE(N_BC_PER_BIN)

    Tf_x1 = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_Tf_x1)
    c_Tf_x1 = segment_sum(Tf_x1, ids_Tf_x1, K_BC_TF_X1) / DTYPE(N_BC_PER_BIN)

    c_bc_Tf = jnp.concatenate([c_Tf_y0, c_Tf_y1, c_Tf_x1], axis=0)

    # Interface constraints
    out_if = mlp_apply(params, X_if)
    Ts_if = out_if[:, 1]
    Tf_if = out_if[:, 2]

    c_if_T = segment_sum(Ts_if - Tf_if, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    Tsx_if = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_if)
    Tfx_if = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_if)

    flux_jump = -DTYPE(k_s) * Tsx_if + DTYPE(k_f) * Tfx_if
    c_if_q = segment_sum(flux_jump, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    c_if = jnp.concatenate([c_if_T, c_if_q], axis=0)

    # ICs: separate sets, no masks
    out_phi0 = mlp_apply(params, X_ic_phi)
    out_Ts0  = mlp_apply(params, X_ic_Ts)
    out_Tf0  = mlp_apply(params, X_ic_Tf)

    phi0 = out_phi0[:, 0]
    Ts0  = out_Ts0[:, 1]
    Tf0  = out_Tf0[:, 2]

    y_phi0 = X_ic_phi[:, 1]
    c_ic_phi = segment_sum(phi0 - phi_ic_target(y_phi0), ids_ic_phi, K_IC_PHI) / DTYPE(N_IC_PER_BIN)
    c_ic_Ts  = segment_sum(Ts0 - Ts_ic_target(X_ic_Ts[:, 0], X_ic_Ts[:, 1]), ids_ic_Ts, K_IC_TS) / DTYPE(N_IC_PER_BIN)
    c_ic_Tf  = segment_sum(Tf0 - Tf_ic_target(X_ic_Tf[:, 0], X_ic_Tf[:, 1]), ids_ic_Tf, K_IC_TF) / DTYPE(N_IC_PER_BIN)

    c_ic = jnp.concatenate([c_ic_phi, c_ic_Ts, c_ic_Tf], axis=0)

    return jnp.concatenate([
        c_pde_phi,
        c_pde_Ts,
        c_pde_Tf,
        c_bc_phi,
        c_bc_Ts,
        c_bc_Tf,
        c_if,
        c_ic
    ], axis=0)

@partial(jax.jit, static_argnames=("shapes",))
def C_and_J(theta, shapes, *args):
    def c_fun(th):
        return constraint_vector(th, shapes, *args)

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J, c = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c, J

@partial(jax.jit, static_argnames=("shapes",))
def C_only(theta, shapes, *args):
    return constraint_vector(theta, shapes, *args)

# ============================================================
# KKT solve
# ============================================================
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, mu_damp):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)
    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -mu_damp * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)
    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y

# ============================================================
# STEP HELPERS
# ============================================================
def cal_tau_mu(H, d, sigma, tau_pre, eps_tau, g, c, mu_eff, y):
    denom = float(g @ d + 0.5 * (d @ (H @ d)))
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    if (denom <= 1e-12) or (delta_c <= 0.0):
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * delta_c / denom
    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)

def cal_ksi_mu(d, tau, ksi_old, eps_ksi, g, c, mu_eff, y):
    d2 = float(jnp.linalg.norm(d) ** 2)
    if d2 <= 1e-18 or tau <= 1e-18:
        return ksi_old
    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    ksi_trial = Dl / (tau * d2)
    ksi_trial = max(0.0, ksi_trial)
    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)

def phi_mu(alpha, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma):
    gd = float(g @ d)
    d2 = float(d @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    term1 = (eta - 1.0) * alpha * beta * Dl
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * c1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3

def cal_alpha_mu(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c, mu_eff, y):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0
    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)
    while (
        phi_mu(1.1 * a, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma) < 0.0
        and (1.1 * a < alpha_min + theta_val * beta)
    ):
        a *= 1.1
    return float(a)

# ============================================================
# BLOCK SLICES / PRINTS
# ============================================================
def _block_slices():
    s = {}
    i = 0
    s["pde_phi"] = slice(i, i + K_CON_PHI); i += K_CON_PHI
    s["pde_Ts"]  = slice(i, i + K_CON_TS);  i += K_CON_TS
    s["pde_Tf"]  = slice(i, i + K_CON_TF);  i += K_CON_TF
    s["bc_phi"]  = slice(i, i + N_BC_PHI);  i += N_BC_PHI
    s["bc_Ts"]   = slice(i, i + N_BC_TS);   i += N_BC_TS
    s["bc_Tf"]   = slice(i, i + N_BC_TF);   i += N_BC_TF
    s["iface"]   = slice(i, i + N_IF);      i += N_IF
    s["ic"]      = slice(i, i + N_IC);      i += N_IC
    assert i == M_CON, (i, M_CON)
    return s

BLOCKS = _block_slices()

def _rms(x):
    return float(jnp.sqrt(jnp.mean(x * x) + DTYPE(1e-30)))

def _maxabs(x):
    return float(jnp.max(jnp.abs(x)))

def print_block_stats(prefix, c):
    def pr(name):
        sl = BLOCKS[name]
        v = c[sl]
        print(f"  {name:10s}: rms={_rms(v):.3e}  max={_maxabs(v):.3e}")
    print(prefix)
    pr("pde_phi")
    pr("pde_Ts")
    pr("pde_Tf")
    pr("bc_phi")
    pr("bc_Ts")
    pr("bc_Tf")
    pr("iface")
    pr("ic")

# ============================================================
# TRAIN SQP (FIXED BASE BATCHES, JITTER ONLY)
# ============================================================
def train_sqp(
    seed=0,
    hidden_dim=35,
    num_hidden=3,
    max_iters=700,
    print_every=10,
    beta_shift=200.0,
    beta_power=0.6,
    alpha_cap=1e1,
    L_lip=40.0,
    Gamma_lip=40.0,
    mu_damp=1e-4,
    jitter_every_iter=True,
    sx=1e-5,
    sy=1e-5,
    st=1e-5,
    sx_bc=1e-5,
    sy_bc=1e-5,
    st_bc=1e-5,
    sx_ic=1e-5,
    sy_ic=1e-5,
    sy_if=1e-5,
    st_if=1e-5,
    w_obj_phi=10.0,
    w_obj_Ts=10.0,
    w_obj_Tf=10.0,
    d_phi=0.05,
    sigma_a=1.0,
    rho_s_cp_s=1.0,
    rho_f_cp_f=1.0,
    k_s=0.50,
    k_f=0.15,
    gamma=10.0,
    vy=1.0,
):
    key = random.PRNGKey(seed)

    layer_sizes = [3] + [hidden_dim] * num_hidden + [3]
    key, k0 = random.split(key)
    params0 = init_mlp_params(k0, layer_sizes)
    theta, shapes = flatten_params(params0)

    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    # ========================================================
    # FIXED base sets: sample ONCE only
    # ========================================================
    key, k_obj_phi, k_obj_Ts, k_obj_Tf = random.split(key, 4)
    X_obj_phi, _ = sample_stratified_3d(k_obj_phi, x_min, Ls, y_min, y_max, t_min, t_max, NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI)
    X_obj_Ts, _  = sample_stratified_3d(k_obj_Ts,  x_min, Ls, y_min, y_max, t_min, t_max, NX_OBJ_TS,  NY_OBJ_TS,  NT_OBJ_TS)
    X_obj_Tf, _  = sample_stratified_3d(k_obj_Tf,  Ls,    x_max, y_min, y_max, t_min, t_max, NX_OBJ_TF, NY_OBJ_TF, NT_OBJ_TF)

    key, k_con_phi, k_con_Ts, k_con_Tf = random.split(key, 4)
    X_con_phi, ids_con_phi = sample_stratified_3d(k_con_phi, x_min, Ls, y_min, y_max, t_min, t_max, NX_CON_PHI, NY_CON_PHI, NT_CON_PHI)
    X_con_Ts,  ids_con_Ts  = sample_stratified_3d(k_con_Ts,  x_min, Ls, y_min, y_max, t_min, t_max, NX_CON_TS,  NY_CON_TS,  NT_CON_TS)
    X_con_Tf,  ids_con_Tf  = sample_stratified_3d(k_con_Tf,  Ls,    x_max, y_min, y_max, t_min, t_max, NX_CON_TF, NY_CON_TF, NT_CON_TF)

    key, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13 = random.split(key, 14)

    X_phi_left, ids_phi_left = sample_bc_time_binned(k1, K_BC_PHI_LEFT, x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_phi_y0,   ids_phi_y0   = sample_bc_time_binned(k2, K_BC_PHI_Y0, y_fixed=y_min, x_lo=x_min, x_hi=Ls)
    X_phi_y1,   ids_phi_y1   = sample_bc_time_binned(k3, K_BC_PHI_Y1, y_fixed=y_max, x_lo=x_min, x_hi=Ls)
    X_phi_if,   ids_phi_if   = sample_bc_time_binned(k4, K_BC_PHI_IF, x_fixed=Ls, y_lo=y_min, y_hi=y_max)

    X_Ts_x0, ids_Ts_x0 = sample_bc_time_binned(k5, K_BC_TS_X0, x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_Ts_y0, ids_Ts_y0 = sample_bc_time_binned(k6, K_BC_TS_Y0, y_fixed=y_min, x_lo=x_min, x_hi=Ls)
    X_Ts_y1, ids_Ts_y1 = sample_bc_time_binned(k7, K_BC_TS_Y1, y_fixed=y_max, x_lo=x_min, x_hi=Ls)

    xL = float(DTYPE(Ls) + DTYPE(1e-8))
    xR = float(x_max - DTYPE(1e-8))
    X_Tf_y0, ids_Tf_y0 = sample_bc_time_binned(k8,  K_BC_TF_Y0, y_fixed=y_min, x_lo=xL, x_hi=xR)
    X_Tf_y1, ids_Tf_y1 = sample_bc_time_binned(k9,  K_BC_TF_Y1, y_fixed=y_max, x_lo=xL, x_hi=xR)
    X_Tf_x1, ids_Tf_x1 = sample_bc_time_binned(k10, K_BC_TF_X1, x_fixed=x_max, y_lo=y_min, y_hi=y_max)

    X_if, ids_if = sample_interface_yt(k11)

    X_ic_phi, ids_ic_phi = sample_ic_xy(k12, x_min, Ls, y_min, y_max, NX_IC, NY_IC)
    X_ic_Ts,  ids_ic_Ts  = sample_ic_xy(k13, x_min, Ls, y_min, y_max, NX_IC, NY_IC)
    key, k_ic_tf = random.split(key)
    X_ic_Tf,  ids_ic_Tf  = sample_ic_xy(k_ic_tf, Ls, x_max, y_min, y_max, NX_IC, NY_IC)

    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 1.0, 1.0

    print("M_CON =", int(M_CON), "n_params =", int(n))
    print("Fixed-base mode: no resampling, fresh jitter only.")

    t0_clock = time.time()

    for it in range(1, max_iters + 1):
        k_beta = (it // 10) * 10
        beta_k = float(min(1.0, (beta_shift / (beta_shift + k_beta)) ** beta_power))

        if jitter_every_iter:
            key, *ks = random.split(key, 17)
            (
                kj_obj_phi, kj_obj_Ts, kj_obj_Tf,
                kj_con_phi, kj_con_Ts, kj_con_Tf,
                kj_phi_left, kj_phi_y0, kj_phi_y1, kj_phi_if,
                kj_Ts_x0, kj_Ts_y0, kj_Ts_y1,
                kj_Tf_y0, kj_Tf_y1, kj_Tf_x1
            ) = ks[:16]
            key, kj_if = random.split(key)
            key, kj_ic_phi = random.split(key)
            key, kj_ic_Ts = random.split(key)
            key, kj_ic_Tf = random.split(key)

            # Objective sets
            X_obj_phi_use = jitter_xyt(kj_obj_phi, X_obj_phi, sx, sy, st)
            X_obj_Ts_use  = jitter_xyt(kj_obj_Ts,  X_obj_Ts,  sx, sy, st)
            X_obj_Tf_use  = jitter_xyt(kj_obj_Tf,  X_obj_Tf,  sx, sy, st)

            # PDE anchors
            X_con_phi_use = jitter_xyt(kj_con_phi, X_con_phi, sx, sy, st)
            X_con_Ts_use  = jitter_xyt(kj_con_Ts,  X_con_Ts,  sx, sy, st)
            X_con_Tf_use  = jitter_xyt(kj_con_Tf,  X_con_Tf,  sx, sy, st)

            # Neutron BCs
            X_phi_left_use = project_x_fixed(jitter_xyt(kj_phi_left, X_phi_left, 0.0, sy_bc, st_bc), x_min)
            X_phi_y0_use   = project_y_fixed(jitter_xyt(kj_phi_y0, X_phi_y0, sx_bc, 0.0, st_bc), y_min, x_lo=x_min, x_hi=Ls)
            X_phi_y1_use   = project_y_fixed(jitter_xyt(kj_phi_y1, X_phi_y1, sx_bc, 0.0, st_bc), y_max, x_lo=x_min, x_hi=Ls)
            X_phi_if_use   = project_x_fixed(jitter_xyt(kj_phi_if, X_phi_if, 0.0, sy_bc, st_bc), Ls)

            # Fuel thermal BCs
            X_Ts_x0_use = project_x_fixed(jitter_xyt(kj_Ts_x0, X_Ts_x0, 0.0, sy_bc, st_bc), x_min)
            X_Ts_y0_use = project_y_fixed(jitter_xyt(kj_Ts_y0, X_Ts_y0, sx_bc, 0.0, st_bc), y_min, x_lo=x_min, x_hi=Ls)
            X_Ts_y1_use = project_y_fixed(jitter_xyt(kj_Ts_y1, X_Ts_y1, sx_bc, 0.0, st_bc), y_max, x_lo=x_min, x_hi=Ls)

            # Coolant thermal BCs
            X_Tf_y0_use = project_y_fixed(jitter_xyt(kj_Tf_y0, X_Tf_y0, sx_bc, 0.0, st_bc), y_min, x_lo=xL, x_hi=xR)
            X_Tf_y1_use = project_y_fixed(jitter_xyt(kj_Tf_y1, X_Tf_y1, sx_bc, 0.0, st_bc), y_max, x_lo=xL, x_hi=xR)
            X_Tf_x1_use = project_x_fixed(jitter_xyt(kj_Tf_x1, X_Tf_x1, 0.0, sy_bc, st_bc), x_max)

            # Interface + IC
            X_if_use = project_interface(jitter_xyt(kj_if, X_if, 0.0, sy_if, st_if))
            X_ic_phi_use = project_t0(jitter_xyt(kj_ic_phi, X_ic_phi, sx_ic, sy_ic, 0.0))
            X_ic_Ts_use  = project_t0(jitter_xyt(kj_ic_Ts,  X_ic_Ts,  sx_ic, sy_ic, 0.0))
            X_ic_Tf_use  = project_t0(jitter_xyt(kj_ic_Tf,  X_ic_Tf,  sx_ic, sy_ic, 0.0))
        else:
            X_obj_phi_use, X_obj_Ts_use, X_obj_Tf_use = X_obj_phi, X_obj_Ts, X_obj_Tf
            X_con_phi_use, X_con_Ts_use, X_con_Tf_use = X_con_phi, X_con_Ts, X_con_Tf
            X_phi_left_use, X_phi_y0_use, X_phi_y1_use, X_phi_if_use = X_phi_left, X_phi_y0, X_phi_y1, X_phi_if
            X_Ts_x0_use, X_Ts_y0_use, X_Ts_y1_use = X_Ts_x0, X_Ts_y0, X_Ts_y1
            X_Tf_y0_use, X_Tf_y1_use, X_Tf_x1_use = X_Tf_y0, X_Tf_y1, X_Tf_x1
            X_if_use = X_if
            X_ic_phi_use, X_ic_Ts_use, X_ic_Tf_use = X_ic_phi, X_ic_Ts, X_ic_Tf

        obj_val, g = F_and_g_obj(
            theta, shapes,
            X_obj_phi_use, X_obj_Ts_use, X_obj_Tf_use,
            DTYPE(w_obj_phi), DTYPE(w_obj_Ts), DTYPE(w_obj_Tf),
            DTYPE(d_phi), DTYPE(sigma_a),
            DTYPE(rho_s_cp_s), DTYPE(k_s), DTYPE(gamma),
            DTYPE(rho_f_cp_f), DTYPE(k_f), DTYPE(vy)
        )

        args = (
            X_con_phi_use, ids_con_phi,
            X_con_Ts_use, ids_con_Ts,
            X_con_Tf_use, ids_con_Tf,
            X_phi_left_use, ids_phi_left,
            X_phi_y0_use, ids_phi_y0,
            X_phi_y1_use, ids_phi_y1,
            X_phi_if_use, ids_phi_if,
            X_Ts_x0_use, ids_Ts_x0,
            X_Ts_y0_use, ids_Ts_y0,
            X_Ts_y1_use, ids_Ts_y1,
            X_Tf_y0_use, ids_Tf_y0,
            X_Tf_y1_use, ids_Tf_y1,
            X_Tf_x1_use, ids_Tf_x1,
            X_if_use, ids_if,
            X_ic_phi_use, ids_ic_phi,
            X_ic_Ts_use, ids_ic_Ts,
            X_ic_Tf_use, ids_ic_Tf,
            DTYPE(d_phi), DTYPE(sigma_a),
            DTYPE(rho_s_cp_s), DTYPE(k_s), DTYPE(gamma),
            DTYPE(rho_f_cp_f), DTYPE(k_f), DTYPE(vy)
        )

        c, J = C_and_J(theta, shapes, *args)

        # no rescaling; fixed batch + jitter only
        c_s, J_s = c, J

        d, y = kkt_solve_once(H, J_s, g, c_s, DTYPE(mu_damp))

        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-12:
            tau_k = cal_tau_mu(H, d, sigma, tau_k, eps_tau, g, c_s, DTYPE(mu_damp), y)
            ksi_k = cal_ksi_mu(d, tau_k, ksi_k, eps_ksi, g, c_s, DTYPE(mu_damp), y)
            alpha = cal_alpha_mu(d, eta, beta_k, ksi_k, tau_k, L_lip, Gamma_lip, theta_val, g, c_s, DTYPE(mu_damp), y)
        else:
            alpha = 0.0

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d

        if it % int(print_every) == 0:
            c_now = C_only(theta, shapes, *args)
            feas_raw = float(jnp.mean(c_now ** 2))
            station  = float(jnp.linalg.norm(g + J.T @ y, jnp.inf))

            print(f"[it={it}] obj={float(obj_val):.3e} feas_raw={feas_raw:.3e} alpha={alpha:.2e} beta={beta_k:.2e} station={station:.2e} dn={dn:.2e}")
            print_block_stats("blocks (raw c):", c_now)

            params_now = unflatten_params(theta, shapes)
            r_phi_obj = residual_phi(params_now, X_obj_phi_use, DTYPE(d_phi), DTYPE(sigma_a))
            r_Ts_obj  = residual_Ts(params_now, X_obj_Ts_use, DTYPE(rho_s_cp_s), DTYPE(k_s), DTYPE(gamma))
            r_Tf_obj  = residual_Tf(params_now, X_obj_Tf_use, DTYPE(rho_f_cp_f), DTYPE(k_f), DTYPE(vy))
            print(
                "Raw PDE RMS on obj:",
                "phi", _rms(r_phi_obj),
                "Ts", _rms(r_Ts_obj),
                "Tf", _rms(r_Tf_obj),
            )

    print(f"[done] elapsed={time.time() - t0_clock:.2f}s")
    return theta, shapes

# ============================================================
# MAIN
# ============================================================
def main():
    theta, shapes = train_sqp(
        seed=0,
        hidden_dim=30,
        num_hidden=3,
        max_iters=10000,
        print_every=10,
        beta_shift=400.0,
        beta_power=0.6,
        alpha_cap=1e1,
        L_lip=40.0,
        Gamma_lip=40.0,
        mu_damp=1e-4,
        jitter_every_iter=True,
        sx=1e-4,
        sy=1e-4,
        st=1e-4,
        sx_bc=1e-4,
        sy_bc=1e-4,
        st_bc=1e-4,
        sx_ic=1e-4,
        sy_ic=1e-4,
        sy_if=1e-4,
        st_if=1e-4,
        w_obj_phi=10.0,
        w_obj_Ts=10.0,
        w_obj_Tf=10.0,
        d_phi=0.05,
        sigma_a=1.0,
        rho_s_cp_s=1.0,
        rho_f_cp_f=1.0,
        k_s=0.50,
        k_f=0.15,
        gamma=10.0,
        vy=1.0,
    )

    np.save("theta_sqp_coupled_fixedbatch_jitter3.npy", np.array(theta))
    print("Saved theta -> theta_sqp_coupled_fixedbatch_jitter3.npy")

# %%
if __name__ == "__main__":
    main()
# Out:
# M_CON = 2002 n_params = 2073
# Fixed-base mode: no resampling, fresh jitter only.
# [it=10] obj=5.912e+02 feas_raw=7.803e+00 alpha=1.19e-01 beta=9.85e-01 station=2.90e+00 dn=2.90e+00
# blocks (raw c):
#   pde_phi   : rms=1.220e+00  max=2.914e+00
#   pde_Ts    : rms=6.504e+00  max=1.675e+01
#   pde_Tf    : rms=1.104e+00  max=4.060e+00
#   bc_phi    : rms=7.490e-01  max=2.137e+00
#   bc_Ts     : rms=6.272e-01  max=1.532e+00
#   bc_Tf     : rms=3.523e-01  max=1.122e+00
#   iface     : rms=6.961e-01  max=1.595e+00
#   ic        : rms=3.894e-01  max=8.664e-01
# Raw PDE RMS on obj: phi 1.2208495295573305 Ts 6.5130993184054935 Tf 1.090172571300848
# [it=20] obj=3.284e+01 feas_raw=1.198e-01 alpha=1.27e+00 beta=9.71e-01 station=1.99e-01 dn=1.99e-01
# blocks (raw c):
#   pde_phi   : rms=1.314e-01  max=4.329e-01
#   pde_Ts    : rms=6.795e-01  max=2.131e+00
#   pde_Tf    : rms=4.515e-01  max=1.337e+00
#   bc_phi    : rms=1.045e-01  max=4.068e-01
#   bc_Ts     : rms=8.582e-02  max=2.878e-01
#   bc_Tf     : rms=1.069e-01  max=3.671e-01
#   iface     : rms=6.870e-02  max=1.461e-01
#   ic        : rms=5.012e-02  max=1.966e-01
# Raw PDE RMS on obj: phi 0.15568326368891106 Ts 0.6938191364664414 Tf 0.7302187543146119
# [it=30] obj=1.022e+00 feas_raw=2.314e-05 alpha=4.37e-01 beta=9.58e-01 station=5.17e-02 dn=5.17e-02
# blocks (raw c):
#   pde_phi   : rms=1.799e-03  max=4.009e-03
#   pde_Ts    : rms=8.606e-03  max=3.016e-02
#   pde_Tf    : rms=6.672e-03  max=3.009e-02
#   bc_phi    : rms=2.431e-03  max=6.676e-03
#   bc_Ts     : rms=2.128e-03  max=5.208e-03
#   bc_Tf     : rms=3.130e-03  max=9.543e-03
#   iface     : rms=1.544e-03  max=8.484e-03
#   ic        : rms=1.265e-03  max=5.161e-03
# Raw PDE RMS on obj: phi 0.10940906442417098 Ts 0.09970925333392863 Tf 0.27944820742656973
# [it=40] obj=9.011e-01 feas_raw=3.054e-06 alpha=1.83e-01 beta=9.44e-01 station=4.21e-02 dn=4.21e-02
# blocks (raw c):
#   pde_phi   : rms=6.981e-04  max=2.696e-03
#   pde_Ts    : rms=3.165e-03  max=1.438e-02
#   pde_Tf    : rms=2.113e-03  max=8.325e-03
#   bc_phi    : rms=9.725e-04  max=2.858e-03
#   bc_Ts     : rms=8.902e-04  max=3.102e-03
#   bc_Tf     : rms=1.097e-03  max=4.682e-03
#   iface     : rms=1.114e-03  max=6.883e-03
#   ic        : rms=8.327e-04  max=4.329e-03
# Raw PDE RMS on obj: phi 0.11214778650534457 Ts 0.10188411298704969 Tf 0.2579274621952144
# [it=50] obj=8.581e-01 feas_raw=1.252e-06 alpha=1.12e-01 beta=9.32e-01 station=3.69e-02 dn=3.69e-02
# blocks (raw c):
#   pde_phi   : rms=5.392e-04  max=3.931e-03
#   pde_Ts    : rms=1.834e-03  max=7.681e-03
#   pde_Tf    : rms=1.385e-03  max=1.593e-02
#   bc_phi    : rms=6.541e-04  max=2.071e-03
#   bc_Ts     : rms=6.848e-04  max=2.963e-03
#   bc_Tf     : rms=6.704e-04  max=3.997e-03
#   iface     : rms=1.019e-03  max=6.392e-03
#   ic        : rms=7.224e-04  max=4.226e-03
# Raw PDE RMS on obj: phi 0.11350102013677262 Ts 0.10190878223015223 Tf 0.2496247130354946
# [it=60] obj=8.393e-01 feas_raw=6.730e-07 alpha=8.31e-02 beta=9.20e-01 station=3.58e-02 dn=3.58e-02
# blocks (raw c):
#   pde_phi   : rms=4.261e-04  max=2.940e-03
#   pde_Ts    : rms=1.221e-03  max=5.815e-03
#   pde_Tf    : rms=9.102e-04  max=8.848e-03
#   bc_phi    : rms=5.272e-04  max=2.138e-03
#   bc_Ts     : rms=6.229e-04  max=2.718e-03
#   bc_Tf     : rms=5.115e-04  max=3.528e-03
#   iface     : rms=9.801e-04  max=6.066e-03
#   ic        : rms=6.757e-04  max=3.993e-03
# Raw PDE RMS on obj: phi 0.11437716887536094 Ts 0.10177848167635417 Tf 0.2456409922443503
# [it=70] obj=8.260e-01 feas_raw=4.876e-07 alpha=6.78e-02 beta=9.08e-01 station=3.49e-02 dn=3.49e-02
# blocks (raw c):
#   pde_phi   : rms=3.687e-04  max=3.176e-03
#   pde_Ts    : rms=8.385e-04  max=3.431e-03
#   pde_Tf    : rms=8.361e-04  max=7.993e-03
#   bc_phi    : rms=4.664e-04  max=2.155e-03
#   bc_Ts     : rms=5.923e-04  max=2.624e-03
#   bc_Tf     : rms=4.844e-04  max=3.488e-03
#   iface     : rms=9.479e-04  max=5.871e-03
#   ic        : rms=6.547e-04  max=3.970e-03
# Raw PDE RMS on obj: phi 0.11499124917612324 Ts 0.10166692239340924 Tf 0.24281082907965076
# [it=80] obj=8.155e-01 feas_raw=3.887e-07 alpha=5.53e-02 beta=8.96e-01 station=3.25e-02 dn=3.25e-02
# blocks (raw c):
#   pde_phi   : rms=2.551e-04  max=1.900e-03
#   pde_Ts    : rms=6.555e-04  max=2.411e-03
#   pde_Tf    : rms=7.241e-04  max=7.045e-03
#   bc_phi    : rms=4.310e-04  max=2.152e-03
#   bc_Ts     : rms=5.722e-04  max=2.528e-03
#   bc_Tf     : rms=4.589e-04  max=3.255e-03
#   iface     : rms=9.266e-04  max=5.710e-03
#   ic        : rms=6.422e-04  max=3.871e-03
# Raw PDE RMS on obj: phi 0.11540659900709008 Ts 0.10138276462080918 Tf 0.24058949645441216
# [it=90] obj=8.070e-01 feas_raw=5.108e-07 alpha=5.46e-02 beta=8.85e-01 station=3.53e-02 dn=3.53e-02
# blocks (raw c):
#   pde_phi   : rms=2.849e-04  max=1.506e-03
#   pde_Ts    : rms=5.445e-04  max=3.133e-03
#   pde_Tf    : rms=1.194e-03  max=1.573e-02
#   bc_phi    : rms=4.035e-04  max=2.114e-03
#   bc_Ts     : rms=5.557e-04  max=2.366e-03
#   bc_Tf     : rms=4.511e-04  max=3.150e-03
#   iface     : rms=9.073e-04  max=5.574e-03
#   ic        : rms=6.278e-04  max=3.748e-03
# Raw PDE RMS on obj: phi 0.11573301551842057 Ts 0.10126202488336833 Tf 0.23868824415834122
# [it=100] obj=7.999e-01 feas_raw=3.376e-07 alpha=4.91e-02 beta=8.75e-01 station=3.18e-02 dn=3.18e-02
# blocks (raw c):
#   pde_phi   : rms=3.193e-04  max=3.068e-03
#   pde_Ts    : rms=4.790e-04  max=2.855e-03
#   pde_Tf    : rms=7.135e-04  max=8.292e-03
#   bc_phi    : rms=3.916e-04  max=2.088e-03
#   bc_Ts     : rms=5.406e-04  max=2.245e-03
#   bc_Tf     : rms=4.241e-04  max=3.084e-03
#   iface     : rms=8.993e-04  max=5.614e-03
#   ic        : rms=6.244e-04  max=3.755e-03
# Raw PDE RMS on obj: phi 0.11601914648977554 Ts 0.1008171687004089 Tf 0.2372509819504028
# [it=110] obj=7.943e-01 feas_raw=3.497e-07 alpha=4.85e-02 beta=8.64e-01 station=2.99e-02 dn=2.99e-02
# blocks (raw c):
#   pde_phi   : rms=3.047e-04  max=2.693e-03
#   pde_Ts    : rms=4.462e-04  max=4.095e-03
#   pde_Tf    : rms=8.066e-04  max=8.942e-03
#   bc_phi    : rms=3.882e-04  max=2.056e-03
#   bc_Ts     : rms=5.403e-04  max=2.312e-03
#   bc_Tf     : rms=4.128e-04  max=2.817e-03
#   iface     : rms=8.838e-04  max=5.404e-03
#   ic        : rms=6.135e-04  max=3.670e-03
# Raw PDE RMS on obj: phi 0.11626503400004864 Ts 0.1006364183571531 Tf 0.2360409517614349
# [it=120] obj=7.871e-01 feas_raw=5.047e-07 alpha=5.27e-02 beta=8.54e-01 station=3.17e-02 dn=3.17e-02
# blocks (raw c):
#   pde_phi   : rms=3.258e-04  max=2.314e-03
#   pde_Ts    : rms=5.473e-04  max=5.336e-03
#   pde_Tf    : rms=1.216e-03  max=1.860e-02
#   bc_phi    : rms=3.678e-04  max=2.017e-03
#   bc_Ts     : rms=5.209e-04  max=2.112e-03
#   bc_Tf     : rms=4.238e-04  max=2.856e-03
#   iface     : rms=8.724e-04  max=5.339e-03
#   ic        : rms=6.094e-04  max=3.682e-03
# Raw PDE RMS on obj: phi 0.11646807972796683 Ts 0.10046328074128531 Tf 0.23448214672024534
# [it=130] obj=7.810e-01 feas_raw=2.931e-07 alpha=4.74e-02 beta=8.45e-01 station=2.82e-02 dn=2.82e-02
# blocks (raw c):
#   pde_phi   : rms=2.489e-04  max=1.504e-03
#   pde_Ts    : rms=3.734e-04  max=2.120e-03
#   pde_Tf    : rms=6.836e-04  max=5.285e-03
#   bc_phi    : rms=3.618e-04  max=1.972e-03
#   bc_Ts     : rms=5.111e-04  max=2.067e-03
#   bc_Tf     : rms=3.975e-04  max=2.809e-03
#   iface     : rms=8.654e-04  max=5.408e-03
#   ic        : rms=6.017e-04  max=3.632e-03
# Raw PDE RMS on obj: phi 0.11660604220948151 Ts 0.10005489840062019 Tf 0.23327774228252618
# [it=140] obj=7.730e-01 feas_raw=3.962e-07 alpha=5.15e-02 beta=8.35e-01 station=2.93e-02 dn=2.93e-02
# blocks (raw c):
#   pde_phi   : rms=3.112e-04  max=2.144e-03
#   pde_Ts    : rms=3.982e-04  max=2.722e-03
#   pde_Tf    : rms=1.027e-03  max=1.429e-02
#   bc_phi    : rms=3.525e-04  max=1.944e-03
#   bc_Ts     : rms=5.023e-04  max=1.952e-03
#   bc_Tf     : rms=4.002e-04  max=2.714e-03
#   iface     : rms=8.520e-04  max=5.279e-03
#   ic        : rms=5.959e-04  max=3.598e-03
# Raw PDE RMS on obj: phi 0.11679193013978569 Ts 0.09982877781500013 Tf 0.23156654455963957
# [it=150] obj=7.659e-01 feas_raw=3.818e-07 alpha=5.10e-02 beta=8.26e-01 station=2.76e-02 dn=2.76e-02
# blocks (raw c):
#   pde_phi   : rms=2.722e-04  max=1.860e-03
#   pde_Ts    : rms=5.119e-04  max=5.552e-03
#   pde_Tf    : rms=9.491e-04  max=1.299e-02
#   bc_phi    : rms=3.538e-04  max=1.920e-03
#   bc_Ts     : rms=4.891e-04  max=1.917e-03
#   bc_Tf     : rms=4.130e-04  max=2.584e-03
#   iface     : rms=8.418e-04  max=5.214e-03
#   ic        : rms=5.891e-04  max=3.472e-03
# Raw PDE RMS on obj: phi 0.11687680373351814 Ts 0.09962428280283178 Tf 0.23008295592019745
# [it=160] obj=7.591e-01 feas_raw=2.626e-07 alpha=5.04e-02 beta=8.17e-01 station=2.70e-02 dn=2.70e-02
# blocks (raw c):
#   pde_phi   : rms=2.529e-04  max=1.740e-03
#   pde_Ts    : rms=4.243e-04  max=2.859e-03
#   pde_Tf    : rms=5.831e-04  max=6.116e-03
#   bc_phi    : rms=3.398e-04  max=1.891e-03
#   bc_Ts     : rms=4.826e-04  max=1.879e-03
#   bc_Tf     : rms=3.809e-04  max=2.526e-03
#   iface     : rms=8.231e-04  max=5.146e-03
#   ic        : rms=5.836e-04  max=3.491e-03
# Raw PDE RMS on obj: phi 0.11691891043120278 Ts 0.09931025864226789 Tf 0.22868327479565065
# [it=170] obj=7.506e-01 feas_raw=3.652e-07 alpha=5.49e-02 beta=8.09e-01 station=2.69e-02 dn=2.69e-02
# blocks (raw c):
#   pde_phi   : rms=2.333e-04  max=1.215e-03
#   pde_Ts    : rms=5.545e-04  max=6.062e-03
#   pde_Tf    : rms=9.099e-04  max=1.200e-02
#   bc_phi    : rms=3.355e-04  max=1.835e-03
#   bc_Ts     : rms=4.732e-04  max=1.882e-03
#   bc_Tf     : rms=3.803e-04  max=2.523e-03
#   iface     : rms=8.238e-04  max=5.156e-03
#   ic        : rms=5.797e-04  max=3.567e-03
# Raw PDE RMS on obj: phi 0.11702913111720985 Ts 0.09878948823639325 Tf 0.22704215499486505
# [it=180] obj=7.432e-01 feas_raw=3.803e-07 alpha=5.98e-02 beta=8.00e-01 station=2.64e-02 dn=2.64e-02
# blocks (raw c):
#   pde_phi   : rms=2.729e-04  max=1.797e-03
#   pde_Ts    : rms=5.520e-04  max=6.457e-03
#   pde_Tf    : rms=9.650e-04  max=9.136e-03
#   bc_phi    : rms=3.296e-04  max=1.790e-03
#   bc_Ts     : rms=4.648e-04  max=1.761e-03
#   bc_Tf     : rms=3.733e-04  max=2.526e-03
#   iface     : rms=8.166e-04  max=5.128e-03
#   ic        : rms=5.711e-04  max=3.433e-03
# Raw PDE RMS on obj: phi 0.11713595914589164 Ts 0.0986482615053365 Tf 0.2253659313510219
# [it=190] obj=7.357e-01 feas_raw=2.611e-07 alpha=5.38e-02 beta=7.92e-01 station=2.51e-02 dn=2.51e-02
# blocks (raw c):
#   pde_phi   : rms=2.519e-04  max=1.636e-03
#   pde_Ts    : rms=3.891e-04  max=1.938e-03
#   pde_Tf    : rms=6.465e-04  max=5.715e-03
#   bc_phi    : rms=3.292e-04  max=1.772e-03
#   bc_Ts     : rms=4.542e-04  max=1.767e-03
#   bc_Tf     : rms=3.683e-04  max=2.501e-03
#   iface     : rms=8.069e-04  max=5.018e-03
#   ic        : rms=5.654e-04  max=3.378e-03
# Raw PDE RMS on obj: phi 0.11717107973546771 Ts 0.09826593607622679 Tf 0.22387014637961367
# [it=200] obj=7.283e-01 feas_raw=2.913e-07 alpha=5.86e-02 beta=7.84e-01 station=2.44e-02 dn=2.44e-02
# blocks (raw c):
#   pde_phi   : rms=2.847e-04  max=1.662e-03
#   pde_Ts    : rms=5.502e-04  max=6.645e-03
#   pde_Tf    : rms=6.709e-04  max=7.479e-03
#   bc_phi    : rms=3.272e-04  max=1.727e-03
#   bc_Ts     : rms=4.437e-04  max=1.563e-03
#   bc_Tf     : rms=3.784e-04  max=2.443e-03
#   iface     : rms=7.970e-04  max=5.056e-03
#   ic        : rms=5.583e-04  max=3.310e-03
# Raw PDE RMS on obj: phi 0.1172868529699795 Ts 0.09792627855019745 Tf 0.22230479905829328
# [it=210] obj=7.178e-01 feas_raw=3.277e-07 alpha=6.38e-02 beta=7.76e-01 station=2.26e-02 dn=2.26e-02
# blocks (raw c):
#   pde_phi   : rms=2.502e-04  max=1.670e-03
#   pde_Ts    : rms=4.112e-04  max=2.446e-03
#   pde_Tf    : rms=9.177e-04  max=9.084e-03
#   bc_phi    : rms=3.180e-04  max=1.702e-03
#   bc_Ts     : rms=4.345e-04  max=1.552e-03
#   bc_Tf     : rms=3.599e-04  max=2.394e-03
#   iface     : rms=7.850e-04  max=4.868e-03
#   ic        : rms=5.501e-04  max=3.213e-03
# Raw PDE RMS on obj: phi 0.1172731958172426 Ts 0.09751427040034527 Tf 0.2201035847835643
# [it=220] obj=7.089e-01 feas_raw=3.012e-07 alpha=6.95e-02 beta=7.69e-01 station=2.16e-02 dn=2.16e-02
# blocks (raw c):
#   pde_phi   : rms=2.227e-04  max=1.570e-03
#   pde_Ts    : rms=4.464e-04  max=2.778e-03
#   pde_Tf    : rms=8.242e-04  max=8.073e-03
#   bc_phi    : rms=3.181e-04  max=1.676e-03
#   bc_Ts     : rms=4.226e-04  max=1.531e-03
#   bc_Tf     : rms=3.731e-04  max=2.427e-03
#   iface     : rms=7.756e-04  max=4.905e-03
#   ic        : rms=5.451e-04  max=3.270e-03
# Raw PDE RMS on obj: phi 0.11732158131903535 Ts 0.09737184701797989 Tf 0.21814629214228337
# [it=230] obj=6.981e-01 feas_raw=2.931e-07 alpha=6.88e-02 beta=7.61e-01 station=2.13e-02 dn=2.13e-02
# blocks (raw c):
#   pde_phi   : rms=2.989e-04  max=2.574e-03
#   pde_Ts    : rms=4.161e-04  max=2.035e-03
#   pde_Tf    : rms=8.136e-04  max=8.232e-03
#   bc_phi    : rms=3.225e-04  max=1.642e-03
#   bc_Ts     : rms=4.123e-04  max=1.449e-03
#   bc_Tf     : rms=3.567e-04  max=2.076e-03
#   iface     : rms=7.632e-04  max=4.757e-03
#   ic        : rms=5.359e-04  max=3.170e-03
# Raw PDE RMS on obj: phi 0.11734358413654437 Ts 0.09698962690045963 Tf 0.21573624012758696
# [it=240] obj=6.899e-01 feas_raw=2.896e-07 alpha=7.50e-02 beta=7.54e-01 station=2.18e-02 dn=2.18e-02
# blocks (raw c):
#   pde_phi   : rms=2.280e-04  max=1.307e-03
#   pde_Ts    : rms=5.828e-04  max=5.905e-03
#   pde_Tf    : rms=7.309e-04  max=9.907e-03
#   bc_phi    : rms=3.092e-04  max=1.596e-03
#   bc_Ts     : rms=4.008e-04  max=1.440e-03
#   bc_Tf     : rms=3.398e-04  max=2.309e-03
#   iface     : rms=7.516e-04  max=4.785e-03
#   ic        : rms=5.266e-04  max=3.045e-03
# Raw PDE RMS on obj: phi 0.11734278889631493 Ts 0.09653687692172197 Tf 0.21401382963831364
# [it=250] obj=6.776e-01 feas_raw=2.854e-07 alpha=8.17e-02 beta=7.47e-01 station=2.08e-02 dn=2.08e-02
# blocks (raw c):
#   pde_phi   : rms=2.138e-04  max=1.102e-03
#   pde_Ts    : rms=6.394e-04  max=5.205e-03
#   pde_Tf    : rms=6.834e-04  max=8.479e-03
#   bc_phi    : rms=3.065e-04  max=1.563e-03
#   bc_Ts     : rms=3.886e-04  max=1.421e-03
#   bc_Tf     : rms=3.314e-04  max=2.115e-03
#   iface     : rms=7.401e-04  max=4.814e-03
#   ic        : rms=5.229e-04  max=3.120e-03
# Raw PDE RMS on obj: phi 0.1173150849508833 Ts 0.09607886891757156 Tf 0.21134745643211236
# [it=260] obj=6.666e-01 feas_raw=2.387e-07 alpha=8.10e-02 beta=7.40e-01 station=1.99e-02 dn=1.99e-02
# blocks (raw c):
#   pde_phi   : rms=3.138e-04  max=2.574e-03
#   pde_Ts    : rms=5.423e-04  max=2.670e-03
#   pde_Tf    : rms=5.488e-04  max=4.882e-03
#   bc_phi    : rms=2.981e-04  max=1.535e-03
#   bc_Ts     : rms=3.827e-04  max=1.369e-03
#   bc_Tf     : rms=3.150e-04  max=2.025e-03
#   iface     : rms=7.347e-04  max=4.761e-03
#   ic        : rms=5.132e-04  max=3.029e-03
# Raw PDE RMS on obj: phi 0.11734230142592117 Ts 0.09587883076357695 Tf 0.2088016510725479
# [it=270] obj=6.585e-01 feas_raw=2.684e-07 alpha=8.83e-02 beta=7.34e-01 station=1.93e-02 dn=1.93e-02
# blocks (raw c):
#   pde_phi   : rms=2.640e-04  max=1.574e-03
#   pde_Ts    : rms=6.097e-04  max=3.962e-03
#   pde_Tf    : rms=6.654e-04  max=9.443e-03
#   bc_phi    : rms=2.931e-04  max=1.515e-03
#   bc_Ts     : rms=3.692e-04  max=1.360e-03
#   bc_Tf     : rms=3.095e-04  max=1.959e-03
#   iface     : rms=7.204e-04  max=4.675e-03
#   ic        : rms=5.058e-04  max=3.077e-03
# Raw PDE RMS on obj: phi 0.11733296010893737 Ts 0.09555835310485264 Tf 0.20693284735341327
# [it=280] obj=6.460e-01 feas_raw=2.661e-07 alpha=9.62e-02 beta=7.27e-01 station=1.82e-02 dn=1.82e-02
# blocks (raw c):
#   pde_phi   : rms=2.729e-04  max=1.954e-03
#   pde_Ts    : rms=5.596e-04  max=1.979e-03
#   pde_Tf    : rms=7.097e-04  max=1.044e-02
#   bc_phi    : rms=3.001e-04  max=1.466e-03
#   bc_Ts     : rms=3.594e-04  max=1.363e-03
#   bc_Tf     : rms=3.074e-04  max=2.039e-03
#   iface     : rms=7.107e-04  max=4.637e-03
#   ic        : rms=4.951e-04  max=2.967e-03
# Raw PDE RMS on obj: phi 0.11733161380905022 Ts 0.09530658060112834 Tf 0.20406787970379903
# [it=290] obj=6.355e-01 feas_raw=2.520e-07 alpha=1.05e-01 beta=7.21e-01 station=1.88e-02 dn=1.88e-02
# blocks (raw c):
#   pde_phi   : rms=2.263e-04  max=1.099e-03
#   pde_Ts    : rms=6.772e-04  max=5.310e-03
#   pde_Tf    : rms=5.681e-04  max=6.281e-03
#   bc_phi    : rms=2.862e-04  max=1.419e-03
#   bc_Ts     : rms=3.526e-04  max=1.300e-03
#   bc_Tf     : rms=3.014e-04  max=1.928e-03
#   iface     : rms=6.918e-04  max=4.587e-03
#   ic        : rms=4.877e-04  max=2.948e-03
# Raw PDE RMS on obj: phi 0.11725887798791115 Ts 0.09485789471405413 Tf 0.20168093370355128
# [it=300] obj=6.243e-01 feas_raw=2.458e-07 alpha=1.04e-01 beta=7.15e-01 station=1.80e-02 dn=1.80e-02
# blocks (raw c):
#   pde_phi   : rms=3.930e-04  max=4.697e-03
#   pde_Ts    : rms=6.079e-04  max=4.003e-03
#   pde_Tf    : rms=5.779e-04  max=6.860e-03
#   bc_phi    : rms=2.897e-04  max=1.373e-03
#   bc_Ts     : rms=3.401e-04  max=1.279e-03
#   bc_Tf     : rms=2.889e-04  max=1.767e-03
#   iface     : rms=6.785e-04  max=4.466e-03
#   ic        : rms=4.809e-04  max=2.837e-03
# Raw PDE RMS on obj: phi 0.11726041381849055 Ts 0.09469786772860397 Tf 0.1989007102141991
# [it=310] obj=6.130e-01 feas_raw=2.277e-07 alpha=1.03e-01 beta=7.09e-01 station=1.64e-02 dn=1.64e-02
# blocks (raw c):
#   pde_phi   : rms=2.464e-04  max=1.467e-03
#   pde_Ts    : rms=5.330e-04  max=3.162e-03
#   pde_Tf    : rms=6.265e-04  max=9.038e-03
#   bc_phi    : rms=2.862e-04  max=1.324e-03
#   bc_Ts     : rms=3.327e-04  max=1.269e-03
#   bc_Tf     : rms=2.980e-04  max=1.712e-03
#   iface     : rms=6.672e-04  max=4.356e-03
#   ic        : rms=4.692e-04  max=2.815e-03
# Raw PDE RMS on obj: phi 0.11725403718769288 Ts 0.09440076414426937 Tf 0.19629990183877158
# [it=320] obj=6.008e-01 feas_raw=2.150e-07 alpha=1.02e-01 beta=7.03e-01 station=1.74e-02 dn=1.74e-02
# blocks (raw c):
#   pde_phi   : rms=2.357e-04  max=1.395e-03
#   pde_Ts    : rms=5.132e-04  max=3.915e-03
#   pde_Tf    : rms=5.973e-04  max=6.880e-03
#   bc_phi    : rms=3.069e-04  max=1.426e-03
#   bc_Ts     : rms=3.254e-04  max=1.248e-03
#   bc_Tf     : rms=2.859e-04  max=1.613e-03
#   iface     : rms=6.523e-04  max=4.395e-03
#   ic        : rms=4.625e-04  max=2.759e-03
# Raw PDE RMS on obj: phi 0.11722427300204696 Ts 0.09410394998791842 Tf 0.1933057626224506
# [it=330] obj=5.912e-01 feas_raw=2.552e-07 alpha=1.12e-01 beta=6.97e-01 station=1.54e-02 dn=1.54e-02
# blocks (raw c):
#   pde_phi   : rms=3.587e-04  max=4.208e-03
#   pde_Ts    : rms=4.447e-04  max=2.256e-03
#   pde_Tf    : rms=8.002e-04  max=1.042e-02
#   bc_phi    : rms=2.733e-04  max=1.265e-03
#   bc_Ts     : rms=3.196e-04  max=1.224e-03
#   bc_Tf     : rms=2.878e-04  max=1.633e-03
#   iface     : rms=6.429e-04  max=4.244e-03
#   ic        : rms=4.537e-04  max=2.655e-03
# Raw PDE RMS on obj: phi 0.11707995291002879 Ts 0.09400512336775435 Tf 0.19095738564433412
# [it=340] obj=5.813e-01 feas_raw=2.196e-07 alpha=1.11e-01 beta=6.91e-01 station=1.46e-02 dn=1.46e-02
# blocks (raw c):
#   pde_phi   : rms=3.367e-04  max=3.525e-03
#   pde_Ts    : rms=4.647e-04  max=3.292e-03
#   pde_Tf    : rms=6.704e-04  max=7.563e-03
#   bc_phi    : rms=2.707e-04  max=1.211e-03
#   bc_Ts     : rms=3.086e-04  max=1.208e-03
#   bc_Tf     : rms=2.678e-04  max=1.614e-03
#   iface     : rms=6.286e-04  max=4.199e-03
#   ic        : rms=4.482e-04  max=2.704e-03
# Raw PDE RMS on obj: phi 0.11694644520019283 Ts 0.09395890302754116 Tf 0.18849916025435742
# [it=350] obj=5.720e-01 feas_raw=3.568e-07 alpha=1.10e-01 beta=6.86e-01 station=1.42e-02 dn=1.42e-02
# blocks (raw c):
#   pde_phi   : rms=3.167e-04  max=3.473e-03
#   pde_Ts    : rms=4.187e-04  max=2.177e-03
#   pde_Tf    : rms=1.145e-03  max=1.806e-02
#   bc_phi    : rms=2.682e-04  max=1.194e-03
#   bc_Ts     : rms=3.074e-04  max=1.190e-03
#   bc_Tf     : rms=2.864e-04  max=1.583e-03
#   iface     : rms=6.185e-04  max=4.123e-03
#   ic        : rms=4.382e-04  max=2.578e-03
# Raw PDE RMS on obj: phi 0.11679929993090277 Ts 0.09376584515375949 Tf 0.18622253113678722
# [it=360] obj=5.628e-01 feas_raw=2.768e-07 alpha=1.20e-01 beta=6.80e-01 station=1.41e-02 dn=1.41e-02
# blocks (raw c):
#   pde_phi   : rms=2.238e-04  max=1.264e-03
#   pde_Ts    : rms=3.935e-04  max=4.057e-03
#   pde_Tf    : rms=9.590e-04  max=1.541e-02
#   bc_phi    : rms=2.619e-04  max=1.168e-03
#   bc_Ts     : rms=2.990e-04  max=1.171e-03
#   bc_Tf     : rms=2.694e-04  max=1.559e-03
#   iface     : rms=6.035e-04  max=4.022e-03
#   ic        : rms=4.333e-04  max=2.618e-03
# Raw PDE RMS on obj: phi 0.11652688107717392 Ts 0.09359446485566567 Tf 0.18395327497316605
# [it=370] obj=5.540e-01 feas_raw=2.675e-07 alpha=1.19e-01 beta=6.75e-01 station=1.37e-02 dn=1.37e-02
# blocks (raw c):
#   pde_phi   : rms=2.429e-04  max=1.473e-03
#   pde_Ts    : rms=4.955e-04  max=6.145e-03
#   pde_Tf    : rms=8.845e-04  max=1.430e-02
#   bc_phi    : rms=2.651e-04  max=1.130e-03
#   bc_Ts     : rms=2.945e-04  max=1.167e-03
#   bc_Tf     : rms=2.614e-04  max=1.464e-03
#   iface     : rms=5.935e-04  max=3.955e-03
#   ic        : rms=4.280e-04  max=2.546e-03
# Raw PDE RMS on obj: phi 0.11625445846900546 Ts 0.09349951630089838 Tf 0.1817787368946945
# [it=380] obj=5.452e-01 feas_raw=2.406e-07 alpha=1.30e-01 beta=6.70e-01 station=1.41e-02 dn=1.41e-02
# blocks (raw c):
#   pde_phi   : rms=2.665e-04  max=1.965e-03
#   pde_Ts    : rms=3.900e-04  max=4.662e-03
#   pde_Tf    : rms=8.521e-04  max=1.008e-02
#   bc_phi    : rms=2.579e-04  max=1.131e-03
#   bc_Ts     : rms=2.887e-04  max=1.181e-03
#   bc_Tf     : rms=2.633e-04  max=1.532e-03
#   iface     : rms=5.838e-04  max=3.986e-03
#   ic        : rms=4.223e-04  max=2.486e-03
# Raw PDE RMS on obj: phi 0.11597169966797294 Ts 0.09333579509431832 Tf 0.17968817581480437
# [it=390] obj=5.364e-01 feas_raw=2.518e-07 alpha=1.29e-01 beta=6.65e-01 station=1.29e-02 dn=1.29e-02
# blocks (raw c):
#   pde_phi   : rms=2.818e-04  max=2.528e-03
#   pde_Ts    : rms=5.626e-04  max=7.862e-03
#   pde_Tf    : rms=7.979e-04  max=1.247e-02
#   bc_phi    : rms=2.535e-04  max=1.076e-03
#   bc_Ts     : rms=2.861e-04  max=1.148e-03
#   bc_Tf     : rms=2.478e-04  max=1.459e-03
#   iface     : rms=5.781e-04  max=3.862e-03
#   ic        : rms=4.161e-04  max=2.476e-03
# Raw PDE RMS on obj: phi 0.11554295825108454 Ts 0.09324750339710172 Tf 0.17758623056582998
# [it=400] obj=5.282e-01 feas_raw=2.438e-07 alpha=1.28e-01 beta=6.60e-01 station=1.43e-02 dn=1.43e-02
# blocks (raw c):
#   pde_phi   : rms=2.461e-04  max=1.496e-03
#   pde_Ts    : rms=3.208e-04  max=2.785e-03
#   pde_Tf    : rms=9.056e-04  max=1.370e-02
#   bc_phi    : rms=2.638e-04  max=1.202e-03
#   bc_Ts     : rms=2.809e-04  max=1.151e-03
#   bc_Tf     : rms=2.774e-04  max=1.809e-03
#   iface     : rms=5.606e-04  max=3.756e-03
#   ic        : rms=4.115e-04  max=2.457e-03
# Raw PDE RMS on obj: phi 0.11504674520992401 Ts 0.09314302315651812 Tf 0.17562041986087937
# [it=410] obj=5.193e-01 feas_raw=1.885e-07 alpha=1.40e-01 beta=6.55e-01 station=1.33e-02 dn=1.33e-02
# blocks (raw c):
#   pde_phi   : rms=2.548e-04  max=2.662e-03
#   pde_Ts    : rms=4.136e-04  max=4.899e-03
#   pde_Tf    : rms=6.730e-04  max=7.811e-03
#   bc_phi    : rms=2.619e-04  max=1.108e-03
#   bc_Ts     : rms=2.768e-04  max=1.149e-03
#   bc_Tf     : rms=2.387e-04  max=1.364e-03
#   iface     : rms=5.449e-04  max=3.718e-03
#   ic        : rms=4.058e-04  max=2.481e-03
# Raw PDE RMS on obj: phi 0.11449097972916451 Ts 0.09293454499195418 Tf 0.1734303429394691
# [it=420] obj=5.115e-01 feas_raw=1.541e-07 alpha=1.39e-01 beta=6.50e-01 station=1.39e-02 dn=1.39e-02
# blocks (raw c):
#   pde_phi   : rms=2.051e-04  max=1.075e-03
#   pde_Ts    : rms=4.062e-04  max=4.977e-03
#   pde_Tf    : rms=5.329e-04  max=5.704e-03
#   bc_phi    : rms=2.598e-04  max=1.020e-03
#   bc_Ts     : rms=2.742e-04  max=1.149e-03
#   bc_Tf     : rms=2.436e-04  max=1.386e-03
#   iface     : rms=5.344e-04  max=3.669e-03
#   ic        : rms=3.993e-04  max=2.387e-03
# Raw PDE RMS on obj: phi 0.11411821676064474 Ts 0.0925390224151244 Tf 0.17166119702696384
# [it=430] obj=5.023e-01 feas_raw=3.532e-07 alpha=1.51e-01 beta=6.45e-01 station=1.20e-02 dn=1.20e-02
# blocks (raw c):
#   pde_phi   : rms=1.894e-04  max=1.145e-03
#   pde_Ts    : rms=3.990e-04  max=5.348e-03
#   pde_Tf    : rms=1.211e-03  max=2.045e-02
#   bc_phi    : rms=2.463e-04  max=1.001e-03
#   bc_Ts     : rms=2.719e-04  max=1.125e-03
#   bc_Tf     : rms=2.514e-04  max=1.331e-03
#   iface     : rms=5.261e-04  max=3.572e-03
#   ic        : rms=3.965e-04  max=2.433e-03
# Raw PDE RMS on obj: phi 0.11356923245105606 Ts 0.09218289399622136 Tf 0.16961290937709547
# [it=440] obj=4.951e-01 feas_raw=1.330e-07 alpha=1.50e-01 beta=6.41e-01 station=1.35e-02 dn=1.35e-02
# blocks (raw c):
#   pde_phi   : rms=2.542e-04  max=1.608e-03
#   pde_Ts    : rms=4.341e-04  max=5.284e-03
#   pde_Tf    : rms=3.906e-04  max=3.002e-03
#   bc_phi    : rms=2.407e-04  max=9.910e-04
#   bc_Ts     : rms=2.662e-04  max=1.118e-03
#   bc_Tf     : rms=2.352e-04  max=1.333e-03
#   iface     : rms=5.169e-04  max=3.553e-03
#   ic        : rms=3.889e-04  max=2.309e-03
# Raw PDE RMS on obj: phi 0.11305236985125876 Ts 0.09188914200533783 Tf 0.16797729509204104
# [it=450] obj=4.860e-01 feas_raw=1.672e-07 alpha=1.64e-01 beta=6.36e-01 station=1.24e-02 dn=1.24e-02
# blocks (raw c):
#   pde_phi   : rms=2.731e-04  max=2.238e-03
#   pde_Ts    : rms=4.853e-04  max=6.049e-03
#   pde_Tf    : rms=5.558e-04  max=6.220e-03
#   bc_phi    : rms=2.408e-04  max=9.851e-04
#   bc_Ts     : rms=2.600e-04  max=1.093e-03
#   bc_Tf     : rms=2.338e-04  max=1.230e-03
#   iface     : rms=5.094e-04  max=3.491e-03
#   ic        : rms=3.832e-04  max=2.271e-03
# Raw PDE RMS on obj: phi 0.11241307604807 Ts 0.09153903750466062 Tf 0.16599260198793875
# [it=460] obj=4.792e-01 feas_raw=3.179e-07 alpha=1.79e-01 beta=6.32e-01 station=1.17e-02 dn=1.17e-02
# blocks (raw c):
#   pde_phi   : rms=2.369e-04  max=1.676e-03
#   pde_Ts    : rms=3.787e-04  max=3.958e-03
#   pde_Tf    : rms=1.143e-03  max=1.935e-02
#   bc_phi    : rms=2.327e-04  max=9.578e-04
#   bc_Ts     : rms=2.573e-04  max=1.064e-03
#   bc_Tf     : rms=2.239e-04  max=1.240e-03
#   iface     : rms=5.000e-04  max=3.413e-03
#   ic        : rms=3.806e-04  max=2.332e-03
# Raw PDE RMS on obj: phi 0.11189140371060384 Ts 0.09120766516630992 Tf 0.1643340952218303
# [it=470] obj=4.713e-01 feas_raw=2.326e-07 alpha=1.78e-01 beta=6.27e-01 station=1.21e-02 dn=1.21e-02
# blocks (raw c):
#   pde_phi   : rms=2.137e-04  max=1.329e-03
#   pde_Ts    : rms=4.164e-04  max=5.260e-03
#   pde_Tf    : rms=8.953e-04  max=1.238e-02
#   bc_phi    : rms=2.228e-04  max=9.324e-04
#   bc_Ts     : rms=2.539e-04  max=1.071e-03
#   bc_Tf     : rms=2.171e-04  max=1.218e-03
#   iface     : rms=4.884e-04  max=3.357e-03
#   ic        : rms=3.732e-04  max=2.173e-03
# Raw PDE RMS on obj: phi 0.11145122581005903 Ts 0.09087799771803826 Tf 0.16246543353997814
# [it=480] obj=4.636e-01 feas_raw=1.345e-07 alpha=1.77e-01 beta=6.23e-01 station=1.12e-02 dn=1.12e-02
# blocks (raw c):
#   pde_phi   : rms=1.912e-04  max=8.594e-04
#   pde_Ts    : rms=3.366e-04  max=3.275e-03
#   pde_Tf    : rms=5.490e-04  max=7.848e-03
#   bc_phi    : rms=2.309e-04  max=1.213e-03
#   bc_Ts     : rms=2.488e-04  max=1.038e-03
#   bc_Tf     : rms=2.140e-04  max=1.130e-03
#   iface     : rms=4.815e-04  max=3.320e-03
#   ic        : rms=3.681e-04  max=2.164e-03
# Raw PDE RMS on obj: phi 0.11086807523897793 Ts 0.09042602199356645 Tf 0.16066366480405841
# [it=490] obj=4.562e-01 feas_raw=1.786e-07 alpha=1.76e-01 beta=6.19e-01 station=1.17e-02 dn=1.17e-02
# blocks (raw c):
#   pde_phi   : rms=2.505e-04  max=2.085e-03
#   pde_Ts    : rms=3.403e-04  max=3.717e-03
#   pde_Tf    : rms=7.394e-04  max=1.120e-02
#   bc_phi    : rms=2.346e-04  max=9.098e-04
#   bc_Ts     : rms=2.445e-04  max=1.010e-03
#   bc_Tf     : rms=2.101e-04  max=1.128e-03
#   iface     : rms=4.746e-04  max=3.230e-03
#   ic        : rms=3.644e-04  max=2.168e-03
# Raw PDE RMS on obj: phi 0.11044064185104065 Ts 0.09013091608887651 Tf 0.15889060858298334
# [it=500] obj=4.499e-01 feas_raw=1.381e-07 alpha=1.92e-01 beta=6.15e-01 station=1.09e-02 dn=1.09e-02
# blocks (raw c):
#   pde_phi   : rms=2.765e-04  max=2.280e-03
#   pde_Ts    : rms=2.910e-04  max=2.662e-03
#   pde_Tf    : rms=5.924e-04  max=8.132e-03
#   bc_phi    : rms=2.230e-04  max=9.446e-04
#   bc_Ts     : rms=2.431e-04  max=9.831e-04
#   bc_Tf     : rms=2.045e-04  max=1.092e-03
#   iface     : rms=4.571e-04  max=3.176e-03
#   ic        : rms=3.587e-04  max=2.057e-03
# Raw PDE RMS on obj: phi 0.10995387653948584 Ts 0.08984735633312362 Tf 0.15720379100923126
# [it=510] obj=4.407e-01 feas_raw=1.606e-07 alpha=1.91e-01 beta=6.11e-01 station=1.08e-02 dn=1.08e-02
# blocks (raw c):
#   pde_phi   : rms=2.685e-04  max=2.332e-03
#   pde_Ts    : rms=6.244e-04  max=7.521e-03
#   pde_Tf    : rms=4.373e-04  max=5.846e-03
#   bc_phi    : rms=2.154e-04  max=8.489e-04
#   bc_Ts     : rms=2.351e-04  max=9.422e-04
#   bc_Tf     : rms=2.027e-04  max=1.108e-03
#   iface     : rms=4.496e-04  max=3.089e-03
#   ic        : rms=3.541e-04  max=2.030e-03
# Raw PDE RMS on obj: phi 0.10953402353260144 Ts 0.0891973852896223 Tf 0.15509495131885076
# [it=520] obj=4.337e-01 feas_raw=2.303e-07 alpha=2.08e-01 beta=6.07e-01 station=1.07e-02 dn=1.07e-02
# blocks (raw c):
#   pde_phi   : rms=2.354e-04  max=1.732e-03
#   pde_Ts    : rms=2.838e-04  max=1.727e-03
#   pde_Tf    : rms=9.624e-04  max=1.593e-02
#   bc_phi    : rms=2.158e-04  max=8.639e-04
#   bc_Ts     : rms=2.343e-04  max=9.263e-04
#   bc_Tf     : rms=1.949e-04  max=1.114e-03
#   iface     : rms=4.431e-04  max=3.030e-03
#   ic        : rms=3.497e-04  max=2.013e-03
# Raw PDE RMS on obj: phi 0.10911707043316365 Ts 0.08878897255659665 Tf 0.15345134662989374
# [it=530] obj=4.273e-01 feas_raw=1.145e-07 alpha=2.28e-01 beta=6.03e-01 station=1.06e-02 dn=1.06e-02
# blocks (raw c):
#   pde_phi   : rms=3.195e-04  max=2.976e-03
#   pde_Ts    : rms=3.393e-04  max=3.478e-03
#   pde_Tf    : rms=4.444e-04  max=4.790e-03
#   bc_phi    : rms=2.156e-04  max=1.200e-03
#   bc_Ts     : rms=2.278e-04  max=8.958e-04
#   bc_Tf     : rms=1.983e-04  max=1.031e-03
#   iface     : rms=4.288e-04  max=2.891e-03
#   ic        : rms=3.446e-04  max=1.999e-03
# Raw PDE RMS on obj: phi 0.10877754310832723 Ts 0.0883131041898862 Tf 0.1516127712056692
# [it=540] obj=4.184e-01 feas_raw=2.063e-07 alpha=2.49e-01 beta=5.99e-01 station=1.08e-02 dn=1.08e-02
# blocks (raw c):
#   pde_phi   : rms=2.586e-04  max=2.678e-03
#   pde_Ts    : rms=2.616e-04  max=1.692e-03
#   pde_Tf    : rms=8.995e-04  max=1.357e-02
#   bc_phi    : rms=2.088e-04  max=8.719e-04
#   bc_Ts     : rms=2.227e-04  max=9.016e-04
#   bc_Tf     : rms=2.034e-04  max=1.300e-03
#   iface     : rms=4.273e-04  max=2.850e-03
#   ic        : rms=3.377e-04  max=1.915e-03
# Raw PDE RMS on obj: phi 0.10826608286022829 Ts 0.08788064749448887 Tf 0.14939063337189865
# [it=550] obj=4.120e-01 feas_raw=3.466e-07 alpha=2.72e-01 beta=5.95e-01 station=1.06e-02 dn=1.06e-02
# blocks (raw c):
#   pde_phi   : rms=3.405e-04  max=3.783e-03
#   pde_Ts    : rms=3.854e-04  max=5.441e-03
#   pde_Tf    : rms=1.235e-03  max=2.209e-02
#   bc_phi    : rms=2.136e-04  max=1.488e-03
#   bc_Ts     : rms=2.159e-04  max=9.074e-04
#   bc_Tf     : rms=2.001e-04  max=1.335e-03
#   iface     : rms=4.167e-04  max=2.796e-03
#   ic        : rms=3.328e-04  max=1.904e-03
# Raw PDE RMS on obj: phi 0.10808940707933067 Ts 0.08715187997872376 Tf 0.14774118874691552
# [it=560] obj=4.034e-01 feas_raw=1.502e-07 alpha=2.70e-01 beta=5.91e-01 station=8.36e-03 dn=8.36e-03
# blocks (raw c):
#   pde_phi   : rms=1.690e-04  max=9.177e-04
#   pde_Ts    : rms=3.410e-04  max=4.701e-03
#   pde_Tf    : rms=6.964e-04  max=7.364e-03
#   bc_phi    : rms=1.897e-04  max=7.805e-04
#   bc_Ts     : rms=2.155e-04  max=8.993e-04
#   bc_Tf     : rms=1.873e-04  max=9.429e-04
#   iface     : rms=4.052e-04  max=2.685e-03
#   ic        : rms=3.274e-04  max=1.894e-03
# Raw PDE RMS on obj: phi 0.10777179160035345 Ts 0.08626053603024639 Tf 0.1456559049394528
# [it=570] obj=3.979e-01 feas_raw=1.188e-07 alpha=2.95e-01 beta=5.88e-01 station=1.00e-02 dn=1.00e-02
# blocks (raw c):
#   pde_phi   : rms=2.301e-04  max=1.963e-03
#   pde_Ts    : rms=4.079e-04  max=4.934e-03
#   pde_Tf    : rms=4.955e-04  max=5.370e-03
#   bc_phi    : rms=1.911e-04  max=7.908e-04
#   bc_Ts     : rms=2.045e-04  max=9.011e-04
#   bc_Tf     : rms=1.880e-04  max=9.196e-04
#   iface     : rms=3.984e-04  max=2.611e-03
#   ic        : rms=3.200e-04  max=1.780e-03
# Raw PDE RMS on obj: phi 0.10768829953113801 Ts 0.08594276659888243 Tf 0.14396117637020953
# [it=580] obj=3.905e-01 feas_raw=2.450e-07 alpha=3.23e-01 beta=5.84e-01 station=8.10e-03 dn=8.10e-03
# blocks (raw c):
#   pde_phi   : rms=1.916e-04  max=1.682e-03
#   pde_Ts    : rms=2.453e-04  max=1.419e-03
#   pde_Tf    : rms=1.053e-03  max=1.635e-02
#   bc_phi    : rms=1.790e-04  max=7.483e-04
#   bc_Ts     : rms=2.013e-04  max=9.020e-04
#   bc_Tf     : rms=1.948e-04  max=1.475e-03
#   iface     : rms=3.894e-04  max=2.466e-03
#   ic        : rms=3.146e-04  max=1.766e-03
# Raw PDE RMS on obj: phi 0.10740146131885783 Ts 0.0851368483775023 Tf 0.14192928084906592
# [it=590] obj=3.834e-01 feas_raw=7.931e-08 alpha=2.92e-01 beta=5.81e-01 station=8.19e-03 dn=8.19e-03
# blocks (raw c):
#   pde_phi   : rms=1.722e-04  max=1.329e-03
#   pde_Ts    : rms=3.207e-04  max=3.172e-03
#   pde_Tf    : rms=3.393e-04  max=3.424e-03
#   bc_phi    : rms=1.800e-04  max=7.174e-04
#   bc_Ts     : rms=1.977e-04  max=8.872e-04
#   bc_Tf     : rms=1.556e-04  max=7.946e-04
#   iface     : rms=3.871e-04  max=2.460e-03
#   ic        : rms=3.081e-04  max=1.750e-03
# Raw PDE RMS on obj: phi 0.10718792189853733 Ts 0.08468895355550027 Tf 0.14012142613176687
# [it=600] obj=3.762e-01 feas_raw=1.652e-07 alpha=3.51e-01 beta=5.77e-01 station=7.96e-03 dn=7.96e-03
# blocks (raw c):
#   pde_phi   : rms=2.137e-04  max=1.483e-03
#   pde_Ts    : rms=2.743e-04  max=3.050e-03
#   pde_Tf    : rms=8.031e-04  max=1.306e-02
#   bc_phi    : rms=1.750e-04  max=7.072e-04
#   bc_Ts     : rms=1.891e-04  max=8.867e-04
#   bc_Tf     : rms=1.500e-04  max=7.929e-04
#   iface     : rms=3.789e-04  max=2.403e-03
#   ic        : rms=3.011e-04  max=1.692e-03
# Raw PDE RMS on obj: phi 0.10699298407728029 Ts 0.08389725400366693 Tf 0.13812866947342015
# [it=610] obj=3.689e-01 feas_raw=1.295e-07 alpha=3.84e-01 beta=5.74e-01 station=9.05e-03 dn=9.05e-03
# blocks (raw c):
#   pde_phi   : rms=1.995e-04  max=2.008e-03
#   pde_Ts    : rms=2.528e-04  max=1.234e-03
#   pde_Tf    : rms=6.781e-04  max=1.110e-02
#   bc_phi    : rms=1.743e-04  max=6.828e-04
#   bc_Ts     : rms=1.832e-04  max=8.542e-04
#   bc_Tf     : rms=1.471e-04  max=7.617e-04
#   iface     : rms=3.718e-04  max=2.404e-03
#   ic        : rms=2.950e-04  max=1.728e-03
# Raw PDE RMS on obj: phi 0.10670954488857808 Ts 0.08336449396854885 Tf 0.13607102692214207
# [it=620] obj=3.610e-01 feas_raw=4.988e-07 alpha=4.19e-01 beta=5.70e-01 station=7.04e-03 dn=7.04e-03
# blocks (raw c):
#   pde_phi   : rms=1.422e-04  max=8.774e-04
#   pde_Ts    : rms=2.857e-04  max=3.661e-03
#   pde_Tf    : rms=1.616e-03  max=2.945e-02
#   bc_phi    : rms=1.781e-04  max=1.042e-03
#   bc_Ts     : rms=1.779e-04  max=8.424e-04
#   bc_Tf     : rms=1.739e-04  max=1.366e-03
#   iface     : rms=3.655e-04  max=2.386e-03
#   ic        : rms=2.887e-04  max=1.688e-03
# Raw PDE RMS on obj: phi 0.10621829186415793 Ts 0.08238105624651182 Tf 0.13402557538491477
# [it=630] obj=3.539e-01 feas_raw=7.768e-08 alpha=3.79e-01 beta=5.67e-01 station=6.67e-03 dn=6.67e-03
# blocks (raw c):
#   pde_phi   : rms=2.154e-04  max=2.254e-03
#   pde_Ts    : rms=3.113e-04  max=4.033e-03
#   pde_Tf    : rms=3.690e-04  max=3.824e-03
#   bc_phi    : rms=1.562e-04  max=6.656e-04
#   bc_Ts     : rms=1.750e-04  max=8.158e-04
#   bc_Tf     : rms=1.564e-04  max=1.126e-03
#   iface     : rms=3.609e-04  max=2.425e-03
#   ic        : rms=2.812e-04  max=1.608e-03
# Raw PDE RMS on obj: phi 0.10600575999384505 Ts 0.08164752799794828 Tf 0.13211247629022485
# [it=640] obj=3.470e-01 feas_raw=1.269e-07 alpha=4.15e-01 beta=5.64e-01 station=6.49e-03 dn=6.49e-03
# blocks (raw c):
#   pde_phi   : rms=1.735e-04  max=1.226e-03
#   pde_Ts    : rms=3.139e-04  max=3.565e-03
#   pde_Tf    : rms=6.663e-04  max=1.149e-02
#   bc_phi    : rms=1.591e-04  max=6.685e-04
#   bc_Ts     : rms=1.678e-04  max=7.965e-04
#   bc_Tf     : rms=1.316e-04  max=6.564e-04
#   iface     : rms=3.497e-04  max=2.424e-03
#   ic        : rms=2.750e-04  max=1.590e-03
# Raw PDE RMS on obj: phi 0.1056364954680208 Ts 0.08091832486385737 Tf 0.1299994277429462
# [it=650] obj=3.396e-01 feas_raw=7.834e-08 alpha=4.12e-01 beta=5.60e-01 station=6.93e-03 dn=6.93e-03
# blocks (raw c):
#   pde_phi   : rms=1.557e-04  max=8.963e-04
#   pde_Ts    : rms=2.651e-04  max=2.603e-03
#   pde_Tf    : rms=4.434e-04  max=6.346e-03
#   bc_phi    : rms=1.470e-04  max=6.272e-04
#   bc_Ts     : rms=1.636e-04  max=7.636e-04
#   bc_Tf     : rms=1.633e-04  max=1.360e-03
#   iface     : rms=3.442e-04  max=2.422e-03
#   ic        : rms=2.681e-04  max=1.541e-03
# Raw PDE RMS on obj: phi 0.10525897956739012 Ts 0.08020680746410885 Tf 0.12805046242113055
# [it=660] obj=3.311e-01 feas_raw=6.548e-08 alpha=4.96e-01 beta=5.57e-01 station=7.07e-03 dn=7.07e-03
# blocks (raw c):
#   pde_phi   : rms=2.125e-04  max=2.122e-03
#   pde_Ts    : rms=2.222e-04  max=1.822e-03
#   pde_Tf    : rms=3.758e-04  max=5.091e-03
#   bc_phi    : rms=1.480e-04  max=6.646e-04
#   bc_Ts     : rms=1.577e-04  max=7.158e-04
#   bc_Tf     : rms=1.361e-04  max=8.269e-04
#   iface     : rms=3.341e-04  max=2.409e-03
#   ic        : rms=2.619e-04  max=1.505e-03
# Raw PDE RMS on obj: phi 0.10473654229743637 Ts 0.07934337584322206 Tf 0.1255689565836792
# [it=670] obj=3.244e-01 feas_raw=2.103e-07 alpha=5.97e-01 beta=5.54e-01 station=6.77e-03 dn=6.77e-03
# blocks (raw c):
#   pde_phi   : rms=1.083e-04  max=5.626e-04
#   pde_Ts    : rms=1.984e-04  max=9.444e-04
#   pde_Tf    : rms=1.014e-03  max=1.792e-02
#   bc_phi    : rms=1.405e-04  max=6.267e-04
#   bc_Ts     : rms=1.508e-04  max=6.817e-04
#   bc_Tf     : rms=1.324e-04  max=5.795e-04
#   iface     : rms=3.263e-04  max=2.397e-03
#   ic        : rms=2.536e-04  max=1.461e-03
# Raw PDE RMS on obj: phi 0.10416496348866623 Ts 0.07853624821789011 Tf 0.12369086740005272
# [it=680] obj=3.165e-01 feas_raw=1.801e-07 alpha=6.53e-01 beta=5.51e-01 station=7.13e-03 dn=7.13e-03
# blocks (raw c):
#   pde_phi   : rms=1.474e-04  max=1.011e-03
#   pde_Ts    : rms=1.813e-04  max=1.107e-03
#   pde_Tf    : rms=9.266e-04  max=1.673e-02
#   bc_phi    : rms=1.388e-04  max=5.577e-04
#   bc_Ts     : rms=1.483e-04  max=6.184e-04
#   bc_Tf     : rms=1.255e-04  max=5.902e-04
#   iface     : rms=3.187e-04  max=2.398e-03
#   ic        : rms=2.478e-04  max=1.399e-03
# Raw PDE RMS on obj: phi 0.1033995459389754 Ts 0.07774990270165844 Tf 0.12175031677766127
# [it=690] obj=3.097e-01 feas_raw=4.719e-08 alpha=5.37e-01 beta=5.48e-01 station=5.91e-03 dn=5.91e-03
# blocks (raw c):
#   pde_phi   : rms=1.424e-04  max=9.992e-04
#   pde_Ts    : rms=2.355e-04  max=2.020e-03
#   pde_Tf    : rms=2.600e-04  max=3.061e-03
#   bc_phi    : rms=1.291e-04  max=5.798e-04
#   bc_Ts     : rms=1.414e-04  max=5.856e-04
#   bc_Tf     : rms=1.361e-04  max=9.819e-04
#   iface     : rms=3.113e-04  max=2.353e-03
#   ic        : rms=2.420e-04  max=1.359e-03
# Raw PDE RMS on obj: phi 0.10291550687877979 Ts 0.07688250646760496 Tf 0.11991859993566921
# [it=700] obj=3.038e-01 feas_raw=1.010e-07 alpha=5.87e-01 beta=5.45e-01 station=7.98e-03 dn=7.98e-03
# blocks (raw c):
#   pde_phi   : rms=1.403e-04  max=1.116e-03
#   pde_Ts    : rms=2.363e-04  max=1.747e-03
#   pde_Tf    : rms=6.234e-04  max=1.041e-02
#   bc_phi    : rms=1.265e-04  max=5.812e-04
#   bc_Ts     : rms=1.363e-04  max=5.423e-04
#   bc_Tf     : rms=1.291e-04  max=7.247e-04
#   iface     : rms=3.032e-04  max=2.351e-03
#   ic        : rms=2.370e-04  max=1.355e-03
# Raw PDE RMS on obj: phi 0.10239481447349068 Ts 0.07642686134412006 Tf 0.11842890786740337
# [it=710] obj=2.973e-01 feas_raw=7.934e-08 alpha=5.31e-01 beta=5.42e-01 station=5.95e-03 dn=5.95e-03
# blocks (raw c):
#   pde_phi   : rms=2.007e-04  max=1.409e-03
#   pde_Ts    : rms=1.798e-04  max=1.479e-03
#   pde_Tf    : rms=5.300e-04  max=8.747e-03
#   bc_phi    : rms=1.264e-04  max=5.206e-04
#   bc_Ts     : rms=1.318e-04  max=4.960e-04
#   bc_Tf     : rms=1.162e-04  max=4.694e-04
#   iface     : rms=2.958e-04  max=2.317e-03
#   ic        : rms=2.296e-04  max=1.261e-03
# Raw PDE RMS on obj: phi 0.10179049079606672 Ts 0.07562639633480037 Tf 0.11628885093779494
# [it=720] obj=2.905e-01 feas_raw=9.345e-08 alpha=7.03e-01 beta=5.39e-01 station=6.00e-03 dn=6.00e-03
# blocks (raw c):
#   pde_phi   : rms=8.942e-05  max=5.966e-04
#   pde_Ts    : rms=2.076e-04  max=2.374e-03
#   pde_Tf    : rms=6.162e-04  max=1.068e-02
#   bc_phi    : rms=1.198e-04  max=5.862e-04
#   bc_Ts     : rms=1.267e-04  max=4.643e-04
#   bc_Tf     : rms=1.201e-04  max=5.894e-04
#   iface     : rms=2.869e-04  max=2.312e-03
#   ic        : rms=2.231e-04  max=1.217e-03
# Raw PDE RMS on obj: phi 0.10116548955915054 Ts 0.0746894369862294 Tf 0.11423828609049134
# [it=730] obj=2.832e-01 feas_raw=5.200e-08 alpha=7.69e-01 beta=5.36e-01 station=5.70e-03 dn=5.70e-03
# blocks (raw c):
#   pde_phi   : rms=7.533e-05  max=4.762e-04
#   pde_Ts    : rms=1.556e-04  max=5.998e-04
#   pde_Tf    : rms=4.073e-04  max=6.949e-03
#   bc_phi    : rms=1.101e-04  max=4.818e-04
#   bc_Ts     : rms=1.205e-04  max=4.509e-04
#   bc_Tf     : rms=1.100e-04  max=4.069e-04
#   iface     : rms=2.805e-04  max=2.298e-03
#   ic        : rms=2.178e-04  max=1.142e-03
# Raw PDE RMS on obj: phi 0.10055930138057574 Ts 0.07427621538804492 Tf 0.11221470674242065
# [it=740] obj=2.764e-01 feas_raw=2.959e-08 alpha=6.95e-01 beta=5.33e-01 station=5.00e-03 dn=5.00e-03
# blocks (raw c):
#   pde_phi   : rms=1.032e-04  max=8.901e-04
#   pde_Ts    : rms=1.335e-04  max=5.465e-04
#   pde_Tf    : rms=2.080e-04  max=2.565e-03
#   bc_phi    : rms=1.107e-04  max=5.020e-04
#   bc_Ts     : rms=1.157e-04  max=4.224e-04
#   bc_Tf     : rms=1.097e-04  max=3.695e-04
#   iface     : rms=2.739e-04  max=2.243e-03
#   ic        : rms=2.120e-04  max=1.043e-03
# Raw PDE RMS on obj: phi 0.09987653747506908 Ts 0.07353385835302528 Tf 0.11050047808781899
# [it=750] obj=2.683e-01 feas_raw=3.101e-08 alpha=8.37e-01 beta=5.31e-01 station=5.47e-03 dn=5.47e-03
# blocks (raw c):
#   pde_phi   : rms=8.565e-05  max=8.464e-04
#   pde_Ts    : rms=1.008e-04  max=7.535e-04
#   pde_Tf    : rms=2.618e-04  max=4.072e-03
#   bc_phi    : rms=1.039e-04  max=4.892e-04
#   bc_Ts     : rms=1.113e-04  max=4.167e-04
#   bc_Tf     : rms=1.037e-04  max=3.725e-04
#   iface     : rms=2.653e-04  max=2.233e-03
#   ic        : rms=2.055e-04  max=1.034e-03
# Raw PDE RMS on obj: phi 0.09887336655425964 Ts 0.0726852745649814 Tf 0.10816417476338562
# [it=760] obj=2.619e-01 feas_raw=2.103e-08 alpha=9.16e-01 beta=5.28e-01 station=4.58e-03 dn=4.58e-03
# blocks (raw c):
#   pde_phi   : rms=6.099e-05  max=3.245e-04
#   pde_Ts    : rms=1.280e-04  max=4.551e-04
#   pde_Tf    : rms=1.023e-04  max=7.574e-04
#   bc_phi    : rms=9.967e-05  max=4.621e-04
#   bc_Ts     : rms=1.065e-04  max=3.985e-04
#   bc_Tf     : rms=1.049e-04  max=3.748e-04
#   iface     : rms=2.601e-04  max=2.224e-03
#   ic        : rms=2.013e-04  max=9.758e-04
# Raw PDE RMS on obj: phi 0.09784998649139962 Ts 0.07208819490689342 Tf 0.10608176197287016
# [it=770] obj=2.539e-01 feas_raw=4.383e-08 alpha=5.66e-01 beta=5.25e-01 station=7.74e-03 dn=7.74e-03
# blocks (raw c):
#   pde_phi   : rms=1.365e-04  max=6.741e-04
#   pde_Ts    : rms=2.392e-04  max=1.807e-03
#   pde_Tf    : rms=3.041e-04  max=4.015e-03
#   bc_phi    : rms=1.108e-04  max=6.925e-04
#   bc_Ts     : rms=1.057e-04  max=3.992e-04
#   bc_Tf     : rms=1.205e-04  max=8.191e-04
#   iface     : rms=2.553e-04  max=2.201e-03
#   ic        : rms=1.981e-04  max=9.623e-04
# Raw PDE RMS on obj: phi 0.0970539665770147 Ts 0.07161391244182087 Tf 0.10441650517295883
# [it=780] obj=2.484e-01 feas_raw=2.000e-08 alpha=9.97e-01 beta=5.23e-01 station=4.12e-03 dn=4.12e-03
# blocks (raw c):
#   pde_phi   : rms=4.868e-05  max=1.522e-04
#   pde_Ts    : rms=1.473e-04  max=4.044e-04
#   pde_Tf    : rms=8.954e-05  max=3.800e-04
#   bc_phi    : rms=9.262e-05  max=3.771e-04
#   bc_Ts     : rms=9.952e-05  max=3.832e-04
#   bc_Tf     : rms=1.029e-04  max=3.814e-04
#   iface     : rms=2.478e-04  max=2.118e-03
#   ic        : rms=1.942e-04  max=9.248e-04
# Raw PDE RMS on obj: phi 0.09611840887012826 Ts 0.07093588299341891 Tf 0.10214487775876784
# [it=790] obj=2.415e-01 feas_raw=2.210e-08 alpha=9.92e-01 beta=5.20e-01 station=5.07e-03 dn=5.07e-03
# blocks (raw c):
#   pde_phi   : rms=4.013e-05  max=1.199e-04
#   pde_Ts    : rms=1.523e-04  max=4.073e-04
#   pde_Tf    : rms=1.463e-04  max=7.624e-04
#   bc_phi    : rms=9.214e-05  max=3.952e-04
#   bc_Ts     : rms=9.919e-05  max=3.665e-04
#   bc_Tf     : rms=1.053e-04  max=3.714e-04
#   iface     : rms=2.445e-04  max=2.096e-03
#   ic        : rms=1.901e-04  max=9.225e-04
# Raw PDE RMS on obj: phi 0.09492758266171653 Ts 0.0704818132792031 Tf 0.10023523204223421
# [it=800] obj=2.356e-01 feas_raw=2.306e-08 alpha=9.87e-01 beta=5.17e-01 station=3.82e-03 dn=3.82e-03
# blocks (raw c):
#   pde_phi   : rms=5.408e-05  max=1.632e-04
#   pde_Ts    : rms=1.627e-04  max=5.794e-04
#   pde_Tf    : rms=1.575e-04  max=9.115e-04
#   bc_phi    : rms=9.592e-05  max=3.224e-04
#   bc_Ts     : rms=9.471e-05  max=3.532e-04
#   bc_Tf     : rms=1.007e-04  max=3.669e-04
#   iface     : rms=2.423e-04  max=2.088e-03
#   ic        : rms=1.875e-04  max=8.925e-04
# Raw PDE RMS on obj: phi 0.09388184185362923 Ts 0.0698331908604406 Tf 0.09901109149043484
# [it=810] obj=2.295e-01 feas_raw=2.239e-08 alpha=9.82e-01 beta=5.15e-01 station=4.15e-03 dn=4.15e-03
# blocks (raw c):
#   pde_phi   : rms=6.684e-05  max=1.791e-04
#   pde_Ts    : rms=2.063e-04  max=5.262e-04
#   pde_Tf    : rms=8.748e-05  max=4.176e-04
#   bc_phi    : rms=8.499e-05  max=3.218e-04
#   bc_Ts     : rms=9.512e-05  max=3.375e-04
#   bc_Tf     : rms=9.946e-05  max=3.836e-04
#   iface     : rms=2.387e-04  max=2.075e-03
#   ic        : rms=1.835e-04  max=8.936e-04
# Raw PDE RMS on obj: phi 0.09304657177995933 Ts 0.06945903910219259 Tf 0.097682870657572
# [it=820] obj=2.235e-01 feas_raw=2.297e-08 alpha=8.88e-01 beta=5.12e-01 station=4.48e-03 dn=4.48e-03
# blocks (raw c):
#   pde_phi   : rms=6.917e-05  max=3.878e-04
#   pde_Ts    : rms=1.789e-04  max=4.559e-04
#   pde_Tf    : rms=1.494e-04  max=1.218e-03
#   bc_phi    : rms=8.842e-05  max=3.030e-04
#   bc_Ts     : rms=9.211e-05  max=3.192e-04
#   bc_Tf     : rms=9.719e-05  max=3.749e-04
#   iface     : rms=2.381e-04  max=2.085e-03
#   ic        : rms=1.814e-04  max=8.931e-04
# Raw PDE RMS on obj: phi 0.09187533453728028 Ts 0.06896195431037072 Tf 0.09605669198710928
# [it=830] obj=2.193e-01 feas_raw=1.725e-08 alpha=9.72e-01 beta=5.10e-01 station=4.62e-03 dn=4.62e-03
# blocks (raw c):
#   pde_phi   : rms=5.240e-05  max=1.682e-04
#   pde_Ts    : rms=1.272e-04  max=3.378e-04
#   pde_Tf    : rms=9.219e-05  max=8.142e-04
#   bc_phi    : rms=7.982e-05  max=3.081e-04
#   bc_Ts     : rms=9.067e-05  max=3.082e-04
#   bc_Tf     : rms=9.648e-05  max=3.614e-04
#   iface     : rms=2.370e-04  max=2.041e-03
#   ic        : rms=1.784e-04  max=8.794e-04
# Raw PDE RMS on obj: phi 0.09111255931701569 Ts 0.06847415129165264 Tf 0.094852405386899
# [it=840] obj=2.146e-01 feas_raw=1.920e-08 alpha=9.68e-01 beta=5.07e-01 station=4.48e-03 dn=4.48e-03
# blocks (raw c):
#   pde_phi   : rms=5.199e-05  max=1.615e-04
#   pde_Ts    : rms=1.581e-04  max=5.076e-04
#   pde_Tf    : rms=1.164e-04  max=1.352e-03
#   bc_phi    : rms=7.765e-05  max=3.101e-04
#   bc_Ts     : rms=8.836e-05  max=3.303e-04
#   bc_Tf     : rms=9.327e-05  max=3.657e-04
#   iface     : rms=2.339e-04  max=2.041e-03
#   ic        : rms=1.758e-04  max=8.720e-04
# Raw PDE RMS on obj: phi 0.09043762716978505 Ts 0.06809380888020185 Tf 0.09338718188458675
# [it=850] obj=2.096e-01 feas_raw=2.075e-08 alpha=9.63e-01 beta=5.05e-01 station=4.69e-03 dn=4.69e-03
# blocks (raw c):
#   pde_phi   : rms=6.089e-05  max=1.775e-04
#   pde_Ts    : rms=1.978e-04  max=4.800e-04
#   pde_Tf    : rms=1.013e-04  max=9.699e-04
#   bc_phi    : rms=7.653e-05  max=3.027e-04
#   bc_Ts     : rms=9.103e-05  max=3.396e-04
#   bc_Tf     : rms=9.046e-05  max=3.813e-04
#   iface     : rms=2.309e-04  max=2.049e-03
#   ic        : rms=1.710e-04  max=8.977e-04
# Raw PDE RMS on obj: phi 0.08955372959393554 Ts 0.06780100924820827 Tf 0.09203572607768765
# [it=860] obj=2.064e-01 feas_raw=2.627e-08 alpha=9.58e-01 beta=5.02e-01 station=4.73e-03 dn=4.73e-03
# blocks (raw c):
#   pde_phi   : rms=5.770e-05  max=1.800e-04
#   pde_Ts    : rms=2.524e-04  max=1.049e-03
#   pde_Tf    : rms=1.371e-04  max=1.390e-03
#   bc_phi    : rms=7.414e-05  max=2.506e-04
#   bc_Ts     : rms=9.325e-05  max=3.368e-04
#   bc_Tf     : rms=9.283e-05  max=3.670e-04
#   iface     : rms=2.299e-04  max=2.039e-03
#   ic        : rms=1.692e-04  max=8.344e-04
# Raw PDE RMS on obj: phi 0.08873210973791225 Ts 0.06735938871749683 Tf 0.09116054489255837
# [it=870] obj=2.029e-01 feas_raw=2.184e-08 alpha=8.67e-01 beta=5.00e-01 station=5.49e-03 dn=5.49e-03
# blocks (raw c):
#   pde_phi   : rms=7.240e-05  max=3.844e-04
#   pde_Ts    : rms=1.763e-04  max=8.622e-04
#   pde_Tf    : rms=1.623e-04  max=1.786e-03
#   bc_phi    : rms=7.431e-05  max=2.598e-04
#   bc_Ts     : rms=8.752e-05  max=3.148e-04
#   bc_Tf     : rms=8.877e-05  max=3.680e-04
#   iface     : rms=2.272e-04  max=2.011e-03
#   ic        : rms=1.679e-04  max=8.157e-04
# Raw PDE RMS on obj: phi 0.08799419105861184 Ts 0.06706177241046903 Tf 0.09016113593144412
# [it=880] obj=1.990e-01 feas_raw=1.786e-08 alpha=9.49e-01 beta=4.98e-01 station=4.00e-03 dn=4.00e-03
# blocks (raw c):
# ...
# blocks (raw c):
#   pde_phi   : rms=5.330e-05  max=3.771e-04
#   pde_Ts    : rms=6.499e-05  max=4.422e-04
#   pde_Tf    : rms=5.870e-04  max=1.038e-02
#   bc_phi    : rms=3.522e-05  max=3.591e-04
#   bc_Ts     : rms=3.149e-05  max=1.376e-04
#   bc_Tf     : rms=4.797e-05  max=4.377e-04
#   iface     : rms=7.492e-05  max=5.450e-04
#   ic        : rms=5.080e-05  max=2.284e-04
# Raw PDE RMS on obj: phi 0.03540951250086095 Ts 0.032244037801351745 Tf 0.0356229386105369
# [it=9730] obj=3.545e-02 feas_raw=1.707e-08 alpha=3.32e-01 beta=1.44e-01 station=2.89e-03 dn=2.89e-03
# blocks (raw c):
#   pde_phi   : rms=1.166e-04  max=5.692e-04
#   pde_Ts    : rms=1.716e-04  max=2.161e-03
#   pde_Tf    : rms=2.294e-04  max=3.452e-03
#   bc_phi    : rms=4.840e-05  max=2.990e-04
#   bc_Ts     : rms=4.152e-05  max=2.863e-04
#   bc_Tf     : rms=4.378e-05  max=3.680e-04
#   iface     : rms=7.558e-05  max=5.320e-04
#   ic        : rms=4.927e-05  max=2.288e-04
# Raw PDE RMS on obj: phi 0.03536591478467517 Ts 0.03226046072903681 Tf 0.035278357470969905
# [it=9740] obj=3.544e-02 feas_raw=2.988e-08 alpha=4.42e-01 beta=1.44e-01 station=3.10e-03 dn=3.10e-03
# blocks (raw c):
#   pde_phi   : rms=7.692e-05  max=5.056e-04
#   pde_Ts    : rms=1.058e-04  max=9.288e-04
#   pde_Tf    : rms=3.853e-04  max=6.350e-03
#   bc_phi    : rms=4.322e-05  max=3.865e-04
#   bc_Ts     : rms=4.941e-05  max=3.985e-04
#   bc_Tf     : rms=7.637e-05  max=8.875e-04
#   iface     : rms=7.463e-05  max=5.347e-04
#   ic        : rms=4.940e-05  max=2.317e-04
# Raw PDE RMS on obj: phi 0.035404653501573166 Ts 0.03228618930560523 Tf 0.03535303336990711
# [it=9750] obj=3.541e-02 feas_raw=8.561e-09 alpha=7.11e-01 beta=1.44e-01 station=1.91e-03 dn=1.91e-03
# blocks (raw c):
#   pde_phi   : rms=4.420e-05  max=3.023e-04
#   pde_Ts    : rms=7.699e-05  max=8.573e-04
#   pde_Tf    : rms=1.849e-04  max=3.308e-03
#   bc_phi    : rms=4.087e-05  max=4.791e-04
#   bc_Ts     : rms=3.934e-05  max=2.542e-04
#   bc_Tf     : rms=4.942e-05  max=5.871e-04
#   iface     : rms=7.427e-05  max=5.285e-04
#   ic        : rms=4.955e-05  max=2.278e-04
# Raw PDE RMS on obj: phi 0.035359964994777976 Ts 0.03234449608806859 Tf 0.035350405700601
# [it=9760] obj=3.547e-02 feas_raw=7.788e-08 alpha=6.46e-01 beta=1.44e-01 station=2.41e-03 dn=2.41e-03
# blocks (raw c):
#   pde_phi   : rms=5.251e-05  max=3.708e-04
#   pde_Ts    : rms=7.701e-05  max=6.327e-04
#   pde_Tf    : rms=6.620e-04  max=1.150e-02
#   bc_phi    : rms=2.896e-05  max=1.640e-04
#   bc_Ts     : rms=3.879e-05  max=3.018e-04
#   bc_Tf     : rms=5.924e-05  max=7.194e-04
#   iface     : rms=7.406e-05  max=5.416e-04
#   ic        : rms=5.002e-05  max=2.269e-04
# Raw PDE RMS on obj: phi 0.03539783336372534 Ts 0.03223859668717789 Tf 0.03532255994160317
# [it=9770] obj=3.537e-02 feas_raw=3.046e-08 alpha=7.81e-01 beta=1.43e-01 station=1.94e-03 dn=1.94e-03
# blocks (raw c):
#   pde_phi   : rms=3.052e-05  max=1.723e-04
#   pde_Ts    : rms=5.228e-05  max=6.299e-04
#   pde_Tf    : rms=4.085e-04  max=7.273e-03
#   bc_phi    : rms=3.785e-05  max=4.077e-04
#   bc_Ts     : rms=3.354e-05  max=1.388e-04
#   bc_Tf     : rms=3.449e-05  max=3.309e-04
#   iface     : rms=7.395e-05  max=5.262e-04
#   ic        : rms=5.000e-05  max=2.335e-04
# Raw PDE RMS on obj: phi 0.035328905171332435 Ts 0.03228405450232156 Tf 0.035297682094324524
# [it=9780] obj=3.538e-02 feas_raw=3.294e-08 alpha=7.81e-01 beta=1.43e-01 station=2.12e-03 dn=2.12e-03
# blocks (raw c):
#   pde_phi   : rms=4.103e-05  max=3.431e-04
#   pde_Ts    : rms=5.555e-05  max=4.652e-04
#   pde_Tf    : rms=4.248e-04  max=7.653e-03
#   bc_phi    : rms=2.956e-05  max=1.934e-04
#   bc_Ts     : rms=3.722e-05  max=2.638e-04
#   bc_Tf     : rms=4.179e-05  max=4.659e-04
#   iface     : rms=7.427e-05  max=5.424e-04
#   ic        : rms=4.998e-05  max=2.247e-04
# Raw PDE RMS on obj: phi 0.03528926637008268 Ts 0.032276356750231536 Tf 0.03529796215530537
# [it=9790] obj=3.544e-02 feas_raw=1.445e-08 alpha=3.64e-01 beta=1.43e-01 station=3.17e-03 dn=3.17e-03
# blocks (raw c):
#   pde_phi   : rms=1.312e-04  max=1.123e-03
#   pde_Ts    : rms=1.575e-04  max=1.721e-03
#   pde_Tf    : rms=2.001e-04  max=2.251e-03
#   bc_phi    : rms=3.518e-05  max=2.431e-04
#   bc_Ts     : rms=4.947e-05  max=4.967e-04
#   bc_Tf     : rms=4.299e-05  max=4.405e-04
#   iface     : rms=7.567e-05  max=5.389e-04
#   ic        : rms=5.022e-05  max=2.286e-04
# Raw PDE RMS on obj: phi 0.035320531274539234 Ts 0.032213968584922606 Tf 0.035243995645778
# [it=9800] obj=3.528e-02 feas_raw=5.697e-08 alpha=6.44e-01 beta=1.43e-01 station=2.53e-03 dn=2.53e-03
# blocks (raw c):
#   pde_phi   : rms=8.174e-05  max=5.931e-04
#   pde_Ts    : rms=1.078e-04  max=1.106e-03
#   pde_Tf    : rms=5.548e-04  max=7.459e-03
#   bc_phi    : rms=4.409e-05  max=3.494e-04
#   bc_Ts     : rms=3.884e-05  max=2.473e-04
#   bc_Tf     : rms=4.927e-05  max=4.908e-04
#   iface     : rms=7.381e-05  max=5.282e-04
#   ic        : rms=5.058e-05  max=2.276e-04
# Raw PDE RMS on obj: phi 0.03531822583730627 Ts 0.03222349312646828 Tf 0.03528084237818966
# [it=9810] obj=3.533e-02 feas_raw=1.561e-07 alpha=5.85e-01 beta=1.43e-01 station=2.69e-03 dn=2.69e-03
# blocks (raw c):
#   pde_phi   : rms=6.605e-05  max=5.135e-04
#   pde_Ts    : rms=1.148e-04  max=1.095e-03
#   pde_Tf    : rms=9.418e-04  max=1.680e-02
#   bc_phi    : rms=4.358e-05  max=4.149e-04
#   bc_Ts     : rms=3.914e-05  max=3.144e-04
#   bc_Tf     : rms=2.909e-05  max=1.525e-04
#   iface     : rms=7.397e-05  max=5.333e-04
#   ic        : rms=4.966e-05  max=2.233e-04
# Raw PDE RMS on obj: phi 0.035210093220348376 Ts 0.03224275193547407 Tf 0.03530471227466662
# [it=9820] obj=3.531e-02 feas_raw=1.035e-08 alpha=6.44e-01 beta=1.43e-01 station=1.63e-03 dn=1.63e-03
# blocks (raw c):
#   pde_phi   : rms=5.362e-05  max=4.677e-04
#   pde_Ts    : rms=5.983e-05  max=5.181e-04
#   pde_Tf    : rms=2.170e-04  max=3.822e-03
#   bc_phi    : rms=2.877e-05  max=1.571e-04
#   bc_Ts     : rms=3.583e-05  max=2.288e-04
#   bc_Tf     : rms=5.115e-05  max=4.673e-04
#   iface     : rms=7.386e-05  max=5.266e-04
#   ic        : rms=4.919e-05  max=2.248e-04
# Raw PDE RMS on obj: phi 0.035305755565753195 Ts 0.03221820580764995 Tf 0.03529956610620501
# [it=9830] obj=3.522e-02 feas_raw=2.008e-08 alpha=7.08e-01 beta=1.43e-01 station=1.93e-03 dn=1.93e-03
# blocks (raw c):
#   pde_phi   : rms=6.810e-05  max=6.200e-04
#   pde_Ts    : rms=6.740e-05  max=3.306e-04
#   pde_Tf    : rms=3.190e-04  max=4.661e-03
#   bc_phi    : rms=2.993e-05  max=1.683e-04
#   bc_Ts     : rms=3.418e-05  max=1.657e-04
#   bc_Tf     : rms=5.206e-05  max=6.109e-04
#   iface     : rms=7.384e-05  max=5.253e-04
#   ic        : rms=4.958e-05  max=2.320e-04
# Raw PDE RMS on obj: phi 0.03528551886931262 Ts 0.03221032472159638 Tf 0.03522697590468523
# [it=9840] obj=3.541e-02 feas_raw=1.092e-07 alpha=3.63e-01 beta=1.43e-01 station=3.60e-03 dn=3.60e-03
# blocks (raw c):
#   pde_phi   : rms=8.751e-05  max=4.694e-04
#   pde_Ts    : rms=1.251e-04  max=1.071e-03
#   pde_Tf    : rms=7.712e-04  max=1.310e-02
#   bc_phi    : rms=4.466e-05  max=4.050e-04
#   bc_Ts     : rms=5.731e-05  max=6.242e-04
#   bc_Tf     : rms=1.596e-04  max=2.103e-03
#   iface     : rms=7.510e-05  max=5.259e-04
#   ic        : rms=4.936e-05  max=2.277e-04
# Raw PDE RMS on obj: phi 0.0352748963523178 Ts 0.03227808989105085 Tf 0.03527718264506169
# [it=9850] obj=3.530e-02 feas_raw=1.128e-08 alpha=7.07e-01 beta=1.43e-01 station=2.09e-03 dn=2.09e-03
# blocks (raw c):
#   pde_phi   : rms=4.671e-05  max=3.253e-04
#   pde_Ts    : rms=8.801e-05  max=9.687e-04
#   pde_Tf    : rms=2.232e-04  max=2.893e-03
#   bc_phi    : rms=3.046e-05  max=1.847e-04
#   bc_Ts     : rms=3.217e-05  max=1.395e-04
#   bc_Tf     : rms=2.618e-05  max=1.192e-04
#   iface     : rms=7.439e-05  max=5.368e-04
#   ic        : rms=4.905e-05  max=2.310e-04
# Raw PDE RMS on obj: phi 0.035228673166486854 Ts 0.032241573552695676 Tf 0.03539350629696452
# [it=9860] obj=3.516e-02 feas_raw=1.514e-08 alpha=4.39e-01 beta=1.43e-01 station=2.97e-03 dn=2.97e-03
# blocks (raw c):
#   pde_phi   : rms=9.081e-05  max=3.946e-04
#   pde_Ts    : rms=1.387e-04  max=1.884e-03
#   pde_Tf    : rms=2.334e-04  max=3.112e-03
#   bc_phi    : rms=5.240e-05  max=6.058e-04
#   bc_Ts     : rms=4.629e-05  max=3.373e-04
#   bc_Tf     : rms=4.214e-05  max=2.847e-04
#   iface     : rms=7.508e-05  max=5.321e-04
#   ic        : rms=4.977e-05  max=2.297e-04
# Raw PDE RMS on obj: phi 0.03519686932087828 Ts 0.03215152396644926 Tf 0.03515996130386998
# [it=9870] obj=3.522e-02 feas_raw=2.166e-08 alpha=7.77e-01 beta=1.43e-01 station=2.01e-03 dn=2.01e-03
# blocks (raw c):
#   pde_phi   : rms=5.836e-05  max=6.658e-04
#   pde_Ts    : rms=7.051e-05  max=6.704e-04
#   pde_Tf    : rms=3.351e-04  max=5.690e-03
#   bc_phi    : rms=3.236e-05  max=2.351e-04
#   bc_Ts     : rms=3.272e-05  max=1.402e-04
#   bc_Tf     : rms=3.216e-05  max=3.033e-04
#   iface     : rms=7.283e-05  max=5.263e-04
#   ic        : rms=4.931e-05  max=2.216e-04
# Raw PDE RMS on obj: phi 0.035174105823909174 Ts 0.03226193506394055 Tf 0.035129387217834374
# [it=9880] obj=3.532e-02 feas_raw=6.890e-08 alpha=3.62e-01 beta=1.43e-01 station=3.02e-03 dn=3.02e-03
# blocks (raw c):
#   pde_phi   : rms=1.423e-04  max=1.183e-03
#   pde_Ts    : rms=1.350e-04  max=1.366e-03
#   pde_Tf    : rms=6.019e-04  max=1.073e-02
#   bc_phi    : rms=3.693e-05  max=1.932e-04
#   bc_Ts     : rms=6.151e-05  max=6.643e-04
#   bc_Tf     : rms=3.422e-05  max=3.328e-04
#   iface     : rms=7.423e-05  max=5.329e-04
#   ic        : rms=4.972e-05  max=2.287e-04
# Raw PDE RMS on obj: phi 0.03521554508614975 Ts 0.03218055673533897 Tf 0.035200600153330965
# [it=9890] obj=3.524e-02 feas_raw=1.990e-07 alpha=5.30e-01 beta=1.42e-01 station=2.61e-03 dn=2.61e-03
# blocks (raw c):
#   pde_phi   : rms=8.798e-05  max=7.609e-04
#   pde_Ts    : rms=1.234e-04  max=1.417e-03
#   pde_Tf    : rms=1.064e-03  max=1.962e-02
#   bc_phi    : rms=3.096e-05  max=1.565e-04
#   bc_Ts     : rms=3.648e-05  max=2.559e-04
#   bc_Tf     : rms=5.489e-05  max=6.029e-04
#   iface     : rms=7.327e-05  max=5.208e-04
#   ic        : rms=4.952e-05  max=2.329e-04
# Raw PDE RMS on obj: phi 0.03512887987293658 Ts 0.03216674273024801 Tf 0.035317989921502806
# [it=9900] obj=3.526e-02 feas_raw=1.035e-08 alpha=7.05e-01 beta=1.42e-01 station=1.83e-03 dn=1.83e-03
# blocks (raw c):
#   pde_phi   : rms=5.524e-05  max=4.769e-04
#   pde_Ts    : rms=6.629e-05  max=5.418e-04
#   pde_Tf    : rms=2.162e-04  max=2.487e-03
#   bc_phi    : rms=2.760e-05  max=1.555e-04
#   bc_Ts     : rms=4.070e-05  max=3.326e-04
#   bc_Tf     : rms=2.866e-05  max=2.348e-04
#   iface     : rms=7.510e-05  max=5.229e-04
#   ic        : rms=5.036e-05  max=2.292e-04
# Raw PDE RMS on obj: phi 0.03522127730622646 Ts 0.0322644309770658 Tf 0.03532917591378051
# [it=9910] obj=3.514e-02 feas_raw=1.117e-08 alpha=4.81e-01 beta=1.42e-01 station=2.11e-03 dn=2.11e-03
# blocks (raw c):
#   pde_phi   : rms=9.089e-05  max=6.038e-04
#   pde_Ts    : rms=1.300e-04  max=1.173e-03
#   pde_Tf    : rms=1.814e-04  max=2.343e-03
#   bc_phi    : rms=3.760e-05  max=2.870e-04
#   bc_Ts     : rms=5.584e-05  max=5.944e-04
#   bc_Tf     : rms=6.392e-05  max=6.096e-04
#   iface     : rms=7.415e-05  max=5.315e-04
#   ic        : rms=5.001e-05  max=2.277e-04
# Raw PDE RMS on obj: phi 0.03520167713944777 Ts 0.03217040202031885 Tf 0.035230800110708074
# [it=9920] obj=3.517e-02 feas_raw=8.651e-08 alpha=5.82e-01 beta=1.42e-01 station=2.64e-03 dn=2.64e-03
# blocks (raw c):
#   pde_phi   : rms=6.440e-05  max=4.651e-04
#   pde_Ts    : rms=9.754e-05  max=8.475e-04
#   pde_Tf    : rms=6.961e-04  max=1.051e-02
#   bc_phi    : rms=4.172e-05  max=3.637e-04
#   bc_Ts     : rms=4.807e-05  max=3.821e-04
#   bc_Tf     : rms=2.613e-05  max=1.053e-04
#   iface     : rms=7.481e-05  max=5.406e-04
#   ic        : rms=4.974e-05  max=2.267e-04
# Raw PDE RMS on obj: phi 0.03515513170954065 Ts 0.03218130695609657 Tf 0.035187618031740704
# [it=9930] obj=3.525e-02 feas_raw=1.822e-07 alpha=3.97e-01 beta=1.42e-01 station=3.67e-03 dn=3.67e-03
# blocks (raw c):
#   pde_phi   : rms=1.413e-04  max=1.335e-03
#   pde_Ts    : rms=1.481e-04  max=1.069e-03
#   pde_Tf    : rms=1.006e-03  max=1.805e-02
#   bc_phi    : rms=4.041e-05  max=3.579e-04
#   bc_Ts     : rms=8.338e-05  max=1.005e-03
#   bc_Tf     : rms=1.086e-04  max=1.330e-03
#   iface     : rms=7.325e-05  max=5.200e-04
#   ic        : rms=4.984e-05  max=2.279e-04
# Raw PDE RMS on obj: phi 0.03519716155080317 Ts 0.0321616103635635 Tf 0.035148902569769096
# [it=9940] obj=3.521e-02 feas_raw=5.612e-08 alpha=6.39e-01 beta=1.42e-01 station=2.38e-03 dn=2.38e-03
# blocks (raw c):
#   pde_phi   : rms=8.489e-05  max=9.225e-04
#   pde_Ts    : rms=8.881e-05  max=9.172e-04
#   pde_Tf    : rms=5.518e-04  max=9.851e-03
#   bc_phi    : rms=4.975e-05  max=6.068e-04
#   bc_Ts     : rms=3.205e-05  max=1.357e-04
#   bc_Tf     : rms=7.664e-05  max=9.353e-04
#   iface     : rms=7.336e-05  max=5.176e-04
#   ic        : rms=4.908e-05  max=2.343e-04
# Raw PDE RMS on obj: phi 0.035176796705148776 Ts 0.03216480950007643 Tf 0.03523560010136057
# [it=9950] obj=3.508e-02 feas_raw=1.238e-08 alpha=7.03e-01 beta=1.42e-01 station=1.84e-03 dn=1.84e-03
# blocks (raw c):
#   pde_phi   : rms=5.098e-05  max=3.017e-04
#   pde_Ts    : rms=5.480e-05  max=3.545e-04
#   pde_Tf    : rms=2.452e-04  max=3.834e-03
#   bc_phi    : rms=2.921e-05  max=1.621e-04
#   bc_Ts     : rms=3.514e-05  max=1.936e-04
#   bc_Tf     : rms=4.210e-05  max=3.863e-04
#   iface     : rms=7.408e-05  max=5.385e-04
#   ic        : rms=4.919e-05  max=2.245e-04
# Raw PDE RMS on obj: phi 0.0351264711009897 Ts 0.03213774581824642 Tf 0.035237741304181835
# [it=9960] obj=3.510e-02 feas_raw=1.048e-07 alpha=6.38e-01 beta=1.42e-01 station=2.45e-03 dn=2.45e-03
# blocks (raw c):
#   pde_phi   : rms=8.870e-05  max=8.827e-04
#   pde_Ts    : rms=8.869e-05  max=5.618e-04
#   pde_Tf    : rms=7.684e-04  max=1.415e-02
#   bc_phi    : rms=2.923e-05  max=1.567e-04
#   bc_Ts     : rms=4.354e-05  max=3.890e-04
#   bc_Tf     : rms=4.963e-05  max=5.432e-04
#   iface     : rms=7.431e-05  max=5.412e-04
#   ic        : rms=4.964e-05  max=2.269e-04
# Raw PDE RMS on obj: phi 0.03515458053936945 Ts 0.032181005475217586 Tf 0.03520394820481573
# [it=9970] obj=3.507e-02 feas_raw=2.074e-08 alpha=6.38e-01 beta=1.42e-01 station=2.19e-03 dn=2.19e-03
# blocks (raw c):
#   pde_phi   : rms=6.771e-05  max=5.418e-04
#   pde_Ts    : rms=6.607e-05  max=5.617e-04
#   pde_Tf    : rms=3.248e-04  max=5.352e-03
#   bc_phi    : rms=4.404e-05  max=5.142e-04
#   bc_Ts     : rms=3.959e-05  max=3.250e-04
#   bc_Tf     : rms=3.939e-05  max=3.424e-04
#   iface     : rms=7.374e-05  max=5.243e-04
#   ic        : rms=4.951e-05  max=2.304e-04
# Raw PDE RMS on obj: phi 0.035151184087839994 Ts 0.03217996174711861 Tf 0.035261366737427635
# [it=9980] obj=3.506e-02 feas_raw=3.731e-08 alpha=3.96e-01 beta=1.42e-01 station=2.73e-03 dn=2.73e-03
# blocks (raw c):
#   pde_phi   : rms=1.396e-04  max=1.315e-03
#   pde_Ts    : rms=1.363e-04  max=1.472e-03
#   pde_Tf    : rms=4.127e-04  max=7.374e-03
#   bc_phi    : rms=1.103e-04  max=1.523e-03
#   bc_Ts     : rms=5.154e-05  max=4.294e-04
#   bc_Tf     : rms=4.738e-05  max=5.026e-04
#   iface     : rms=7.533e-05  max=5.294e-04
#   ic        : rms=4.999e-05  max=2.337e-04
# Raw PDE RMS on obj: phi 0.03506113901207223 Ts 0.03215339331897128 Tf 0.03511340264097443
# [it=9990] obj=3.499e-02 feas_raw=1.035e-07 alpha=5.79e-01 beta=1.42e-01 station=3.00e-03 dn=3.00e-03
# blocks (raw c):
#   pde_phi   : rms=7.221e-05  max=5.579e-04
#   pde_Ts    : rms=9.382e-05  max=8.585e-04
#   pde_Tf    : rms=7.630e-04  max=1.382e-02
#   bc_phi    : rms=4.833e-05  max=5.802e-04
#   bc_Ts     : rms=3.212e-05  max=1.353e-04
#   bc_Tf     : rms=6.713e-05  max=7.253e-04
#   iface     : rms=7.443e-05  max=5.356e-04
#   ic        : rms=4.933e-05  max=2.283e-04
# Raw PDE RMS on obj: phi 0.035005277649791194 Ts 0.032061169081347256 Tf 0.035196179726315675
# [it=10000] obj=3.509e-02 feas_raw=6.805e-08 alpha=4.79e-01 beta=1.42e-01 station=2.80e-03 dn=2.80e-03
# blocks (raw c):
#   pde_phi   : rms=9.851e-05  max=6.011e-04
#   pde_Ts    : rms=1.010e-04  max=6.972e-04
#   pde_Tf    : rms=6.105e-04  max=1.044e-02
#   bc_phi    : rms=4.165e-05  max=2.846e-04
#   bc_Ts     : rms=3.871e-05  max=2.965e-04
#   bc_Tf     : rms=3.664e-05  max=2.940e-04
#   iface     : rms=7.479e-05  max=5.275e-04
#   ic        : rms=4.975e-05  max=2.271e-04
# Raw PDE RMS on obj: phi 0.035080611831048415 Ts 0.0321555628287131 Tf 0.03516971106700051
# [done] elapsed=16399.45s
# Saved theta -> theta_sqp_coupled_fixedbatch_jitter3.npy

# %%
# Out:
# ===== COOLANT TOP VALUE CHECK =====
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 print("\n===== COOLANT TOP VALUE CHECK =====")
# ----> 3 jy_top = len(y) - 1
#       4 jy_mid = np.argmin(np.abs(y - 0.5))
#       5 jy_low = np.argmin(np.abs(y - 0.2))
#
# NameError: name 'y' is not defined

# %%
16399.45s
