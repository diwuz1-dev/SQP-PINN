# %%
# Out:
# Generated transport data: t (600,) x (256,) usol (600, 256) c 40.0
# Domain: x=[0.0, 6.283185307179586], t=[0.0, 1.0]
# Traditional ALM-PINN with L-BFGS inner solve:
#   fixed points
#   no jitter
#   no resampling
#   theta inner optimizer: scipy L-BFGS-B
#   lambda update: lambda <- lambda + rho*c
#   rho update: blockwise if feasibility stalls
# PDE residual = (u_t + c*u_x)/sqrt(1+c^2)
# BC_MODE = periodic_value
# USE_PDE_ANCHORS = True
# n_params = 1981
# constraints: pde 900 bc 100 ic 200 total 1200
# objective points = 6400
# network = [2, 30, 30, 30, 1]
# W_PDE_OBJ = 1.0
# TOTAL_LBFGS_BUDGET = 50000
# MAX_OUTER = 50 INNER_MAXITER = 1000
# rho0: pde 1.0 bc 1.0 ic 10.0
# rho_growth = 1.2 rho_max = 1000.0
#
# [OUTER 1/50] rho_pde=1.000e+00, rho_bc=1.000e+00, rho_ic=1.000e+01
# [ALM] outer=001 loss=4.268e-03 obj=2.368e-03 pde=(4.904e-02,3.713e-01) bc=(3.499e-02,1.449e-01) ic=(4.125e-03,1.583e-02) relL2=9.830e-01 best=9.830e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=4.904e-02, bc=3.499e-02, ic=4.125e-02
#       >>> new best relL2=9.830e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER 2/50] rho_pde=1.000e+00, rho_bc=1.000e+00, rho_ic=1.000e+01
# [ALM] outer=002 loss=2.885e-03 obj=1.565e-03 pde=(3.784e-02,1.667e-01) bc=(2.953e-02,7.324e-02) ic=(3.384e-03,1.821e-02) relL2=9.096e-01 best=9.096e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=7.425e-02, bc=2.934e-02, ic=2.540e-02
#       >>> new best relL2=9.096e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER 3/50] rho_pde=1.000e+00, rho_bc=1.000e+00, rho_ic=1.000e+01
# [ALM] outer=003 loss=2.552e-03 obj=1.103e-03 pde=(3.300e-02,1.365e-01) bc=(1.969e-02,5.059e-02) ic=(1.418e-03,4.063e-03) relL2=8.618e-01 best=8.618e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.194e-02, bc=2.883e-02, ic=2.309e-02
#       >>> new best relL2=8.618e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER 4/50] rho_pde=1.000e+00, rho_bc=1.000e+00, rho_ic=1.000e+01
# [ALM] outer=004 loss=3.146e-03 obj=9.578e-04 pde=(2.995e-02,1.054e-01) bc=(1.697e-02,3.622e-02) ic=(1.649e-03,4.521e-03) relL2=8.378e-01 best=8.378e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.123e-01, bc=3.190e-02, ic=2.956e-02
#       >>> new best relL2=8.378e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER 5/50] rho_pde=1.200e+00, rho_bc=1.000e+00, rho_ic=1.200e+01
# [ALM] outer=005 loss=3.476e-03 obj=8.920e-04 pde=(2.889e-02,1.029e-01) bc=(1.135e-02,2.807e-02) ic=(1.261e-03,2.373e-03) relL2=8.148e-01 best=8.148e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.357e-01, bc=3.685e-02, ic=2.810e-02
#       >>> new best relL2=8.148e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER 6/50] rho_pde=1.440e+00, rho_bc=1.000e+00, rho_ic=1.200e+01
# [ALM] outer=006 loss=3.960e-03 obj=8.287e-04 pde=(2.814e-02,9.220e-02) bc=(1.838e-02,5.739e-02) ic=(6.624e-04,1.816e-03) relL2=8.004e-01 best=8.004e-01 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.645e-01, bc=4.006e-02, ic=2.881e-02
#       >>> new best relL2=8.004e-01; saved -> traditional_alm_transport_best.npy
#
# [OUTER
-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.391e-01, bc=6.455e-01, ic=2.258e-01
#
# [OUTER 41/50] rho_pde=1.374e+02, rho_bc=3.834e+01, rho_ic=2.662e+02
# [ALM] outer=041 loss=9.659e-04 obj=1.794e-06 pde=(1.337e-03,3.537e-03) bc=(3.764e-03,1.137e-02) ic=(3.185e-04,8.832e-04) relL2=4.226e-02 best=4.059e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.435e-01, bc=7.001e-01, ic=1.959e-01
#
# [OUTER 42/50] rho_pde=1.374e+02, rho_bc=4.601e+01, rho_ic=3.195e+02
# [ALM] outer=042 loss=1.201e-03 obj=2.007e-06 pde=(1.393e-03,3.811e-03) bc=(2.615e-03,7.422e-03) ic=(2.811e-04,6.226e-04) relL2=4.606e-02 best=4.059e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.678e-01, bc=7.653e-01, ic=1.793e-01
#
# [OUTER 43/50] rho_pde=1.648e+02, rho_bc=4.601e+01, rho_ic=3.195e+02
# [ALM] outer=043 loss=1.271e-03 obj=1.187e-06 pde=(1.082e-03,4.082e-03) bc=(2.895e-03,1.014e-02) ic=(2.873e-04,6.698e-04) relL2=3.202e-02 best=3.202e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.562e-01, bc=8.429e-01, ic=1.403e-01
#       >>> new best relL2=3.202e-02; saved -> traditional_alm_transport_best.npy
#
# [OUTER 44/50] rho_pde=1.648e+02, rho_bc=5.521e+01, rho_ic=3.834e+02
# [ALM] outer=044 loss=1.313e-03 obj=1.093e-06 pde=(1.016e-03,4.059e-03) bc=(2.314e-03,7.669e-03) ic=(2.178e-04,8.163e-04) relL2=3.403e-02 best=3.202e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.792e-01, bc=9.166e-01, ic=1.478e-01
#
# [OUTER 45/50] rho_pde=1.978e+02, rho_bc=5.521e+01, rho_ic=3.834e+02
# [ALM] outer=045 loss=1.390e-03 obj=4.275e-07 pde=(6.612e-04,3.379e-03) bc=(2.650e-03,8.295e-03) ic=(2.381e-04,7.491e-04) relL2=1.443e-02 best=1.443e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.727e-01, bc=9.980e-01, ic=1.743e-01
#       >>> new best relL2=1.443e-02; saved -> traditional_alm_transport_best.npy
#
# [OUTER 46/50] rho_pde=1.978e+02, rho_bc=6.625e+01, rho_ic=4.601e+02
# [ALM] outer=046 loss=1.332e-03 obj=5.384e-07 pde=(7.324e-04,2.388e-03) bc=(2.198e-03,7.533e-03) ic=(2.145e-04,7.087e-04) relL2=1.651e-02 best=1.443e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=9.949e-01, bc=1.075e+00, ic=2.182e-01
#
# [OUTER 47/50] rho_pde=2.374e+02, rho_bc=6.625e+01, rho_ic=5.521e+02
# [ALM] outer=047 loss=1.439e-03 obj=3.912e-07 pde=(6.272e-04,2.845e-03) bc=(2.132e-03,8.565e-03) ic=(1.985e-04,8.683e-04) relL2=1.796e-02 best=1.443e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.008e+00, bc=1.156e+00, ic=2.783e-01
#
# [OUTER 48/50] rho_pde=2.374e+02, rho_bc=7.950e+01, rho_ic=6.625e+02
# [ALM] outer=048 loss=1.460e-03 obj=2.514e-07 pde=(5.064e-04,1.913e-03) bc=(1.903e-03,6.967e-03) ic=(1.222e-04,2.826e-04) relL2=1.431e-02 best=1.431e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.030e+00, bc=1.244e+00, ic=3.361e-01
#       >>> new best relL2=1.431e-02; saved -> traditional_alm_transport_best.npy
#
# [OUTER 49/50] rho_pde=2.374e+02, rho_bc=7.950e+01, rho_ic=6.625e+02
# [ALM] outer=049 loss=1.253e-03 obj=1.326e-06 pde=(1.164e-03,3.145e-03) bc=(3.246e-03,1.393e-02) ic=(1.924e-04,3.654e-04) relL2=1.859e-02 best=1.431e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.064e+00, bc=1.312e+00, ic=3.527e-01
#
# [OUTER 50/50] rho_pde=2.849e+02, rho_bc=9.540e+01, rho_ic=7.950e+02
# [ALM] outer=050 loss=7.922e-04 obj=8.771e-07 pde=(9.393e-04,3.043e-03) bc=(2.543e-03,1.047e-02) ic=(8.404e-05,1.686e-04) relL2=1.046e-02 best=1.046e-02 lbfgs_success=False nit=1000 msg='STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT'
#       lam_rms: pde=1.029e+00, bc=1.378e+00, ic=3.137e-01
#       >>> new best relL2=1.046e-02; saved -> traditional_alm_transport_best.npy
#
# [done] elapsed = 291.14s
# [FINAL] full-grid MSE=5.474142e-05, relL2=1.046317e-02
# [BEST]  outer=50, full-grid MSE=5.474142e-05, relL2=1.046317e-02
# Saved best theta -> traditional_alm_transport_best.npy
# Saved final theta -> traditional_alm_transport_final.npy
# Saved: traditional_alm_transport_best_heatmaps.png
# Saved: traditional_alm_transport_best_heatmaps.pdf
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# ============================================================
# Traditional ALM-PINN for 1D Transport / Advection Equation
# JAX + SciPy L-BFGS-B
#
# PDE:
#     u_t + c u_x = 0, (x,t) in [0, 2*pi] x [0, 1]
#
# IC:
#     u(x,0) = sin(x)
#
# Periodic BC:
#     u(0,t) = u(2*pi,t)
#
# Exact:
#     u(t,x) = sin((x - c*t) mod 2*pi)
#
# ALM:
#     theta^{k+1} approximately minimizes
#         obj(theta) + lambda^T c(theta) + 0.5*rho*||c(theta)||^2
#     lambda <- lambda + rho*c(theta)
#
# This is traditional deterministic ALM:
#   - fixed objective points
#   - fixed PDE/BC/IC constraint points
#   - no jitter
#   - no resampling
#   - full-batch SciPy L-BFGS-B inner solve
#
# This matches your transport SQP setup:
#   - scaled residual: (u_t + c*u_x)/sqrt(1+c^2)
#   - periodic value BC only
#   - no derivative BC
#   - input normalization ON
#   - network [2, 30, 30, 30, 1]
# ============================================================

import os
import time
import math
from functools import partial

import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt

# -----------------------------
# Device
# -----------------------------
USE_CPU = False
CUDA_DEVICE = "0"

if USE_CPU:
    os.environ["JAX_PLATFORMS"] = "cpu"
else:
    os.environ.setdefault("CUDA_VISIBLE_DEVICES", CUDA_DEVICE)

os.environ.setdefault("XLA_FLAGS", "--xla_gpu_autotune_level=0")
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")

import jax
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_matmul_precision", "highest")

import jax.numpy as jnp
from jax import random, grad, vmap


# ============================================================
# Precision
# ============================================================
DTYPE = jnp.float64
EPS = DTYPE(1e-12)


# ============================================================
# Problem setup
# ============================================================
T_FINAL = 1.0
L_DOMAIN = 2.0 * np.pi
C_ADV = 40.0

N_T_REF = 600
N_X_REF = 256

# ============================================================
# Point counts: match your SQP transport setup
# ============================================================
NX_PDE_OBJ = 80
NT_PDE_OBJ = 80
K_PDE_OBJ = NX_PDE_OBJ * NT_PDE_OBJ

NX_PDE_CON = 30
NT_PDE_CON = 30
K_PDE_CON = NX_PDE_CON * NT_PDE_CON

K_BC = 100
K_IC = 200

USE_PDE_ANCHORS = True

# Constraint dimension:
# PDE anchors + periodic value BC + IC
M_CON = K_PDE_CON + K_BC + K_IC


# ============================================================
# Network
# ============================================================
HIDDEN_DIM = 30
NUM_HIDDEN = 3


# ============================================================
# ALM / L-BFGS settings
# ============================================================
W_PDE_OBJ = 10.0

TOTAL_LBFGS_BUDGET = 50000
INNER_MAXITER = 500
MAX_OUTER = int(math.ceil(TOTAL_LBFGS_BUDGET / INNER_MAXITER))

LBFGS_FTOL = 1e-12
LBFGS_GTOL = 1e-8
LBFGS_MAXLS = 50
LBFGS_MAXCOR = 50

RHO_PDE0 = 1.0
RHO_BC0 = 1.0
RHO_IC0 = 10.0

RHO_GROWTH = 1.5
RHO_MAX = 1e2
IMPROVE_THRESHOLD = 0.9

SEED = 0
SAVE_PREFIX = "traditional_alm_transport"
SAVE_BEST = f"{SAVE_PREFIX}_best.npy"
SAVE_FINAL = f"{SAVE_PREFIX}_final.npy"


# ============================================================
# Dataset
# ============================================================
def generate_transport_dataset(T=T_FINAL, L=L_DOMAIN, c=C_ADV, n_t=N_T_REF, n_x=N_X_REF):
    t = np.linspace(0.0, T, n_t)
    x = np.linspace(0.0, L, n_x)
    TT, XX = np.meshgrid(t, x, indexing="ij")
    usol = np.sin((XX - c * TT) % L)
    return t, x, usol, float(c)


def make_grid_points(x_np, t_np):
    TT, XX = np.meshgrid(t_np, x_np, indexing="ij")
    X_grid = np.stack([XX.reshape(-1), TT.reshape(-1)], axis=1)
    return X_grid, TT.shape


# ============================================================
# Network helpers
# ============================================================
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)

    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})

    return params


def normalize_xt(X):
    # X[:,0] = x in [0, L_DOMAIN]
    # X[:,1] = t in [0, T_FINAL]
    x = X[:, 0:1]
    t = X[:, 1:2]

    x_n = DTYPE(2.0) * x / DTYPE(L_DOMAIN) - DTYPE(1.0)
    t_n = DTYPE(2.0) * t / DTYPE(T_FINAL) - DTYPE(1.0)

    return jnp.concatenate([x_n, t_n], axis=1)


def mlp_apply(params, X):
    h = normalize_xt(X)

    for i, layer in enumerate(params):
        h = h @ layer["W"] + layer["b"]
        if i < len(params) - 1:
            h = jnp.tanh(h)

    return h


def flatten_params(params):
    flat_parts = []
    shapes = []

    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))

    return jnp.concatenate(flat_parts).astype(DTYPE), tuple(shapes)


def unflatten_params(theta, shapes):
    params = []
    idx = 0

    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)

        W = theta[idx:idx + W_size].reshape(W_shape)
        idx += W_size

        b = theta[idx:idx + b_size].reshape(b_shape)
        idx += b_size

        params.append({"W": W, "b": b})

    if idx != theta.size:
        raise ValueError(f"Used {idx} parameters but theta has size {theta.size}")

    return params


# ============================================================
# Fixed point sets
# ============================================================
def sample_pde_obj_fixed(key, x_min, x_max, t_min, t_max):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_OBJ)
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_OBJ)

    it, ix = jnp.meshgrid(
        jnp.arange(NT_PDE_OBJ),
        jnp.arange(NX_PDE_OBJ),
        indexing="ij",
    )
    it = it.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)

    x0 = DTYPE(x_min) + DTYPE(ix) * dx
    t0 = DTYPE(t_min) + DTYPE(it) * dt

    u = random.uniform(key, (K_PDE_OBJ, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = x0 + u[:, 0] * dx
    ts = t0 + u[:, 1] * dt

    return jnp.stack([xs, ts], axis=1)


def sample_pde_con_fixed(key, x_min, x_max, t_min, t_max):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_CON)
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_CON)

    it, ix = jnp.meshgrid(
        jnp.arange(NT_PDE_CON),
        jnp.arange(NX_PDE_CON),
        indexing="ij",
    )
    it = it.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)

    x0 = DTYPE(x_min) + DTYPE(ix) * dx
    t0 = DTYPE(t_min) + DTYPE(it) * dt

    u = random.uniform(key, (K_PDE_CON, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = x0 + u[:, 0] * dx
    ts = t0 + u[:, 1] * dt

    return jnp.stack([xs, ts], axis=1)


def sample_bc_fixed(key, x_min, x_max, t_min, t_max):
    # Periodic pair with matched times.
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(K_BC)

    j = jnp.arange(K_BC, dtype=jnp.int32)
    t0 = DTYPE(t_min) + DTYPE(j) * dt

    u = random.uniform(key, (K_BC,), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (t0 + u * dt).reshape(-1, 1)

    XL = jnp.concatenate([DTYPE(x_min) * jnp.ones_like(ts), ts], axis=1)
    XR = jnp.concatenate([DTYPE(x_max) * jnp.ones_like(ts), ts], axis=1)

    return XL, XR


def sample_ic_fixed(key, x_min, x_max, t0):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(K_IC)

    j = jnp.arange(K_IC, dtype=jnp.int32)
    x0 = DTYPE(x_min) + DTYPE(j) * dx

    u = random.uniform(key, (K_IC,), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (x0 + u * dx).reshape(-1, 1)

    ts = DTYPE(t0) * jnp.ones_like(xs)
    Xic = jnp.concatenate([xs, ts], axis=1)

    u0 = jnp.sin(xs[:, 0])

    return Xic, u0


# ============================================================
# PDE residual
# ============================================================
def pde_residual(params, X, c):
    """
    Scaled transport residual:
        r = (u_t + c*u_x) / sqrt(1+c^2)

    Scaling matches your SQP transport code and improves conditioning.
    """
    def u_fun(xt):
        return mlp_apply(params, xt[None, :])[0, 0]

    du = vmap(grad(u_fun))(X)
    u_x = du[:, 0]
    u_t = du[:, 1]

    return (u_t + DTYPE(c) * u_x) / jnp.sqrt(DTYPE(1.0) + DTYPE(c) ** 2)


# ============================================================
# Objective and constraints
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def pde_objective(theta, shapes, X_obj, c, w_pde_obj):
    params = unflatten_params(theta, shapes)
    r = pde_residual(params, X_obj, c)
    return DTYPE(w_pde_obj) * jnp.mean(r ** 2)


@partial(jax.jit, static_argnames=("shapes", "use_pde_anchors"))
def constraint_blocks(theta, shapes,
                      X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic, c,
                      use_pde_anchors: bool):
    params = unflatten_params(theta, shapes)

    if use_pde_anchors:
        c_pde = pde_residual(params, X_pde_con, c)
    else:
        c_pde = jnp.zeros((0,), dtype=DTYPE)

    # Periodic value BC only.
    uL = mlp_apply(params, X_bc_L)[:, 0]
    uR = mlp_apply(params, X_bc_R)[:, 0]
    c_bc = uL - uR

    # IC.
    u_ic = mlp_apply(params, X_ic)[:, 0]
    c_ic = u_ic - u0_ic

    return c_pde, c_bc, c_ic


@partial(jax.jit, static_argnames=("shapes", "use_pde_anchors"))
def alm_loss_and_grad(theta, shapes,
                      lam_pde, lam_bc, lam_ic,
                      rho_pde, rho_bc, rho_ic,
                      X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
                      c, w_pde_obj,
                      use_pde_anchors: bool):
    def loss_fn(th):
        obj = pde_objective(th, shapes, X_obj, c, w_pde_obj)

        c_pde, c_bc, c_ic = constraint_blocks(
            th, shapes,
            X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic, c,
            use_pde_anchors,
        )

        if use_pde_anchors:
            alm_pde = (
                jnp.mean(lam_pde * c_pde)
                + DTYPE(0.5) * DTYPE(rho_pde) * jnp.mean(c_pde ** 2)
            )
            pde_rms = jnp.sqrt(jnp.mean(c_pde ** 2) + EPS)
            pde_max = jnp.max(jnp.abs(c_pde))
        else:
            alm_pde = DTYPE(0.0)
            pde_rms = DTYPE(0.0)
            pde_max = DTYPE(0.0)

        alm_bc = (
            jnp.mean(lam_bc * c_bc)
            + DTYPE(0.5) * DTYPE(rho_bc) * jnp.mean(c_bc ** 2)
        )
        alm_ic = (
            jnp.mean(lam_ic * c_ic)
            + DTYPE(0.5) * DTYPE(rho_ic) * jnp.mean(c_ic ** 2)
        )

        loss = obj + alm_pde + alm_bc + alm_ic

        aux = {
            "obj": obj,
            "alm_pde": alm_pde,
            "alm_bc": alm_bc,
            "alm_ic": alm_ic,
            "pde_rms": pde_rms,
            "bc_rms": jnp.sqrt(jnp.mean(c_bc ** 2) + EPS),
            "ic_rms": jnp.sqrt(jnp.mean(c_ic ** 2) + EPS),
            "pde_max": pde_max,
            "bc_max": jnp.max(jnp.abs(c_bc)),
            "ic_max": jnp.max(jnp.abs(c_ic)),
        }

        return loss, aux

    (loss, aux), g = jax.value_and_grad(loss_fn, has_aux=True)(theta)
    return loss, g, aux


# ============================================================
# Evaluation
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def predict_u(theta, shapes, X):
    params = unflatten_params(theta, shapes)
    return mlp_apply(params, X)[:, 0]


def eval_full_grid(theta, shapes, x_np, t_np, usol_np):
    X_grid_np, grid_shape = make_grid_points(x_np, t_np)
    X_grid = jnp.asarray(X_grid_np, dtype=DTYPE)

    u_pred = np.asarray(predict_u(theta, shapes, X_grid)).reshape(grid_shape)
    u_true = np.asarray(usol_np, dtype=np.float64)

    mse = float(np.mean((u_pred - u_true) ** 2))
    rel_l2 = float(np.linalg.norm(u_pred - u_true) / (np.linalg.norm(u_true) + 1e-12))

    return mse, rel_l2, u_pred


def block_stats(arr):
    arr = np.asarray(arr)
    if arr.size == 0:
        return 0.0, 0.0
    return float(np.sqrt(np.mean(arr ** 2) + 1e-30)), float(np.max(np.abs(arr)))


def save_heatmaps(x_np, t_np, u_true, u_pred, prefix=SAVE_PREFIX):
    err = np.abs(u_pred - u_true)

    fig, axes = plt.subplots(1, 3, figsize=(16, 4.5), constrained_layout=True)

    vmin = min(float(np.min(u_true)), float(np.min(u_pred)))
    vmax = max(float(np.max(u_true)), float(np.max(u_pred)))

    panels = [
        (u_true, "Exact", vmin, vmax),
        (u_pred, "ALM-PINN Prediction", vmin, vmax),
        (err, "Absolute error", None, None),
    ]

    for ax, (arr, title, lo, hi) in zip(axes, panels):
        kwargs = {}
        if lo is not None and hi is not None:
            kwargs["vmin"] = lo
            kwargs["vmax"] = hi

        im = ax.imshow(
            arr.T,
            origin="lower",
            aspect="auto",
            extent=[t_np[0], t_np[-1], x_np[0], x_np[-1]],
            interpolation="nearest",
            **kwargs,
        )
        ax.set_xlabel("t")
        ax.set_ylabel("x")
        ax.set_title(title)
        fig.colorbar(im, ax=ax)

    out_png = f"{prefix}_heatmaps.png"
    out_pdf = f"{prefix}_heatmaps.pdf"

    plt.savefig(out_png, dpi=300)
    plt.savefig(out_pdf)

    print("Saved:", out_png)
    print("Saved:", out_pdf)
    plt.show()


# ============================================================
# SciPy L-BFGS inner solve
# ============================================================
def lbfgs_inner_solve(theta, shapes,
                      lam_pde, lam_bc, lam_ic,
                      rho_pde, rho_bc, rho_ic,
                      X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
                      c, w_pde_obj,
                      use_pde_anchors,
                      maxiter):
    def fun_and_jac(theta_np):
        th = jnp.asarray(theta_np, dtype=DTYPE)

        loss, g, _ = alm_loss_and_grad(
            th, shapes,
            lam_pde, lam_bc, lam_ic,
            DTYPE(rho_pde), DTYPE(rho_bc), DTYPE(rho_ic),
            X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
            DTYPE(c), DTYPE(w_pde_obj),
            use_pde_anchors,
        )

        return float(loss), np.asarray(g, dtype=np.float64)

    theta0_np = np.asarray(theta, dtype=np.float64)

    res = scipy.optimize.minimize(
        fun_and_jac,
        theta0_np,
        method="L-BFGS-B",
        jac=True,
        options={
            "maxiter": int(maxiter),
            "ftol": LBFGS_FTOL,
            "gtol": LBFGS_GTOL,
            "maxls": LBFGS_MAXLS,
            "maxcor": LBFGS_MAXCOR,
            "disp": False,
        },
    )

    return jnp.asarray(res.x, dtype=DTYPE), res


# ============================================================
# Training
# ============================================================
def train_traditional_alm_transport():
    t_np, x_np, usol_np, c = generate_transport_dataset()

    x_min, x_max = float(x_np.min()), float(x_np.max())
    t_min, t_max = float(t_np.min()), float(t_np.max())

    key = random.PRNGKey(SEED)
    key, k_params, k_obj, k_pde, k_bc, k_ic = random.split(key, 6)

    layer_sizes = [2] + [HIDDEN_DIM] * NUM_HIDDEN + [1]
    params0 = init_mlp_params(k_params, layer_sizes)
    theta, shapes = flatten_params(params0)

    X_obj = sample_pde_obj_fixed(k_obj, x_min, x_max, t_min, t_max)
    X_pde_con = sample_pde_con_fixed(k_pde, x_min, x_max, t_min, t_max)
    X_bc_L, X_bc_R = sample_bc_fixed(k_bc, x_min, x_max, t_min, t_max)
    X_ic, u0_ic = sample_ic_fixed(k_ic, x_min, x_max, t_min)

    n_pde = K_PDE_CON if USE_PDE_ANCHORS else 0
    n_bc = K_BC
    n_ic = K_IC
    m_con = n_pde + n_bc + n_ic

    lam_pde = jnp.zeros((n_pde,), dtype=DTYPE)
    lam_bc = jnp.zeros((n_bc,), dtype=DTYPE)
    lam_ic = jnp.zeros((n_ic,), dtype=DTYPE)

    rho_pde = float(RHO_PDE0)
    rho_bc = float(RHO_BC0)
    rho_ic = float(RHO_IC0)

    prev_pde_rms = None
    prev_bc_rms = None
    prev_ic_rms = None

    best_rel = float("inf")
    best_mse = float("inf")
    best_theta = theta
    best_outer = 0

    print("Generated transport data:", "t", t_np.shape, "x", x_np.shape, "usol", usol_np.shape, "c", c)
    print(f"Domain: x=[{x_min}, {x_max}], t=[{t_min}, {t_max}]")
    print("Traditional ALM-PINN with L-BFGS inner solve:")
    print("  fixed points")
    print("  no jitter")
    print("  no resampling")
    print("  theta inner optimizer: scipy L-BFGS-B")
    print("  lambda update: lambda <- lambda + rho*c")
    print("  rho update: blockwise if feasibility stalls")
    print("PDE residual = (u_t + c*u_x)/sqrt(1+c^2)")
    print("BC_MODE = periodic_value")
    print("USE_PDE_ANCHORS =", USE_PDE_ANCHORS)
    print("n_params =", int(theta.size))
    print("constraints: pde", n_pde, "bc", n_bc, "ic", n_ic, "total", m_con)
    print("objective points =", K_PDE_OBJ)
    print("network =", layer_sizes)
    print("W_PDE_OBJ =", W_PDE_OBJ)
    print("TOTAL_LBFGS_BUDGET =", TOTAL_LBFGS_BUDGET)
    print("MAX_OUTER =", MAX_OUTER, "INNER_MAXITER =", INNER_MAXITER)
    print("rho0: pde", rho_pde, "bc", rho_bc, "ic", rho_ic)
    print("rho_growth =", RHO_GROWTH, "rho_max =", RHO_MAX)

    t0_wall = time.time()

    # Warm-up compile
    _ = alm_loss_and_grad(
        theta, shapes,
        lam_pde, lam_bc, lam_ic,
        DTYPE(rho_pde), DTYPE(rho_bc), DTYPE(rho_ic),
        X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
        DTYPE(c), DTYPE(W_PDE_OBJ),
        USE_PDE_ANCHORS,
    )

    for outer in range(1, MAX_OUTER + 1):
        print(
            f"\n[OUTER {outer}/{MAX_OUTER}] "
            f"rho_pde={rho_pde:.3e}, rho_bc={rho_bc:.3e}, rho_ic={rho_ic:.3e}"
        )

        theta, res = lbfgs_inner_solve(
            theta, shapes,
            lam_pde, lam_bc, lam_ic,
            rho_pde, rho_bc, rho_ic,
            X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
            DTYPE(c), DTYPE(W_PDE_OBJ),
            USE_PDE_ANCHORS,
            maxiter=INNER_MAXITER,
        )

        loss, _, aux = alm_loss_and_grad(
            theta, shapes,
            lam_pde, lam_bc, lam_ic,
            DTYPE(rho_pde), DTYPE(rho_bc), DTYPE(rho_ic),
            X_obj, X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
            DTYPE(c), DTYPE(W_PDE_OBJ),
            USE_PDE_ANCHORS,
        )

        c_pde, c_bc, c_ic = constraint_blocks(
            theta, shapes,
            X_pde_con, X_bc_L, X_bc_R, X_ic, u0_ic,
            DTYPE(c),
            USE_PDE_ANCHORS,
        )

        pde_rms, pde_max = block_stats(np.asarray(c_pde))
        bc_rms, bc_max = block_stats(np.asarray(c_bc))
        ic_rms, ic_max = block_stats(np.asarray(c_ic))

        # Classical multiplier update.
        if USE_PDE_ANCHORS:
            lam_pde = lam_pde + DTYPE(rho_pde) * c_pde
        lam_bc = lam_bc + DTYPE(rho_bc) * c_bc
        lam_ic = lam_ic + DTYPE(rho_ic) * c_ic

        # Blockwise rho update.
        if USE_PDE_ANCHORS and prev_pde_rms is not None and pde_rms > IMPROVE_THRESHOLD * prev_pde_rms:
            rho_pde = min(RHO_GROWTH * rho_pde, RHO_MAX)

        if prev_bc_rms is not None and bc_rms > IMPROVE_THRESHOLD * prev_bc_rms:
            rho_bc = min(RHO_GROWTH * rho_bc, RHO_MAX)

        if prev_ic_rms is not None and ic_rms > IMPROVE_THRESHOLD * prev_ic_rms:
            rho_ic = min(RHO_GROWTH * rho_ic, RHO_MAX)

        prev_pde_rms = pde_rms
        prev_bc_rms = bc_rms
        prev_ic_rms = ic_rms

        mse, rel_l2, _ = eval_full_grid(theta, shapes, x_np, t_np, usol_np)

        if rel_l2 < best_rel:
            best_rel = rel_l2
            best_mse = mse
            best_theta = theta
            best_outer = outer
            np.save(SAVE_BEST, np.asarray(best_theta, dtype=np.float64))
            improved = True
        else:
            improved = False

        lam_pde_rms = block_stats(np.asarray(lam_pde))[0]
        lam_bc_rms = block_stats(np.asarray(lam_bc))[0]
        lam_ic_rms = block_stats(np.asarray(lam_ic))[0]

        print(
            f"[ALM] outer={outer:03d} "
            f"loss={float(loss):.3e} "
            f"obj={float(aux['obj']):.3e} "
            f"pde=({pde_rms:.3e},{pde_max:.3e}) "
            f"bc=({bc_rms:.3e},{bc_max:.3e}) "
            f"ic=({ic_rms:.3e},{ic_max:.3e}) "
            f"relL2={rel_l2:.3e} "
            f"best={best_rel:.3e} "
            f"lbfgs_success={res.success} "
            f"nit={res.nit} "
            f"msg='{res.message}'"
        )

        print(
            f"      lam_rms: pde={lam_pde_rms:.3e}, "
            f"bc={lam_bc_rms:.3e}, ic={lam_ic_rms:.3e}"
        )

        if improved:
            print(f"      >>> new best relL2={best_rel:.3e}; saved -> {SAVE_BEST}")

        if not np.isfinite(rel_l2) or not np.isfinite(float(loss)):
            print("Stopping early because non-finite value appeared.")
            break

    elapsed = time.time() - t0_wall

    np.save(SAVE_FINAL, np.asarray(theta, dtype=np.float64))
    print("\n[done] elapsed = {:.2f}s".format(elapsed))
    print(f"[FINAL] full-grid MSE={mse:.6e}, relL2={rel_l2:.6e}")
    print(f"[BEST]  outer={best_outer}, full-grid MSE={best_mse:.6e}, relL2={best_rel:.6e}")
    print("Saved best theta ->", SAVE_BEST)
    print("Saved final theta ->", SAVE_FINAL)

    mse_b, rel_b, u_pred_b = eval_full_grid(best_theta, shapes, x_np, t_np, usol_np)
    save_heatmaps(x_np, t_np, usol_np, u_pred_b, prefix=SAVE_PREFIX + "_best")

    return best_theta, theta, shapes, x_np, t_np, usol_np


if __name__ == "__main__":
    train_traditional_alm_transport()
