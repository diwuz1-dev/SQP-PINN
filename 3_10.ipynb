# %%
## ============================================================
# Stochastic SQP-PINN (JAX) for Nuclear Thermal Coupling (M2PDE Exp2 / MOOSE-style)
# One NN outputs: [phi, Ts, u, v, p, Tf]
#
# FULL VERSION:
#   - block-wise anchor row scaling
#   - region-separated PDE objective/constraints
#   - left BC ramped from IC -> phi.txt
#   - right BC ramped from IC -> 0
#   - top/bottom neutron BC = 0.5
#   - bounded phi with PHI_REF large enough for phi.txt
#   - solid residual scaled consistently with bounded phi
#
# Notes:
#   - SQP tau logic is unchanged
#   - this version fixes the main phi-side compatibility/scaling issues
# ============================================================

import os
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "1")


import time, math
from functools import partial
import numpy as np

import jax
import jax.numpy as jnp
from jax import random, vmap, jacrev, hessian

# -----------------------------
# Precision / dtype
# -----------------------------
USE_X64 = True
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = DTYPE(1e-12)

# ============================================================
# USER SETTINGS
# ============================================================
Ls = DTYPE(0.0076)
Lf = DTYPE(0.0114)
Ly = DTYPE(0.75)
T_end = DTYPE(5.0)

x_min, x_max = DTYPE(0.0), DTYPE(Ls + Lf)
y_min, y_max = DTYPE(0.0), DTYPE(Ly)
t_min, t_max = DTYPE(0.0), DTYPE(T_end)

V_INLET   = DTYPE(0.4)
T_INLET   = DTYPE(560.0)
P_OUTLET  = DTYPE(0.0)

# neutron BC targets
PHI_TOPBOT_VAL = DTYPE(0.5)
PHI_RIGHT_VAL  = DTYPE(0.0)
T_RAMP_PHI     = DTYPE(0.2)

MU_DAMP_FIXED = DTYPE(1e-4)
X_MARGIN = DTYPE(2e-5)

PHI_TXT_PATH = "./phi.txt"

# -----------------------------
# Scaling targets (block-wise)
# -----------------------------
S_TARGET_PDE   = DTYPE(1.0)
S_TARGET_BC    = DTYPE(1.0)
S_TARGET_IF    = DTYPE(1.0)
S_TARGET_IC    = DTYPE(1.0)
S_ROW_MIN      = DTYPE(1e-6)
S_ROW_MAX      = DTYPE(1.0)   # shrink-only

# ============================================================
# DISCRETIZATION
# ============================================================
NX_OBJ, NY_OBJ, NT_OBJ = 16, 16, 16

NX_CON, NY_CON, NT_CON = 6, 8, 6
K_CON = NX_CON * NY_CON * NT_CON
N_PER_CELL = 1

K_BC = 24
N_BC_PER_BIN = 1

NX_IC, NY_IC = 6, 8
K_IC = NX_IC * NY_IC
N_IC_PER_BIN = 1

NY_IF, NT_IF = 8, 6
K_IF = NY_IF * NT_IF
N_IF_PER_BIN = 1

# block sizes
N_PDE    = 6 * K_CON
N_BC_PHI = 4 * K_BC
N_BC_SOL = 3 * K_BC
N_BC_FLD = 11 * K_BC
N_IF     = 4 * K_IF
N_IC     = 5 * K_IC

M_CON = N_PDE + N_BC_PHI + N_BC_SOL + N_BC_FLD + N_IF + N_IC

# ============================================================
# 1) Load phi.txt + bilinear interp (JIT-safe)
# ============================================================
def load_phi_piecewise_multilinear(path: str):
    with open(path, "r") as f:
        lines = [ln.strip() for ln in f if ln.strip()]

    iy = lines.index("AXIS Y")
    it = lines.index("AXIS T")
    idata = lines.index("DATA")

    y_tokens = []
    k = iy + 1
    while k < len(lines) and lines[k] != "AXIS T":
        for tok in lines[k].split():
            try:
                float(tok)
                y_tokens.append(tok)
            except Exception:
                pass
        k += 1
    y = np.array([float(s) for s in y_tokens], dtype=np.float64)

    t_tokens = []
    k = it + 1
    while k < len(lines) and lines[k] != "DATA":
        for tok in lines[k].split():
            try:
                float(tok)
                t_tokens.append(tok)
            except Exception:
                pass
        k += 1
    t = np.array([float(s) for s in t_tokens], dtype=np.float64)

    Ny = len(y)
    Nt = len(t)

    data_tokens = []
    for ln in lines[idata + 1:]:
        for tok in ln.split():
            data_tokens.append(float(tok))
    data = np.array(data_tokens, dtype=np.float64)

    if data.size != Ny * Nt:
        raise ValueError(
            f"phi.txt DATA size mismatch: got {data.size}, expected {Ny*Nt} (Ny={Ny}, Nt={Nt})"
        )

    Z_t_y = data.reshape(Nt, Ny)
    Z_y_t = Z_t_y.T
    return y, t, Z_y_t


y_np, t_np, Z_np = load_phi_piecewise_multilinear(PHI_TXT_PATH)
PHI_Y = jnp.array(y_np, dtype=DTYPE)
PHI_T = jnp.array(t_np, dtype=DTYPE)
PHI_Z = jnp.array(Z_np, dtype=DTYPE)

print(
    "Loaded phi.txt:",
    y_np.shape,
    t_np.shape,
    Z_np.shape,
    "range=",
    float(Z_np.min()),
    float(Z_np.max()),
)

@jax.jit
def phi_bc_yt(y, t, y_grid, t_grid, Z):
    y = jnp.asarray(y, dtype=DTYPE)
    t = jnp.asarray(t, dtype=DTYPE)

    Ny = y_grid.shape[0]
    Nt = t_grid.shape[0]

    iy = jnp.clip(jnp.searchsorted(y_grid, y, side="right") - 1, 0, Ny - 2)
    it = jnp.clip(jnp.searchsorted(t_grid, t, side="right") - 1, 0, Nt - 2)

    y0 = y_grid[iy]
    y1 = y_grid[iy + 1]
    t0 = t_grid[it]
    t1 = t_grid[it + 1]

    wy = (y - y0) / (y1 - y0 + EPS)
    wt = (t - t0) / (t1 - t0 + EPS)

    z00 = Z[iy,     it]
    z10 = Z[iy + 1, it]
    z01 = Z[iy,     it + 1]
    z11 = Z[iy + 1, it + 1]

    z0 = z00 + wy * (z10 - z00)
    z1 = z01 + wy * (z11 - z01)
    return z0 + wt * (z1 - z0)

# ============================================================
# 2) Material laws
# ============================================================
rho_f = DTYPE(11096.0)
rho_s = DTYPE(16020.0)

def safe_T(T):
    return jnp.clip(T, DTYPE(300.0), DTYPE(1200.0))

def mu_f_fun(T):
    T = safe_T(T)
    return DTYPE(4.94e-4) * jnp.exp(DTYPE(754.1) / (T + EPS))

def k_f_fun(T):
    T = safe_T(T)
    return DTYPE(3.61) + DTYPE(1.517e-2) * T - DTYPE(1.741e-6) * T * T

def cp_f_fun(T):
    T = safe_T(T)
    return DTYPE(159.0) - DTYPE(2.72e-2) * T + DTYPE(7.12e-6) * T * T

def cp_s_fun(T):
    T = safe_T(T)
    return (DTYPE(1.359) + DTYPE(0.05812) * T + DTYPE(1.086e6) / (T * T + EPS)) * DTYPE(5.0)

def k_s_fun(T):
    T = safe_T(T)
    c0 = DTYPE(17.5) * (DTYPE(1.0) - DTYPE(0.223)) / (DTYPE(1.0) + DTYPE(0.161))
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c0 + c1 * T + c2 * T * T

POWER_COEF = DTYPE(5e7)

# Neutron
v_neu   = DTYPE(2.416)
D_fuel  = DTYPE(0.008249)
D_fluid = DTYPE(0.01)

def sigma_af_fuel(T):
    T = safe_T(T)
    return (
        DTYPE(2.416) * DTYPE(583.5) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
        - (DTYPE(13.47) * (T - DTYPE(560.0)) / (DTYPE(900.0) - DTYPE(560.0)) + DTYPE(7.53))
          * DTYPE(2.1479) * DTYPE(1.602)
        + DTYPE(0.185) * DTYPE(6.6072) * DTYPE(0.1)
        - DTYPE(680.9) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
    )

def sigma_af_fluid(T):
    T = safe_T(T)
    return -(DTYPE(20.0) + DTYPE(20.0) * (T - DTYPE(560.0)) / (DTYPE(800.0) - DTYPE(560.0)))

# ---- variable-coefficient diffusion helpers ----
def dk_s_dT(T):
    T = safe_T(T)
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c1 + DTYPE(2.0) * c2 * T

def dk_f_dT(T):
    T = safe_T(T)
    a = DTYPE(1.517e-2)
    b = DTYPE(1.741e-6)
    return a - DTYPE(2.0) * b * T

def dmu_f_dT(T):
    T = safe_T(T)
    mu = mu_f_fun(T)
    return mu * (-DTYPE(754.1)) / (T * T + EPS)

def div_k_grad_scalar(k, dk_dT_fun, T, Tx, Ty, Txx, Tyy):
    # div(k(T) grad T) = k*(Txx+Tyy) + dk/dT*(Tx^2+Ty^2)
    return k * (Txx + Tyy) + dk_dT_fun(T) * (Tx * Tx + Ty * Ty)

def div_mu_grad_component(mu, dmu_dT_fun, Tf, Tfx, Tfy, ux, uy, uxx, uyy):
    # div(mu(Tf) grad u) = mu*(uxx+uyy) + dmu/dT*(Tfx*ux + Tfy*uy)
    return mu * (uxx + uyy) + dmu_dT_fun(Tf) * (Tfx * ux + Tfy * uy)

# ============================================================
# Physics-based reference scales
# ============================================================
Lx       = (x_max - x_min) + EPS
Ly_len   = (y_max - y_min) + EPS
Lx_fluid = (x_max - Ls) + EPS
Lx_solid = (Ls - x_min) + EPS

T_SCALE = DTYPE(100.0)
U_SCALE = V_INLET + EPS
P_SCALE = rho_f * (V_INLET ** 2) + EPS

t_ref = Ly_len / U_SCALE

# Must be large enough to cover phi.txt max (~6.2)
PHI_REF = DTYPE(7.0)

D_MAX   = jnp.maximum(D_fuel, D_fluid)
SIG_REF = jnp.maximum(jnp.abs(sigma_af_fuel(T_INLET)), jnp.abs(sigma_af_fluid(T_INLET)))
Lmin    = jnp.minimum(Lx, Ly_len)
R_diff  = D_MAX * PHI_REF / (Lmin ** 2 + EPS)
R_reac  = SIG_REF * PHI_REF
R_time  = PHI_REF / (v_neu * (t_ref + EPS))
PHI_SCALE = R_diff + R_reac + R_time + EPS

GRAD_UY_SCALE  = U_SCALE / Ly_len
GRAD_TY_SCALE  = T_SCALE / Ly_len
GRAD_UX_SCALE  = U_SCALE / Lx_fluid
GRAD_TX_SCALE  = T_SCALE / Lx_fluid
GRAD_PX_SCALE  = P_SCALE / Lx_fluid
GRAD_TSX_SCALE = T_SCALE / Lx_solid

K_REF      = k_s_fun(T_INLET)
DT_REF     = DTYPE(100.0)
FLUX_SCALE = K_REF * DT_REF / Lx_fluid + EPS

CONT_SCALE = U_SCALE / (jnp.minimum(Lx_fluid, Ly_len) + EPS)

# ============================================================
# Targets (phi IC + ramped BC)
# ============================================================
@jax.jit
# ============================================================
# Targets (phi IC + hard BC, no ramp)
# ============================================================
@jax.jit
def phi_ic(y):
    return DTYPE(0.5) + DTYPE(1.5) * jnp.cos(DTYPE(jnp.pi) * (y - DTYPE(0.375)) / DTYPE(0.75))

def phi_left_target(y, t):
    # hard left BC from phi.txt for all t
    t_clip = jnp.clip(t, PHI_T[0], PHI_T[-1])
    return phi_bc_yt(y, t_clip, PHI_Y, PHI_T, PHI_Z)

def phi_right_target(y, t):
    # hard right BC = 0 for all t
    return PHI_RIGHT_VAL * jnp.ones_like(y)

def phi_y_target(y_fixed, t):
    # hard top/bottom BC = 0.5 for all t
    return PHI_TOPBOT_VAL * jnp.ones_like(t)

def inlet_v_profile(x):
    return V_INLET * jnp.ones_like(x)

# ============================================================
# 4) MLP
# ============================================================
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params

def mlp_apply(params, X):
    """
    Network outputs are dimensionless -> map to physical here.

    Outputs:
      phi = PHI_REF * tanh(phi_hat)
      Ts  = T_INLET + TAMP * tanh(Ts_hat)
      u,v = U_SCALE * tanh(u_hat, v_hat)
      p   = P_SCALE * tanh(p_hat)
      Tf  = T_INLET + TAMP * tanh(Tf_hat)
    """
    h = X
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)

    phi_hat = h[:, 0:1]
    Ts_hat  = h[:, 1:2]
    u_hat   = h[:, 2:3]
    v_hat   = h[:, 3:4]
    p_hat   = h[:, 4:5]
    Tf_hat  = h[:, 5:6]

    phi = PHI_REF * jnp.tanh(phi_hat)

    TAMP = DTYPE(20.0)
    Ts = T_INLET + TAMP * jnp.tanh(Ts_hat)
    Tf = T_INLET + TAMP * jnp.tanh(Tf_hat)

    u = U_SCALE * jnp.tanh(u_hat)
    v = U_SCALE * jnp.tanh(v_hat)
    p = P_SCALE * jnp.tanh(p_hat)

    return jnp.concatenate([phi, Ts, u, v, p, Tf], axis=1)

def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)

def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape)
        idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape)
        idx += b_size
        params.append({"W": W, "b": b})
    return params

# ============================================================
# segment sum
# ============================================================
def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)

# ============================================================
# Sampling helpers
# ============================================================
def sample_stratified_3d(key, x0, x1, y0, y1, t0, t1, NX, NY, NT):
    dx = (DTYPE(x1) - DTYPE(x0)) / DTYPE(NX)
    dy = (DTYPE(y1) - DTYPE(y0)) / DTYPE(NY)
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(NT)

    it, iy, ix = jnp.meshgrid(jnp.arange(NT), jnp.arange(NY), jnp.arange(NX), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids = (it * (NY * NX) + iy * NX + ix).astype(jnp.int32)

    xb = DTYPE(x0) + DTYPE(ix) * dx
    yb = DTYPE(y0) + DTYPE(iy) * dy
    tb = DTYPE(t0) + DTYPE(it) * dt

    K = NX * NY * NT
    u = random.uniform(key, (K, 3), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = xb + u[:, 0] * dx
    ys = yb + u[:, 1] * dy
    ts = tb + u[:, 2] * dt
    X = jnp.stack([xs, ys, ts], axis=1)
    return X, ids

def sample_bc_time_binned(key, K, *, x_fixed=None, y_fixed=None, t0=t_min, t1=t_max,
                          x_lo=None, x_hi=None, y_lo=None, y_hi=None):
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(K)
    j = jnp.arange(K, dtype=jnp.int32)
    tb = DTYPE(t0) + DTYPE(j) * dt

    key, kt, kr = random.split(key, 3)
    u_t = random.uniform(kt, (K, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (tb[:, None] + u_t * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    if x_fixed is not None:
        lo = DTYPE(y_min if y_lo is None else y_lo)
        hi = DTYPE(y_max if y_hi is None else y_hi)
        y = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        x = DTYPE(x_fixed) * jnp.ones_like(y)
        return jnp.concatenate([x, y, ts], axis=1), ids

    if y_fixed is not None:
        lo = DTYPE(x_min if x_lo is None else x_lo)
        hi = DTYPE(x_max if x_hi is None else x_hi)
        x = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        y = DTYPE(y_fixed) * jnp.ones_like(x)
        return jnp.concatenate([x, y, ts], axis=1), ids

    raise ValueError("Provide x_fixed or y_fixed")

def sample_ic_xy(key):
    y0 = DTYPE(0.02)
    y1 = y_max - DTYPE(0.02)

    dx = (x_max - x_min) / DTYPE(NX_IC)
    dy = (y1 - y0) / DTYPE(NY_IC)

    iy, ix = jnp.meshgrid(jnp.arange(NY_IC), jnp.arange(NX_IC), indexing="ij")
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids0 = (iy * NX_IC + ix).astype(jnp.int32)

    xb = x_min + DTYPE(ix) * dx
    yb = y0 + DTYPE(iy) * dy

    u = random.uniform(key, (K_IC, N_IC_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (xb[:, None] + u[:, :, 0] * dx).reshape(-1, 1)
    ys = (yb[:, None] + u[:, :, 1] * dy).reshape(-1, 1)
    ts = t_min * jnp.ones_like(xs)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IC_PER_BIN)
    return X, ids

def sample_interface_yt(key):
    dy = (y_max - y_min) / DTYPE(NY_IF)
    dt = (t_max - t_min) / DTYPE(NT_IF)

    it, iy = jnp.meshgrid(jnp.arange(NT_IF), jnp.arange(NY_IF), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ids0 = (it * NY_IF + iy).astype(jnp.int32)

    yb = y_min + DTYPE(iy) * dy
    tb = t_min + DTYPE(it) * dt

    u = random.uniform(key, (NY_IF * NT_IF, N_IF_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    ys = (yb[:, None] + u[:, :, 0] * dy).reshape(-1, 1)
    ts = (tb[:, None] + u[:, :, 1] * dt).reshape(-1, 1)
    xs = Ls * jnp.ones_like(ys)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IF_PER_BIN)
    return X, ids

# ============================================================
# Jitter + projection
# ============================================================
def jitter_xyt(key, X, sx, sy, st, clip_k=2.0):
    if (sx <= 0) and (sy <= 0) and (st <= 0):
        return X
    key, kx, ky, kt = random.split(key, 4)
    dx = DTYPE(sx) * random.normal(kx, (X.shape[0],), dtype=DTYPE)
    dy = DTYPE(sy) * random.normal(ky, (X.shape[0],), dtype=DTYPE)
    dt = DTYPE(st) * random.normal(kt, (X.shape[0],), dtype=DTYPE)
    k = DTYPE(clip_k)
    dx = jnp.clip(dx, -k * DTYPE(sx), +k * DTYPE(sx))
    dy = jnp.clip(dy, -k * DTYPE(sy), +k * DTYPE(sy))
    dt = jnp.clip(dt, -k * DTYPE(st), +k * DTYPE(st))
    x = jnp.clip(X[:, 0] + dx, x_min, x_max)
    y = jnp.clip(X[:, 1] + dy, y_min, y_max)
    t = jnp.clip(X[:, 2] + dt, t_min, t_max)
    return jnp.stack([x, y, t], axis=1)

def project_x_fixed(X, x_fixed):
    return jnp.stack(
        [
            DTYPE(x_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE),
            X[:, 1],
            X[:, 2],
        ],
        axis=1,
    )

def project_y_fixed(X, y_fixed, *, x_lo=None, x_hi=None):
    x = X[:, 0]
    if (x_lo is not None) or (x_hi is not None):
        lo = DTYPE(x_lo if x_lo is not None else x_min)
        hi = DTYPE(x_hi if x_hi is not None else x_max)
        x = jnp.clip(x, lo, hi)
    y = DTYPE(y_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE)
    return jnp.stack([x, y, X[:, 2]], axis=1)

def project_t0(X):
    return jnp.stack(
        [X[:, 0], X[:, 1], t_min * jnp.ones((X.shape[0],), dtype=DTYPE)],
        axis=1,
    )

def project_interface(X):
    return project_x_fixed(X, Ls)

# ============================================================
# PDE residuals
# ============================================================
def forward6(params, xyt):
    return mlp_apply(params, xyt[None, :])[0, :]

def eval_fields_and_derivs(params, X):
    out = vmap(lambda z: forward6(params, z))(X)
    J   = vmap(jacrev(lambda z: forward6(params, z)))(X)
    H   = vmap(hessian(lambda z: forward6(params, z)))(X)
    return out, J, H

def residuals_all(params, X):
    out, J, H = eval_fields_and_derivs(params, X)

    phi = out[:, 0]
    Ts  = out[:, 1]
    u   = out[:, 2]
    v   = out[:, 3]
    p   = out[:, 4]
    Tf  = out[:, 5]

    x = X[:, 0]
    m_s = (x <= Ls).astype(DTYPE)
    m_f = (x >  Ls).astype(DTYPE)

    # neutron
    phi_t  = J[:, 0, 2]
    phi_xx = H[:, 0, 0, 0]
    phi_yy = H[:, 0, 1, 1]
    lap_phi = phi_xx + phi_yy

    # solid
    Ts_x  = J[:, 1, 0]
    Ts_y  = J[:, 1, 1]
    Ts_t  = J[:, 1, 2]
    Ts_xx = H[:, 1, 0, 0]
    Ts_yy = H[:, 1, 1, 1]

    # fluid
    u_x, u_y, u_t = J[:, 2, 0], J[:, 2, 1], J[:, 2, 2]
    v_x, v_y, v_t = J[:, 3, 0], J[:, 3, 1], J[:, 3, 2]
    p_x, p_y      = J[:, 4, 0], J[:, 4, 1]
    Tf_x, Tf_y, Tf_t = J[:, 5, 0], J[:, 5, 1], J[:, 5, 2]

    u_xx, u_yy   = H[:, 2, 0, 0], H[:, 2, 1, 1]
    v_xx, v_yy   = H[:, 3, 0, 0], H[:, 3, 1, 1]
    Tf_xx, Tf_yy = H[:, 5, 0, 0], H[:, 5, 1, 1]

    is_solid = (x <= Ls)
    T_for_sigma = jnp.where(is_solid, Ts, Tf)
    D_here      = jnp.where(is_solid, D_fuel, D_fluid)
    sig_fuel    = sigma_af_fuel(T_for_sigma)
    sig_fluid   = sigma_af_fluid(T_for_sigma)
    sig_here    = jnp.where(is_solid, sig_fuel, sig_fluid)

    r_phi_raw = (DTYPE(1.0) / v_neu) * phi_t - D_here * lap_phi - sig_here * phi
    r_phi = r_phi_raw / PHI_SCALE

    div_k_grad_Ts = div_k_grad_scalar(k_s_fun(Ts), dk_s_dT, Ts, Ts_x, Ts_y, Ts_xx, Ts_yy)
    r_Ts_raw = rho_s * cp_s_fun(Ts) * Ts_t - div_k_grad_Ts - POWER_COEF * phi
    r_Ts = r_Ts_raw / (POWER_COEF * PHI_REF + EPS)

    r_cont = (u_x + v_y) / (CONT_SCALE + EPS)

    mu_here = mu_f_fun(Tf)
    visc_u = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, u_x, u_y, u_xx, u_yy)
    visc_v = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, v_x, v_y, v_xx, v_yy)

    r_u_raw = rho_f * (u_t + u * u_x + v * u_y) + p_x - visc_u
    r_v_raw = rho_f * (v_t + u * v_x + v * v_y) + p_y - visc_v

    cp_here = cp_f_fun(Tf)
    div_k_grad_Tf = div_k_grad_scalar(k_f_fun(Tf), dk_f_dT, Tf, Tf_x, Tf_y, Tf_xx, Tf_yy)
    r_Tf_raw = rho_f * cp_here * (Tf_t + u * Tf_x + v * Tf_y) - div_k_grad_Tf

    r_u  = r_u_raw / rho_f
    r_v  = r_v_raw / rho_f
    r_Tf = r_Tf_raw / (rho_f * cp_here + EPS)

    return r_phi, r_Ts, r_cont, r_u, r_v, r_Tf, m_s, m_f

# ============================================================
# Objective: PDE residual MSE on objective points
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_pde_obj(theta, shapes, X_obj):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        r_phi, r_Ts, r_cont, r_u, r_v, r_Tf, m_s, m_f = residuals_all(params, X_obj)
        term = (r_phi ** 2) + m_s * (r_Ts ** 2) + m_f * (r_cont ** 2 + r_u ** 2 + r_v ** 2 + r_Tf ** 2)
        return jnp.mean(term)
    val, g = jax.value_and_grad(obj_theta)(theta)
    return val, g

# ============================================================
# Constraint vector (UNSCALED) + Jacobian
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector(theta, shapes,
                      X_con, ids_con,
                      X_phi_left, ids_phi_left,
                      X_phi_right, ids_phi_right,
                      X_phi_y0, ids_phi_y0,
                      X_phi_y1, ids_phi_y1,
                      X_Ts_x0, ids_Ts_x0,
                      X_Ts_y0, ids_Ts_y0,
                      X_Ts_y1, ids_Ts_y1,
                      X_f_inlet, ids_f_inlet,
                      X_f_outlet, ids_f_outlet,
                      X_f_right, ids_f_right,
                      X_if, ids_if,
                      X_ic, ids_ic):
    params = unflatten_params(theta, shapes)

    r_phi, r_Ts, r_cont, r_u, r_v, r_Tf, m_s, m_f = residuals_all(params, X_con)

    # PDE constraints (binned)
    c_phi  = segment_sum(r_phi,        ids_con, K_CON) / DTYPE(N_PER_CELL)
    c_Ts   = segment_sum(m_s * r_Ts,   ids_con, K_CON) / DTYPE(N_PER_CELL)
    c_cont = segment_sum(m_f * r_cont, ids_con, K_CON) / DTYPE(N_PER_CELL)
    c_ru   = segment_sum(m_f * r_u,    ids_con, K_CON) / DTYPE(N_PER_CELL)
    c_rv   = segment_sum(m_f * r_v,    ids_con, K_CON) / DTYPE(N_PER_CELL)
    c_rTf  = segment_sum(m_f * r_Tf,   ids_con, K_CON) / DTYPE(N_PER_CELL)

    c_pde = jnp.concatenate([c_phi, c_Ts, c_cont, c_ru, c_rv, c_rTf], axis=0)

    # -------------------------
    # Neutron BCs (4*K_BC)
    # -------------------------
    phiL = mlp_apply(params, X_phi_left)[:, 0]
    yL, tL = X_phi_left[:, 1], X_phi_left[:, 2]
    c_phi_left = segment_sum((phiL - phi_left_target(yL, tL)) / PHI_REF, ids_phi_left, K_BC) / DTYPE(N_BC_PER_BIN)

    phiR = mlp_apply(params, X_phi_right)[:, 0]
    yR, tR = X_phi_right[:, 1], X_phi_right[:, 2]
    c_phi_right = segment_sum((phiR - phi_right_target(yR, tR)) / PHI_REF, ids_phi_right, K_BC) / DTYPE(N_BC_PER_BIN)

    phiB = mlp_apply(params, X_phi_y0)[:, 0]
    tB = X_phi_y0[:, 2]
    c_phi_y0 = segment_sum((phiB - phi_y_target(y_min, tB)) / PHI_REF, ids_phi_y0, K_BC) / DTYPE(N_BC_PER_BIN)

    phiT = mlp_apply(params, X_phi_y1)[:, 0]
    tT = X_phi_y1[:, 2]
    c_phi_y1 = segment_sum((phiT - phi_y_target(y_max, tT)) / PHI_REF, ids_phi_y1, K_BC) / DTYPE(N_BC_PER_BIN)

    c_bc_phi = jnp.concatenate([c_phi_left, c_phi_right, c_phi_y0, c_phi_y1], axis=0)

    # -------------------------
    # Solid BCs (3*K_BC)
    # -------------------------
    def Ts_fun(z):
        return forward6(params, z)[1]

    Tsx_x0 = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_Ts_x0)
    c_Ts_x0 = segment_sum(Tsx_x0 / GRAD_TSX_SCALE, ids_Ts_x0, K_BC) / DTYPE(N_BC_PER_BIN)

    Tsy_y0 = vmap(lambda z: jacrev(Ts_fun)(z)[1])(X_Ts_y0)
    Tsy_y1 = vmap(lambda z: jacrev(Ts_fun)(z)[1])(X_Ts_y1)
    c_Ts_y0 = segment_sum(Tsy_y0 / GRAD_TY_SCALE, ids_Ts_y0, K_BC) / DTYPE(N_BC_PER_BIN)
    c_Ts_y1 = segment_sum(Tsy_y1 / GRAD_TY_SCALE, ids_Ts_y1, K_BC) / DTYPE(N_BC_PER_BIN)

    c_solid_bc = jnp.concatenate([c_Ts_x0, c_Ts_y0, c_Ts_y1], axis=0)

    # -------------------------
    # Fluid BCs (11*K_BC)
    # -------------------------
    def u_fun(z):
        return forward6(params, z)[2]

    def v_fun(z):
        return forward6(params, z)[3]

    def p_fun(z):
        return forward6(params, z)[4]

    def Tf_fun(z):
        return forward6(params, z)[5]

    # inlet y=0
    out_in = mlp_apply(params, X_f_inlet)
    u_in, v_in, Tf_in = out_in[:, 2], out_in[:, 3], out_in[:, 5]
    x_in = X_f_inlet[:, 0]
    v_tar = inlet_v_profile(x_in)

    c_in_u  = segment_sum((u_in - DTYPE(0.0)) / U_SCALE, ids_f_inlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_in_v  = segment_sum((v_in - v_tar) / U_SCALE,      ids_f_inlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_in_Tf = segment_sum((Tf_in - T_INLET) / T_SCALE,   ids_f_inlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_inlet = jnp.concatenate([c_in_u, c_in_v, c_in_Tf], axis=0)

    # outlet y=Ly
    p_out = mlp_apply(params, X_f_outlet)[:, 4]
    c_out_p = segment_sum((p_out - P_OUTLET) / P_SCALE, ids_f_outlet, K_BC) / DTYPE(N_BC_PER_BIN)

    uy_out  = vmap(lambda z: jacrev(u_fun)(z)[1])(X_f_outlet)
    vy_out  = vmap(lambda z: jacrev(v_fun)(z)[1])(X_f_outlet)
    Tfy_out = vmap(lambda z: jacrev(Tf_fun)(z)[1])(X_f_outlet)

    c_out_uy  = segment_sum(uy_out  / GRAD_UY_SCALE, ids_f_outlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_out_vy  = segment_sum(vy_out  / GRAD_UY_SCALE, ids_f_outlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_out_Tfy = segment_sum(Tfy_out / GRAD_TY_SCALE, ids_f_outlet, K_BC) / DTYPE(N_BC_PER_BIN)
    c_outlet = jnp.concatenate([c_out_p, c_out_uy, c_out_vy, c_out_Tfy], axis=0)

    # right symmetry x=x_max: u=0, v_x=0, p_x=0, Tf_x=0
    u_r = mlp_apply(params, X_f_right)[:, 2]
    vx_r  = vmap(lambda z: jacrev(v_fun)(z)[0])(X_f_right)
    px_r  = vmap(lambda z: jacrev(p_fun)(z)[0])(X_f_right)
    Tfx_r = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_f_right)

    c_r_u  = segment_sum(u_r / U_SCALE,       ids_f_right, K_BC) / DTYPE(N_BC_PER_BIN)
    c_r_vx = segment_sum(vx_r / GRAD_UX_SCALE, ids_f_right, K_BC) / DTYPE(N_BC_PER_BIN)
    c_r_px = segment_sum(px_r / GRAD_PX_SCALE, ids_f_right, K_BC) / DTYPE(N_BC_PER_BIN)
    c_r_Tx = segment_sum(Tfx_r / GRAD_TX_SCALE, ids_f_right, K_BC) / DTYPE(N_BC_PER_BIN)
    c_sym = jnp.concatenate([c_r_u, c_r_vx, c_r_px, c_r_Tx], axis=0)

    c_bc_f = jnp.concatenate([c_inlet, c_outlet, c_sym], axis=0)

    # -------------------------
    # Interface (4*K_IF)
    # -------------------------
    out_if = mlp_apply(params, X_if)
    Ts_if, Tf_if = out_if[:, 1], out_if[:, 5]
    u_if, v_if   = out_if[:, 2], out_if[:, 3]

    c_if_T = segment_sum((Ts_if - Tf_if) / T_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    Tsx_if = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_if)
    Tfx_if = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_if)

    q_s = -k_s_fun(Ts_if) * Tsx_if
    q_f = -k_f_fun(Tf_if) * Tfx_if
    c_if_q = segment_sum((q_s - q_f) / FLUX_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    c_if_u = segment_sum(u_if / U_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)
    c_if_v = segment_sum(v_if / U_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)
    c_if = jnp.concatenate([c_if_T, c_if_q, c_if_u, c_if_v], axis=0)

    # -------------------------
    # IC (5*K_IC)
    # -------------------------
    out0 = mlp_apply(params, X_ic)
    phi0 = out0[:, 0]
    Ts0  = out0[:, 1]
    u0   = out0[:, 2]
    v0   = out0[:, 3]
    Tf0  = out0[:, 5]

    x0 = X_ic[:, 0]
    m_s0 = (x0 <= Ls).astype(DTYPE)
    m_f0 = (x0 >  Ls).astype(DTYPE)

    y0 = X_ic[:, 1]
    c_ic_phi = segment_sum((phi0 - phi_ic(y0)) / PHI_REF, ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Ts  = segment_sum(m_s0 * ((Ts0 - T_INLET) / T_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_u   = segment_sum(m_f0 * ((u0  - DTYPE(0.0)) / U_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_v   = segment_sum(m_f0 * ((v0  - DTYPE(0.0)) / U_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Tf  = segment_sum(m_f0 * ((Tf0 - T_INLET) / T_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)

    c_ic = jnp.concatenate([c_ic_phi, c_ic_Ts, c_ic_u, c_ic_v, c_ic_Tf], axis=0)

    return jnp.concatenate([c_pde, c_bc_phi, c_solid_bc, c_bc_f, c_if, c_ic], axis=0)

@partial(jax.jit, static_argnames=("shapes",))
def C_and_J(theta, shapes, *args):
    def c_fun(th):
        return constraint_vector(th, shapes, *args)

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J, c = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c, J

@partial(jax.jit, static_argnames=("shapes",))
def C_only(theta, shapes, *args):
    return constraint_vector(theta, shapes, *args)

# ============================================================
# KKT solve
# ============================================================
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, mu_damp):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)
    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -mu_damp * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)
    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y

# ============================================================
# Zhou-style helpers (unchanged SQP tau logic)
# ============================================================
def cal_tau_mu(H, d, sigma, tau_pre, eps_tau, g, c, mu_eff, y):
    denom = float(g @ d + 0.5 * (d @ (H @ d)))
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    if (denom <= 1e-12) or (delta_c <= 0.0):
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * delta_c / denom
    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)

def cal_ksi_mu(d, tau, ksi_old, eps_ksi, g, c, mu_eff, y):
    d2 = float(jnp.linalg.norm(d) ** 2)
    if d2 <= 1e-18 or tau <= 1e-18:
        return ksi_old
    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    ksi_trial = Dl / (tau * d2)
    ksi_trial = max(0.0, ksi_trial)
    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)

def phi_mu(alpha, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma):
    gd = float(g @ d)
    d2 = float(d @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    term1 = (eta - 1.0) * alpha * beta * Dl
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * c1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3

def cal_alpha_mu(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c, mu_eff, y):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0
    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)
    while (
        phi_mu(1.1 * a, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma) < 0.0
        and (1.1 * a < alpha_min + theta_val * beta)
    ):
        a *= 1.1
    return float(a)

# ============================================================
# BLOCK-WISE ANCHOR SCALING
# ============================================================
def _block_slices():
    s = {}
    i = 0
    s["pde_phi"]  = slice(i, i + K_CON); i += K_CON
    s["pde_Ts"]   = slice(i, i + K_CON); i += K_CON
    s["pde_cont"] = slice(i, i + K_CON); i += K_CON
    s["pde_ru"]   = slice(i, i + K_CON); i += K_CON
    s["pde_rv"]   = slice(i, i + K_CON); i += K_CON
    s["pde_rTf"]  = slice(i, i + K_CON); i += K_CON

    s["bc_phi"]   = slice(i, i + N_BC_PHI); i += N_BC_PHI
    s["bc_solid"] = slice(i, i + N_BC_SOL); i += N_BC_SOL
    s["bc_fluid"] = slice(i, i + N_BC_FLD); i += N_BC_FLD

    s["iface"]    = slice(i, i + N_IF); i += N_IF
    s["ic"]       = slice(i, i + N_IC); i += N_IC
    assert i == M_CON, (i, M_CON)
    return s

BLOCKS = _block_slices()

@jax.jit
def row_rms(J_rows):
    return jnp.sqrt(jnp.mean(J_rows * J_rows, axis=1) + EPS)

@jax.jit
def make_block_row_scales(J, target_pde, target_bc, target_if, target_ic):
    s = jnp.ones((M_CON,), dtype=DTYPE)

    def set_block(name, target):
        sl = BLOCKS[name]
        rr = row_rms(J[sl, :])
        sb = target / jnp.maximum(target, rr)
        sb = jnp.clip(sb, S_ROW_MIN, S_ROW_MAX)
        return rr, sb

    rr_phi,  sb_phi  = set_block("pde_phi",  target_pde)
    rr_Ts,   sb_Ts   = set_block("pde_Ts",   target_pde)
    rr_cont, sb_cont = set_block("pde_cont", target_pde)
    rr_ru,   sb_ru   = set_block("pde_ru",   target_pde)
    rr_rv,   sb_rv   = set_block("pde_rv",   target_pde)
    rr_rTf,  sb_rTf  = set_block("pde_rTf",  target_pde)

    s = s.at[BLOCKS["pde_phi"]].set(sb_phi)
    s = s.at[BLOCKS["pde_Ts"]].set(sb_Ts)
    s = s.at[BLOCKS["pde_cont"]].set(sb_cont)
    s = s.at[BLOCKS["pde_ru"]].set(sb_ru)
    s = s.at[BLOCKS["pde_rv"]].set(sb_rv)
    s = s.at[BLOCKS["pde_rTf"]].set(sb_rTf)

    rr_bcphi, sb_bcphi = set_block("bc_phi", target_bc)
    rr_bcsol, sb_bcsol = set_block("bc_solid", target_bc)
    rr_bcfld, sb_bcfld = set_block("bc_fluid", target_bc)

    s = s.at[BLOCKS["bc_phi"]].set(sb_bcphi)
    s = s.at[BLOCKS["bc_solid"]].set(sb_bcsol)
    s = s.at[BLOCKS["bc_fluid"]].set(sb_bcfld)

    rr_if, sb_if = set_block("iface", target_if)
    rr_ic, sb_ic = set_block("ic", target_ic)

    s = s.at[BLOCKS["iface"]].set(sb_if)
    s = s.at[BLOCKS["ic"]].set(sb_ic)

    diag = jnp.array(
        [
            jnp.min(rr_phi), jnp.median(rr_phi), jnp.max(rr_phi),
            jnp.min(rr_rv),  jnp.median(rr_rv),  jnp.max(rr_rv),
            jnp.min(rr_bcfld), jnp.median(rr_bcfld), jnp.max(rr_bcfld),
            jnp.min(rr_if), jnp.median(rr_if), jnp.max(rr_if),
        ],
        dtype=DTYPE,
    )
    return s, diag

@jax.jit
def apply_row_scale(c, J, s_row):
    return s_row * c, s_row[:, None] * J

def _rms(x):
    return float(jnp.sqrt(jnp.mean(x * x) + 1e-30))

def _maxabs(x):
    return float(jnp.max(jnp.abs(x)))

def print_block_stats(prefix, c):
    def pr(name):
        sl = BLOCKS[name]
        v = c[sl]
        print(f"  {name:10s}: rms={_rms(v):.3e}  max={_maxabs(v):.3e}")

    print(prefix)
    pr("pde_phi")
    pr("pde_Ts")
    pr("pde_cont")
    pr("pde_ru")
    pr("pde_rv")
    pr("pde_rTf")
    pr("bc_phi")
    pr("bc_solid")
    pr("bc_fluid")
    pr("iface")
    pr("ic")

# ============================================================
# Training loop
# ============================================================
def train_sqp(seed=0,
              hidden_dim=35, num_hidden=3,
              max_iters=5000, print_every=10,
              beta_shift=200.0, beta_power=0.6,
              alpha_cap=1e1,
              L_lip=40.0, Gamma_lip=40.0,
              jitter_every_iter=True,
              sx=1e-5, sy=1e-5, st=1e-5,
              sx_ic=1e-5, sy_ic=1e-5,
              sy_if=1e-5, st_if=1e-5,
              w_pde_obj=10.0):

    key = random.PRNGKey(seed)

    layer_sizes = [3] + [hidden_dim] * num_hidden + [6]
    key, k0 = random.split(key, 2)
    params0 = init_mlp_params(k0, layer_sizes)
    theta, shapes = flatten_params(params0)

    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    # objective points: force coverage in both regions
    key, k_obj_s, k_obj_f, k_con = random.split(key, 4)
    X_obj_s, _ = sample_stratified_3d(k_obj_s, x_min, Ls, y_min, y_max, t_min, t_max, NX_OBJ, NY_OBJ, NT_OBJ)
    X_obj_f, _ = sample_stratified_3d(k_obj_f, Ls, x_max, y_min, y_max, t_min, t_max, NX_OBJ, NY_OBJ, NT_OBJ)
    X_obj = jnp.concatenate([X_obj_s, X_obj_f], axis=0)

    X_con, ids_con = sample_stratified_3d(k_con, x_min, x_max, y_min, y_max, t_min, t_max, NX_CON, NY_CON, NT_CON)

    # boundary/interface/ic sets
    key, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k_ic = random.split(key, 13)

    X_phi_left,  ids_phi_left  = sample_bc_time_binned(k1, K_BC, x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_phi_right, ids_phi_right = sample_bc_time_binned(k2, K_BC, x_fixed=x_max, y_lo=y_min, y_hi=y_max)
    X_phi_y0,    ids_phi_y0    = sample_bc_time_binned(k3, K_BC, y_fixed=y_min, x_lo=x_min, x_hi=x_max)
    X_phi_y1,    ids_phi_y1    = sample_bc_time_binned(k4, K_BC, y_fixed=y_max, x_lo=x_min, x_hi=x_max)

    X_Ts_x0, ids_Ts_x0 = sample_bc_time_binned(k5, K_BC, x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_Ts_y0, ids_Ts_y0 = sample_bc_time_binned(k10, K_BC, y_fixed=y_min, x_lo=x_min, x_hi=Ls)
    X_Ts_y1, ids_Ts_y1 = sample_bc_time_binned(k11, K_BC, y_fixed=y_max, x_lo=x_min, x_hi=Ls)

    xL = float(Ls + X_MARGIN)
    xR = float(x_max - X_MARGIN)
    X_f_inlet,  ids_f_inlet  = sample_bc_time_binned(k6, K_BC, y_fixed=y_min, x_lo=xL, x_hi=xR)
    X_f_outlet, ids_f_outlet = sample_bc_time_binned(k7, K_BC, y_fixed=y_max, x_lo=xL, x_hi=xR)
    X_f_right,  ids_f_right  = sample_bc_time_binned(k8, K_BC, x_fixed=x_max, y_lo=y_min, y_hi=y_max)

    X_if, ids_if = sample_interface_yt(k9)
    X_ic, ids_ic = sample_ic_xy(k_ic)

    # line-search params (unchanged)
    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 1.0, 1.0

    print("M_CON =", int(M_CON), "n_params =", int(n))
    print("PHI_SCALE =", float(PHI_SCALE), "FLUX_SCALE =", float(FLUX_SCALE))
    print("PHI_REF =", float(PHI_REF))
    print("T_SCALE =", float(T_SCALE), "U_SCALE =", float(U_SCALE), "P_SCALE =", float(P_SCALE))
    print("CONT_SCALE =", float(CONT_SCALE))
    print("Targets: PDE/BC/IF/IC =", float(S_TARGET_PDE), float(S_TARGET_BC), float(S_TARGET_IF), float(S_TARGET_IC))

    s_row_anchor = None

    t0_clock = time.time()
    for it in range(1, max_iters + 1):
        k_beta = (it // 10) * 10
        beta_k = float(min(1.0, (beta_shift / (beta_shift + k_beta)) ** beta_power))

        if jitter_every_iter:
            key, kj_obj, kj_con, kjL, kjR, kjB, kjT, kjSx, kjSy0, kjSy1, kjIn, kjOut, kjSym, kjIf, kjIc = random.split(key, 15)

            X_obj_use = jitter_xyt(kj_obj, X_obj, sx, sy, st)
            X_con_use = jitter_xyt(kj_con, X_con, sx, sy, st)

            X_phi_left_use  = project_x_fixed(jitter_xyt(kjL, X_phi_left,  0.0, sy, st), x_min)
            X_phi_right_use = project_x_fixed(jitter_xyt(kjR, X_phi_right, 0.0, sy, st), x_max)
            X_phi_y0_use    = project_y_fixed(jitter_xyt(kjB, X_phi_y0, sx, 0.0, st), y_min)
            X_phi_y1_use    = project_y_fixed(jitter_xyt(kjT, X_phi_y1, sx, 0.0, st), y_max)

            X_Ts_x0_use = project_x_fixed(jitter_xyt(kjSx, X_Ts_x0, 0.0, sy, st), x_min)
            X_Ts_y0_use = project_y_fixed(jitter_xyt(kjSy0, X_Ts_y0, sx, 0.0, st), y_min, x_lo=float(x_min), x_hi=float(Ls))
            X_Ts_y1_use = project_y_fixed(jitter_xyt(kjSy1, X_Ts_y1, sx, 0.0, st), y_max, x_lo=float(x_min), x_hi=float(Ls))

            X_f_inlet_use  = project_y_fixed(jitter_xyt(kjIn,  X_f_inlet,  sx, 0.0, st), y_min, x_lo=xL, x_hi=xR)
            X_f_outlet_use = project_y_fixed(jitter_xyt(kjOut, X_f_outlet, sx, 0.0, st), y_max, x_lo=xL, x_hi=xR)
            X_f_right_use  = project_x_fixed(jitter_xyt(kjSym, X_f_right,  0.0, sy, st), x_max)

            X_if_use = project_interface(jitter_xyt(kjIf, X_if, 0.0, sy_if, st_if))
            X_ic_use = project_t0(jitter_xyt(kjIc, X_ic, sx_ic, sy_ic, 0.0))
        else:
            X_obj_use = X_obj
            X_con_use = X_con
            X_phi_left_use, X_phi_right_use, X_phi_y0_use, X_phi_y1_use = X_phi_left, X_phi_right, X_phi_y0, X_phi_y1
            X_Ts_x0_use, X_Ts_y0_use, X_Ts_y1_use = X_Ts_x0, X_Ts_y0, X_Ts_y1
            X_f_inlet_use, X_f_outlet_use, X_f_right_use = X_f_inlet, X_f_outlet, X_f_right
            X_if_use, X_ic_use = X_if, X_ic

        obj_val, g = F_and_g_pde_obj(theta, shapes, X_obj_use)
        g = DTYPE(w_pde_obj) * g

        args = (
            X_con_use, ids_con,
            X_phi_left_use, ids_phi_left,
            X_phi_right_use, ids_phi_right,
            X_phi_y0_use, ids_phi_y0,
            X_phi_y1_use, ids_phi_y1,
            X_Ts_x0_use, ids_Ts_x0,
            X_Ts_y0_use, ids_Ts_y0,
            X_Ts_y1_use, ids_Ts_y1,
            X_f_inlet_use, ids_f_inlet,
            X_f_outlet_use, ids_f_outlet,
            X_f_right_use, ids_f_right,
            X_if_use, ids_if,
            X_ic_use, ids_ic,
        )

        c, J = C_and_J(theta, shapes, *args)

        if s_row_anchor is None:
            s_row_anchor, diag = make_block_row_scales(J, S_TARGET_PDE, S_TARGET_BC, S_TARGET_IF, S_TARGET_IC)

            print("[anchor] applied block-wise row scaling.")
            print(
                "  s_row min/med/max:",
                float(jnp.min(s_row_anchor)),
                float(jnp.median(s_row_anchor)),
                float(jnp.max(s_row_anchor)),
            )
            print("  s_row fraction<1:", float(jnp.mean((s_row_anchor < 0.999).astype(DTYPE))))
            print("  diag(row_rms) [phi min/med/max, rv min/med/max, bc_fluid min/med/max, iface min/med/max]:")
            print(" ", [float(x) for x in diag])

        c_s, J_s = apply_row_scale(c, J, s_row_anchor)

        d, y_s = kkt_solve_once(H, J_s, g, c_s, MU_DAMP_FIXED)

        # map multipliers back
        y = s_row_anchor * y_s

        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-12:
            tau_k = cal_tau_mu(H, d, sigma, tau_k, eps_tau, g, c_s, MU_DAMP_FIXED, y_s)
            ksi_k = cal_ksi_mu(d, tau_k, ksi_k, eps_ksi, g, c_s, MU_DAMP_FIXED, y_s)
            alpha = cal_alpha_mu(d, eta, beta_k, ksi_k, tau_k, L_lip, Gamma_lip, theta_val, g, c_s, MU_DAMP_FIXED, y_s)
        else:
            alpha = 0.0

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d

        if it % int(print_every) == 0:
            c_now = C_only(theta, shapes, *args)

            feas_raw = float(jnp.mean(c_now ** 2))
            feas_s   = float(jnp.mean((s_row_anchor * c_now) ** 2))
            station  = float(jnp.linalg.norm(g + J.T @ y, jnp.inf))

            print(
                f"[it={it}] obj={float(w_pde_obj * obj_val):.3e} feas_raw={feas_raw:.3e} "
                f"feas_s={feas_s:.3e} alpha={alpha:.2e} beta={beta_k:.2e} "
                f"station={station:.2e} tau={tau_k:.3e} dn={dn:.2e}"
            )

            print_block_stats("blocks (unscaled c):", c_now)

            params_now = unflatten_params(theta, shapes)
            r_phi, r_Ts, r_cont, r_u, r_v, r_Tf, ms, mf = residuals_all(params_now, X_obj_use)
            mf_obj = (X_obj_use[:, 0] > Ls).astype(DTYPE)
            ms_obj = DTYPE(1.0) - mf_obj
            print(
                "PDE RMS on obj:",
                "phi", _rms(r_phi),
                "Ts(solid)", _rms(ms_obj * r_Ts),
                "cont(fluid)", _rms(mf_obj * r_cont),
                "ru(fluid)", _rms(mf_obj * r_u),
                "rv(fluid)", _rms(mf_obj * r_v),
                "rTf(fluid)", _rms(mf_obj * r_Tf),
            )

    print(f"[done] elapsed={time.time() - t0_clock:.2f}s")
    return theta

# ============================================================
# Run
# ============================================================
def main():
    theta = train_sqp(
        seed=0,
        hidden_dim=35,
        num_hidden=3,
        max_iters=20000,
        print_every=10,
        beta_shift=800.0,
        beta_power=0.4,
        alpha_cap=1e1,
        L_lip=10.0,
        Gamma_lip=10.0,
        jitter_every_iter=True,
        sx=2e-7,#try 2e-7
        sy=1e-6,#2e-6
        st=1e-5,#5e-5
        sx_ic=2e-7,
        sy_ic=1e-6,
        sy_if=1e-6,
        st_if=1e-5,
        w_pde_obj=10.0,
    )
    np.save("theta_sqp_pinn_exp2_block_anchor_scaled.npy", np.array(theta))
    print("Saved theta -> theta_sqp_pinn_exp2_block_anchor_scaled.npy")

if __name__ == "__main__":
    main()
# Out:
# Loaded phi.txt: (65,) (16,) (65, 16) range= 0.5 6.2
# M_CON = 2592 n_params = 2876
# PHI_SCALE = 1081.5332578341051 FLUX_SCALE = 194095.13007348892
# PHI_REF = 7.0
# T_SCALE = 100.0 U_SCALE = 0.400000000001 P_SCALE = 1775.3600000000013
# CONT_SCALE = 35.08771929217759
# Targets: PDE/BC/IF/IC = 1.0 1.0 1.0 1.0
# [anchor] applied block-wise row scaling.
#   s_row min/med/max: 0.2140773895318467 1.0 1.0
#   s_row fraction<1: 0.011574074074074073
#   diag(row_rms) [phi min/med/max, rv min/med/max, bc_fluid min/med/max, iface min/med/max]:
#   [0.00962390318144111, 0.019232701120766076, 0.12412863380867056, 1e-06, 0.010327352417367052, 0.11334091044104165, 7.640696595966051e-05, 0.019119245147106813, 0.14080741058792381, 0.00017590674776668205, 0.023914693947328414, 0.12928520679172287]
# [it=10] obj=7.174e+01 feas_raw=1.037e+00 feas_s=2.140e-01 alpha=4.94e-02 beta=9.95e-01 station=5.47e+00 tau=1.893e-01 dn=5.47e+00
# blocks (unscaled c):
#   pde_phi   : rms=1.566e-01  max=3.295e-01
#   pde_Ts    : rms=1.856e-01  max=4.168e-01
#   pde_cont  : rms=9.040e-03  max=5.428e-02
#   pde_ru    : rms=1.122e-01  max=5.702e-01
#   pde_rv    : rms=4.105e-02  max=1.649e-01
#   pde_rTf   : rms=3.003e+00  max=1.554e+01
#   bc_phi    : rms=4.415e-01  max=9.984e-01
#   bc_solid  : rms=2.822e-02  max=8.463e-02
#   bc_fluid  : rms=3.100e-01  max=6.953e-01
#   iface     : rms=3.057e-01  max=6.383e-01
#   ic        : rms=1.651e-01  max=4.173e-01
# PDE RMS on obj: phi 0.17480230999583865 Ts(solid) 0.20975707209206362 cont(fluid) 0.008260231115381505 ru(fluid) 0.09187682273231841 rv(fluid) 0.03953125527997889 rTf(fluid) 2.2570508881042617
# [it=20] obj=2.708e+01 feas_raw=5.118e-01 feas_s=6.919e-02 alpha=6.55e-02 beta=9.90e-01 station=2.97e+00 tau=1.893e-01 dn=2.97e+00
# blocks (unscaled c):
#   pde_phi   : rms=4.442e-02  max=1.487e-01
#   pde_Ts    : rms=5.859e-02  max=2.015e-01
#   pde_cont  : rms=7.728e-03  max=6.356e-02
#   pde_ru    : rms=7.103e-02  max=3.452e-01
#   pde_rv    : rms=4.086e-02  max=2.941e-01
#   pde_rTf   : rms=2.130e+00  max=1.423e+01
#   bc_phi    : rms=1.638e-01  max=4.016e-01
#   bc_solid  : rms=4.069e-02  max=1.037e-01
#   bc_fluid  : rms=1.677e-01  max=4.250e-01
#   iface     : rms=1.565e-01  max=3.575e-01
#   ic        : rms=7.462e-02  max=2.766e-01
# PDE RMS on obj: phi 0.06105257483001358 Ts(solid) 0.08483244537792545 cont(fluid) 0.017567874584764245 ru(fluid) 0.0681649643585449 rv(fluid) 0.08130833417827468 rTf(fluid) 1.559465951184263
# [it=30] obj=9.058e+01 feas_raw=2.746e+00 feas_s=1.746e+00 alpha=2.72e-01 beta=9.85e-01 station=1.58e+00 tau=1.893e-01 dn=1.58e+00
# blocks (unscaled c):
#   pde_phi   : rms=2.986e-01  max=7.450e-01
#   pde_Ts    : rms=3.635e-01  max=1.006e+00
#   pde_cont  : rms=2.350e-02  max=1.560e-01
#   pde_ru    : rms=8.085e-02  max=5.230e-01
#   pde_rv    : rms=1.880e-01  max=1.320e+00
#   pde_rTf   : rms=4.920e+00  max=2.303e+01
#   bc_phi    : rms=6.765e-01  max=1.216e+00
#   bc_solid  : rms=1.614e-01  max=6.569e-01
#   bc_fluid  : rms=1.724e-01  max=1.521e+00
#   iface     : rms=1.518e-01  max=6.792e-01
#   ic        : rms=2.243e-01  max=6.068e-01
# PDE RMS on obj: phi 0.3277125026827483 Ts(solid) 0.40095211969706923 cont(fluid) 0.04692467412162753 ru(fluid) 0.10419511821900662 rv(fluid) 0.2635071201107294 rTf(fluid) 4.009829386930785
# [it=40] obj=1.498e+01 feas_raw=7.081e-02 feas_s=6.635e-02 alpha=3.61e-01 beta=9.81e-01 station=9.86e-01 tau=1.893e-01 dn=9.86e-01
# blocks (unscaled c):
#   pde_phi   : rms=1.644e-01  max=6.672e-01
#   pde_Ts    : rms=1.902e-01  max=7.901e-01
#   pde_cont  : rms=9.316e-03  max=9.037e-02
#   pde_ru    : rms=5.895e-02  max=5.102e-01
#   pde_rv    : rms=9.323e-02  max=9.857e-01
#   pde_rTf   : rms=6.963e-01  max=3.840e+00
#   bc_phi    : rms=3.173e-01  max=7.994e-01
#   bc_solid  : rms=1.131e-01  max=3.612e-01
#   bc_fluid  : rms=4.853e-02  max=2.790e-01
#   iface     : rms=4.234e-02  max=2.920e-01
#   ic        : rms=2.105e-01  max=7.105e-01
# PDE RMS on obj: phi 0.19577172312124694 Ts(solid) 0.24654447209716945 cont(fluid) 0.051171264805891875 ru(fluid) 0.07757841053708069 rv(fluid) 0.3750749167458372 rTf(fluid) 0.9547206999900428
# [it=50] obj=2.981e+00 feas_raw=5.858e-03 feas_s=5.851e-03 alpha=6.36e-01 beta=9.76e-01 station=4.99e-01 tau=1.893e-01 dn=4.99e-01
# blocks (unscaled c):
#   pde_phi   : rms=1.068e-01  max=3.936e-01
#   pde_Ts    : rms=1.291e-01  max=4.960e-01
#   pde_cont  : rms=3.991e-03  max=5.765e-02
#   pde_ru    : rms=8.704e-03  max=7.565e-02
#   pde_rv    : rms=4.539e-02  max=6.869e-01
#   pde_rTf   : rms=1.999e-02  max=1.628e-01
#   bc_phi    : rms=2.284e-01  max=5.196e-01
#   bc_solid  : rms=5.300e-02  max=2.241e-01
#   bc_fluid  : rms=5.267e-02  max=4.889e-01
#   iface     : rms=1.018e-02  max=7.118e-02
#   ic        : rms=4.066e-02  max=1.715e-01
# PDE RMS on obj: phi 0.14498781093172441 Ts(solid) 0.1829662153566895 cont(fluid) 0.06401698129116014 ru(fluid) 0.0340095965354622 rv(fluid) 0.4411688512059412 rTf(fluid) 0.023105110718083483
# [it=60] obj=1.551e+00 feas_raw=5.750e-06 feas_s=5.750e-06 alpha=1.23e+00 beta=9.71e-01 station=6.97e-02 tau=1.893e-01 dn=6.97e-02
# blocks (unscaled c):
#   pde_phi   : rms=2.921e-03  max=1.237e-02
#   pde_Ts    : rms=3.441e-03  max=1.522e-02
#   pde_cont  : rms=5.715e-04  max=7.736e-03
#   pde_ru    : rms=3.235e-04  max=2.005e-03
#   pde_rv    : rms=3.516e-03  max=5.598e-02
#   pde_rTf   : rms=1.286e-07  max=8.953e-07
#   bc_phi    : rms=4.554e-03  max=1.520e-02
#   bc_solid  : rms=6.611e-03  max=3.578e-02
#   bc_fluid  : rms=4.457e-04  max=3.125e-03
#   iface     : rms=6.661e-04  max=6.757e-03
#   ic        : rms=5.643e-04  max=1.846e-03
# PDE RMS on obj: phi 0.10454362104719425 Ts(solid) 0.12640180208548796 cont(fluid) 0.05943081076288374 ru(fluid) 0.03396919446753701 rv(fluid) 0.35386405810435806 rTf(fluid) 2.6209793008978476e-07
# [it=70] obj=1.395e+00 feas_raw=4.054e-08 feas_s=4.054e-08 alpha=6.30e-01 beta=9.67e-01 station=2.67e-02 tau=1.893e-01 dn=2.67e-02
# blocks (unscaled c):
#   pde_phi   : rms=2.252e-04  max=8.914e-04
#   pde_Ts    : rms=2.416e-04  max=1.002e-03
#   pde_cont  : rms=1.991e-04  max=7.551e-04
#   pde_ru    : rms=1.260e-04  max=5.544e-04
#   pde_rv    : rms=1.783e-04  max=1.855e-03
#   pde_rTf   : rms=6.206e-08  max=3.497e-07
#   bc_phi    : rms=3.418e-04  max=9.430e-04
#   bc_solid  : rms=4.150e-04  max=2.356e-03
#   bc_fluid  : rms=1.803e-04  max=1.180e-03
#   iface     : rms=1.936e-04  max=6.479e-04
#   ic        : rms=1.949e-04  max=6.624e-04
# PDE RMS on obj: phi 0.09993491709890272 Ts(solid) 0.1193331218778022 cont(fluid) 0.0577738118146981 ru(fluid) 0.034342987156979754 rv(fluid) 0.3319130490440851 rTf(fluid) 1.3778609327618354e-07
# [it=80] obj=1.315e+00 feas_raw=4.325e-08 feas_s=4.325e-08 alpha=1.01e+00 beta=9.63e-01 station=1.53e-02 tau=1.893e-01 dn=1.53e-02
# blocks (unscaled c):
#   pde_phi   : rms=2.788e-04  max=1.037e-03
#   pde_Ts    : rms=3.280e-04  max=1.323e-03
#   pde_cont  : rms=1.753e-04  max=7.211e-04
#   pde_ru    : rms=1.093e-04  max=4.426e-04
#   pde_rv    : rms=9.638e-05  max=4.619e-04
#   pde_rTf   : rms=8.362e-08  max=6.126e-07
#   bc_phi    : rms=4.808e-04  max=1.154e-03
#   bc_solid  : rms=1.994e-04  max=7.709e-04
#   bc_fluid  : rms=1.687e-04  max=1.135e-03
#   iface     : rms=1.579e-04  max=5.312e-04
#   ic        : rms=1.636e-04  max=6.111e-04
# PDE RMS on obj: phi 0.0977670822722862 Ts(solid) 0.11427469190686079 cont(fluid) 0.056643517244164915 ru(fluid) 0.03517702684579579 rv(fluid) 0.32147889448250744 rTf(fluid) 1.4912432243802242e-07
# [it=90] obj=1.233e+00 feas_raw=1.455e-08 feas_s=1.455e-08 alpha=5.16e-01 beta=9.58e-01 station=1.60e-02 tau=1.893e-01 dn=1.60e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.215e-04  max=4.775e-04
#   pde_Ts    : rms=1.294e-04  max=5.332e-04
#   pde_cont  : rms=1.609e-04  max=6.903e-04
#   pde_ru    : rms=9.876e-05  max=3.901e-04
#   pde_rv    : rms=8.159e-05  max=3.268e-04
#   pde_rTf   : rms=9.453e-08  max=7.021e-07
#   bc_phi    : rms=1.790e-04  max=4.325e-04
#   bc_solid  : rms=1.302e-04  max=6.428e-04
#   bc_fluid  : rms=1.598e-04  max=1.071e-03
#   iface     : rms=1.401e-04  max=5.059e-04
#   ic        : rms=8.310e-05  max=3.341e-04
# PDE RMS on obj: phi 0.09586536826751385 Ts(solid) 0.10962855611106172 cont(fluid) 0.05544096636902982 ru(fluid) 0.03632175149628318 rv(fluid) 0.311801264762433 rTf(fluid) 1.3858310619523906e-07
# [it=100] obj=1.189e+00 feas_raw=1.106e-08 feas_s=1.106e-08 alpha=3.51e-01 beta=9.54e-01 station=1.66e-02 tau=1.893e-01 dn=1.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.780e-05  max=4.328e-04
#   pde_Ts    : rms=8.457e-05  max=3.579e-04
#   pde_cont  : rms=1.540e-04  max=6.891e-04
#   pde_ru    : rms=9.446e-05  max=3.627e-04
#   pde_rv    : rms=7.976e-05  max=4.528e-04
#   pde_rTf   : rms=9.723e-08  max=7.147e-07
#   bc_phi    : rms=1.162e-04  max=2.865e-04
#   bc_solid  : rms=1.109e-04  max=5.701e-04
#   bc_fluid  : rms=1.548e-04  max=1.034e-03
#   iface     : rms=1.334e-04  max=5.020e-04
#   ic        : rms=7.165e-05  max=3.466e-04
# PDE RMS on obj: phi 0.09485709417761935 Ts(solid) 0.10721478365240684 cont(fluid) 0.05472709703770282 ru(fluid) 0.03713017843406692 rv(fluid) 0.30613745915697255 rTf(fluid) 1.3534191966496498e-07
# [it=110] obj=1.161e+00 feas_raw=9.701e-09 feas_s=9.701e-09 alpha=2.39e-01 beta=9.50e-01 station=1.69e-02 tau=1.893e-01 dn=1.69e-02
# blocks (unscaled c):
#   pde_phi   : rms=6.892e-05  max=4.016e-04
#   pde_Ts    : rms=5.763e-05  max=3.111e-04
#   pde_cont  : rms=1.502e-04  max=6.884e-04
#   pde_ru    : rms=9.180e-05  max=3.455e-04
#   pde_rv    : rms=8.853e-05  max=8.077e-04
#   pde_rTf   : rms=9.833e-08  max=7.216e-07
#   bc_phi    : rms=7.139e-05  max=1.916e-04
#   bc_solid  : rms=9.949e-05  max=5.251e-04
#   bc_fluid  : rms=1.514e-04  max=1.009e-03
#   iface     : rms=1.300e-04  max=5.015e-04
#   ic        : rms=6.888e-05  max=3.400e-04
# PDE RMS on obj: phi 0.09427432950457705 Ts(solid) 0.10583492631081515 cont(fluid) 0.05425532204506447 ru(fluid) 0.03771682292181791 rv(fluid) 0.3023990717421474 rTf(fluid) 1.3493757910244257e-07
# [it=120] obj=1.142e+00 feas_raw=8.933e-09 feas_s=8.933e-09 alpha=1.78e-01 beta=9.46e-01 station=1.71e-02 tau=1.893e-01 dn=1.71e-02
# blocks (unscaled c):
#   pde_phi   : rms=6.105e-05  max=3.871e-04
#   pde_Ts    : rms=4.633e-05  max=2.983e-04
#   pde_cont  : rms=1.476e-04  max=6.877e-04
#   pde_ru    : rms=9.001e-05  max=3.384e-04
#   pde_rv    : rms=7.948e-05  max=5.118e-04
#   pde_rTf   : rms=9.886e-08  max=7.358e-07
#   bc_phi    : rms=5.419e-05  max=1.349e-04
#   bc_solid  : rms=9.367e-05  max=4.946e-04
#   bc_fluid  : rms=1.491e-04  max=9.919e-04
#   iface     : rms=1.279e-04  max=5.017e-04
#   ic        : rms=6.800e-05  max=3.350e-04
# PDE RMS on obj: phi 0.09389949635602089 Ts(solid) 0.10495926511429476 cont(fluid) 0.0539242902135755 ru(fluid) 0.03815493216153894 rv(fluid) 0.29972043055915476 rTf(fluid) 1.3487615908087528e-07
# [it=130] obj=1.127e+00 feas_raw=8.439e-09 feas_s=8.439e-09 alpha=1.33e-01 beta=9.42e-01 station=1.74e-02 tau=1.893e-01 dn=1.74e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.650e-05  max=3.778e-04
#   pde_Ts    : rms=3.995e-05  max=2.906e-04
#   pde_cont  : rms=1.457e-04  max=6.869e-04
#   pde_ru    : rms=8.875e-05  max=3.327e-04
#   pde_rv    : rms=7.183e-05  max=3.058e-04
#   pde_rTf   : rms=9.889e-08  max=7.438e-07
#   bc_phi    : rms=4.061e-05  max=1.047e-04
#   bc_solid  : rms=8.893e-05  max=4.718e-04
#   bc_fluid  : rms=1.473e-04  max=9.790e-04
#   iface     : rms=1.266e-04  max=5.020e-04
#   ic        : rms=6.754e-05  max=3.304e-04
# PDE RMS on obj: phi 0.09363062443262539 Ts(solid) 0.10433205225235043 cont(fluid) 0.05367025964815646 ru(fluid) 0.03851562800979567 rv(fluid) 0.2976295929366356 rTf(fluid) 1.3462881671938897e-07
# [it=140] obj=1.114e+00 feas_raw=8.709e-09 feas_s=8.709e-09 alpha=1.33e-01 beta=9.38e-01 station=1.75e-02 tau=1.893e-01 dn=1.75e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.624e-05  max=3.739e-04
#   pde_Ts    : rms=3.718e-05  max=2.871e-04
#   pde_cont  : rms=1.442e-04  max=6.859e-04
#   pde_ru    : rms=8.773e-05  max=3.277e-04
#   pde_rv    : rms=9.740e-05  max=1.141e-03
#   pde_rTf   : rms=9.864e-08  max=7.482e-07
#   bc_phi    : rms=3.261e-05  max=7.982e-05
#   bc_solid  : rms=8.466e-05  max=4.521e-04
#   bc_fluid  : rms=1.458e-04  max=9.686e-04
#   iface     : rms=1.253e-04  max=5.026e-04
#   ic        : rms=6.724e-05  max=3.298e-04
# PDE RMS on obj: phi 0.09340656271225219 Ts(solid) 0.10380931193732454 cont(fluid) 0.053439550977138525 ru(fluid) 0.03884925746198301 rv(fluid) 0.29570541958346036 rTf(fluid) 1.342003450967793e-07
# [it=150] obj=1.103e+00 feas_raw=8.019e-09 feas_s=8.019e-09 alpha=1.09e-01 beta=9.34e-01 station=1.77e-02 tau=1.893e-01 dn=1.77e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.238e-05  max=3.702e-04
#   pde_Ts    : rms=3.507e-05  max=2.839e-04
#   pde_cont  : rms=1.427e-04  max=6.848e-04
#   pde_ru    : rms=8.679e-05  max=3.232e-04
#   pde_rv    : rms=7.089e-05  max=2.997e-04
#   pde_rTf   : rms=9.828e-08  max=7.509e-07
#   bc_phi    : rms=3.309e-05  max=1.135e-04
#   bc_solid  : rms=8.277e-05  max=4.361e-04
#   bc_fluid  : rms=1.445e-04  max=9.596e-04
#   iface     : rms=1.244e-04  max=5.029e-04
#   ic        : rms=6.700e-05  max=3.318e-04
# PDE RMS on obj: phi 0.09323094732052063 Ts(solid) 0.10339377646586725 cont(fluid) 0.05325000538691964 ru(fluid) 0.039138964551470604 rv(fluid) 0.294110678684145 rTf(fluid) 1.3378021613090776e-07
# [it=160] obj=1.093e+00 feas_raw=8.182e-09 feas_s=8.182e-09 alpha=1.09e-01 beta=9.30e-01 station=1.78e-02 tau=1.893e-01 dn=1.78e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.170e-05  max=3.681e-04
#   pde_Ts    : rms=3.330e-05  max=2.821e-04
#   pde_cont  : rms=1.415e-04  max=6.835e-04
#   pde_ru    : rms=8.590e-05  max=3.189e-04
#   pde_rv    : rms=8.888e-05  max=9.103e-04
#   pde_rTf   : rms=9.793e-08  max=7.536e-07
#   bc_phi    : rms=2.861e-05  max=9.607e-05
#   bc_solid  : rms=7.943e-05  max=4.213e-04
#   bc_fluid  : rms=1.432e-04  max=9.501e-04
#   iface     : rms=1.235e-04  max=5.031e-04
#   ic        : rms=6.681e-05  max=3.323e-04
# PDE RMS on obj: phi 0.09307282175180415 Ts(solid) 0.10301665904749156 cont(fluid) 0.05306556433559406 ru(fluid) 0.03942407362618245 rv(fluid) 0.29253962609412987 rTf(fluid) 1.334467729568844e-07
# [it=170] obj=1.084e+00 feas_raw=7.761e-09 feas_s=7.761e-09 alpha=9.86e-02 beta=9.26e-01 station=1.79e-02 tau=1.893e-01 dn=1.79e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.022e-05  max=3.660e-04
#   pde_Ts    : rms=3.272e-05  max=2.806e-04
#   pde_cont  : rms=1.404e-04  max=6.821e-04
#   pde_ru    : rms=8.514e-05  max=3.150e-04
#   pde_rv    : rms=7.246e-05  max=3.053e-04
#   pde_rTf   : rms=9.740e-08  max=7.542e-07
#   bc_phi    : rms=2.478e-05  max=8.397e-05
#   bc_solid  : rms=7.911e-05  max=4.080e-04
#   bc_fluid  : rms=1.421e-04  max=9.432e-04
#   iface     : rms=1.228e-04  max=5.033e-04
#   ic        : rms=6.664e-05  max=3.329e-04
# PDE RMS on obj: phi 0.09293315557742858 Ts(solid) 0.1026830065519302 cont(fluid) 0.05289262248812648 ru(fluid) 0.039692661157200576 rv(fluid) 0.29106589724553145 rTf(fluid) 1.3291907221328858e-07
# [it=180] obj=1.075e+00 feas_raw=9.035e-09 feas_s=9.035e-09 alpha=1.19e-01 beta=9.22e-01 station=1.81e-02 tau=1.893e-01 dn=1.81e-02
# blocks (unscaled c):
#   pde_phi   : rms=5.185e-05  max=3.656e-04
#   pde_Ts    : rms=3.144e-05  max=2.804e-04
#   pde_cont  : rms=1.396e-04  max=6.805e-04
#   pde_ru    : rms=8.437e-05  max=3.125e-04
#   pde_rv    : rms=1.325e-04  max=1.918e-03
#   pde_rTf   : rms=9.679e-08  max=7.541e-07
#   bc_phi    : rms=2.391e-05  max=6.007e-05
#   bc_solid  : rms=7.503e-05  max=3.957e-04
#   bc_fluid  : rms=1.410e-04  max=9.391e-04
#   iface     : rms=1.222e-04  max=5.034e-04
#   ic        : rms=6.649e-05  max=3.329e-04
# PDE RMS on obj: phi 0.0928069589709561 Ts(solid) 0.10237680727947208 cont(fluid) 0.05273325841074483 ru(fluid) 0.039956879772635984 rv(fluid) 0.28964794868033034 rTf(fluid) 1.3234423944486218e-07
# [it=190] obj=1.066e+00 feas_raw=7.500e-09 feas_s=7.500e-09 alpha=8.89e-02 beta=9.18e-01 station=1.82e-02 tau=1.893e-01 dn=1.82e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.857e-05  max=3.639e-04
#   pde_Ts    : rms=3.115e-05  max=2.799e-04
#   pde_cont  : rms=1.382e-04  max=6.787e-04
#   pde_ru    : rms=8.365e-05  max=3.139e-04
#   pde_rv    : rms=7.062e-05  max=2.899e-04
#   pde_rTf   : rms=9.602e-08  max=7.523e-07
#   bc_phi    : rms=2.142e-05  max=6.970e-05
#   bc_solid  : rms=7.462e-05  max=3.842e-04
#   bc_fluid  : rms=1.401e-04  max=9.354e-04
#   iface     : rms=1.218e-04  max=5.034e-04
#   ic        : rms=6.635e-05  max=3.330e-04
# PDE RMS on obj: phi 0.09269069133499178 Ts(solid) 0.1020905335305445 cont(fluid) 0.052575078480626036 ru(fluid) 0.04021845291377418 rv(fluid) 0.2882508487251348 rTf(fluid) 1.3161468094173598e-07
# [it=200] obj=1.057e+00 feas_raw=7.409e-09 feas_s=7.409e-09 alpha=8.86e-02 beta=9.15e-01 station=1.84e-02 tau=1.893e-01 dn=1.84e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.829e-05  max=3.639e-04
#   pde_Ts    : rms=3.053e-05  max=2.796e-04
#   pde_cont  : rms=1.374e-04  max=6.769e-04
#   pde_ru    : rms=8.309e-05  max=3.153e-04
#   pde_rv    : rms=7.069e-05  max=2.878e-04
#   pde_rTf   : rms=9.523e-08  max=7.503e-07
#   bc_phi    : rms=2.350e-05  max=1.098e-04
#   bc_solid  : rms=7.194e-05  max=3.737e-04
#   bc_fluid  : rms=1.392e-04  max=9.320e-04
#   iface     : rms=1.210e-04  max=5.032e-04
#   ic        : rms=6.623e-05  max=3.332e-04
# PDE RMS on obj: phi 0.09258792316435255 Ts(solid) 0.10183300695980868 cont(fluid) 0.0524285987499126 ru(fluid) 0.04046837626753704 rv(fluid) 0.2869447983543668 rTf(fluid) 1.3090018359135887e-07
# [it=210] obj=1.049e+00 feas_raw=7.272e-09 feas_s=7.272e-09 alpha=8.82e-02 beta=9.11e-01 station=1.85e-02 tau=1.893e-01 dn=1.85e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.763e-05  max=3.646e-04
#   pde_Ts    : rms=3.084e-05  max=2.804e-04
#   pde_cont  : rms=1.363e-04  max=6.748e-04
#   pde_ru    : rms=8.236e-05  max=3.166e-04
#   pde_rv    : rms=6.818e-05  max=2.856e-04
#   pde_rTf   : rms=9.423e-08  max=7.466e-07
#   bc_phi    : rms=2.011e-05  max=5.713e-05
#   bc_solid  : rms=7.011e-05  max=3.630e-04
#   bc_fluid  : rms=1.383e-04  max=9.286e-04
#   iface     : rms=1.205e-04  max=5.029e-04
#   ic        : rms=6.613e-05  max=3.322e-04
# PDE RMS on obj: phi 0.09248553926770202 Ts(solid) 0.10157193928913871 cont(fluid) 0.052277338237142805 ru(fluid) 0.04073336919046269 rv(fluid) 0.2855623462068099 rTf(fluid) 1.3004637122166105e-07
# [it=220] obj=1.041e+00 feas_raw=7.188e-09 feas_s=7.188e-09 alpha=8.79e-02 beta=9.07e-01 station=1.86e-02 tau=1.893e-01 dn=1.86e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.698e-05  max=3.635e-04
#   pde_Ts    : rms=3.030e-05  max=2.795e-04
#   pde_cont  : rms=1.354e-04  max=6.727e-04
#   pde_ru    : rms=8.174e-05  max=3.177e-04
#   pde_rv    : rms=6.860e-05  max=2.835e-04
#   pde_rTf   : rms=9.341e-08  max=7.439e-07
#   bc_phi    : rms=1.973e-05  max=7.183e-05
#   bc_solid  : rms=6.865e-05  max=3.534e-04
#   bc_fluid  : rms=1.374e-04  max=9.249e-04
#   iface     : rms=1.200e-04  max=5.024e-04
#   ic        : rms=6.602e-05  max=3.324e-04
# PDE RMS on obj: phi 0.09239553639585371 Ts(solid) 0.1013371435185376 cont(fluid) 0.05213497574439119 ru(fluid) 0.04098220497223141 rv(fluid) 0.28424895368141345 rTf(fluid) 1.2953079895614125e-07
# [it=230] obj=1.032e+00 feas_raw=7.254e-09 feas_s=7.254e-09 alpha=1.06e-01 beta=9.04e-01 station=1.86e-02 tau=1.893e-01 dn=1.86e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.702e-05  max=3.645e-04
#   pde_Ts    : rms=3.025e-05  max=2.803e-04
#   pde_cont  : rms=1.344e-04  max=6.702e-04
#   pde_ru    : rms=8.114e-05  max=3.189e-04
#   pde_rv    : rms=7.728e-05  max=6.026e-04
#   pde_rTf   : rms=9.256e-08  max=7.412e-07
#   bc_phi    : rms=2.092e-05  max=8.202e-05
#   bc_solid  : rms=6.764e-05  max=3.436e-04
#   bc_fluid  : rms=1.365e-04  max=9.211e-04
#   iface     : rms=1.196e-04  max=5.018e-04
#   ic        : rms=6.593e-05  max=3.316e-04
# PDE RMS on obj: phi 0.09230461295259204 Ts(solid) 0.10109144745083785 cont(fluid) 0.05198460566071538 ru(fluid) 0.04125537178350715 rv(fluid) 0.2828594413977011 rTf(fluid) 1.2913312809983123e-07
# [it=240] obj=1.024e+00 feas_raw=7.083e-09 feas_s=7.083e-09 alpha=9.59e-02 beta=9.00e-01 station=1.88e-02 tau=1.893e-01 dn=1.88e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.626e-05  max=3.642e-04
#   pde_Ts    : rms=2.999e-05  max=2.800e-04
#   pde_cont  : rms=1.336e-04  max=6.678e-04
#   pde_ru    : rms=8.054e-05  max=3.199e-04
#   pde_rv    : rms=7.186e-05  max=4.056e-04
#   pde_rTf   : rms=9.166e-08  max=7.376e-07
#   bc_phi    : rms=2.035e-05  max=6.059e-05
#   bc_solid  : rms=6.756e-05  max=3.348e-04
#   bc_fluid  : rms=1.358e-04  max=9.177e-04
#   iface     : rms=1.188e-04  max=5.010e-04
#   ic        : rms=6.584e-05  max=3.316e-04
# PDE RMS on obj: phi 0.09222273041650386 Ts(solid) 0.10087032305534886 cont(fluid) 0.05184608137582435 ru(fluid) 0.04150932977905753 rv(fluid) 0.2815531869253123 rTf(fluid) 1.2865359017867305e-07
# [it=250] obj=1.017e+00 feas_raw=7.243e-09 feas_s=7.243e-09 alpha=1.05e-01 beta=8.97e-01 station=1.88e-02 tau=1.893e-01 dn=1.88e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.544e-05  max=3.633e-04
#   pde_Ts    : rms=2.996e-05  max=2.797e-04
#   pde_cont  : rms=1.327e-04  max=6.653e-04
#   pde_ru    : rms=8.004e-05  max=3.208e-04
#   pde_rv    : rms=8.583e-05  max=8.836e-04
#   pde_rTf   : rms=9.072e-08  max=7.333e-07
#   bc_phi    : rms=1.988e-05  max=6.431e-05
#   bc_solid  : rms=6.450e-05  max=3.264e-04
#   bc_fluid  : rms=1.350e-04  max=9.140e-04
#   iface     : rms=1.183e-04  max=5.000e-04
#   ic        : rms=6.575e-05  max=3.311e-04
# PDE RMS on obj: phi 0.09214730293258244 Ts(solid) 0.10065657566694855 cont(fluid) 0.05170843463684324 ru(fluid) 0.04176343814972767 rv(fluid) 0.2802469743867729 rTf(fluid) 1.2824463612158824e-07
# [it=260] obj=1.009e+00 feas_raw=6.921e-09 feas_s=6.921e-09 alpha=9.52e-02 beta=8.94e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.525e-05  max=3.637e-04
#   pde_Ts    : rms=3.034e-05  max=2.799e-04
#   pde_cont  : rms=1.319e-04  max=6.626e-04
#   pde_ru    : rms=7.943e-05  max=3.217e-04
#   pde_rv    : rms=7.104e-05  max=4.235e-04
#   pde_rTf   : rms=8.975e-08  max=7.287e-07
#   bc_phi    : rms=1.849e-05  max=5.925e-05
#   bc_solid  : rms=6.467e-05  max=3.185e-04
#   bc_fluid  : rms=1.343e-04  max=9.105e-04
#   iface     : rms=1.180e-04  max=4.989e-04
#   ic        : rms=6.566e-05  max=3.310e-04
# PDE RMS on obj: phi 0.09207886324857976 Ts(solid) 0.10045789602868607 cont(fluid) 0.05157680999197311 ru(fluid) 0.0420096437791014 rv(fluid) 0.2790020675254787 rTf(fluid) 1.2789371301874705e-07
# [it=270] obj=1.002e+00 feas_raw=6.782e-09 feas_s=6.782e-09 alpha=8.62e-02 beta=8.90e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.420e-05  max=3.636e-04
#   pde_Ts    : rms=3.005e-05  max=2.805e-04
#   pde_cont  : rms=1.310e-04  max=6.598e-04
#   pde_ru    : rms=7.888e-05  max=3.224e-04
#   pde_rv    : rms=6.669e-05  max=2.747e-04
#   pde_rTf   : rms=8.862e-08  max=7.222e-07
#   bc_phi    : rms=1.973e-05  max=1.057e-04
#   bc_solid  : rms=6.448e-05  max=3.111e-04
#   bc_fluid  : rms=1.337e-04  max=9.069e-04
#   iface     : rms=1.176e-04  max=4.976e-04
#   ic        : rms=6.558e-05  max=3.304e-04
# PDE RMS on obj: phi 0.09201202689474315 Ts(solid) 0.10026186693676402 cont(fluid) 0.05144505751997075 ru(fluid) 0.04225580425817997 rv(fluid) 0.27777629503523504 rTf(fluid) 1.2730437960726768e-07
# [it=280] obj=9.943e-01 feas_raw=7.217e-09 feas_s=7.217e-09 alpha=1.04e-01 beta=8.87e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.481e-05  max=3.630e-04
#   pde_Ts    : rms=3.001e-05  max=2.805e-04
#   pde_cont  : rms=1.302e-04  max=6.569e-04
#   pde_ru    : rms=7.845e-05  max=3.228e-04
#   pde_rv    : rms=9.417e-05  max=1.123e-03
#   pde_rTf   : rms=8.771e-08  max=7.175e-07
#   bc_phi    : rms=1.873e-05  max=5.381e-05
#   bc_solid  : rms=6.378e-05  max=3.038e-04
#   bc_fluid  : rms=1.331e-04  max=9.033e-04
#   iface     : rms=1.170e-04  max=4.962e-04
#   ic        : rms=6.553e-05  max=3.296e-04
# PDE RMS on obj: phi 0.09194778938963089 Ts(solid) 0.1000671248887351 cont(fluid) 0.05131326074945705 ru(fluid) 0.042506862204930336 rv(fluid) 0.27648552971268753 rTf(fluid) 1.271717842750746e-07
# [it=290] obj=9.868e-01 feas_raw=6.651e-09 feas_s=6.651e-09 alpha=8.56e-02 beta=8.84e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.395e-05  max=3.640e-04
#   pde_Ts    : rms=2.948e-05  max=2.811e-04
#   pde_cont  : rms=1.294e-04  max=6.541e-04
#   pde_ru    : rms=7.788e-05  max=3.232e-04
#   pde_rv    : rms=6.689e-05  max=2.718e-04
#   pde_rTf   : rms=8.674e-08  max=7.121e-07
#   bc_phi    : rms=1.602e-05  max=5.398e-05
#   bc_solid  : rms=6.310e-05  max=2.970e-04
#   bc_fluid  : rms=1.325e-04  max=8.996e-04
#   iface     : rms=1.165e-04  max=4.945e-04
#   ic        : rms=6.543e-05  max=3.293e-04
# PDE RMS on obj: phi 0.09188718396587921 Ts(solid) 0.09988031357360201 cont(fluid) 0.05118370871101667 ru(fluid) 0.042749888179720724 rv(fluid) 0.2752266493635409 rTf(fluid) 1.2703116474452336e-07
# [it=300] obj=9.798e-01 feas_raw=6.606e-09 feas_s=6.606e-09 alpha=8.52e-02 beta=8.80e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.389e-05  max=3.624e-04
#   pde_Ts    : rms=2.956e-05  max=2.812e-04
#   pde_cont  : rms=1.286e-04  max=6.512e-04
#   pde_ru    : rms=7.749e-05  max=3.234e-04
#   pde_rv    : rms=6.792e-05  max=2.706e-04
#   pde_rTf   : rms=8.580e-08  max=7.067e-07
#   bc_phi    : rms=1.772e-05  max=6.132e-05
#   bc_solid  : rms=6.119e-05  max=2.907e-04
#   bc_fluid  : rms=1.319e-04  max=8.959e-04
#   iface     : rms=1.158e-04  max=4.928e-04
#   ic        : rms=6.534e-05  max=3.290e-04
# PDE RMS on obj: phi 0.0918302726922769 Ts(solid) 0.0997014856167511 cont(fluid) 0.05106017975816153 ru(fluid) 0.04298538269914793 rv(fluid) 0.27401566530696303 rTf(fluid) 1.26924211197023e-07
# [it=310] obj=9.727e-01 feas_raw=7.722e-09 feas_s=7.722e-09 alpha=1.13e-01 beta=8.77e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.499e-05  max=3.633e-04
#   pde_Ts    : rms=2.888e-05  max=2.820e-04
#   pde_cont  : rms=1.280e-04  max=6.481e-04
#   pde_ru    : rms=7.691e-05  max=3.236e-04
#   pde_rv    : rms=1.230e-04  max=1.768e-03
#   pde_rTf   : rms=8.494e-08  max=7.019e-07
#   bc_phi    : rms=1.757e-05  max=5.193e-05
#   bc_solid  : rms=5.842e-05  max=2.843e-04
#   bc_fluid  : rms=1.314e-04  max=8.922e-04
#   iface     : rms=1.153e-04  max=4.909e-04
#   ic        : rms=6.528e-05  max=3.281e-04
# PDE RMS on obj: phi 0.09177478414151873 Ts(solid) 0.09951780854536833 cont(fluid) 0.050935124273487245 ru(fluid) 0.04323049211208733 rv(fluid) 0.2727586708233339 rTf(fluid) 1.2700875589347402e-07
# [it=320] obj=9.652e-01 feas_raw=6.448e-09 feas_s=6.448e-09 alpha=9.31e-02 beta=8.74e-01 station=1.89e-02 tau=1.893e-01 dn=1.89e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.224e-05  max=3.629e-04
#   pde_Ts    : rms=2.966e-05  max=2.821e-04
#   pde_cont  : rms=1.269e-04  max=6.450e-04
#   pde_ru    : rms=7.650e-05  max=3.237e-04
#   pde_rv    : rms=6.606e-05  max=2.680e-04
#   pde_rTf   : rms=8.397e-08  max=6.957e-07
#   bc_phi    : rms=1.802e-05  max=5.442e-05
#   bc_solid  : rms=5.921e-05  max=2.781e-04
#   bc_fluid  : rms=1.309e-04  max=8.885e-04
#   iface     : rms=1.149e-04  max=4.888e-04
#   ic        : rms=6.520e-05  max=3.274e-04
# PDE RMS on obj: phi 0.0917194777425036 Ts(solid) 0.09933583043844176 cont(fluid) 0.050806546286157724 ru(fluid) 0.04347534351787817 rv(fluid) 0.27147764854005085 rTf(fluid) 1.2694335780049754e-07
# [it=330] obj=9.583e-01 feas_raw=7.175e-09 feas_s=7.175e-09 alpha=1.02e-01 beta=8.71e-01 station=1.88e-02 tau=1.893e-01 dn=1.88e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.343e-05  max=3.639e-04
#   pde_Ts    : rms=2.905e-05  max=2.828e-04
#   pde_cont  : rms=1.263e-04  max=6.418e-04
#   pde_ru    : rms=7.615e-05  max=3.234e-04
#   pde_rv    : rms=1.067e-04  max=1.418e-03
#   pde_rTf   : rms=8.312e-08  max=6.904e-07
#   bc_phi    : rms=1.413e-05  max=5.656e-05
#   bc_solid  : rms=5.720e-05  max=2.723e-04
#   bc_fluid  : rms=1.304e-04  max=8.846e-04
#   iface     : rms=1.143e-04  max=4.867e-04
#   ic        : rms=6.510e-05  max=3.266e-04
# PDE RMS on obj: phi 0.09166823283219953 Ts(solid) 0.099161181903873 cont(fluid) 0.0506867035723884 ru(fluid) 0.04371437197926226 rv(fluid) 0.27025176528593775 rTf(fluid) 1.2711633051867794e-07
# [it=340] obj=9.516e-01 feas_raw=6.349e-09 feas_s=6.349e-09 alpha=8.40e-02 beta=8.68e-01 station=1.88e-02 tau=1.893e-01 dn=1.88e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.188e-05  max=3.639e-04
#   pde_Ts    : rms=2.856e-05  max=2.828e-04
#   pde_cont  : rms=1.254e-04  max=6.390e-04
#   pde_ru    : rms=7.561e-05  max=3.232e-04
#   pde_rv    : rms=6.776e-05  max=3.222e-04
#   pde_rTf   : rms=8.240e-08  max=6.858e-07
#   bc_phi    : rms=1.735e-05  max=6.823e-05
#   bc_solid  : rms=5.643e-05  max=2.671e-04
#   bc_fluid  : rms=1.300e-04  max=8.814e-04
#   iface     : rms=1.137e-04  max=4.846e-04
#   ic        : rms=6.497e-05  max=3.264e-04
# PDE RMS on obj: phi 0.09161958640858994 Ts(solid) 0.09899783272558384 cont(fluid) 0.05057434977837461 ru(fluid) 0.04393438466593264 rv(fluid) 0.2691146209911613 rTf(fluid) 1.2736194214406702e-07
# [it=350] obj=9.451e-01 feas_raw=6.405e-09 feas_s=6.405e-09 alpha=9.21e-02 beta=8.65e-01 station=1.87e-02 tau=1.893e-01 dn=1.87e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.251e-05  max=3.627e-04
#   pde_Ts    : rms=2.948e-05  max=2.838e-04
#   pde_cont  : rms=1.248e-04  max=6.360e-04
#   pde_ru    : rms=7.524e-05  max=3.227e-04
#   pde_rv    : rms=7.360e-05  max=5.176e-04
#   pde_rTf   : rms=8.160e-08  max=6.805e-07
#   bc_phi    : rms=1.834e-05  max=8.723e-05
#   bc_solid  : rms=5.523e-05  max=2.621e-04
#   bc_fluid  : rms=1.296e-04  max=8.778e-04
#   iface     : rms=1.133e-04  max=4.823e-04
#   ic        : rms=6.485e-05  max=3.257e-04
# PDE RMS on obj: phi 0.0915726429332153 Ts(solid) 0.0988357959713442 cont(fluid) 0.05045981358995666 ru(fluid) 0.04415335494391366 rv(fluid) 0.2679487164773023 rTf(fluid) 1.2751253942788966e-07
# [it=360] obj=9.383e-01 feas_raw=6.255e-09 feas_s=6.255e-09 alpha=9.18e-02 beta=8.62e-01 station=1.86e-02 tau=1.893e-01 dn=1.86e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.152e-05  max=3.641e-04
#   pde_Ts    : rms=2.888e-05  max=2.849e-04
#   pde_cont  : rms=1.239e-04  max=6.329e-04
#   pde_ru    : rms=7.500e-05  max=3.221e-04
#   pde_rv    : rms=6.750e-05  max=2.686e-04
#   pde_rTf   : rms=8.105e-08  max=6.772e-07
#   bc_phi    : rms=1.971e-05  max=8.213e-05
#   bc_solid  : rms=5.726e-05  max=2.571e-04
#   bc_fluid  : rms=1.292e-04  max=8.792e-04
#   iface     : rms=1.126e-04  max=4.800e-04
#   ic        : rms=6.477e-05  max=3.246e-04
# PDE RMS on obj: phi 0.09152505578801597 Ts(solid) 0.0986704874981551 cont(fluid) 0.050346417616005563 ru(fluid) 0.044378861403860256 rv(fluid) 0.26674334205130157 rTf(fluid) 1.280860785429913e-07
# [it=370] obj=9.315e-01 feas_raw=7.057e-09 feas_s=7.057e-09 alpha=1.22e-01 beta=8.59e-01 station=1.85e-02 tau=1.893e-01 dn=1.85e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.278e-05  max=3.644e-04
#   pde_Ts    : rms=2.912e-05  max=2.862e-04
#   pde_cont  : rms=1.233e-04  max=6.296e-04
#   pde_ru    : rms=7.453e-05  max=3.213e-04
#   pde_rv    : rms=1.102e-04  max=1.503e-03
#   pde_rTf   : rms=8.038e-08  max=6.729e-07
#   bc_phi    : rms=1.794e-05  max=8.823e-05
#   bc_solid  : rms=5.577e-05  max=2.520e-04
#   bc_fluid  : rms=1.287e-04  max=8.817e-04
#   iface     : rms=1.120e-04  max=4.773e-04
#   ic        : rms=6.468e-05  max=3.233e-04
# PDE RMS on obj: phi 0.09147544377260683 Ts(solid) 0.09849582285191366 cont(fluid) 0.05022347802650166 ru(fluid) 0.04461437878527378 rv(fluid) 0.26549224728471466 rTf(fluid) 1.2857227630922133e-07
# [it=380] obj=9.248e-01 feas_raw=6.129e-09 feas_s=6.129e-09 alpha=9.12e-02 beta=8.56e-01 station=1.84e-02 tau=1.893e-01 dn=1.84e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.117e-05  max=3.639e-04
#   pde_Ts    : rms=2.867e-05  max=2.862e-04
#   pde_cont  : rms=1.224e-04  max=6.264e-04
#   pde_ru    : rms=7.408e-05  max=3.205e-04
#   pde_rv    : rms=6.737e-05  max=2.712e-04
#   pde_rTf   : rms=7.976e-08  max=6.689e-07
#   bc_phi    : rms=1.511e-05  max=4.192e-05
#   bc_solid  : rms=5.377e-05  max=2.474e-04
#   bc_fluid  : rms=1.284e-04  max=8.841e-04
#   iface     : rms=1.114e-04  max=4.748e-04
#   ic        : rms=6.452e-05  max=3.227e-04
# PDE RMS on obj: phi 0.09142788830465975 Ts(solid) 0.09833400533276856 cont(fluid) 0.0501124656831776 ru(fluid) 0.04483032262294896 rv(fluid) 0.26432174457180047 rTf(fluid) 1.289507032041431e-07
# [it=390] obj=9.187e-01 feas_raw=6.102e-09 feas_s=6.102e-09 alpha=9.09e-02 beta=8.53e-01 station=1.83e-02 tau=1.893e-01 dn=1.83e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.072e-05  max=3.638e-04
#   pde_Ts    : rms=2.836e-05  max=2.866e-04
#   pde_cont  : rms=1.217e-04  max=6.235e-04
#   pde_ru    : rms=7.370e-05  max=3.196e-04
#   pde_rv    : rms=6.891e-05  max=3.912e-04
#   pde_rTf   : rms=7.926e-08  max=6.658e-07
#   bc_phi    : rms=1.796e-05  max=8.318e-05
#   bc_solid  : rms=5.287e-05  max=2.433e-04
#   bc_fluid  : rms=1.280e-04  max=8.870e-04
#   iface     : rms=1.109e-04  max=4.723e-04
#   ic        : rms=6.436e-05  max=3.222e-04
# PDE RMS on obj: phi 0.09138353370598568 Ts(solid) 0.0981822949473634 cont(fluid) 0.050010861795585136 ru(fluid) 0.04503068121929447 rv(fluid) 0.2632357839923668 rTf(fluid) 1.2936153887202122e-07
# [it=400] obj=9.123e-01 feas_raw=6.642e-09 feas_s=6.642e-09 alpha=1.10e-01 beta=8.50e-01 station=1.82e-02 tau=1.893e-01 dn=1.82e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.180e-05  max=3.642e-04
#   pde_Ts    : rms=2.885e-05  max=2.878e-04
#   pde_cont  : rms=1.211e-04  max=6.205e-04
#   pde_ru    : rms=7.355e-05  max=3.185e-04
#   pde_rv    : rms=9.935e-05  max=1.279e-03
#   pde_rTf   : rms=7.868e-08  max=6.618e-07
#   bc_phi    : rms=1.755e-05  max=7.732e-05
#   bc_solid  : rms=5.199e-05  max=2.391e-04
#   bc_fluid  : rms=1.277e-04  max=8.898e-04
#   iface     : rms=1.102e-04  max=4.697e-04
#   ic        : rms=6.422e-05  max=3.211e-04
# PDE RMS on obj: phi 0.09133583200334051 Ts(solid) 0.09802444369463058 cont(fluid) 0.04989899763522684 ru(fluid) 0.045234743406519604 rv(fluid) 0.26205827004324994 rTf(fluid) 1.2968388433584538e-07
# [it=410] obj=9.060e-01 feas_raw=6.244e-09 feas_s=6.244e-09 alpha=1.09e-01 beta=8.47e-01 station=1.81e-02 tau=1.893e-01 dn=1.81e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.069e-05  max=3.649e-04
#   pde_Ts    : rms=2.898e-05  max=2.888e-04
#   pde_cont  : rms=1.203e-04  max=6.174e-04
#   pde_ru    : rms=7.309e-05  max=3.173e-04
#   pde_rv    : rms=8.206e-05  max=8.489e-04
#   pde_rTf   : rms=7.819e-08  max=6.585e-07
#   bc_phi    : rms=1.757e-05  max=6.751e-05
#   bc_solid  : rms=5.480e-05  max=2.351e-04
#   bc_fluid  : rms=1.273e-04  max=8.927e-04
#   iface     : rms=1.097e-04  max=4.671e-04
#   ic        : rms=6.407e-05  max=3.202e-04
# PDE RMS on obj: phi 0.0912899998264646 Ts(solid) 0.09787254421034292 cont(fluid) 0.04979593290286888 ru(fluid) 0.04543195318571845 rv(fluid) 0.26091387968684465 rTf(fluid) 1.300587833149955e-07
# [it=420] obj=8.998e-01 feas_raw=6.212e-09 feas_s=6.212e-09 alpha=9.90e-02 beta=8.45e-01 station=1.80e-02 tau=1.893e-01 dn=1.80e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.078e-05  max=3.643e-04
#   pde_Ts    : rms=2.821e-05  max=2.898e-04
#   pde_cont  : rms=1.196e-04  max=6.144e-04
#   pde_ru    : rms=7.273e-05  max=3.166e-04
#   pde_rv    : rms=8.369e-05  max=9.106e-04
#   pde_rTf   : rms=7.760e-08  max=6.545e-07
#   bc_phi    : rms=1.556e-05  max=5.155e-05
#   bc_solid  : rms=5.115e-05  max=2.312e-04
#   bc_fluid  : rms=1.270e-04  max=8.961e-04
#   iface     : rms=1.091e-04  max=4.644e-04
#   ic        : rms=6.392e-05  max=3.188e-04
# PDE RMS on obj: phi 0.09124227214196795 Ts(solid) 0.09771571368875549 cont(fluid) 0.049687831133379774 ru(fluid) 0.04563424564425352 rv(fluid) 0.25979723320075665 rTf(fluid) 1.3026959646107146e-07
# [it=430] obj=8.935e-01 feas_raw=6.289e-09 feas_s=6.289e-09 alpha=1.09e-01 beta=8.42e-01 station=1.79e-02 tau=1.893e-01 dn=1.79e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.085e-05  max=3.648e-04
#   pde_Ts    : rms=2.840e-05  max=2.907e-04
#   pde_cont  : rms=1.189e-04  max=6.113e-04
#   pde_ru    : rms=7.255e-05  max=3.182e-04
#   pde_rv    : rms=8.967e-05  max=1.072e-03
#   pde_rTf   : rms=7.702e-08  max=6.505e-07
#   bc_phi    : rms=1.448e-05  max=6.268e-05
#   bc_solid  : rms=5.311e-05  max=2.273e-04
#   bc_fluid  : rms=1.266e-04  max=8.996e-04
#   iface     : rms=1.084e-04  max=4.616e-04
#   ic        : rms=6.377e-05  max=3.174e-04
# PDE RMS on obj: phi 0.09119191777023528 Ts(solid) 0.0975591352095648 cont(fluid) 0.049583686288142095 ru(fluid) 0.04583524260749204 rv(fluid) 0.2586287521303077 rTf(fluid) 1.3054145198249967e-07
# [it=440] obj=8.872e-01 feas_raw=5.943e-09 feas_s=5.943e-09 alpha=9.83e-02 beta=8.39e-01 station=1.77e-02 tau=1.893e-01 dn=1.77e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.023e-05  max=3.657e-04
#   pde_Ts    : rms=2.834e-05  max=2.917e-04
#   pde_cont  : rms=1.180e-04  max=6.081e-04
#   pde_ru    : rms=7.215e-05  max=3.196e-04
#   pde_rv    : rms=7.389e-05  max=6.148e-04
#   pde_rTf   : rms=7.640e-08  max=6.461e-07
#   bc_phi    : rms=1.740e-05  max=8.349e-05
#   bc_solid  : rms=5.071e-05  max=2.234e-04
#   bc_fluid  : rms=1.263e-04  max=9.038e-04
#   iface     : rms=1.077e-04  max=4.588e-04
#   ic        : rms=6.360e-05  max=3.159e-04
# PDE RMS on obj: phi 0.09114147162655241 Ts(solid) 0.09740119124329759 cont(fluid) 0.049479818915019194 ru(fluid) 0.046030867561620115 rv(fluid) 0.25747973632805277 rTf(fluid) 1.3054337270967203e-07
# [it=450] obj=8.808e-01 feas_raw=7.438e-09 feas_s=7.438e-09 alpha=1.43e-01 beta=8.37e-01 station=1.75e-02 tau=1.893e-01 dn=1.75e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.314e-05  max=3.658e-04
#   pde_Ts    : rms=2.819e-05  max=2.932e-04
#   pde_cont  : rms=1.176e-04  max=6.047e-04
#   pde_ru    : rms=7.177e-05  max=3.208e-04
#   pde_rv    : rms=1.378e-04  max=2.073e-03
#   pde_rTf   : rms=7.571e-08  max=6.412e-07
#   bc_phi    : rms=1.745e-05  max=4.733e-05
#   bc_solid  : rms=5.067e-05  max=2.198e-04
#   bc_fluid  : rms=1.260e-04  max=9.078e-04
#   iface     : rms=1.071e-04  max=4.559e-04
#   ic        : rms=6.344e-05  max=3.143e-04
# PDE RMS on obj: phi 0.09108847790961581 Ts(solid) 0.09724345932029393 cont(fluid) 0.04937036590587918 ru(fluid) 0.04622694147247991 rv(fluid) 0.25626654046797537 rTf(fluid) 1.3044926281311344e-07
# [it=460] obj=8.748e-01 feas_raw=6.235e-09 feas_s=6.235e-09 alpha=1.18e-01 beta=8.34e-01 station=1.75e-02 tau=1.893e-01 dn=1.75e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.102e-05  max=3.649e-04
#   pde_Ts    : rms=2.863e-05  max=2.932e-04
#   pde_cont  : rms=1.166e-04  max=6.018e-04
#   pde_ru    : rms=7.151e-05  max=3.216e-04
#   pde_rv    : rms=9.369e-05  max=1.153e-03
#   pde_rTf   : rms=7.527e-08  max=6.383e-07
#   bc_phi    : rms=1.622e-05  max=5.690e-05
#   bc_solid  : rms=5.055e-05  max=2.165e-04
#   bc_fluid  : rms=1.257e-04  max=9.121e-04
#   iface     : rms=1.065e-04  max=4.534e-04
#   ic        : rms=6.324e-05  max=3.136e-04
# PDE RMS on obj: phi 0.0910379994279385 Ts(solid) 0.0970998876215695 cont(fluid) 0.04927511130587877 ru(fluid) 0.04640187241184933 rv(fluid) 0.2551753213280499 rTf(fluid) 1.305838724447503e-07
# [it=470] obj=8.690e-01 feas_raw=6.228e-09 feas_s=6.228e-09 alpha=1.18e-01 beta=8.31e-01 station=1.73e-02 tau=1.893e-01 dn=1.73e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.053e-05  max=3.664e-04
#   pde_Ts    : rms=2.824e-05  max=2.945e-04
#   pde_cont  : rms=1.159e-04  max=5.988e-04
#   pde_ru    : rms=7.119e-05  max=3.222e-04
#   pde_rv    : rms=9.577e-05  max=1.206e-03
#   pde_rTf   : rms=7.459e-08  max=6.331e-07
#   bc_phi    : rms=1.679e-05  max=7.761e-05
#   bc_solid  : rms=4.989e-05  max=2.135e-04
#   bc_fluid  : rms=1.254e-04  max=9.162e-04
#   iface     : rms=1.059e-04  max=4.508e-04
#   ic        : rms=6.306e-05  max=3.122e-04
# PDE RMS on obj: phi 0.09098857329361018 Ts(solid) 0.09695603334685379 cont(fluid) 0.04918146763762887 ru(fluid) 0.046572956359459614 rv(fluid) 0.25410496671425326 rTf(fluid) 1.3034572815846977e-07
# [it=480] obj=8.627e-01 feas_raw=5.804e-09 feas_s=5.804e-09 alpha=1.07e-01 beta=8.29e-01 station=1.71e-02 tau=1.893e-01 dn=1.71e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.046e-05  max=3.674e-04
#   pde_Ts    : rms=2.804e-05  max=2.956e-04
#   pde_cont  : rms=1.151e-04  max=5.958e-04
#   pde_ru    : rms=7.095e-05  max=3.226e-04
#   pde_rv    : rms=7.626e-05  max=6.782e-04
#   pde_rTf   : rms=7.378e-08  max=6.270e-07
#   bc_phi    : rms=1.505e-05  max=6.523e-05
#   bc_solid  : rms=4.881e-05  max=2.103e-04
#   bc_fluid  : rms=1.252e-04  max=9.216e-04
#   iface     : rms=1.052e-04  max=4.480e-04
#   ic        : rms=6.288e-05  max=3.104e-04
# PDE RMS on obj: phi 0.09093085289671969 Ts(solid) 0.0968021124545557 cont(fluid) 0.04908032227530849 ru(fluid) 0.046752790061789895 rv(fluid) 0.252943163933833 rTf(fluid) 1.2971561840089994e-07
# [it=490] obj=8.560e-01 feas_raw=5.861e-09 feas_s=5.861e-09 alpha=1.29e-01 beta=8.26e-01 station=1.71e-02 tau=1.893e-01 dn=1.71e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.082e-05  max=3.686e-04
#   pde_Ts    : rms=2.843e-05  max=2.980e-04
#   pde_cont  : rms=1.144e-04  max=5.923e-04
#   pde_ru    : rms=7.054e-05  max=3.225e-04
#   pde_rv    : rms=8.111e-05  max=8.095e-04
#   pde_rTf   : rms=7.282e-08  max=6.197e-07
#   bc_phi    : rms=1.898e-05  max=6.672e-05
#   bc_solid  : rms=5.185e-05  max=2.068e-04
#   bc_fluid  : rms=1.249e-04  max=9.280e-04
#   iface     : rms=1.044e-04  max=4.450e-04
#   ic        : rms=6.271e-05  max=3.080e-04
# PDE RMS on obj: phi 0.09086792411690854 Ts(solid) 0.09663443713555513 cont(fluid) 0.04896702436426442 ru(fluid) 0.04694603822268011 rv(fluid) 0.25164769952213756 rTf(fluid) 1.2892071485892835e-07
# [it=500] obj=8.497e-01 feas_raw=5.519e-09 feas_s=5.519e-09 alpha=9.65e-02 beta=8.23e-01 station=1.69e-02 tau=1.893e-01 dn=1.69e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.922e-05  max=3.683e-04
#   pde_Ts    : rms=2.865e-05  max=2.979e-04
#   pde_cont  : rms=1.136e-04  max=5.892e-04
#   pde_ru    : rms=7.018e-05  max=3.222e-04
#   pde_rv    : rms=6.430e-05  max=2.772e-04
#   pde_rTf   : rms=7.201e-08  max=6.135e-07
#   bc_phi    : rms=1.510e-05  max=5.350e-05
#   bc_solid  : rms=4.896e-05  max=2.040e-04
#   bc_fluid  : rms=1.246e-04  max=9.335e-04
#   iface     : rms=1.039e-04  max=4.423e-04
#   ic        : rms=6.250e-05  max=3.070e-04
# PDE RMS on obj: phi 0.09081305887223086 Ts(solid) 0.09648945994630179 cont(fluid) 0.048873093503723875 ru(fluid) 0.0471111516099077 rv(fluid) 0.2505067558144223 rTf(fluid) 1.2825970120348062e-07
# [it=510] obj=8.435e-01 feas_raw=5.531e-09 feas_s=5.531e-09 alpha=1.06e-01 beta=8.21e-01 station=1.66e-02 tau=1.893e-01 dn=1.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.933e-05  max=3.686e-04
#   pde_Ts    : rms=2.855e-05  max=2.990e-04
#   pde_cont  : rms=1.128e-04  max=5.859e-04
#   pde_ru    : rms=6.984e-05  max=3.216e-04
#   pde_rv    : rms=6.755e-05  max=4.094e-04
#   pde_rTf   : rms=7.108e-08  max=6.065e-07
#   bc_phi    : rms=1.648e-05  max=6.634e-05
#   bc_solid  : rms=4.935e-05  max=2.013e-04
#   bc_fluid  : rms=1.244e-04  max=9.398e-04
#   iface     : rms=1.034e-04  max=4.397e-04
#   ic        : rms=6.231e-05  max=3.051e-04
# PDE RMS on obj: phi 0.09075314776405066 Ts(solid) 0.09634020062711944 cont(fluid) 0.0487719607078858 ru(fluid) 0.04727787149956873 rv(fluid) 0.24932901585942202 rTf(fluid) 1.2726067411593205e-07
# [it=520] obj=8.372e-01 feas_raw=6.473e-09 feas_s=6.473e-09 alpha=1.28e-01 beta=8.18e-01 station=1.65e-02 tau=1.893e-01 dn=1.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.148e-05  max=3.683e-04
#   pde_Ts    : rms=2.908e-05  max=2.998e-04
#   pde_cont  : rms=1.123e-04  max=5.827e-04
#   pde_ru    : rms=6.959e-05  max=3.206e-04
#   pde_rv    : rms=1.150e-04  max=1.631e-03
#   pde_rTf   : rms=6.998e-08  max=5.979e-07
#   bc_phi    : rms=1.541e-05  max=5.483e-05
#   bc_solid  : rms=4.802e-05  max=1.986e-04
#   bc_fluid  : rms=1.241e-04  max=9.467e-04
#   iface     : rms=1.025e-04  max=4.371e-04
#   ic        : rms=6.212e-05  max=3.032e-04
# PDE RMS on obj: phi 0.09069126615473237 Ts(solid) 0.09619147614125036 cont(fluid) 0.04867514134757798 ru(fluid) 0.04743884405979226 rv(fluid) 0.24810784662412866 rTf(fluid) 1.2584610714324266e-07
# [it=530] obj=8.309e-01 feas_raw=6.074e-09 feas_s=6.074e-09 alpha=1.40e-01 beta=8.16e-01 station=1.64e-02 tau=1.893e-01 dn=1.64e-02
# blocks (unscaled c):
#   pde_phi   : rms=4.186e-05  max=3.694e-04
#   pde_Ts    : rms=2.874e-05  max=3.012e-04
#   pde_cont  : rms=1.115e-04  max=5.793e-04
#   pde_ru    : rms=6.930e-05  max=3.193e-04
#   pde_rv    : rms=9.958e-05  max=1.287e-03
#   pde_rTf   : rms=6.893e-08  max=5.897e-07
#   bc_phi    : rms=1.686e-05  max=8.016e-05
#   bc_solid  : rms=5.054e-05  max=1.961e-04
#   bc_fluid  : rms=1.240e-04  max=9.542e-04
#   iface     : rms=1.019e-04  max=4.345e-04
#   ic        : rms=6.194e-05  max=3.012e-04
# PDE RMS on obj: phi 0.09062967829203182 Ts(solid) 0.09604251165653552 cont(fluid) 0.04857487695437763 ru(fluid) 0.04759875401009423 rv(fluid) 0.24689041514796972 rTf(fluid) 1.2468942304608657e-07
# [it=540] obj=8.252e-01 feas_raw=5.349e-09 feas_s=5.349e-09 alpha=9.53e-02 beta=8.14e-01 station=1.62e-02 tau=1.893e-01 dn=1.62e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.858e-05  max=3.697e-04
#   pde_Ts    : rms=2.859e-05  max=3.009e-04
#   pde_cont  : rms=1.106e-04  max=5.764e-04
#   pde_ru    : rms=6.889e-05  max=3.178e-04
#   pde_rv    : rms=6.398e-05  max=2.747e-04
#   pde_rTf   : rms=6.788e-08  max=5.816e-07
#   bc_phi    : rms=1.662e-05  max=7.740e-05
#   bc_solid  : rms=4.814e-05  max=1.940e-04
#   bc_fluid  : rms=1.239e-04  max=9.613e-04
#   iface     : rms=1.013e-04  max=4.323e-04
#   ic        : rms=6.177e-05  max=2.997e-04
# PDE RMS on obj: phi 0.09057174552842936 Ts(solid) 0.0959095489288314 cont(fluid) 0.04848759057453757 ru(fluid) 0.04773751995592294 rv(fluid) 0.24584388544445812 rTf(fluid) 1.2313005588743375e-07
# [it=550] obj=8.189e-01 feas_raw=5.673e-09 feas_s=5.673e-09 alpha=1.15e-01 beta=8.11e-01 station=1.60e-02 tau=1.893e-01 dn=1.60e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.942e-05  max=3.714e-04
#   pde_Ts    : rms=2.861e-05  max=3.027e-04
#   pde_cont  : rms=1.100e-04  max=5.731e-04
#   pde_ru    : rms=6.852e-05  max=3.157e-04
#   pde_rv    : rms=8.512e-05  max=9.759e-04
#   pde_rTf   : rms=6.650e-08  max=5.704e-07
#   bc_phi    : rms=1.747e-05  max=5.213e-05
#   bc_solid  : rms=4.901e-05  max=1.917e-04
#   bc_fluid  : rms=1.238e-04  max=9.696e-04
#   iface     : rms=1.006e-04  max=4.297e-04
#   ic        : rms=6.160e-05  max=2.972e-04
# PDE RMS on obj: phi 0.09050839384522727 Ts(solid) 0.09576400764764988 cont(fluid) 0.048393235471158036 ru(fluid) 0.04788721345958805 rv(fluid) 0.24460517707738966 rTf(fluid) 1.210606178582574e-07
# [it=560] obj=8.126e-01 feas_raw=5.459e-09 feas_s=5.459e-09 alpha=1.15e-01 beta=8.09e-01 station=1.58e-02 tau=1.893e-01 dn=1.58e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.883e-05  max=3.724e-04
#   pde_Ts    : rms=2.836e-05  max=3.039e-04
#   pde_cont  : rms=1.092e-04  max=5.698e-04
#   pde_ru    : rms=6.815e-05  max=3.133e-04
#   pde_rv    : rms=7.584e-05  max=7.368e-04
#   pde_rTf   : rms=6.504e-08  max=5.587e-07
#   bc_phi    : rms=1.811e-05  max=1.006e-04
#   bc_solid  : rms=4.718e-05  max=1.896e-04
#   bc_fluid  : rms=1.237e-04  max=9.787e-04
#   iface     : rms=9.999e-05  max=4.274e-04
#   ic        : rms=6.143e-05  max=2.950e-04
# PDE RMS on obj: phi 0.090443196771814 Ts(solid) 0.09561795941377346 cont(fluid) 0.048295072710678746 ru(fluid) 0.04803245491197897 rv(fluid) 0.2433844735183239 rTf(fluid) 1.1895516061438056e-07
# [it=570] obj=8.067e-01 feas_raw=5.535e-09 feas_s=5.535e-09 alpha=1.26e-01 beta=8.06e-01 station=1.56e-02 tau=1.893e-01 dn=1.56e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.942e-05  max=3.721e-04
#   pde_Ts    : rms=2.829e-05  max=3.039e-04
#   pde_cont  : rms=1.086e-04  max=5.666e-04
#   pde_ru    : rms=6.782e-05  max=3.109e-04
#   pde_rv    : rms=8.153e-05  max=8.593e-04
#   pde_rTf   : rms=6.360e-08  max=5.473e-07
#   bc_phi    : rms=1.412e-05  max=4.016e-05
#   bc_solid  : rms=5.061e-05  max=1.880e-04
#   bc_fluid  : rms=1.236e-04  max=9.870e-04
#   iface     : rms=9.939e-05  max=4.253e-04
#   ic        : rms=6.127e-05  max=2.930e-04
# PDE RMS on obj: phi 0.09038440326724805 Ts(solid) 0.09548499524237201 cont(fluid) 0.04820534356079122 ru(fluid) 0.04816090774952461 rv(fluid) 0.24223739878387723 rTf(fluid) 1.1662544430413712e-07
# [it=580] obj=8.005e-01 feas_raw=5.208e-09 feas_s=5.208e-09 alpha=1.14e-01 beta=8.04e-01 station=1.55e-02 tau=1.893e-01 dn=1.55e-02
# blocks (unscaled c):
#   pde_phi   : rms=3.811e-05  max=3.734e-04
#   pde_Ts    : rms=2.821e-05  max=3.050e-04
#   pde_cont  : rms=1.078e-04  max=5.634e-04
#   pde_ru    : rms=6.755e-05  max=3.080e-04
#   pde_rv    : rms=6.321e-05  max=2.728e-04
#   pde_rTf   : rms=6.204e-08  max=5.346e-07
#   bc_phi    : rms=2.004e-05  max=7.741e-05
#   bc_solid  : rms=5.171e-05  max=1.862e-04
# ...
#   bc_solid  : rms=3.836e-05  max=2.156e-04
#   bc_fluid  : rms=3.641e-05  max=3.075e-04
#   iface     : rms=3.031e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185949704122349 Ts(solid) 0.06467223296442112 cont(fluid) 0.03691029301902261 ru(fluid) 0.027748862637985188 rv(fluid) 0.07540062980892706 rTf(fluid) 3.5884839739247626e-08
# [it=5660] obj=1.583e-01 feas_raw=8.262e-10 feas_s=8.262e-10 alpha=0.00e+00 beta=4.34e-01 station=3.66e-02 tau=1.893e-01 dn=3.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.004e-05  max=7.380e-05
#   pde_Ts    : rms=7.269e-06  max=4.528e-05
#   pde_cont  : rms=3.381e-05  max=1.226e-04
#   pde_ru    : rms=3.130e-05  max=1.306e-04
#   pde_rv    : rms=4.761e-05  max=5.445e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.491e-05  max=5.637e-05
#   bc_solid  : rms=3.928e-05  max=2.134e-04
#   bc_fluid  : rms=3.638e-05  max=3.075e-04
#   iface     : rms=3.034e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185951167878229 Ts(solid) 0.06467200860860979 cont(fluid) 0.0369092232464717 ru(fluid) 0.027748528343824345 rv(fluid) 0.07540686692060954 rTf(fluid) 3.588457541948006e-08
# [it=5670] obj=1.583e-01 feas_raw=7.655e-10 feas_s=7.655e-10 alpha=0.00e+00 beta=4.33e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.167e-05  max=1.561e-04
#   pde_Ts    : rms=5.845e-06  max=4.578e-05
#   pde_cont  : rms=3.379e-05  max=1.226e-04
#   pde_ru    : rms=3.126e-05  max=1.306e-04
#   pde_rv    : rms=4.092e-05  max=3.827e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.735e-05  max=6.715e-05
#   bc_solid  : rms=3.970e-05  max=2.060e-04
#   bc_fluid  : rms=3.638e-05  max=3.075e-04
#   iface     : rms=3.032e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185947156524138 Ts(solid) 0.06467199552817637 cont(fluid) 0.03691265596598042 ru(fluid) 0.02774908206700145 rv(fluid) 0.07539449247884016 rTf(fluid) 3.5884930039024096e-08
# [it=5680] obj=1.583e-01 feas_raw=6.947e-10 feas_s=6.947e-10 alpha=0.00e+00 beta=4.33e-01 station=3.68e-02 tau=1.893e-01 dn=3.68e-02
# blocks (unscaled c):
#   pde_phi   : rms=7.464e-06  max=4.015e-05
#   pde_Ts    : rms=6.357e-06  max=4.885e-05
#   pde_cont  : rms=3.338e-05  max=1.226e-04
#   pde_ru    : rms=3.111e-05  max=1.306e-04
#   pde_rv    : rms=3.468e-05  max=1.901e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.433e-05  max=7.815e-05
#   bc_solid  : rms=3.856e-05  max=2.304e-04
#   bc_fluid  : rms=3.637e-05  max=3.075e-04
#   iface     : rms=3.032e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185922428769237 Ts(solid) 0.06467220784329972 cont(fluid) 0.03691147585571789 ru(fluid) 0.02774891418903552 rv(fluid) 0.0754156769106168 rTf(fluid) 3.588451845363905e-08
# [it=5690] obj=1.583e-01 feas_raw=6.938e-10 feas_s=6.938e-10 alpha=0.00e+00 beta=4.33e-01 station=3.64e-02 tau=1.893e-01 dn=3.64e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.994e-06  max=8.292e-05
#   pde_Ts    : rms=7.417e-06  max=5.169e-05
#   pde_cont  : rms=3.348e-05  max=1.226e-04
#   pde_ru    : rms=3.106e-05  max=1.306e-04
#   pde_rv    : rms=3.305e-05  max=1.251e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.610e-05  max=7.960e-05
#   bc_solid  : rms=3.963e-05  max=2.113e-04
#   bc_fluid  : rms=3.640e-05  max=3.075e-04
#   iface     : rms=3.031e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185952947484505 Ts(solid) 0.06467233641745898 cont(fluid) 0.03691249410118336 ru(fluid) 0.027748251324067157 rv(fluid) 0.07540236627320386 rTf(fluid) 3.5884882924691306e-08
# [it=5700] obj=1.583e-01 feas_raw=7.407e-10 feas_s=7.407e-10 alpha=0.00e+00 beta=4.33e-01 station=3.67e-02 tau=1.893e-01 dn=3.67e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.367e-06  max=7.258e-05
#   pde_Ts    : rms=5.836e-06  max=4.765e-05
#   pde_cont  : rms=3.373e-05  max=1.226e-04
#   pde_ru    : rms=3.104e-05  max=1.306e-04
#   pde_rv    : rms=3.854e-05  max=2.730e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.800e-05  max=1.175e-04
#   bc_solid  : rms=4.172e-05  max=2.210e-04
#   bc_fluid  : rms=3.638e-05  max=3.074e-04
#   iface     : rms=3.034e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.061859293466911526 Ts(solid) 0.06467230544009576 cont(fluid) 0.036910700909469796 ru(fluid) 0.02774889061423976 rv(fluid) 0.07540886715407359 rTf(fluid) 3.5884724708519434e-08
# [it=5710] obj=1.583e-01 feas_raw=6.924e-10 feas_s=6.924e-10 alpha=0.00e+00 beta=4.32e-01 station=3.66e-02 tau=1.893e-01 dn=3.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=6.633e-06  max=2.784e-05
#   pde_Ts    : rms=5.520e-06  max=2.849e-05
#   pde_cont  : rms=3.337e-05  max=1.226e-04
#   pde_ru    : rms=3.120e-05  max=1.306e-04
#   pde_rv    : rms=3.385e-05  max=2.203e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.439e-05  max=5.072e-05
#   bc_solid  : rms=4.125e-05  max=2.171e-04
#   bc_fluid  : rms=3.635e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185943252441302 Ts(solid) 0.06467194514965025 cont(fluid) 0.03690992796593059 ru(fluid) 0.02774919631048173 rv(fluid) 0.07539288160243351 rTf(fluid) 3.588461376468844e-08
# [it=5720] obj=1.583e-01 feas_raw=8.488e-10 feas_s=8.488e-10 alpha=0.00e+00 beta=4.32e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.052e-06  max=8.240e-05
#   pde_Ts    : rms=6.289e-06  max=6.082e-05
#   pde_cont  : rms=3.358e-05  max=1.226e-04
#   pde_ru    : rms=3.118e-05  max=1.306e-04
#   pde_rv    : rms=4.978e-05  max=6.244e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.437e-05  max=5.591e-05
#   bc_solid  : rms=4.185e-05  max=2.210e-04
#   bc_fluid  : rms=3.641e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185941135505872 Ts(solid) 0.06467201813379511 cont(fluid) 0.03691108469706013 ru(fluid) 0.027748696213171165 rv(fluid) 0.07541422709103913 rTf(fluid) 3.5884847707786376e-08
# [it=5730] obj=1.583e-01 feas_raw=7.100e-10 feas_s=7.100e-10 alpha=0.00e+00 beta=4.32e-01 station=3.66e-02 tau=1.893e-01 dn=3.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.655e-06  max=6.186e-05
#   pde_Ts    : rms=6.778e-06  max=7.352e-05
#   pde_cont  : rms=3.345e-05  max=1.226e-04
#   pde_ru    : rms=3.099e-05  max=1.306e-04
#   pde_rv    : rms=3.617e-05  max=1.954e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.541e-05  max=8.046e-05
#   bc_solid  : rms=3.823e-05  max=2.103e-04
#   bc_fluid  : rms=3.645e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185954771113385 Ts(solid) 0.06467195938413674 cont(fluid) 0.0369104221813399 ru(fluid) 0.02774926731291795 rv(fluid) 0.07541334405850919 rTf(fluid) 3.588479308008423e-08
# [it=5740] obj=1.583e-01 feas_raw=7.320e-10 feas_s=7.320e-10 alpha=0.00e+00 beta=4.32e-01 station=3.67e-02 tau=1.893e-01 dn=3.67e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.233e-06  max=8.403e-05
#   pde_Ts    : rms=7.261e-06  max=8.878e-05
#   pde_cont  : rms=3.356e-05  max=1.226e-04
#   pde_ru    : rms=3.128e-05  max=1.306e-04
#   pde_rv    : rms=3.884e-05  max=3.701e-04
#   pde_rTf   : rms=1.740e-08  max=1.702e-07
#   bc_phi    : rms=1.542e-05  max=6.579e-05
#   bc_solid  : rms=3.603e-05  max=1.952e-04
#   bc_fluid  : rms=3.640e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185949628008095 Ts(solid) 0.06467194589320117 cont(fluid) 0.03691099274746649 ru(fluid) 0.027748527695047626 rv(fluid) 0.07540321127558677 rTf(fluid) 3.588455857486031e-08
# [it=5750] obj=1.583e-01 feas_raw=7.015e-10 feas_s=7.015e-10 alpha=0.00e+00 beta=4.31e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=7.173e-06  max=3.068e-05
#   pde_Ts    : rms=5.856e-06  max=4.002e-05
#   pde_cont  : rms=3.347e-05  max=1.226e-04
#   pde_ru    : rms=3.128e-05  max=1.306e-04
#   pde_rv    : rms=3.481e-05  max=2.013e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.527e-05  max=7.335e-05
#   bc_solid  : rms=4.018e-05  max=2.295e-04
#   bc_fluid  : rms=3.644e-05  max=3.075e-04
#   iface     : rms=3.034e-05  max=1.155e-04
#   ic        : rms=2.695e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185961205072616 Ts(solid) 0.06467217205903705 cont(fluid) 0.03691123695002997 ru(fluid) 0.02774781783095603 rv(fluid) 0.0754056180791203 rTf(fluid) 3.5884600427758353e-08
# [it=5760] obj=1.583e-01 feas_raw=7.588e-10 feas_s=7.588e-10 alpha=0.00e+00 beta=4.31e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.084e-05  max=1.133e-04
#   pde_Ts    : rms=6.446e-06  max=4.902e-05
#   pde_cont  : rms=3.414e-05  max=1.226e-04
#   pde_ru    : rms=3.133e-05  max=1.306e-04
#   pde_rv    : rms=3.926e-05  max=2.726e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.579e-05  max=6.113e-05
#   bc_solid  : rms=4.304e-05  max=2.176e-04
#   bc_fluid  : rms=3.643e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185948971837054 Ts(solid) 0.06467214448916539 cont(fluid) 0.03690892789648847 ru(fluid) 0.02774889691012734 rv(fluid) 0.07541686086094274 rTf(fluid) 3.588477271732316e-08
# [it=5770] obj=1.583e-01 feas_raw=7.023e-10 feas_s=7.023e-10 alpha=0.00e+00 beta=4.31e-01 station=3.67e-02 tau=1.893e-01 dn=3.67e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.106e-05  max=1.215e-04
#   pde_Ts    : rms=7.122e-06  max=7.686e-05
#   pde_cont  : rms=3.350e-05  max=1.226e-04
#   pde_ru    : rms=3.111e-05  max=1.306e-04
#   pde_rv    : rms=3.384e-05  max=1.372e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.493e-05  max=6.496e-05
#   bc_solid  : rms=4.017e-05  max=2.304e-04
#   bc_fluid  : rms=3.643e-05  max=3.075e-04
#   iface     : rms=3.032e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185948640645036 Ts(solid) 0.06467207085643732 cont(fluid) 0.036912573653130464 ru(fluid) 0.027748859586191256 rv(fluid) 0.07541233445728629 rTf(fluid) 3.588458803894214e-08
# [it=5780] obj=1.583e-01 feas_raw=6.854e-10 feas_s=6.854e-10 alpha=0.00e+00 beta=4.30e-01 station=3.66e-02 tau=1.893e-01 dn=3.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.129e-06  max=5.417e-05
#   pde_Ts    : rms=6.850e-06  max=4.990e-05
#   pde_cont  : rms=3.342e-05  max=1.226e-04
#   pde_ru    : rms=3.098e-05  max=1.306e-04
#   pde_rv    : rms=3.284e-05  max=1.251e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.614e-05  max=9.058e-05
#   bc_solid  : rms=3.909e-05  max=2.229e-04
#   bc_fluid  : rms=3.639e-05  max=3.075e-04
#   iface     : rms=3.029e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.061859376828616426 Ts(solid) 0.0646720995074631 cont(fluid) 0.036912283419147214 ru(fluid) 0.027749397922659937 rv(fluid) 0.0754236625659688 rTf(fluid) 3.588443543789e-08
# [it=5790] obj=1.583e-01 feas_raw=7.421e-10 feas_s=7.421e-10 alpha=0.00e+00 beta=4.30e-01 station=3.64e-02 tau=1.893e-01 dn=3.64e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.494e-06  max=5.395e-05
#   pde_Ts    : rms=7.241e-06  max=6.899e-05
#   pde_cont  : rms=3.350e-05  max=1.226e-04
#   pde_ru    : rms=3.124e-05  max=1.306e-04
#   pde_rv    : rms=3.843e-05  max=2.528e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=2.026e-05  max=1.140e-04
#   bc_solid  : rms=4.042e-05  max=2.259e-04
#   bc_fluid  : rms=3.640e-05  max=3.075e-04
#   iface     : rms=3.035e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185956195137381 Ts(solid) 0.0646720941896889 cont(fluid) 0.03690945990063065 ru(fluid) 0.027749207398138055 rv(fluid) 0.07541087570257032 rTf(fluid) 3.588461022235548e-08
# [it=5800] obj=1.583e-01 feas_raw=6.898e-10 feas_s=6.898e-10 alpha=0.00e+00 beta=4.30e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.595e-06  max=6.766e-05
#   pde_Ts    : rms=8.934e-06  max=1.191e-04
#   pde_cont  : rms=3.343e-05  max=1.226e-04
#   pde_ru    : rms=3.114e-05  max=1.306e-04
#   pde_rv    : rms=3.326e-05  max=1.514e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.492e-05  max=6.100e-05
#   bc_solid  : rms=3.754e-05  max=2.316e-04
#   bc_fluid  : rms=3.641e-05  max=3.075e-04
#   iface     : rms=3.034e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185930754144585 Ts(solid) 0.06467196437079803 cont(fluid) 0.03691147524664969 ru(fluid) 0.027748892662164047 rv(fluid) 0.0754025794083554 rTf(fluid) 3.58848076357643e-08
# [it=5810] obj=1.583e-01 feas_raw=7.942e-10 feas_s=7.942e-10 alpha=0.00e+00 beta=4.30e-01 station=3.64e-02 tau=1.893e-01 dn=3.64e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.749e-06  max=1.050e-04
#   pde_Ts    : rms=4.879e-06  max=2.181e-05
#   pde_cont  : rms=3.418e-05  max=1.226e-04
#   pde_ru    : rms=3.121e-05  max=1.306e-04
#   pde_rv    : rms=4.432e-05  max=4.549e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.490e-05  max=7.614e-05
#   bc_solid  : rms=4.075e-05  max=2.193e-04
#   bc_fluid  : rms=3.641e-05  max=3.075e-04
#   iface     : rms=3.030e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185965269692832 Ts(solid) 0.0646720637810674 cont(fluid) 0.03691147383031854 ru(fluid) 0.027749081746771424 rv(fluid) 0.07539595046009365 rTf(fluid) 3.58850391893432e-08
# [it=5820] obj=1.583e-01 feas_raw=7.559e-10 feas_s=7.559e-10 alpha=0.00e+00 beta=4.29e-01 station=3.68e-02 tau=1.893e-01 dn=3.68e-02
# blocks (unscaled c):
#   pde_phi   : rms=7.535e-06  max=4.024e-05
#   pde_Ts    : rms=5.713e-06  max=4.169e-05
#   pde_cont  : rms=3.354e-05  max=1.226e-04
#   pde_ru    : rms=3.123e-05  max=1.306e-04
#   pde_rv    : rms=4.135e-05  max=3.891e-04
#   pde_rTf   : rms=1.740e-08  max=1.702e-07
#   bc_phi    : rms=1.444e-05  max=4.879e-05
#   bc_solid  : rms=4.007e-05  max=2.289e-04
#   bc_fluid  : rms=3.639e-05  max=3.075e-04
#   iface     : rms=3.033e-05  max=1.156e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185928941039737 Ts(solid) 0.06467220719016951 cont(fluid) 0.0369105184698715 ru(fluid) 0.027749043109584242 rv(fluid) 0.07541374238476643 rTf(fluid) 3.5884866163113264e-08
# [it=5830] obj=1.583e-01 feas_raw=7.721e-10 feas_s=7.721e-10 alpha=0.00e+00 beta=4.29e-01 station=3.65e-02 tau=1.893e-01 dn=3.65e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.347e-06  max=4.453e-05
#   pde_Ts    : rms=5.959e-06  max=5.080e-05
#   pde_cont  : rms=3.347e-05  max=1.226e-04
#   pde_ru    : rms=3.120e-05  max=1.306e-04
#   pde_rv    : rms=4.296e-05  max=4.516e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.254e-05  max=4.038e-05
#   bc_solid  : rms=4.085e-05  max=2.241e-04
#   bc_fluid  : rms=3.642e-05  max=3.075e-04
#   iface     : rms=3.032e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.06185955679632101 Ts(solid) 0.06467227607569333 cont(fluid) 0.036911059064672014 ru(fluid) 0.027748185959529617 rv(fluid) 0.07541613451035531 rTf(fluid) 3.5884873112087674e-08
# [it=5840] obj=1.583e-01 feas_raw=7.227e-10 feas_s=7.227e-10 alpha=0.00e+00 beta=4.29e-01 station=3.66e-02 tau=1.893e-01 dn=3.66e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.182e-06  max=6.542e-05
#   pde_Ts    : rms=6.489e-06  max=4.803e-05
#   pde_cont  : rms=3.358e-05  max=1.226e-04
#   pde_ru    : rms=3.125e-05  max=1.306e-04
#   pde_rv    : rms=3.722e-05  max=3.047e-04
#   pde_rTf   : rms=1.740e-08  max=1.701e-07
#   bc_phi    : rms=1.459e-05  max=4.816e-05
#   bc_solid  : rms=3.921e-05  max=2.321e-04
#   bc_fluid  : rms=3.640e-05  max=3.075e-04
#   iface     : rms=3.034e-05  max=1.155e-04
#   ic        : rms=2.696e-05  max=1.763e-04
# PDE RMS on obj: phi 0.061859582539404885 Ts(solid) 0.06467196026690435 cont(fluid) 0.03691124397308355 ru(fluid) 0.027748668088712774 rv(fluid) 0.07539614131751034 rTf(fluid) 3.588484579552774e-08

# %%
# !nvidia-smi
