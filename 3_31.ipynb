# %%
# ============================================================
# STOCHASTIC SQP-PINN (JAX) FOR NUCLEAR THERMAL COUPLING
# One NN outputs: [phi, Ts, u, v, p, Tf]
#
# NOTES:
#   - phi BC/IC match neutron MOOSE input exactly
#   - right fluid boundary uses MOOSE VALUE targets:
#         u=u_M, v=v_M, p=p_M, Tf=Tf_M
#   - old fluid case:
#         u(x,y,0)=1, v(x,y,0)=1e-12, Tf(x,y,0)=560
#         inlet: u=0, v=0.4, Tf=560
# ============================================================

import os
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "1")
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_FLAGS"] = "--xla_gpu_enable_command_buffer="

import time
import math
from functools import partial
import numpy as np

import jax
import jax.numpy as jnp
from jax import random, vmap, jacrev, hessian

# ============================================================
# Precision / dtype
# ============================================================
USE_X64 = True
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = DTYPE(1e-12)

# ============================================================
# USER SETTINGS / BENCHMARK
# ============================================================
Ls = DTYPE(0.0076)
Lf = DTYPE(0.0114)
Ly = DTYPE(0.75)
T_end = DTYPE(5.0)

x_min, x_max = DTYPE(0.0), DTYPE(Ls + Lf)
y_min, y_max = DTYPE(0.0), DTYPE(Ly)
t_min, t_max = DTYPE(0.0), DTYPE(T_end)

rho_f = DTYPE(11096.0)
rho_s = DTYPE(16020.0)

V_INLET_BC = DTYPE(0.4)
T_INLET = DTYPE(560.0)
P_OUTLET = DTYPE(0.0)
POWER_COEF = DTYPE(5e7)

# old fluid case
FLUID_U_IC = DTYPE(1.0)
FLUID_V_IC = DTYPE(1e-12)
FLUID_T_IC = DTYPE(560.0)

v_neu   = DTYPE(2.416)
D_fuel  = DTYPE(0.008249)
D_fluid = DTYPE(0.01)

# phi from neutron MOOSE file
PHI_TOPBOT_VAL = DTYPE(0.5)
PHI_RIGHT_VAL  = DTYPE(0.0)

MU_DAMP_FIXED = DTYPE(1e-4)

PHI_TXT_PATH = "./phi.txt"
TFLUID_PATH  = "/projects/549120ce-e7e0-45e0-a453-c9903649fea2/sqp/moose/output/nft_Tfluid.npy"

X_MARGIN = DTYPE(2e-5)

# ============================================================
# OUTPUT SCALES
# ============================================================
# IMPORTANT: phi can be much larger than 7 in the solution field
PHI_OUT_SCALE = DTYPE(15.0)
TS_OUT_SCALE  = DTYPE(350.0)
TF_OUT_SCALE  = DTYPE(250.0)
U_OUT_SCALE   = DTYPE(1.0)
V_OUT_SCALE   = DTYPE(0.5)
P_OUT_SCALE   = DTYPE(7.0)

PHI_VAL_SCALE = PHI_OUT_SCALE
TS_VAL_SCALE  = TS_OUT_SCALE
TF_VAL_SCALE  = TF_OUT_SCALE
U_VAL_SCALE   = U_OUT_SCALE
V_VAL_SCALE   = V_OUT_SCALE
P_VAL_SCALE   = P_OUT_SCALE
T_IF_VAL_SCALE = jnp.maximum(TS_VAL_SCALE, TF_VAL_SCALE)

# ============================================================
# SAMPLE COUNTS
# ==================================================
# =========
NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI = 20, 20, 10
NX_OBJ_S,   NY_OBJ_S,   NT_OBJ_S   = 20, 20, 10
NX_OBJ_F,   NY_OBJ_F,   NT_OBJ_F   = 20, 20, 10

NX_CON_PHI, NY_CON_PHI, NT_CON_PHI = 4, 4, 4
NX_CON_S,   NY_CON_S,   NT_CON_S   = 4, 4, 4
NX_CON_F,   NY_CON_F,   NT_CON_F   = 5, 5, 5

K_CON_PHI = NX_CON_PHI * NY_CON_PHI * NT_CON_PHI
K_CON_S   = NX_CON_S   * NY_CON_S   * NT_CON_S
K_CON_F   = NX_CON_F   * NY_CON_F   * NT_CON_F

N_PER_CELL = 1
N_BC_PER_BIN = 1
N_IC_PER_BIN = 1
N_IF_PER_BIN = 1

# separate BC counts
K_BC_PHI_LEFT   = 40
K_BC_PHI_RIGHT  = 30
K_BC_PHI_Y0     = 30
K_BC_PHI_Y1     = 30

K_BC_TS_X0      = 40

K_BC_F_INLET    = 50
K_BC_F_OUTLET   = 50
K_BC_F_RIGHT    = 50

NX_IC, NY_IC = 15, 20
K_IC = NX_IC * NY_IC

NY_IF, NT_IF = 10, 10
K_IF = NY_IF * NT_IF

# ============================================================
# BLOCK SIZES
# ============================================================
N_PDE_PHI = K_CON_PHI
N_PDE_TS  = K_CON_S
N_PDE_FLD = 4 * K_CON_F  # cont, ru, rv, rTf

N_BC_PHI = K_BC_PHI_LEFT + K_BC_PHI_RIGHT + K_BC_PHI_Y0 + K_BC_PHI_Y1
N_BC_SOL = K_BC_TS_X0
N_BC_FLD = 3 * K_BC_F_INLET + 3 * K_BC_F_OUTLET + 2 * K_BC_F_RIGHT
N_IF     = 2 * K_IF
N_IC     = 5 * K_IC

M_CON = N_PDE_PHI + N_PDE_TS + N_PDE_FLD + N_BC_PHI + N_BC_SOL + N_BC_FLD + N_IF + N_IC

# ============================================================
# LOAD phi.txt
# ============================================================
def load_phi_piecewise_multilinear(path: str):
    with open(path, "r") as f:
        lines = [ln.strip() for ln in f if ln.strip()]

    iy = lines.index("AXIS Y")
    it = lines.index("AXIS T")
    idata = lines.index("DATA")

    y_tokens = []
    k = iy + 1
    while k < len(lines) and lines[k] != "AXIS T":
        for tok in lines[k].split():
            try:
                float(tok)
                y_tokens.append(tok)
            except Exception:
                pass
        k += 1
    y = np.array([float(s) for s in y_tokens], dtype=np.float64)

    t_tokens = []
    k = it + 1
    while k < len(lines) and lines[k] != "DATA":
        for tok in lines[k].split():
            try:
                float(tok)
                t_tokens.append(tok)
            except Exception:
                pass
        k += 1
    t = np.array([float(s) for s in t_tokens], dtype=np.float64)

    Ny = len(y)
    Nt = len(t)

    data_tokens = []
    for ln in lines[idata + 1:]:
        for tok in ln.split():
            data_tokens.append(float(tok))
    data = np.array(data_tokens, dtype=np.float64)

    if data.size != Ny * Nt:
        raise ValueError(f"phi.txt DATA size mismatch: got {data.size}, expected {Ny * Nt}")

    Z_t_y = data.reshape(Nt, Ny)
    Z_y_t = Z_t_y.T
    return y, t, Z_y_t

y_np, t_np, Z_np = load_phi_piecewise_multilinear(PHI_TXT_PATH)
PHI_Y = jnp.array(y_np, dtype=DTYPE)
PHI_T = jnp.array(t_np, dtype=DTYPE)
PHI_Z = jnp.array(Z_np, dtype=DTYPE)

print("Loaded phi.txt:", y_np.shape, t_np.shape, Z_np.shape, "range=", float(Z_np.min()), float(Z_np.max()))

@jax.jit
def interp_yt(y, t, y_grid, t_grid, Z):
    y = jnp.asarray(y, dtype=DTYPE)
    t = jnp.asarray(t, dtype=DTYPE)

    Ny = y_grid.shape[0]
    Nt = t_grid.shape[0]

    iy = jnp.clip(jnp.searchsorted(y_grid, y, side="right") - 1, 0, Ny - 2)
    it = jnp.clip(jnp.searchsorted(t_grid, t, side="right") - 1, 0, Nt - 2)

    y0 = y_grid[iy]
    y1 = y_grid[iy + 1]
    t0 = t_grid[it]
    t1 = t_grid[it + 1]

    wy = (y - y0) / (y1 - y0 + EPS)
    wt = (t - t0) / (t1 - t0 + EPS)

    z00 = Z[iy, it]
    z10 = Z[iy + 1, it]
    z01 = Z[iy, it + 1]
    z11 = Z[iy + 1, it + 1]

    z0 = z00 + wy * (z10 - z00)
    z1 = z01 + wy * (z11 - z01)
    return z0 + wt * (z1 - z0)

def phi_left_target(y, t):
    t_clip = jnp.clip(t, PHI_T[0], PHI_T[-1])
    return interp_yt(y, t_clip, PHI_Y, PHI_T, PHI_Z)

# ============================================================
# LOAD MOOSE FLUID TRUTH
# ============================================================
SYNC_TIMES = np.array([
    0.0, 0.3125, 0.625, 0.9375, 1.25, 1.5625, 1.875, 2.1875,
    2.5, 2.8125, 3.125, 3.4375, 3.75, 4.0625, 4.375, 4.6875, 5.0
], dtype=np.float64)

def load_tfluid_truth(path: str, case_idx: int = 0):
    arr = np.load(path)

    # saved as (Ncase, 4, Nt, Nx_f, Ny)
    if arr.ndim == 5:
        arr = arr[case_idx]

    if arr.ndim != 4 or arr.shape[0] != 4:
        raise ValueError(f"Expected shape (4, Nt, Nx_f, Ny), got {arr.shape}")

    return arr

tfluid_np = load_tfluid_truth(TFLUID_PATH)
print("Loaded tfluid truth:", tfluid_np.shape)

# read order from exporter: [T_fluid, pressure, vel_x, vel_y]
Tf_true_np = tfluid_np[0]   # (Nt, Nx_f, Ny)
p_true_np  = tfluid_np[1]
u_true_np  = tfluid_np[2]
v_true_np  = tfluid_np[3]

Nt_true, Nx_f_true, Ny_true = u_true_np.shape
if Nt_true != len(SYNC_TIMES):
    raise ValueError(f"SYNC_TIMES length {len(SYNC_TIMES)} != Nt_true {Nt_true}")

Y_FLUID_np = np.linspace(0.0, float(Ly), Ny_true, dtype=np.float64)

# right boundary values: shape (Nt, Ny)
U_RIGHT_VAL_np  = u_true_np[:, -1, :]
V_RIGHT_VAL_np  = v_true_np[:, -1, :]
P_RIGHT_VAL_np  = p_true_np[:, -1, :]
TF_RIGHT_VAL_np = Tf_true_np[:, -1, :]

Y_FLUID = jnp.array(Y_FLUID_np, dtype=DTYPE)
T_SYNC  = jnp.array(SYNC_TIMES, dtype=DTYPE)

# store as (Ny, Nt) for interpolation
U_RIGHT_VAL  = jnp.array(U_RIGHT_VAL_np.T,  dtype=DTYPE)
V_RIGHT_VAL  = jnp.array(V_RIGHT_VAL_np.T,  dtype=DTYPE)
P_RIGHT_VAL  = jnp.array(P_RIGHT_VAL_np.T,  dtype=DTYPE)
TF_RIGHT_VAL = jnp.array(TF_RIGHT_VAL_np.T, dtype=DTYPE)

def u_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, U_RIGHT_VAL)

def v_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, V_RIGHT_VAL)

def p_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, P_RIGHT_VAL)

def Tf_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, TF_RIGHT_VAL)

# ============================================================
# MATERIAL LAWS
# ============================================================
def safe_T(T):
    return jnp.clip(T, DTYPE(300.0), DTYPE(1200.0))

def mu_f_fun(T):
    T = safe_T(T)
    return DTYPE(4.94e-4) * jnp.exp(DTYPE(754.1) / (T + EPS))

def k_f_fun(T):
    T = safe_T(T)
    return DTYPE(3.61) + DTYPE(1.517e-2) * T - DTYPE(1.741e-6) * T * T

def cp_f_fun(T):
    T = safe_T(T)
    return DTYPE(159.0) - DTYPE(2.72e-2) * T + DTYPE(7.12e-6) * T * T

def cp_s_fun(T):
    T = safe_T(T)
    return (DTYPE(1.359) + DTYPE(0.05812) * T + DTYPE(1.086e6) / (T * T + EPS)) * DTYPE(5.0)

def k_s_fun(T):
    T = safe_T(T)
    c0 = DTYPE(17.5) * (DTYPE(1.0) - DTYPE(0.223)) / (DTYPE(1.0) + DTYPE(0.161))
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c0 + c1 * T + c2 * T * T

def sigma_af_fuel(T):
    T = safe_T(T)
    return (
        DTYPE(2.416) * DTYPE(583.5) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
        - (DTYPE(13.47) * (T - DTYPE(560.0)) / (DTYPE(900.0) - DTYPE(560.0)) + DTYPE(7.53))
        * DTYPE(2.1479) * DTYPE(1.602)
        + DTYPE(0.185) * DTYPE(6.6072) * DTYPE(0.1)
        - DTYPE(680.9) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
    )

def sigma_af_fluid(T):
    T = safe_T(T)
    return -(DTYPE(20.0) + DTYPE(20.0) * (T - DTYPE(560.0)) / (DTYPE(800.0) - DTYPE(560.0)))

def dk_s_dT(T):
    T = safe_T(T)
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c1 + DTYPE(2.0) * c2 * T

def dk_f_dT(T):
    T = safe_T(T)
    a = DTYPE(1.517e-2)
    b = DTYPE(1.741e-6)
    return a - DTYPE(2.0) * b * T

def dmu_f_dT(T):
    T = safe_T(T)
    mu = mu_f_fun(T)
    return mu * (-DTYPE(754.1)) / (T * T + EPS)

def div_k_grad_scalar(k, dk_dT_fun, T, Tx, Ty, Txx, Tyy):
    return k * (Txx + Tyy) + dk_dT_fun(T) * (Tx * Tx + Ty * Ty)

def div_mu_grad_component(mu, dmu_dT_fun, Tf, Tfx, Tfy, ux, uy, uxx, uyy):
    return mu * (uxx + uyy) + dmu_dT_fun(Tf) * (Tfx * ux + Tfy * uy)

# ============================================================
# SCALES
# ============================================================
Lx       = (x_max - x_min) + EPS
Ly_len   = (y_max - y_min) + EPS
Lx_fluid = (x_max - Ls) + EPS
Lx_solid = (Ls - x_min) + EPS
Lmin     = jnp.minimum(Lx, Ly_len)

GRAD_TSX_SCALE = TS_VAL_SCALE / (Lx_solid + EPS)
GRAD_UY_SCALE  = U_VAL_SCALE / (Ly_len + EPS)
GRAD_VY_SCALE  = V_VAL_SCALE / (Ly_len + EPS)
GRAD_VX_SCALE  = V_VAL_SCALE / (Lx_fluid + EPS)

D_MAX    = jnp.maximum(D_fuel, D_fluid)
SIG_REF  = jnp.maximum(jnp.abs(sigma_af_fuel(T_INLET)), jnp.abs(sigma_af_fluid(T_INLET)))
K_S_REF  = k_s_fun(T_INLET)
K_F_REF  = k_f_fun(T_INLET)
CP_S_REF = cp_s_fun(T_INLET)
CP_F_REF = cp_f_fun(T_INLET)
MU_REF   = mu_f_fun(T_INLET)

FLUX_SCALE = jnp.maximum(
    K_S_REF * TS_VAL_SCALE / (Lx_solid + EPS),
    K_F_REF * TF_VAL_SCALE / (Lx_fluid + EPS),
) + EPS

PHI_TIME_REF  = PHI_VAL_SCALE / (v_neu * (T_end + EPS))
PHI_DIFF_REF  = D_MAX * PHI_VAL_SCALE / (Lmin**2 + EPS)
PHI_REAC_REF  = SIG_REF * PHI_VAL_SCALE
PHI_RES_SCALE = PHI_TIME_REF + PHI_DIFF_REF + PHI_REAC_REF + EPS

TS_TIME_REF  = rho_s * CP_S_REF * TS_VAL_SCALE / (T_end + EPS)
TS_DIFF_REF  = K_S_REF * TS_VAL_SCALE / (Lx_solid**2 + EPS)
TS_SRC_REF   = POWER_COEF * PHI_VAL_SCALE
TS_RES_SCALE = TS_TIME_REF + TS_DIFF_REF + TS_SRC_REF + EPS

CONT_SCALE = jnp.maximum(
    U_VAL_SCALE / (Lx_fluid + EPS),
    V_VAL_SCALE / (Ly_len + EPS),
) + EPS

MOMX_TIME_REF  = rho_f * U_VAL_SCALE / (T_end + EPS)
MOMX_ADV_REF   = rho_f * (
    U_VAL_SCALE * U_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * U_VAL_SCALE / (Ly_len + EPS)
)
MOMX_P_REF     = P_VAL_SCALE / (Lx_fluid + EPS)
MOMX_VIS_REF   = MU_REF * (
    U_VAL_SCALE / (Lx_fluid**2 + EPS)
    + U_VAL_SCALE / (Ly_len**2 + EPS)
)
MOMX_RES_SCALE = MOMX_TIME_REF + MOMX_ADV_REF + MOMX_P_REF + MOMX_VIS_REF + EPS

MOMY_TIME_REF  = rho_f * V_VAL_SCALE / (T_end + EPS)
MOMY_ADV_REF   = rho_f * (
    U_VAL_SCALE * V_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * V_VAL_SCALE / (Ly_len + EPS)
)
MOMY_P_REF     = P_VAL_SCALE / (Ly_len + EPS)
MOMY_VIS_REF   = MU_REF * (
    V_VAL_SCALE / (Lx_fluid**2 + EPS)
    + V_VAL_SCALE / (Ly_len**2 + EPS)
)
MOMY_RES_SCALE = MOMY_TIME_REF + MOMY_ADV_REF + MOMY_P_REF + MOMY_VIS_REF + EPS

TF_TIME_REF  = rho_f * CP_F_REF * TF_VAL_SCALE / (T_end + EPS)
TF_ADV_REF   = rho_f * CP_F_REF * (
    U_VAL_SCALE * TF_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * TF_VAL_SCALE / (Ly_len + EPS)
)
TF_DIFF_REF  = K_F_REF * TF_VAL_SCALE * (
    1.0 / (Lx_fluid**2 + EPS)
    + 1.0 / (Ly_len**2 + EPS)
)
TF_RES_SCALE = TF_TIME_REF + TF_ADV_REF + TF_DIFF_REF + EPS

# ============================================================
# TARGETS / ICS
# ============================================================
@jax.jit
def phi_ic(y):
    # correct from MOOSE
    return DTYPE(2.0) * jnp.cos(DTYPE(3.14) * (y - DTYPE(0.375)) / DTYPE(0.75))

def inlet_v_profile(x):
    return DTYPE(0.4) * jnp.ones_like(x)

# ============================================================
# NETWORK
# ============================================================
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params

def normalize_xyt(X):
    x = X[:, 0:1]
    y = X[:, 1:2]
    t = X[:, 2:3]

    x_n = 2.0 * (x - x_min) / (x_max - x_min + EPS) - 1.0
    y_n = 2.0 * (y - y_min) / (y_max - y_min + EPS) - 1.0
    t_n = 2.0 * (t - t_min) / (t_max - t_min + EPS) - 1.0
    return jnp.concatenate([x_n, y_n, t_n], axis=1)

def mlp_apply(params, X):
    h = normalize_xyt(X)
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)

    phi_hat = h[:, 0:1]
    Ts_hat  = h[:, 1:2]
    u_hat   = h[:, 2:3]
    v_hat   = h[:, 3:4]
    p_hat   = h[:, 4:5]
    Tf_hat  = h[:, 5:6]

    phi = PHI_OUT_SCALE * phi_hat
    Ts  = T_INLET + TS_OUT_SCALE * Ts_hat
    u   = U_OUT_SCALE * u_hat
    v   = V_OUT_SCALE * v_hat
    p   = P_OUT_SCALE * p_hat
    Tf  = T_INLET + TF_OUT_SCALE * Tf_hat

    return jnp.concatenate([phi, Ts, u, v, p, Tf], axis=1)

def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)

def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape)
        idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape)
        idx += b_size
        params.append({"W": W, "b": b})
    return params

# ============================================================
# UTILITIES
# ============================================================
def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)

# ============================================================
# STRATIFIED SAMPLING
# ============================================================
def sample_stratified_3d(key, x0, x1, y0, y1, t0, t1, NX, NY, NT):
    dx = (DTYPE(x1) - DTYPE(x0)) / DTYPE(NX)
    dy = (DTYPE(y1) - DTYPE(y0)) / DTYPE(NY)
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(NT)

    it, iy, ix = jnp.meshgrid(jnp.arange(NT), jnp.arange(NY), jnp.arange(NX), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids = (it * (NY * NX) + iy * NX + ix).astype(jnp.int32)

    xb = DTYPE(x0) + DTYPE(ix) * dx
    yb = DTYPE(y0) + DTYPE(iy) * dy
    tb = DTYPE(t0) + DTYPE(it) * dt

    K = NX * NY * NT
    u = random.uniform(key, (K, 3), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = xb + u[:, 0] * dx
    ys = yb + u[:, 1] * dy
    ts = tb + u[:, 2] * dt
    X = jnp.stack([xs, ys, ts], axis=1)
    return X, ids

def sample_bc_time_binned(key, K, *, x_fixed=None, y_fixed=None, t0=t_min, t1=t_max,
                          x_lo=None, x_hi=None, y_lo=None, y_hi=None):
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(K)
    j = jnp.arange(K, dtype=jnp.int32)
    tb = DTYPE(t0) + DTYPE(j) * dt

    key, kt, kr = random.split(key, 3)
    u_t = random.uniform(kt, (K, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (tb[:, None] + u_t * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    if x_fixed is not None:
        lo = DTYPE(y_min if y_lo is None else y_lo)
        hi = DTYPE(y_max if y_hi is None else y_hi)
        y = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        x = DTYPE(x_fixed) * jnp.ones_like(y)
        return jnp.concatenate([x, y, ts], axis=1), ids

    if y_fixed is not None:
        lo = DTYPE(x_min if x_lo is None else x_lo)
        hi = DTYPE(x_max if x_hi is None else x_hi)
        x = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        y = DTYPE(y_fixed) * jnp.ones_like(x)
        return jnp.concatenate([x, y, ts], axis=1), ids

    raise ValueError("Provide x_fixed or y_fixed")

def sample_ic_xy(key):
    y0 = DTYPE(0.02)
    y1 = y_max - DTYPE(0.02)

    dx = (x_max - x_min) / DTYPE(NX_IC)
    dy = (y1 - y0) / DTYPE(NY_IC)

    iy, ix = jnp.meshgrid(jnp.arange(NY_IC), jnp.arange(NX_IC), indexing="ij")
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids0 = (iy * NX_IC + ix).astype(jnp.int32)

    xb = x_min + DTYPE(ix) * dx
    yb = y0 + DTYPE(iy) * dy

    u = random.uniform(key, (K_IC, N_IC_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (xb[:, None] + u[:, :, 0] * dx).reshape(-1, 1)
    ys = (yb[:, None] + u[:, :, 1] * dy).reshape(-1, 1)
    ts = t_min * jnp.ones_like(xs)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IC_PER_BIN)
    return X, ids

def sample_interface_yt(key):
    dy = (y_max - y_min) / DTYPE(NY_IF)
    dt = (t_max - t_min) / DTYPE(NT_IF)

    it, iy = jnp.meshgrid(jnp.arange(NT_IF), jnp.arange(NY_IF), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ids0 = (it * NY_IF + iy).astype(jnp.int32)

    yb = y_min + DTYPE(iy) * dy
    tb = t_min + DTYPE(it) * dt

    u = random.uniform(key, (NY_IF * NT_IF, N_IF_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    ys = (yb[:, None] + u[:, :, 0] * dy).reshape(-1, 1)
    ts = (tb[:, None] + u[:, :, 1] * dt).reshape(-1, 1)
    xs = Ls * jnp.ones_like(ys)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IF_PER_BIN)
    return X, ids

# ============================================================
# JITTER + PROJECTIONS
# ============================================================
def jitter_xyt(key, X, sx, sy, st, clip_k=2.0):
    if X.shape[0] == 0 or ((sx <= 0) and (sy <= 0) and (st <= 0)):
        return X

    key, kx, ky, kt = random.split(key, 4)
    dx = DTYPE(sx) * random.normal(kx, (X.shape[0],), dtype=DTYPE)
    dy = DTYPE(sy) * random.normal(ky, (X.shape[0],), dtype=DTYPE)
    dt = DTYPE(st) * random.normal(kt, (X.shape[0],), dtype=DTYPE)

    k = DTYPE(clip_k)
    dx = jnp.clip(dx, -k * DTYPE(sx), k * DTYPE(sx))
    dy = jnp.clip(dy, -k * DTYPE(sy), k * DTYPE(sy))
    dt = jnp.clip(dt, -k * DTYPE(st), k * DTYPE(st))

    x = jnp.clip(X[:, 0] + dx, x_min, x_max)
    y = jnp.clip(X[:, 1] + dy, y_min, y_max)
    t = jnp.clip(X[:, 2] + dt, t_min, t_max)
    return jnp.stack([x, y, t], axis=1)

def project_x_fixed(X, x_fixed):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        DTYPE(x_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE),
        X[:, 1],
        X[:, 2],
    ], axis=1)

def project_y_fixed(X, y_fixed, *, x_lo=None, x_hi=None):
    if X.shape[0] == 0:
        return X
    x = X[:, 0]
    if (x_lo is not None) or (x_hi is not None):
        lo = DTYPE(x_lo if x_lo is not None else x_min)
        hi = DTYPE(x_hi if x_hi is not None else x_max)
        x = jnp.clip(x, lo, hi)
    y = DTYPE(y_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE)
    return jnp.stack([x, y, X[:, 2]], axis=1)

def project_t0(X):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        X[:, 0],
        X[:, 1],
        t_min * jnp.ones((X.shape[0],), dtype=DTYPE),
    ], axis=1)

def project_interface(X):
    return project_x_fixed(X, Ls)

# ============================================================
# PDE RESIDUALS
# ============================================================
def forward6(params, xyt):
    return mlp_apply(params, xyt[None, :])[0, :]

def eval_fields_and_derivs(params, X):
    out = vmap(lambda z: forward6(params, z))(X)
    J   = vmap(jacrev(lambda z: forward6(params, z)))(X)
    H   = vmap(hessian(lambda z: forward6(params, z)))(X)
    return out, J, H

def residuals_all(params, X):
    out, J, H = eval_fields_and_derivs(params, X)

    phi = out[:, 0]
    Ts  = out[:, 1]
    u   = out[:, 2]
    v   = out[:, 3]
    p   = out[:, 4]
    Tf  = out[:, 5]

    x = X[:, 0]
    is_solid = (x <= Ls)

    phi_t  = J[:, 0, 2]
    phi_xx = H[:, 0, 0, 0]
    phi_yy = H[:, 0, 1, 1]
    lap_phi = phi_xx + phi_yy

    Ts_x  = J[:, 1, 0]
    Ts_y  = J[:, 1, 1]
    Ts_t  = J[:, 1, 2]
    Ts_xx = H[:, 1, 0, 0]
    Ts_yy = H[:, 1, 1, 1]

    u_x, u_y, u_t = J[:, 2, 0], J[:, 2, 1], J[:, 2, 2]
    v_x, v_y, v_t = J[:, 3, 0], J[:, 3, 1], J[:, 3, 2]
    p_x, p_y      = J[:, 4, 0], J[:, 4, 1]
    Tf_x, Tf_y, Tf_t = J[:, 5, 0], J[:, 5, 1], J[:, 5, 2]

    u_xx, u_yy   = H[:, 2, 0, 0], H[:, 2, 1, 1]
    v_xx, v_yy   = H[:, 3, 0, 0], H[:, 3, 1, 1]
    Tf_xx, Tf_yy = H[:, 5, 0, 0], H[:, 5, 1, 1]

    T_for_sigma = jnp.where(is_solid, Ts, Tf)
    D_here      = jnp.where(is_solid, D_fuel, D_fluid)
    sig_here    = jnp.where(is_solid, sigma_af_fuel(T_for_sigma), sigma_af_fluid(T_for_sigma))

    r_phi_raw = (DTYPE(1.0) / v_neu) * phi_t - D_here * lap_phi - sig_here * phi
    r_phi = r_phi_raw / PHI_RES_SCALE

    div_k_grad_Ts = div_k_grad_scalar(k_s_fun(Ts), dk_s_dT, Ts, Ts_x, Ts_y, Ts_xx, Ts_yy)
    r_Ts_raw = rho_s * cp_s_fun(Ts) * Ts_t - div_k_grad_Ts - POWER_COEF * phi
    r_Ts = r_Ts_raw / TS_RES_SCALE

    r_cont_raw = u_x + v_y
    r_cont = r_cont_raw / CONT_SCALE

    mu_here = mu_f_fun(Tf)
    visc_u = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, u_x, u_y, u_xx, u_yy)
    visc_v = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, v_x, v_y, v_xx, v_yy)

    r_u_raw = rho_f * (u_t + u * u_x + v * u_y) + p_x - visc_u
    r_v_raw = rho_f * (v_t + u * v_x + v * v_y) + p_y - visc_v

    cp_here = cp_f_fun(Tf)
    div_k_grad_Tf = div_k_grad_scalar(k_f_fun(Tf), dk_f_dT, Tf, Tf_x, Tf_y, Tf_xx, Tf_yy)
    r_Tf_raw = rho_f * cp_here * (Tf_t + u * Tf_x + v * Tf_y) - div_k_grad_Tf

    r_u  = r_u_raw / MOMX_RES_SCALE
    r_v  = r_v_raw / MOMY_RES_SCALE
    r_Tf = r_Tf_raw / TF_RES_SCALE

    return r_phi, r_Ts, r_cont, r_u, r_v, r_Tf

# ============================================================
# OBJECTIVE
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_obj(theta, shapes, X_obj_phi, X_obj_s, X_obj_f,
                w_obj_phi, w_obj_Ts, w_obj_cont, w_obj_ru, w_obj_rv, w_obj_rTf):
    def obj_theta(th):
        params = unflatten_params(th, shapes)

        r_phi_obj, _, _, _, _, _ = residuals_all(params, X_obj_phi)
        _, r_Ts_obj, _, _, _, _  = residuals_all(params, X_obj_s)
        _, _, r_cont_obj, r_u_obj, r_v_obj, r_Tf_obj = residuals_all(params, X_obj_f)

        return (
            w_obj_phi  * jnp.mean(r_phi_obj ** 2)
            + w_obj_Ts * jnp.mean(r_Ts_obj ** 2)
            + w_obj_cont * jnp.mean(r_cont_obj ** 2)
            + w_obj_ru   * jnp.mean(r_u_obj ** 2)
            + w_obj_rv   * jnp.mean(r_v_obj ** 2)
            + w_obj_rTf  * jnp.mean(r_Tf_obj ** 2)
        )

    val, g = jax.value_and_grad(obj_theta)(theta)
    return val, g

# ============================================================
# CONSTRAINT VECTOR
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector(theta, shapes,
                      X_con_phi, ids_con_phi,
                      X_con_s, ids_con_s,
                      X_con_f, ids_con_f,
                      X_phi_left, ids_phi_left,
                      X_phi_right, ids_phi_right,
                      X_phi_y0, ids_phi_y0,
                      X_phi_y1, ids_phi_y1,
                      X_Ts_x0, ids_Ts_x0,
                      X_f_inlet, ids_f_inlet,
                      X_f_outlet, ids_f_outlet,
                      X_f_right, ids_f_right,
                      X_if, ids_if,
                      X_ic, ids_ic):
    params = unflatten_params(theta, shapes)

    # PDE hard constraints
    r_phi, _, _, _, _, _ = residuals_all(params, X_con_phi)
    _, r_Ts, _, _, _, _  = residuals_all(params, X_con_s)
    _, _, r_cont, r_u, r_v, r_Tf = residuals_all(params, X_con_f)

    c_pde_phi  = segment_sum(r_phi,  ids_con_phi, K_CON_PHI) / DTYPE(N_PER_CELL)
    c_pde_Ts   = segment_sum(r_Ts,   ids_con_s,   K_CON_S)   / DTYPE(N_PER_CELL)
    c_pde_cont = segment_sum(r_cont, ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_ru   = segment_sum(r_u,    ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_rv   = segment_sum(r_v,    ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_rTf  = segment_sum(r_Tf,   ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)

    # phi BCs
    phiL = mlp_apply(params, X_phi_left)[:, 0]
    yL, tL = X_phi_left[:, 1], X_phi_left[:, 2]
    c_phi_left = segment_sum((phiL - phi_left_target(yL, tL)) / PHI_VAL_SCALE, ids_phi_left, K_BC_PHI_LEFT) / DTYPE(N_BC_PER_BIN)

    phiR = mlp_apply(params, X_phi_right)[:, 0]
    c_phi_right = segment_sum((phiR - PHI_RIGHT_VAL) / PHI_VAL_SCALE, ids_phi_right, K_BC_PHI_RIGHT) / DTYPE(N_BC_PER_BIN)

    phiB = mlp_apply(params, X_phi_y0)[:, 0]
    c_phi_y0 = segment_sum((phiB - PHI_TOPBOT_VAL) / PHI_VAL_SCALE, ids_phi_y0, K_BC_PHI_Y0) / DTYPE(N_BC_PER_BIN)

    phiT = mlp_apply(params, X_phi_y1)[:, 0]
    c_phi_y1 = segment_sum((phiT - PHI_TOPBOT_VAL) / PHI_VAL_SCALE, ids_phi_y1, K_BC_PHI_Y1) / DTYPE(N_BC_PER_BIN)

    c_bc_phi = jnp.concatenate([c_phi_left, c_phi_right, c_phi_y0, c_phi_y1], axis=0)

    # solid BC
    def Ts_fun(z):
        return forward6(params, z)[1]

    Tsx_x0 = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_Ts_x0)
    c_bc_sol = segment_sum(Tsx_x0 / GRAD_TSX_SCALE, ids_Ts_x0, K_BC_TS_X0) / DTYPE(N_BC_PER_BIN)

    # fluid BCs
    out_in = mlp_apply(params, X_f_inlet)
    u_in, v_in, Tf_in = out_in[:, 2], out_in[:, 3], out_in[:, 5]
    x_in = X_f_inlet[:, 0]
    v_tar = inlet_v_profile(x_in)

    c_in_u  = segment_sum((u_in - DTYPE(0.0)) / U_VAL_SCALE, ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)
    c_in_v  = segment_sum((v_in - v_tar) / V_VAL_SCALE,      ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)
    c_in_Tf = segment_sum((Tf_in - T_INLET) / TF_VAL_SCALE,  ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)

    def u_fun(z):
        return forward6(params, z)[2]

    def v_fun(z):
        return forward6(params, z)[3]

    p_out = mlp_apply(params, X_f_outlet)[:, 4]
    uy_out = vmap(lambda z: jacrev(u_fun)(z)[1])(X_f_outlet)
    vy_out = vmap(lambda z: jacrev(v_fun)(z)[1])(X_f_outlet)

    c_out_p  = segment_sum((p_out - P_OUTLET) / P_VAL_SCALE, ids_f_outlet, K_BC_F_OUTLET) / DTYPE(N_BC_PER_BIN)
    c_out_uy = segment_sum((uy_out / GRAD_UY_SCALE),         ids_f_outlet, K_BC_F_OUTLET) / DTYPE(N_BC_PER_BIN)
    c_out_vy = segment_sum((vy_out / GRAD_VY_SCALE),         ids_f_outlet, K_BC_F_OUTLET) / DTYPE(N_BC_PER_BIN)

    out_right = mlp_apply(params, X_f_right)
    u_right = out_right[:, 2]
    vx_right = vmap(lambda z: jacrev(v_fun)(z)[0])(X_f_right)

    c_r_u  = segment_sum((u_right / U_VAL_SCALE),     ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)
    c_r_vx = segment_sum((vx_right / GRAD_VX_SCALE),  ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)

    c_bc_fld = jnp.concatenate([
        c_in_u, c_in_v, c_in_Tf,
        c_out_p, c_out_uy, c_out_vy,
        c_r_u, c_r_vx
    ], axis=0)

    # interface
    out_if = mlp_apply(params, X_if)
    Ts_if, Tf_if = out_if[:, 1], out_if[:, 5]

    c_if_T = segment_sum((Ts_if - Tf_if) / T_IF_VAL_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    Tsx_if = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_if)

    def Tf_fun(z):
        return forward6(params, z)[5]

    Tfx_if = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_if)

    flux_jump = -k_s_fun(Ts_if) * Tsx_if + k_f_fun(Tf_if) * Tfx_if
    c_if_q = segment_sum(flux_jump / FLUX_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    c_if = jnp.concatenate([c_if_T, c_if_q], axis=0)

    # IC
    out0 = mlp_apply(params, X_ic)
    phi0 = out0[:, 0]
    Ts0  = out0[:, 1]
    u0   = out0[:, 2]
    v0   = out0[:, 3]
    Tf0  = out0[:, 5]

    x0 = X_ic[:, 0]
    y0 = X_ic[:, 1]

    m_s0 = (x0 <= Ls).astype(DTYPE)
    m_f0 = (x0 >  Ls).astype(DTYPE)

    c_ic_phi = segment_sum((phi0 - phi_ic(y0)) / PHI_VAL_SCALE, ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Ts  = segment_sum(m_s0 * ((Ts0 - T_INLET) / TS_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_u   = segment_sum(m_f0 * ((u0 - FLUID_U_IC) / U_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_v   = segment_sum(m_f0 * ((v0 - FLUID_V_IC) / V_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Tf  = segment_sum(m_f0 * ((Tf0 - FLUID_T_IC) / TF_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)

    c_ic = jnp.concatenate([c_ic_phi, c_ic_Ts, c_ic_u, c_ic_v, c_ic_Tf], axis=0)

    return jnp.concatenate([
        c_pde_phi,
        c_pde_Ts,
        c_pde_cont, c_pde_ru, c_pde_rv, c_pde_rTf,
        c_bc_phi,
        c_bc_sol,
        c_bc_fld,
        c_if,
        c_ic
    ], axis=0)

@partial(jax.jit, static_argnames=("shapes",))
def C_and_J(theta, shapes, *args):
    def c_fun(th):
        return constraint_vector(th, shapes, *args)

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J, c = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c, J

@partial(jax.jit, static_argnames=("shapes",))
def C_only(theta, shapes, *args):
    return constraint_vector(theta, shapes, *args)

# ============================================================
# KKT solve
# ============================================================
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, mu_damp):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)
    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -mu_damp * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)
    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y

# ============================================================
# STEP HELPERS
# ============================================================
def cal_tau_mu(H, d, sigma, tau_pre, eps_tau, g, c, mu_eff, y):
    denom = float(g @ d + 0.5 * (d @ (H @ d)))
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    if (denom <= 1e-12) or (delta_c <= 0.0):
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * delta_c / denom
    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)

def cal_ksi_mu(d, tau, ksi_old, eps_ksi, g, c, mu_eff, y):
    d2 = float(jnp.linalg.norm(d) ** 2)
    if d2 <= 1e-18 or tau <= 1e-18:
        return ksi_old
    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    ksi_trial = Dl / (tau * d2)
    ksi_trial = max(0.0, ksi_trial)
    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)

def phi_mu(alpha, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma):
    gd = float(g @ d)
    d2 = float(d @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    term1 = (eta - 1.0) * alpha * beta * Dl
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * c1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3

def cal_alpha_mu(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c, mu_eff, y):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0
    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)
    while (
        phi_mu(1.1 * a, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma) < 0.0
        and (1.1 * a < alpha_min + theta_val * beta)
    ):
        a *= 1.1
    return float(a)

# ============================================================
# BLOCK SLICES / ROW SCALING
# ============================================================
def _block_slices():
    s = {}
    i = 0

    s["pde_phi"]  = slice(i, i + K_CON_PHI); i += K_CON_PHI
    s["pde_Ts"]   = slice(i, i + K_CON_S);   i += K_CON_S
    s["pde_cont"] = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_ru"]   = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_rv"]   = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_rTf"]  = slice(i, i + K_CON_F);   i += K_CON_F

    s["bc_phi"]   = slice(i, i + N_BC_PHI); i += N_BC_PHI
    s["bc_solid"] = slice(i, i + N_BC_SOL); i += N_BC_SOL
    s["bc_fluid"] = slice(i, i + N_BC_FLD); i += N_BC_FLD

    s["iface"]    = slice(i, i + N_IF); i += N_IF
    s["ic"]       = slice(i, i + N_IC); i += N_IC

    assert i == M_CON, (i, M_CON)
    return s

BLOCKS = _block_slices()

S_TARGET_PDE = DTYPE(1.0)
S_TARGET_BC  = DTYPE(1.0)
S_TARGET_IF  = DTYPE(1.0)
S_TARGET_IC  = DTYPE(1.0)
S_ROW_MIN    = DTYPE(1e-6)
S_ROW_MAX    = DTYPE(1.0)

@jax.jit
def row_rms(J_rows):
    return jnp.sqrt(jnp.mean(J_rows * J_rows, axis=1) + EPS)

@jax.jit
def make_block_row_scales(J, target_pde, target_bc, target_if, target_ic):
    s = jnp.ones((M_CON,), dtype=DTYPE)

    def set_block(name, target):
        sl = BLOCKS[name]
        rr = row_rms(J[sl, :])
        sb = target / jnp.maximum(target, rr)
        sb = jnp.clip(sb, S_ROW_MIN, S_ROW_MAX)
        return rr, sb

    rr_phi, sb_phi   = set_block("pde_phi", target_pde)
    rr_Ts, sb_Ts     = set_block("pde_Ts", target_pde)
    rr_cont, sb_cont = set_block("pde_cont", target_pde)
    rr_ru, sb_ru     = set_block("pde_ru", target_pde)
    rr_rv, sb_rv     = set_block("pde_rv", target_pde)
    rr_rTf, sb_rTf   = set_block("pde_rTf", target_pde)

    s = s.at[BLOCKS["pde_phi"]].set(sb_phi)
    s = s.at[BLOCKS["pde_Ts"]].set(sb_Ts)
    s = s.at[BLOCKS["pde_cont"]].set(sb_cont)
    s = s.at[BLOCKS["pde_ru"]].set(sb_ru)
    s = s.at[BLOCKS["pde_rv"]].set(sb_rv)
    s = s.at[BLOCKS["pde_rTf"]].set(sb_rTf)

    rr_bcphi, sb_bcphi = set_block("bc_phi", target_bc)
    rr_bcsol, sb_bcsol = set_block("bc_solid", target_bc)
    rr_bcfld, sb_bcfld = set_block("bc_fluid", target_bc)

    s = s.at[BLOCKS["bc_phi"]].set(sb_bcphi)
    s = s.at[BLOCKS["bc_solid"]].set(sb_bcsol)
    s = s.at[BLOCKS["bc_fluid"]].set(sb_bcfld)

    rr_if, sb_if = set_block("iface", target_if)
    rr_ic, sb_ic = set_block("ic", target_ic)

    s = s.at[BLOCKS["iface"]].set(sb_if)
    s = s.at[BLOCKS["ic"]].set(sb_ic)

    return s

@jax.jit
def apply_row_scale(c, J, s_row):
    return s_row * c, s_row[:, None] * J

def _rms(x):
    return float(jnp.sqrt(jnp.mean(x * x) + 1e-30))

def _maxabs(x):
    return float(jnp.max(jnp.abs(x)))

def print_block_stats(prefix, c):
    def pr(name):
        sl = BLOCKS[name]
        v = c[sl]
        print(f"  {name:10s}: rms={_rms(v):.3e}  max={_maxabs(v):.3e}")
    print(prefix)
    pr("pde_phi")
    pr("pde_Ts")
    pr("pde_cont")
    pr("pde_ru")
    pr("pde_rv")
    pr("pde_rTf")
    pr("bc_phi")
    pr("bc_solid")
    pr("bc_fluid")
    pr("iface")
    pr("ic")

# ============================================================
# TRAIN SQP
# ============================================================
def train_sqp(
    seed=0,
    hidden_dim=30,
    num_hidden=3,
    max_iters=1000,
    print_every=10,
    beta_shift=400.0,
    beta_power=0.6,
    alpha_cap=1e1,
    L_lip=60.0,
    Gamma_lip=60.0,
    jitter_every_iter=True,
    sx=1e-4,
    sy=1e-4,
    st=1e-4,
    sx_ic=1e-4,
    sy_ic=1e-4,
    sy_if=1e-4,
    st_if=1e-4,
    w_obj_phi=20.0,
    w_obj_Ts=10.0,
    w_obj_cont=20.0,
    w_obj_ru=40.0,
    w_obj_rv=40.0,
    w_obj_rTf=10.0,
):
    key = random.PRNGKey(seed)

    layer_sizes = [3] + [hidden_dim] * num_hidden + [6]
    key, k0 = random.split(key)
    params0 = init_mlp_params(k0, layer_sizes)
    theta, shapes = flatten_params(params0)

    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    # objective sets
    key, k_obj_phi, k_obj_s, k_obj_f = random.split(key, 4)
    X_obj_phi, _ = sample_stratified_3d(k_obj_phi, x_min, x_max, y_min, y_max, t_min, t_max, NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI)
    X_obj_s, _   = sample_stratified_3d(k_obj_s, x_min, Ls, y_min, y_max, t_min, t_max, NX_OBJ_S, NY_OBJ_S, NT_OBJ_S)
    X_obj_f, _   = sample_stratified_3d(k_obj_f, Ls, x_max, y_min, y_max, t_min, t_max, NX_OBJ_F, NY_OBJ_F, NT_OBJ_F)

    # constraint sets
    key, k_con_phi, k_con_s, k_con_f = random.split(key, 4)
    X_con_phi, ids_con_phi = sample_stratified_3d(k_con_phi, x_min, x_max, y_min, y_max, t_min, t_max, NX_CON_PHI, NY_CON_PHI, NT_CON_PHI)
    X_con_s, ids_con_s     = sample_stratified_3d(k_con_s,   x_min, Ls,    y_min, y_max, t_min, t_max, NX_CON_S,   NY_CON_S,   NT_CON_S)
    X_con_f, ids_con_f     = sample_stratified_3d(k_con_f,   Ls,    x_max, y_min, y_max, t_min, t_max, NX_CON_F,   NY_CON_F,   NT_CON_F)

    key, k1, k2, k3, k4, k5, k6, k7, k8, k9, k_ic = random.split(key, 11)

    X_phi_left,  ids_phi_left  = sample_bc_time_binned(k1, K_BC_PHI_LEFT,  x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_phi_right, ids_phi_right = sample_bc_time_binned(k2, K_BC_PHI_RIGHT, x_fixed=x_max, y_lo=y_min, y_hi=y_max)
    X_phi_y0,    ids_phi_y0    = sample_bc_time_binned(k3, K_BC_PHI_Y0,    y_fixed=y_min, x_lo=x_min, x_hi=x_max)
    X_phi_y1,    ids_phi_y1    = sample_bc_time_binned(k4, K_BC_PHI_Y1,    y_fixed=y_max, x_lo=x_min, x_hi=x_max)

    X_Ts_x0, ids_Ts_x0 = sample_bc_time_binned(k5, K_BC_TS_X0, x_fixed=x_min, y_lo=y_min, y_hi=y_max)

    xL = float(Ls + X_MARGIN)
    xR = float(x_max - X_MARGIN)

    X_f_inlet,  ids_f_inlet  = sample_bc_time_binned(k6, K_BC_F_INLET,  y_fixed=y_min, x_lo=xL, x_hi=xR)
    X_f_outlet, ids_f_outlet = sample_bc_time_binned(k7, K_BC_F_OUTLET, y_fixed=y_max, x_lo=xL, x_hi=xR)
    X_f_right,  ids_f_right  = sample_bc_time_binned(k8, K_BC_F_RIGHT,  x_fixed=x_max, y_lo=y_min, y_hi=y_max)

    X_if, ids_if = sample_interface_yt(k9)
    X_ic, ids_ic = sample_ic_xy(k_ic)

    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 1.0, 1.0

    print("M_CON =", int(M_CON), "n_params =", int(n))

    s_row_anchor = None
    t0_clock = time.time()

    for it in range(1, max_iters + 1):
        k_beta = (it // 10) * 10
        beta_k = float(min(1.0, (beta_shift / (beta_shift + k_beta)) ** beta_power))

        if jitter_every_iter:
            key, *ks = random.split(key, 16)
            (kj_obj_phi, kj_obj_s, kj_obj_f,
             kj_con_phi, kj_con_s, kj_con_f,
             kjL, kjR, kjB, kjT,
             kjSx, kjIn, kjOut, kjRight, kjIf) = ks[:15]
            key, kjIc = random.split(key)

            X_obj_phi_use = jitter_xyt(kj_obj_phi, X_obj_phi, sx, sy, st)
            X_obj_s_use   = jitter_xyt(kj_obj_s,   X_obj_s,   sx, sy, st)
            X_obj_f_use   = jitter_xyt(kj_obj_f,   X_obj_f,   sx, sy, st)

            X_con_phi_use = jitter_xyt(kj_con_phi, X_con_phi, sx, sy, st)
            X_con_s_use   = jitter_xyt(kj_con_s,   X_con_s,   sx, sy, st)
            X_con_f_use   = jitter_xyt(kj_con_f,   X_con_f,   sx, sy, st)

            X_phi_left_use  = project_x_fixed(jitter_xyt(kjL, X_phi_left,  0.0, sy, st), x_min)
            X_phi_right_use = project_x_fixed(jitter_xyt(kjR, X_phi_right, 0.0, sy, st), x_max)
            X_phi_y0_use    = project_y_fixed(jitter_xyt(kjB, X_phi_y0, sx, 0.0, st), y_min)
            X_phi_y1_use    = project_y_fixed(jitter_xyt(kjT, X_phi_y1, sx, 0.0, st), y_max)

            X_Ts_x0_use = project_x_fixed(jitter_xyt(kjSx, X_Ts_x0, 0.0, sy, st), x_min)

            X_f_inlet_use  = project_y_fixed(jitter_xyt(kjIn,    X_f_inlet,  sx, 0.0, st), y_min, x_lo=xL, x_hi=xR)
            X_f_outlet_use = project_y_fixed(jitter_xyt(kjOut,   X_f_outlet, sx, 0.0, st), y_max, x_lo=xL, x_hi=xR)
            X_f_right_use  = project_x_fixed(jitter_xyt(kjRight, X_f_right,  0.0, sy, st), x_max)

            X_if_use = project_interface(jitter_xyt(kjIf, X_if, 0.0, sy_if, st_if))
            X_ic_use = project_t0(jitter_xyt(kjIc, X_ic, sx_ic, sy_ic, 0.0))
        else:
            X_obj_phi_use = X_obj_phi
            X_obj_s_use   = X_obj_s
            X_obj_f_use   = X_obj_f
            X_con_phi_use = X_con_phi
            X_con_s_use   = X_con_s
            X_con_f_use   = X_con_f
            X_phi_left_use, X_phi_right_use, X_phi_y0_use, X_phi_y1_use = X_phi_left, X_phi_right, X_phi_y0, X_phi_y1
            X_Ts_x0_use = X_Ts_x0
            X_f_inlet_use, X_f_outlet_use, X_f_right_use = X_f_inlet, X_f_outlet, X_f_right
            X_if_use, X_ic_use = X_if, X_ic

        obj_val, g = F_and_g_obj(
            theta, shapes,
            X_obj_phi_use, X_obj_s_use, X_obj_f_use,
            DTYPE(w_obj_phi), DTYPE(w_obj_Ts), DTYPE(w_obj_cont),
            DTYPE(w_obj_ru), DTYPE(w_obj_rv), DTYPE(w_obj_rTf)
        )

        args = (
            X_con_phi_use, ids_con_phi,
            X_con_s_use, ids_con_s,
            X_con_f_use, ids_con_f,
            X_phi_left_use, ids_phi_left,
            X_phi_right_use, ids_phi_right,
            X_phi_y0_use, ids_phi_y0,
            X_phi_y1_use, ids_phi_y1,
            X_Ts_x0_use, ids_Ts_x0,
            X_f_inlet_use, ids_f_inlet,
            X_f_outlet_use, ids_f_outlet,
            X_f_right_use, ids_f_right,
            X_if_use, ids_if,
            X_ic_use, ids_ic,
        )

        c, J = C_and_J(theta, shapes, *args)

        if s_row_anchor is None:
            s_row_anchor = make_block_row_scales(J, S_TARGET_PDE, S_TARGET_BC, S_TARGET_IF, S_TARGET_IC)

        c_s, J_s = apply_row_scale(c, J, s_row_anchor)

        d, y_s = kkt_solve_once(H, J_s, g, c_s, MU_DAMP_FIXED)
        y = s_row_anchor * y_s

        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-12:
            tau_k = cal_tau_mu(H, d, sigma, tau_k, eps_tau, g, c_s, MU_DAMP_FIXED, y_s)
            ksi_k = cal_ksi_mu(d, tau_k, ksi_k, eps_ksi, g, c_s, MU_DAMP_FIXED, y_s)
            alpha = cal_alpha_mu(d, eta, beta_k, ksi_k, tau_k, L_lip, Gamma_lip, theta_val, g, c_s, MU_DAMP_FIXED, y_s)
        else:
            alpha = 0.0

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d

        if it % int(print_every) == 0:
            c_now = C_only(theta, shapes, *args)
            feas_raw = float(jnp.mean(c_now ** 2))
            station  = float(jnp.linalg.norm(g + J.T @ y, jnp.inf))

            print(f"[it={it}] obj={float(obj_val):.3e} feas_raw={feas_raw:.3e} alpha={alpha:.2e} beta={beta_k:.2e} station={station:.2e} dn={dn:.2e}")
            print_block_stats("blocks (unscaled c):", c_now)

            params_now = unflatten_params(theta, shapes)
            r_phi_obj, _, _, _, _, _ = residuals_all(params_now, X_obj_phi_use)
            _, r_Ts_obj, _, _, _, _  = residuals_all(params_now, X_obj_s_use)
            _, _, r_cont_obj, r_u_obj, r_v_obj, r_Tf_obj = residuals_all(params_now, X_obj_f_use)
            print(
                "Scaled PDE RMS on obj:",
                "phi", _rms(r_phi_obj),
                "Ts", _rms(r_Ts_obj),
                "cont", _rms(r_cont_obj),
                "ru", _rms(r_u_obj),
                "rv", _rms(r_v_obj),
                "rTf", _rms(r_Tf_obj),
            )

    print(f"[done] elapsed={time.time() - t0_clock:.2f}s")
    return theta

# ============================================================
# MAIN
# ============================================================
def main():
    theta = train_sqp(
        seed=0,
        hidden_dim=35,
        num_hidden=3,
        max_iters=700,
        print_every=10,
        beta_shift=200.0,
        beta_power=0.6,
        alpha_cap=1e1,
        L_lip=40.0,
        Gamma_lip=40.0,
        jitter_every_iter=True,
        sx=1e-5,
        sy=1e-5,
        st=1e-5,
        sx_ic=1e-5,
        sy_ic=1e-5,
        sy_if=1e-5,
        st_if=1e-5,
        w_obj_phi=5.0,
        w_obj_Ts=5.0,
        w_obj_cont=20.0,
        w_obj_ru=60.0,
        w_obj_rv=60.0,
        w_obj_rTf=5.0,
    )

    np.save("theta_sqp_pinn_clean.npy", np.array(theta))
    print("Saved theta -> theta_sqp_pinn_clean.npy")

if __name__ == "__main__":
    main()
# Out:
# Loaded phi.txt: (65,) (16,) (65, 16) range= 0.5 6.2
# Loaded tfluid truth: (4, 17, 12, 64)
# M_CON = 2898 n_params = 2876
# [it=10] obj=5.251e+01 feas_raw=6.782e-01 alpha=2.25e-03 beta=9.71e-01 station=1.43e+01 dn=1.43e+01
# blocks (unscaled c):
#   pde_phi   : rms=1.484e+00  max=4.302e+00
#   pde_Ts    : rms=3.636e-01  max=9.792e-01
#   pde_cont  : rms=5.884e-01  max=1.374e+00
#   pde_ru    : rms=5.456e-01  max=1.683e+00
#   pde_rv    : rms=4.862e-01  max=1.696e+00
#   pde_rTf   : rms=3.383e-01  max=9.279e-01
#   bc_phi    : rms=7.796e-01  max=1.692e+00
#   bc_solid  : rms=2.054e-01  max=3.758e-01
#   bc_fluid  : rms=8.788e-01  max=2.397e+00
#   iface     : rms=7.753e-01  max=1.448e+00
#   ic        : rms=8.877e-01  max=2.751e+00
# Scaled PDE RMS on obj: phi 1.4570986050402852 Ts 0.3595779435511053 cont 0.5979890237842167 ru 0.5527235014013908 rv 0.49718888395587757 rTf 0.33302330679516745
# [it=20] obj=4.776e+01 feas_raw=6.345e-01 alpha=3.21e-03 beta=9.44e-01 station=1.84e+01 dn=1.84e+01
# blocks (unscaled c):
#   pde_phi   : rms=1.440e+00  max=4.203e+00
#   pde_Ts    : rms=3.548e-01  max=9.531e-01
#   pde_cont  : rms=5.614e-01  max=1.304e+00
#   pde_ru    : rms=5.127e-01  max=1.541e+00
#   pde_rv    : rms=4.673e-01  max=1.622e+00
#   pde_rTf   : rms=3.242e-01  max=8.768e-01
#   bc_phi    : rms=7.596e-01  max=1.647e+00
#   bc_solid  : rms=1.991e-01  max=3.653e-01
#   bc_fluid  : rms=8.548e-01  max=2.332e+00
#   iface     : rms=7.540e-01  max=1.409e+00
#   ic        : rms=8.575e-01  max=2.656e+00
# Scaled PDE RMS on obj: phi 1.4116270443002978 Ts 0.35143079334382044 cont 0.573555528249833 ru 0.516472102783415 rv 0.47563650323973294 rTf 0.3184551568848226
# [it=30] obj=4.149e+01 feas_raw=5.613e-01 alpha=8.11e-03 beta=9.20e-01 station=1.14e+01 dn=1.14e+01
# blocks (unscaled c):
#   pde_phi   : rms=1.360e+00  max=3.961e+00
#   pde_Ts    : rms=3.385e-01  max=9.091e-01
#   pde_cont  : rms=5.118e-01  max=1.205e+00
#   pde_ru    : rms=4.718e-01  max=1.503e+00
#   pde_rv    : rms=4.326e-01  max=1.493e+00
#   pde_rTf   : rms=3.030e-01  max=8.382e-01
#   bc_phi    : rms=7.202e-01  max=1.562e+00
#   bc_solid  : rms=1.863e-01  max=3.439e-01
#   bc_fluid  : rms=8.069e-01  max=2.214e+00
#   iface     : rms=7.113e-01  max=1.348e+00
#   ic        : rms=8.062e-01  max=2.472e+00
# Scaled PDE RMS on obj: phi 1.326711217199355 Ts 0.336182381987777 cont 0.5417053171015372 ru 0.4789757777850686 rv 0.4400994889954741 rTf 0.2976579016510555
# [it=40] obj=3.845e+01 feas_raw=4.145e-01 alpha=3.30e-02 beta=8.96e-01 station=4.33e+00 dn=4.33e+00
# blocks (unscaled c):
#   pde_phi   : rms=1.135e+00  max=3.280e+00
#   pde_Ts    : rms=2.807e-01  max=7.546e-01
#   pde_cont  : rms=4.449e-01  max=1.103e+00
#   pde_ru    : rms=4.193e-01  max=1.456e+00
#   pde_rv    : rms=3.507e-01  max=1.163e+00
#   pde_rTf   : rms=2.478e-01  max=6.951e-01
#   bc_phi    : rms=6.037e-01  max=1.314e+00
#   bc_solid  : rms=1.485e-01  max=2.864e-01
#   bc_fluid  : rms=6.839e-01  max=1.871e+00
#   iface     : rms=5.946e-01  max=1.115e+00
#   ic        : rms=7.014e-01  max=2.080e+00
# Scaled PDE RMS on obj: phi 1.1041021794337575 Ts 0.2809501034312958 cont 0.6255969742225389 ru 0.5240189015977262 rv 0.383469904245246 rTf 0.24949937450575851
# [it=50] obj=3.635e+01 feas_raw=7.802e-02 alpha=1.11e-01 beta=8.75e-01 station=1.08e+00 dn=1.08e+00
# blocks (unscaled c):
#   pde_phi   : rms=5.238e-01  max=1.488e+00
#   pde_Ts    : rms=1.330e-01  max=3.658e-01
#   pde_cont  : rms=2.780e-01  max=7.387e-01
#   pde_ru    : rms=2.098e-01  max=1.046e+00
#   pde_rv    : rms=1.803e-01  max=4.386e-01
#   pde_rTf   : rms=1.123e-01  max=3.804e-01
#   bc_phi    : rms=2.797e-01  max=6.227e-01
#   bc_solid  : rms=6.943e-02  max=1.323e-01
#   bc_fluid  : rms=2.908e-01  max=8.543e-01
#   iface     : rms=2.733e-01  max=4.976e-01
#   ic        : rms=2.915e-01  max=8.802e-01
# Scaled PDE RMS on obj: phi 0.5703101916766531 Ts 0.13430845415789555 cont 0.8716182265614004 ru 0.47726802723556916 rv 0.2428659189596379 rTf 0.11275613473658852
# [it=60] obj=1.279e+01 feas_raw=4.237e-03 alpha=1.20e-01 beta=8.54e-01 station=4.78e-01 dn=4.78e-01
# blocks (unscaled c):
#   pde_phi   : rms=1.143e-01  max=3.326e-01
#   pde_Ts    : rms=2.504e-02  max=6.572e-02
#   pde_cont  : rms=1.138e-01  max=4.440e-01
#   pde_ru    : rms=6.799e-02  max=4.508e-01
#   pde_rv    : rms=3.389e-02  max=1.032e-01
#   pde_rTf   : rms=2.000e-02  max=6.836e-02
#   bc_phi    : rms=5.439e-02  max=1.228e-01
#   bc_solid  : rms=1.254e-02  max=2.336e-02
#   bc_fluid  : rms=6.707e-02  max=2.373e-01
#   iface     : rms=5.546e-02  max=9.877e-02
#   ic        : rms=6.433e-02  max=2.270e-01
# Scaled PDE RMS on obj: phi 0.3597801155665905 Ts 0.04145853989730001 cont 0.6289390463148191 ru 0.19650373877944727 rv 0.10400821105742394 rTf 0.02573481529536609
# [it=70] obj=3.920e+00 feas_raw=2.477e-04 alpha=2.07e-01 beta=8.35e-01 station=1.96e-01 dn=1.96e-01
# blocks (unscaled c):
#   pde_phi   : rms=1.712e-02  max=4.586e-02
#   pde_Ts    : rms=3.321e-03  max=8.583e-03
#   pde_cont  : rms=4.697e-02  max=2.026e-01
#   pde_ru    : rms=2.319e-02  max=2.000e-01
#   pde_rv    : rms=6.647e-03  max=2.518e-02
#   pde_rTf   : rms=3.267e-03  max=1.417e-02
#   bc_phi    : rms=7.402e-03  max=1.687e-02
#   bc_solid  : rms=1.798e-03  max=3.516e-03
#   bc_fluid  : rms=2.043e-02  max=1.149e-01
#   iface     : rms=7.781e-03  max=1.406e-02
#   ic        : rms=1.040e-02  max=3.900e-02
# Scaled PDE RMS on obj: phi 0.347552725587888 Ts 0.036775332820952335 cont 0.34089082971728923 ru 0.0687500712495993 rv 0.04609723071009965 rTf 0.007810715800105397
# [it=80] obj=1.253e+00 feas_raw=1.478e-05 alpha=1.26e-01 beta=8.17e-01 station=1.21e-01 dn=1.21e-01
# blocks (unscaled c):
#   pde_phi   : rms=3.999e-03  max=1.554e-02
#   pde_Ts    : rms=5.625e-04  max=1.461e-03
#   pde_cont  : rms=1.283e-02  max=3.639e-02
#   pde_ru    : rms=4.534e-03  max=3.685e-02
#   pde_rv    : rms=1.296e-03  max=4.426e-03
#   pde_rTf   : rms=7.022e-04  max=2.485e-03
#   bc_phi    : rms=1.340e-03  max=3.632e-03
#   bc_solid  : rms=2.888e-04  max=5.982e-04
#   bc_fluid  : rms=6.196e-03  max=3.276e-02
#   iface     : rms=1.200e-03  max=2.438e-03
#   ic        : rms=1.286e-03  max=8.565e-03
# Scaled PDE RMS on obj: phi 0.29851853516872356 Ts 0.03894723903379487 cont 0.1820358285410706 ru 0.027339645378521515 rv 0.022832351739107873 rTf 0.0032044547300218353
# [it=90] obj=8.931e-01 feas_raw=2.666e-06 alpha=1.02e-01 beta=8.00e-01 station=7.73e-02 dn=7.73e-02
# blocks (unscaled c):
#   pde_phi   : rms=2.145e-03  max=5.713e-03
#   pde_Ts    : rms=2.511e-04  max=7.125e-04
#   pde_cont  : rms=5.433e-03  max=1.360e-02
#   pde_ru    : rms=1.667e-03  max=1.187e-02
#   pde_rv    : rms=5.647e-04  max=2.022e-03
#   pde_rTf   : rms=4.085e-04  max=1.495e-03
#   bc_phi    : rms=5.268e-04  max=1.872e-03
#   bc_solid  : rms=1.495e-04  max=5.770e-04
#   bc_fluid  : rms=2.676e-03  max=1.339e-02
#   iface     : rms=4.443e-04  max=1.025e-03
#   ic        : rms=5.094e-04  max=2.576e-03
# Scaled PDE RMS on obj: phi 0.27841461540676965 Ts 0.038537037077400325 cont 0.14591194645991973 ru 0.024088262932467644 rv 0.018176639495866155 rTf 0.0021460574655461544
# [it=100] obj=7.637e-01 feas_raw=7.245e-07 alpha=9.06e-02 beta=7.84e-01 station=5.49e-02 dn=5.49e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.997e-03  max=5.439e-03
#   pde_Ts    : rms=1.810e-04  max=5.149e-04
#   pde_cont  : rms=2.683e-03  max=7.691e-03
#   pde_ru    : rms=8.764e-04  max=4.720e-03
#   pde_rv    : rms=2.950e-04  max=9.467e-04
#   pde_rTf   : rms=3.394e-04  max=1.315e-03
#   bc_phi    : rms=2.983e-04  max=1.287e-03
#   bc_solid  : rms=1.300e-04  max=4.915e-04
#   bc_fluid  : rms=1.301e-03  max=6.144e-03
#   iface     : rms=2.826e-04  max=8.722e-04
#   ic        : rms=2.788e-04  max=1.503e-03
# Scaled PDE RMS on obj: phi 0.26598025318131835 Ts 0.03800051490091237 cont 0.1313296837373437 ru 0.023135588308988563 rv 0.0166167094040112 rTf 0.0018561773784109416
# [it=110] obj=6.911e-01 feas_raw=2.680e-07 alpha=7.34e-02 beta=7.69e-01 station=4.49e-02 dn=4.49e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.556e-03  max=4.803e-03
#   pde_Ts    : rms=1.616e-04  max=4.801e-04
#   pde_cont  : rms=1.499e-03  max=4.963e-03
#   pde_ru    : rms=5.795e-04  max=2.269e-03
#   pde_rv    : rms=1.902e-04  max=6.526e-04
#   pde_rTf   : rms=3.128e-04  max=1.237e-03
#   bc_phi    : rms=2.213e-04  max=1.024e-03
#   bc_solid  : rms=1.222e-04  max=4.181e-04
#   bc_fluid  : rms=7.229e-04  max=3.483e-03
#   iface     : rms=2.430e-04  max=7.964e-04
#   ic        : rms=1.872e-04  max=1.011e-03
# Scaled PDE RMS on obj: phi 0.2573911053989961 Ts 0.03759838296445823 cont 0.12285925244164284 ru 0.02257203785355775 rv 0.015780550317624386 rTf 0.0017462413171192605
# [it=120] obj=6.431e-01 feas_raw=1.695e-07 alpha=6.55e-02 beta=7.54e-01 station=3.76e-02 dn=3.76e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.657e-03  max=6.990e-03
#   pde_Ts    : rms=1.197e-04  max=4.413e-04
#   pde_cont  : rms=1.055e-03  max=5.428e-03
#   pde_ru    : rms=4.795e-04  max=1.504e-03
#   pde_rv    : rms=1.649e-04  max=7.820e-04
#   pde_rTf   : rms=3.000e-04  max=1.189e-03
#   bc_phi    : rms=1.830e-04  max=8.592e-04
#   bc_solid  : rms=1.169e-04  max=3.652e-04
#   bc_fluid  : rms=4.577e-04  max=2.792e-03
#   iface     : rms=2.272e-04  max=7.488e-04
#   ic        : rms=1.487e-04  max=7.682e-04
# Scaled PDE RMS on obj: phi 0.2511516836633839 Ts 0.037309153301725406 cont 0.11695457724542725 ru 0.022160650132571957 rv 0.015197807525234244 rTf 0.0016833491173277426
# [it=130] obj=6.060e-01 feas_raw=1.363e-07 alpha=6.43e-02 beta=7.40e-01 station=3.37e-02 dn=3.37e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.443e-03  max=6.003e-03
#   pde_Ts    : rms=1.526e-04  max=5.103e-04
#   pde_cont  : rms=1.080e-03  max=5.041e-03
#   pde_ru    : rms=4.279e-04  max=1.380e-03
#   pde_rv    : rms=1.495e-04  max=6.807e-04
#   pde_rTf   : rms=2.896e-04  max=1.160e-03
#   bc_phi    : rms=1.568e-04  max=7.632e-04
#   bc_solid  : rms=1.130e-04  max=3.303e-04
#   bc_fluid  : rms=3.159e-04  max=1.769e-03
#   iface     : rms=2.171e-04  max=7.133e-04
#   ic        : rms=1.295e-04  max=7.268e-04
# Scaled PDE RMS on obj: phi 0.24593567158722485 Ts 0.037110694321256806 cont 0.11222303656266042 ru 0.02183223532735789 rv 0.014713438446888182 rTf 0.0016321754235941186
# [it=140] obj=5.758e-01 feas_raw=9.724e-08 alpha=6.32e-02 beta=7.27e-01 station=2.96e-02 dn=2.96e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.246e-03  max=5.903e-03
#   pde_Ts    : rms=1.844e-04  max=5.470e-04
#   pde_cont  : rms=8.058e-04  max=3.114e-03
#   pde_ru    : rms=3.897e-04  max=1.289e-03
#   pde_rv    : rms=1.234e-04  max=5.572e-04
#   pde_rTf   : rms=2.815e-04  max=1.129e-03
#   bc_phi    : rms=1.466e-04  max=6.527e-04
#   bc_solid  : rms=1.096e-04  max=3.075e-04
#   bc_fluid  : rms=2.954e-04  max=1.976e-03
#   iface     : rms=2.092e-04  max=6.825e-04
#   ic        : rms=1.191e-04  max=6.583e-04
# Scaled PDE RMS on obj: phi 0.2415188448459476 Ts 0.0369274339965756 cont 0.1082585966939684 ru 0.02155030015987154 rv 0.014308709737186825 rTf 0.0015939663528395098
# [it=150] obj=5.476e-01 feas_raw=1.090e-07 alpha=6.83e-02 beta=7.15e-01 station=2.62e-02 dn=2.62e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.371e-03  max=4.357e-03
#   pde_Ts    : rms=1.658e-04  max=7.136e-04
#   pde_cont  : rms=9.577e-04  max=4.222e-03
#   pde_ru    : rms=3.532e-04  max=1.212e-03
#   pde_rv    : rms=1.266e-04  max=5.406e-04
#   pde_rTf   : rms=2.739e-04  max=1.107e-03
#   bc_phi    : rms=1.316e-04  max=5.832e-04
#   bc_solid  : rms=1.064e-04  max=3.168e-04
#   bc_fluid  : rms=2.374e-04  max=1.583e-03
#   iface     : rms=2.018e-04  max=6.522e-04
#   ic        : rms=1.122e-04  max=6.268e-04
# Scaled PDE RMS on obj: phi 0.23708440557715035 Ts 0.036753136025081665 cont 0.1044923399214241 ru 0.02128117326589919 rv 0.013915918432624587 rTf 0.0015544854929728429
# [it=160] obj=5.228e-01 feas_raw=9.775e-08 alpha=7.39e-02 beta=7.03e-01 station=2.38e-02 dn=2.38e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.201e-03  max=3.590e-03
#   pde_Ts    : rms=1.367e-04  max=4.190e-04
#   pde_cont  : rms=9.732e-04  max=5.721e-03
#   pde_ru    : rms=3.469e-04  max=1.147e-03
#   pde_rv    : rms=1.138e-04  max=4.903e-04
#   pde_rTf   : rms=2.671e-04  max=1.084e-03
#   bc_phi    : rms=1.144e-04  max=4.876e-04
#   bc_solid  : rms=1.032e-04  max=3.251e-04
#   bc_fluid  : rms=2.177e-04  max=1.395e-03
#   iface     : rms=1.951e-04  max=6.240e-04
#   ic        : rms=1.069e-04  max=6.248e-04
# Scaled PDE RMS on obj: phi 0.2330204111653267 Ts 0.03662833588702172 cont 0.10111379322448522 ru 0.021044287949762923 rv 0.013558241024333681 rTf 0.0015193071055223507
# [it=170] obj=4.988e-01 feas_raw=7.440e-08 alpha=7.27e-02 beta=6.91e-01 station=2.17e-02 dn=2.17e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.115e-03  max=3.511e-03
#   pde_Ts    : rms=1.459e-04  max=5.144e-04
#   pde_cont  : rms=7.132e-04  max=3.489e-03
#   pde_ru    : rms=3.168e-04  max=1.077e-03
#   pde_rv    : rms=1.128e-04  max=4.691e-04
#   pde_rTf   : rms=2.593e-04  max=1.057e-03
#   bc_phi    : rms=1.094e-04  max=4.407e-04
#   bc_solid  : rms=1.004e-04  max=3.333e-04
#   bc_fluid  : rms=2.446e-04  max=2.900e-03
#   iface     : rms=1.886e-04  max=5.952e-04
#   ic        : rms=1.020e-04  max=6.036e-04
# Scaled PDE RMS on obj: phi 0.2291053940317585 Ts 0.03650540318683543 cont 0.09776695921313114 ru 0.02081015523781727 rv 0.013193214126188992 rTf 0.001489657934992072
# [it=180] obj=4.762e-01 feas_raw=6.987e-08 alpha=7.87e-02 beta=6.80e-01 station=2.08e-02 dn=2.08e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.743e-04  max=2.538e-03
#   pde_Ts    : rms=1.736e-04  max=6.269e-04
#   pde_cont  : rms=7.801e-04  max=4.872e-03
#   pde_ru    : rms=3.025e-04  max=1.012e-03
#   pde_rv    : rms=1.062e-04  max=4.293e-04
#   pde_rTf   : rms=2.526e-04  max=1.033e-03
#   bc_phi    : rms=9.537e-05  max=4.160e-04
#   bc_solid  : rms=9.768e-05  max=3.388e-04
#   bc_fluid  : rms=2.260e-04  max=2.459e-03
#   iface     : rms=1.822e-04  max=5.653e-04
#   ic        : rms=9.748e-05  max=5.690e-04
# Scaled PDE RMS on obj: phi 0.2249979631650735 Ts 0.036413033996140785 cont 0.09463671938563245 ru 0.020599306257621113 rv 0.012877269388270066 rTf 0.0014593300275596694
# [it=190] obj=4.541e-01 feas_raw=7.573e-08 alpha=9.37e-02 beta=6.70e-01 station=1.86e-02 dn=1.86e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.305e-03  max=4.605e-03
#   pde_Ts    : rms=1.732e-04  max=6.784e-04
#   pde_cont  : rms=6.720e-04  max=3.636e-03
#   pde_ru    : rms=2.902e-04  max=9.627e-04
#   pde_rv    : rms=1.065e-04  max=4.335e-04
#   pde_rTf   : rms=2.448e-04  max=1.012e-03
#   bc_phi    : rms=9.702e-05  max=3.825e-04
#   bc_solid  : rms=9.490e-05  max=3.441e-04
#   bc_fluid  : rms=1.707e-04  max=1.898e-03
#   iface     : rms=1.759e-04  max=5.335e-04
#   ic        : rms=9.387e-05  max=5.387e-04
# Scaled PDE RMS on obj: phi 0.22075737762959538 Ts 0.036318090674045116 cont 0.09148829950043484 ru 0.0203639783588209 rv 0.012532126437803204 rTf 0.0014302703852457732
# [it=200] obj=4.334e-01 feas_raw=7.023e-08 alpha=1.02e-01 beta=6.60e-01 station=1.76e-02 dn=1.76e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.227e-03  max=3.987e-03
#   pde_Ts    : rms=1.498e-04  max=4.587e-04
#   pde_cont  : rms=6.535e-04  max=3.246e-03
#   pde_ru    : rms=2.767e-04  max=9.137e-04
#   pde_rv    : rms=1.002e-04  max=4.269e-04
#   pde_rTf   : rms=2.383e-04  max=9.911e-04
#   bc_phi    : rms=7.882e-05  max=2.984e-04
#   bc_solid  : rms=9.237e-05  max=3.480e-04
#   bc_fluid  : rms=1.964e-04  max=1.959e-03
#   iface     : rms=1.696e-04  max=5.002e-04
#   ic        : rms=8.982e-05  max=4.983e-04
# Scaled PDE RMS on obj: phi 0.21675477681300062 Ts 0.036235928504295974 cont 0.08849533161068308 ru 0.020146890340833664 rv 0.012231325569135289 rTf 0.0014037681931582892
# [it=210] obj=4.140e-01 feas_raw=7.075e-08 alpha=1.21e-01 beta=6.50e-01 station=1.67e-02 dn=1.67e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.134e-03  max=3.482e-03
#   pde_Ts    : rms=1.596e-04  max=6.178e-04
#   pde_cont  : rms=7.576e-04  max=4.354e-03
#   pde_ru    : rms=2.585e-04  max=8.671e-04
#   pde_rv    : rms=1.004e-04  max=4.055e-04
#   pde_rTf   : rms=2.312e-04  max=9.657e-04
#   bc_phi    : rms=8.096e-05  max=3.859e-04
#   bc_solid  : rms=8.975e-05  max=3.506e-04
#   bc_fluid  : rms=1.962e-04  max=1.765e-03
#   iface     : rms=1.635e-04  max=4.671e-04
#   ic        : rms=8.632e-05  max=4.827e-04
# Scaled PDE RMS on obj: phi 0.2126632607733137 Ts 0.036173988844692556 cont 0.0856992949190805 ru 0.01995194354993736 rv 0.011924894545811006 rTf 0.0013781182225000644
# [it=220] obj=3.942e-01 feas_raw=6.995e-08 alpha=1.31e-01 beta=6.41e-01 station=1.49e-02 dn=1.49e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.287e-03  max=4.436e-03
#   pde_Ts    : rms=1.673e-04  max=5.452e-04
#   pde_cont  : rms=6.579e-04  max=3.436e-03
#   pde_ru    : rms=2.466e-04  max=8.113e-04
#   pde_rv    : rms=8.882e-05  max=3.595e-04
#   pde_rTf   : rms=2.236e-04  max=9.410e-04
#   bc_phi    : rms=7.543e-05  max=2.667e-04
#   bc_solid  : rms=8.711e-05  max=3.506e-04
#   bc_fluid  : rms=1.559e-04  max=1.298e-03
#   iface     : rms=1.571e-04  max=4.309e-04
#   ic        : rms=8.281e-05  max=4.433e-04
# Scaled PDE RMS on obj: phi 0.2084089135463494 Ts 0.0361206966935795 cont 0.08275530191431835 ru 0.01975032490316452 rv 0.011622428379927384 rTf 0.0013555153043076345
# [it=230] obj=3.754e-01 feas_raw=5.656e-08 alpha=1.42e-01 beta=6.32e-01 station=1.33e-02 dn=1.33e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.093e-03  max=3.400e-03
#   pde_Ts    : rms=1.304e-04  max=3.977e-04
#   pde_cont  : rms=6.402e-04  max=3.819e-03
#   pde_ru    : rms=2.370e-04  max=8.024e-04
#   pde_rv    : rms=9.283e-05  max=3.723e-04
#   pde_rTf   : rms=2.171e-04  max=9.196e-04
#   bc_phi    : rms=8.057e-05  max=4.168e-04
#   bc_solid  : rms=8.426e-05  max=3.496e-04
#   bc_fluid  : rms=1.234e-04  max=7.230e-04
#   iface     : rms=1.506e-04  max=4.029e-04
#   ic        : rms=7.929e-05  max=4.286e-04
# Scaled PDE RMS on obj: phi 0.20414133747700228 Ts 0.036063929602689296 cont 0.079966278598353 ru 0.019565082710491826 rv 0.01135730924278988 rTf 0.0013339628371968153
# [it=240] obj=3.566e-01 feas_raw=5.465e-08 alpha=1.70e-01 beta=6.23e-01 station=1.29e-02 dn=1.29e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.046e-03  max=3.310e-03
#   pde_Ts    : rms=1.167e-04  max=5.201e-04
#   pde_cont  : rms=6.185e-04  max=3.113e-03
#   pde_ru    : rms=2.218e-04  max=7.640e-04
#   pde_rv    : rms=8.918e-05  max=3.188e-04
#   pde_rTf   : rms=2.108e-04  max=8.987e-04
#   bc_phi    : rms=6.666e-05  max=2.642e-04
#   bc_solid  : rms=8.177e-05  max=3.487e-04
#   bc_fluid  : rms=1.829e-04  max=1.611e-03
#   iface     : rms=1.441e-04  max=3.788e-04
#   ic        : rms=7.576e-05  max=3.954e-04
# Scaled PDE RMS on obj: phi 0.19968888851212785 Ts 0.0360066028018266 cont 0.07710207667685727 ru 0.019377631376194127 rv 0.011106637531204411 rTf 0.0013116212877837229
# [it=250] obj=3.393e-01 feas_raw=5.229e-08 alpha=1.84e-01 beta=6.15e-01 station=1.11e-02 dn=1.11e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.160e-03  max=3.973e-03
#   pde_Ts    : rms=1.151e-04  max=4.573e-04
#   pde_cont  : rms=5.018e-04  max=2.204e-03
#   pde_ru    : rms=2.123e-04  max=7.495e-04
#   pde_rv    : rms=8.562e-05  max=3.204e-04
#   pde_rTf   : rms=2.041e-04  max=8.757e-04
#   bc_phi    : rms=6.320e-05  max=2.522e-04
#   bc_solid  : rms=7.887e-05  max=3.450e-04
#   bc_fluid  : rms=1.501e-04  max=1.159e-03
#   iface     : rms=1.379e-04  max=3.530e-04
#   ic        : rms=7.201e-05  max=3.630e-04
# Scaled PDE RMS on obj: phi 0.19548639713070978 Ts 0.035984482600698094 cont 0.07440720119664525 ru 0.019217453708811692 rv 0.01087355757747297 rTf 0.0012963634606976912
# [it=260] obj=3.221e-01 feas_raw=5.401e-08 alpha=2.00e-01 beta=6.07e-01 station=1.04e-02 dn=1.04e-02
# blocks (unscaled c):
#   pde_phi   : rms=9.546e-04  max=3.099e-03
#   pde_Ts    : rms=1.171e-04  max=4.537e-04
#   pde_cont  : rms=5.879e-04  max=3.547e-03
#   pde_ru    : rms=2.066e-04  max=7.130e-04
#   pde_rv    : rms=8.151e-05  max=2.868e-04
#   pde_rTf   : rms=1.981e-04  max=8.461e-04
#   bc_phi    : rms=6.618e-05  max=3.289e-04
#   bc_solid  : rms=7.568e-05  max=3.391e-04
#   bc_fluid  : rms=2.813e-04  max=4.129e-03
#   iface     : rms=1.318e-04  max=3.399e-04
#   ic        : rms=6.886e-05  max=3.524e-04
# Scaled PDE RMS on obj: phi 0.19089796139381393 Ts 0.0359228961547272 cont 0.0718021802451685 ru 0.019050922691357414 rv 0.01065452157868855 rTf 0.0012796244180284387
# [it=270] obj=3.053e-01 feas_raw=4.505e-08 alpha=2.39e-01 beta=5.99e-01 station=1.04e-02 dn=1.04e-02
# blocks (unscaled c):
#   pde_phi   : rms=8.765e-04  max=2.378e-03
#   pde_Ts    : rms=9.256e-05  max=4.437e-04
#   pde_cont  : rms=5.677e-04  max=3.600e-03
#   pde_ru    : rms=1.973e-04  max=6.755e-04
#   pde_rv    : rms=7.874e-05  max=3.007e-04
#   pde_rTf   : rms=1.914e-04  max=8.097e-04
#   bc_phi    : rms=7.466e-05  max=4.542e-04
#   bc_solid  : rms=7.270e-05  max=3.319e-04
#   bc_fluid  : rms=2.224e-04  max=3.437e-03
#   iface     : rms=1.255e-04  max=3.407e-04
#   ic        : rms=6.559e-05  max=3.211e-04
# Scaled PDE RMS on obj: phi 0.18627004574207595 Ts 0.03587704146931987 cont 0.06913986017785662 ru 0.01889171845757023 rv 0.010466746226112938 rTf 0.0012686269165308281
# [it=280] obj=2.882e-01 feas_raw=3.395e-08 alpha=2.36e-01 beta=5.91e-01 station=8.78e-03 dn=8.78e-03
# blocks (unscaled c):
#   pde_phi   : rms=9.095e-04  max=3.156e-03
#   pde_Ts    : rms=1.026e-04  max=3.763e-04
#   pde_cont  : rms=4.169e-04  max=2.602e-03
#   pde_ru    : rms=1.905e-04  max=6.465e-04
#   pde_rv    : rms=7.890e-05  max=2.812e-04
#   pde_rTf   : rms=1.845e-04  max=7.576e-04
#   bc_phi    : rms=6.088e-05  max=2.374e-04
#   bc_solid  : rms=6.983e-05  max=3.246e-04
#   bc_fluid  : rms=1.007e-04  max=6.009e-04
#   iface     : rms=1.195e-04  max=3.391e-04
#   ic        : rms=6.269e-05  max=3.074e-04
# Scaled PDE RMS on obj: phi 0.1813119364002958 Ts 0.03588253978692979 cont 0.06651429149823142 ru 0.018730939511885255 rv 0.01026794981684155 rTf 0.0012619765484514545
# [it=290] obj=2.725e-01 feas_raw=3.043e-08 alpha=2.56e-01 beta=5.84e-01 station=7.82e-03 dn=7.82e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.101e-04  max=2.393e-03
#   pde_Ts    : rms=1.022e-04  max=3.573e-04
#   pde_cont  : rms=4.257e-04  max=2.452e-03
#   pde_ru    : rms=1.821e-04  max=6.205e-04
#   pde_rv    : rms=7.393e-05  max=2.604e-04
#   pde_rTf   : rms=1.769e-04  max=6.683e-04
#   bc_phi    : rms=5.541e-05  max=2.212e-04
#   bc_solid  : rms=6.691e-05  max=3.140e-04
#   bc_fluid  : rms=1.190e-04  max=1.092e-03
#   iface     : rms=1.139e-04  max=3.421e-04
#   ic        : rms=5.939e-05  max=2.803e-04
# Scaled PDE RMS on obj: phi 0.17644511516187872 Ts 0.035876763339888595 cont 0.0640750801781277 ru 0.018576788535251142 rv 0.010098323633033673 rTf 0.0012565537851405787
# [it=300] obj=2.570e-01 feas_raw=2.607e-08 alpha=3.07e-01 beta=5.77e-01 station=7.00e-03 dn=7.00e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.916e-04  max=2.693e-03
#   pde_Ts    : rms=9.692e-05  max=3.093e-04
#   pde_cont  : rms=3.332e-04  max=1.552e-03
#   pde_ru    : rms=1.739e-04  max=5.945e-04
#   pde_rv    : rms=7.127e-05  max=2.547e-04
#   pde_rTf   : rms=1.674e-04  max=5.176e-04
#   bc_phi    : rms=5.398e-05  max=2.676e-04
#   bc_solid  : rms=6.423e-05  max=3.055e-04
#   bc_fluid  : rms=1.161e-04  max=8.969e-04
#   iface     : rms=1.089e-04  max=3.482e-04
#   ic        : rms=5.616e-05  max=2.591e-04
# Scaled PDE RMS on obj: phi 0.1713486449019289 Ts 0.03591435786018813 cont 0.06164951668899649 ru 0.01840354939141789 rv 0.009917952838862036 rTf 0.0012571904558150145
# [it=310] obj=2.416e-01 feas_raw=2.781e-08 alpha=3.67e-01 beta=5.70e-01 station=5.90e-03 dn=5.90e-03
# blocks (unscaled c):
#   pde_phi   : rms=6.947e-04  max=2.336e-03
#   pde_Ts    : rms=5.713e-05  max=1.837e-04
#   pde_cont  : rms=3.004e-04  max=1.421e-03
#   pde_ru    : rms=1.674e-04  max=5.589e-04
#   pde_rv    : rms=6.783e-05  max=2.540e-04
#   pde_rTf   : rms=1.580e-04  max=4.256e-04
#   bc_phi    : rms=4.231e-05  max=1.582e-04
#   bc_solid  : rms=6.128e-05  max=2.908e-04
#   bc_fluid  : rms=2.457e-04  max=4.227e-03
#   iface     : rms=1.040e-04  max=3.531e-04
#   ic        : rms=5.374e-05  max=2.599e-04
# Scaled PDE RMS on obj: phi 0.16594249438798536 Ts 0.03598974405155053 cont 0.059235247926101006 ru 0.018226717930639763 rv 0.00973537183151833 rTf 0.001265202657535
# [it=320] obj=2.268e-01 feas_raw=2.331e-08 alpha=3.99e-01 beta=5.64e-01 station=5.16e-03 dn=5.16e-03
# blocks (unscaled c):
#   pde_phi   : rms=6.490e-04  max=2.175e-03
#   pde_Ts    : rms=6.792e-05  max=3.182e-04
#   pde_cont  : rms=3.464e-04  max=2.256e-03
#   pde_ru    : rms=1.607e-04  max=5.275e-04
#   pde_rv    : rms=6.604e-05  max=2.337e-04
#   pde_rTf   : rms=1.506e-04  max=4.295e-04
#   bc_phi    : rms=3.921e-05  max=1.677e-04
#   bc_solid  : rms=5.884e-05  max=2.790e-04
#   bc_fluid  : rms=1.765e-04  max=2.274e-03
#   iface     : rms=9.943e-05  max=3.559e-04
#   ic        : rms=5.104e-05  max=2.622e-04
# Scaled PDE RMS on obj: phi 0.1605081739196471 Ts 0.0360687969865621 cont 0.056959738220139236 ru 0.018068888265084345 rv 0.009572524376958368 rTf 0.0012724209817181
# [it=330] obj=2.128e-01 feas_raw=1.906e-08 alpha=4.33e-01 beta=5.57e-01 station=5.21e-03 dn=5.21e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.680e-04  max=1.853e-03
#   pde_Ts    : rms=6.251e-05  max=2.136e-04
#   pde_cont  : rms=2.335e-04  max=7.206e-04
#   pde_ru    : rms=1.544e-04  max=4.891e-04
#   pde_rv    : rms=6.393e-05  max=2.247e-04
#   pde_rTf   : rms=1.441e-04  max=4.204e-04
#   bc_phi    : rms=4.192e-05  max=1.489e-04
#   bc_solid  : rms=5.661e-05  max=2.626e-04
#   bc_fluid  : rms=1.996e-04  max=3.385e-03
#   iface     : rms=9.525e-05  max=3.594e-04
#   ic        : rms=4.725e-05  max=2.376e-04
# Scaled PDE RMS on obj: phi 0.15505927523539256 Ts 0.03616451302140979 cont 0.05476196534091215 ru 0.017908379460829318 rv 0.009415506500786283 rTf 0.0012811451641969692
# [it=340] obj=1.987e-01 feas_raw=1.634e-08 alpha=5.19e-01 beta=5.51e-01 station=4.24e-03 dn=4.24e-03
# blocks (unscaled c):
#   pde_phi   : rms=6.071e-04  max=2.068e-03
#   pde_Ts    : rms=5.643e-05  max=2.019e-04
#   pde_cont  : rms=2.401e-04  max=1.199e-03
#   pde_ru    : rms=1.493e-04  max=4.608e-04
#   pde_rv    : rms=6.021e-05  max=2.153e-04
#   pde_rTf   : rms=1.368e-04  max=3.993e-04
#   bc_phi    : rms=3.295e-05  max=1.374e-04
#   bc_solid  : rms=5.307e-05  max=2.470e-04
#   bc_fluid  : rms=1.201e-04  max=1.692e-03
#   iface     : rms=9.055e-05  max=3.528e-04
#   ic        : rms=4.561e-05  max=2.474e-04
# Scaled PDE RMS on obj: phi 0.14929074213324697 Ts 0.03624620803410693 cont 0.052533068417167796 ru 0.017748096161931237 rv 0.00927623061241101 rTf 0.0012883325664075343
# [it=350] obj=1.854e-01 feas_raw=1.270e-08 alpha=5.13e-01 beta=5.45e-01 station=4.47e-03 dn=4.47e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.248e-04  max=1.331e-03
#   pde_Ts    : rms=5.584e-05  max=1.875e-04
#   pde_cont  : rms=3.082e-04  max=2.411e-03
#   pde_ru    : rms=1.435e-04  max=4.218e-04
#   pde_rv    : rms=5.830e-05  max=2.016e-04
#   pde_rTf   : rms=1.311e-04  max=3.841e-04
#   bc_phi    : rms=3.492e-05  max=2.215e-04
#   bc_solid  : rms=5.049e-05  max=2.289e-04
#   bc_fluid  : rms=9.390e-05  max=8.547e-04
#   iface     : rms=8.634e-05  max=3.407e-04
#   ic        : rms=4.280e-05  max=2.358e-04
# Scaled PDE RMS on obj: phi 0.14360833534980674 Ts 0.03635065576997615 cont 0.05052123314771746 ru 0.017589235488387495 rv 0.009152593760786573 rTf 0.0012962472528094595
# [it=360] obj=1.730e-01 feas_raw=9.443e-09 alpha=6.75e-01 beta=5.39e-01 station=4.40e-03 dn=4.40e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.609e-04  max=1.322e-03
#   pde_Ts    : rms=4.310e-05  max=1.215e-04
#   pde_cont  : rms=2.254e-04  max=1.457e-03
#   pde_ru    : rms=1.368e-04  max=3.905e-04
#   pde_rv    : rms=5.301e-05  max=1.941e-04
#   pde_rTf   : rms=1.247e-04  max=3.585e-04
#   bc_phi    : rms=2.629e-05  max=9.373e-05
#   bc_solid  : rms=4.720e-05  max=2.098e-04
#   bc_fluid  : rms=9.844e-05  max=1.439e-03
#   iface     : rms=8.199e-05  max=3.278e-04
#   ic        : rms=4.103e-05  max=2.248e-04
# Scaled PDE RMS on obj: phi 0.13786557152514053 Ts 0.03635904010553666 cont 0.0484035472531624 ru 0.01743059934356774 rv 0.009022593924995964 rTf 0.0013063437471961372
# [it=370] obj=1.604e-01 feas_raw=6.081e-09 alpha=7.35e-01 beta=5.33e-01 station=4.17e-03 dn=4.17e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.206e-04  max=8.136e-04
#   pde_Ts    : rms=3.230e-05  max=1.091e-04
#   pde_cont  : rms=1.257e-04  max=5.032e-04
#   pde_ru    : rms=1.301e-04  max=3.564e-04
#   pde_rv    : rms=4.903e-05  max=1.720e-04
#   pde_rTf   : rms=1.173e-04  max=3.238e-04
#   bc_phi    : rms=2.174e-05  max=8.119e-05
#   bc_solid  : rms=4.318e-05  max=1.889e-04
#   bc_fluid  : rms=1.044e-04  max=1.703e-03
#   iface     : rms=7.739e-05  max=3.001e-04
#   ic        : rms=4.197e-05  max=2.298e-04
# Scaled PDE RMS on obj: phi 0.13193906169030675 Ts 0.036389747095885265 cont 0.046283012084418644 ru 0.01728054082003995 rv 0.008881515015373887 rTf 0.0013098329551252097
# [it=380] obj=1.482e-01 feas_raw=2.985e-09 alpha=9.68e-01 beta=5.28e-01 station=3.02e-03 dn=3.02e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.738e-05  max=1.004e-04
#   pde_Ts    : rms=1.499e-05  max=7.305e-05
#   pde_cont  : rms=5.720e-05  max=1.611e-04
#   pde_ru    : rms=1.224e-04  max=3.324e-04
#   pde_rv    : rms=4.613e-05  max=1.613e-04
#   pde_rTf   : rms=1.099e-04  max=2.928e-04
#   bc_phi    : rms=1.808e-05  max=7.095e-05
#   bc_solid  : rms=3.987e-05  max=1.682e-04
#   bc_fluid  : rms=4.463e-05  max=2.529e-04
#   iface     : rms=7.250e-05  max=2.719e-04
#   ic        : rms=4.111e-05  max=2.150e-04
# Scaled PDE RMS on obj: phi 0.1260436597945094 Ts 0.03628085497180559 cont 0.04415495101099027 ru 0.017124500949798952 rv 0.008721370550571613 rTf 0.0013171835684554643
# [it=390] obj=1.372e-01 feas_raw=2.573e-09 alpha=9.58e-01 beta=5.23e-01 station=3.18e-03 dn=3.18e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.188e-05  max=1.564e-04
#   pde_Ts    : rms=1.452e-05  max=6.401e-05
#   pde_cont  : rms=3.647e-05  max=1.310e-04
#   pde_ru    : rms=1.161e-04  max=3.323e-04
#   pde_rv    : rms=4.214e-05  max=1.331e-04
#   pde_rTf   : rms=1.024e-04  max=2.532e-04
#   bc_phi    : rms=1.734e-05  max=6.386e-05
#   bc_solid  : rms=3.565e-05  max=1.472e-04
#   bc_fluid  : rms=4.594e-05  max=2.602e-04
#   iface     : rms=6.863e-05  max=2.651e-04
#   ic        : rms=3.662e-05  max=2.006e-04
# Scaled PDE RMS on obj: phi 0.12041890977705873 Ts 0.03616982905318016 cont 0.04216205757473378 ru 0.01698521579372528 rv 0.008585157953535958 rTf 0.0013282498554505295
# [it=400] obj=1.281e-01 feas_raw=2.347e-09 alpha=9.49e-01 beta=5.17e-01 station=2.92e-03 dn=2.92e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.989e-05  max=2.064e-04
#   pde_Ts    : rms=1.443e-05  max=6.100e-05
#   pde_cont  : rms=4.970e-05  max=3.289e-04
#   pde_ru    : rms=1.101e-04  max=3.226e-04
#   pde_rv    : rms=4.190e-05  max=1.430e-04
#   pde_rTf   : rms=9.760e-05  max=2.363e-04
#   bc_phi    : rms=1.402e-05  max=5.501e-05
#   bc_solid  : rms=3.189e-05  max=1.301e-04
#   bc_fluid  : rms=4.401e-05  max=2.381e-04
#   iface     : rms=6.461e-05  max=2.631e-04
#   ic        : rms=3.383e-05  max=1.599e-04
# Scaled PDE RMS on obj: phi 0.11570801935549356 Ts 0.03590307182456382 cont 0.0404394023487878 ru 0.016857731837364838 rv 0.008431470600169728 rTf 0.0013442681603669738
# [it=410] obj=1.206e-01 feas_raw=2.179e-09 alpha=9.39e-01 beta=5.12e-01 station=3.07e-03 dn=3.07e-03
# blocks (unscaled c):
#   pde_phi   : rms=6.774e-05  max=3.010e-04
#   pde_Ts    : rms=1.269e-05  max=5.548e-05
#   pde_cont  : rms=4.174e-05  max=1.797e-04
#   pde_ru    : rms=1.052e-04  max=3.087e-04
#   pde_rv    : rms=3.901e-05  max=1.432e-04
#   pde_rTf   : rms=9.270e-05  max=2.398e-04
#   bc_phi    : rms=1.487e-05  max=5.541e-05
#   bc_solid  : rms=2.830e-05  max=1.140e-04
#   bc_fluid  : rms=3.923e-05  max=2.488e-04
#   iface     : rms=6.176e-05  max=2.594e-04
#   ic        : rms=3.374e-05  max=1.673e-04
# Scaled PDE RMS on obj: phi 0.11151874815907546 Ts 0.0356980024635724 cont 0.03896481934398221 ru 0.01672794383955242 rv 0.0082676090085322 rTf 0.0013192484125210352
# [it=420] obj=1.141e-01 feas_raw=2.296e-09 alpha=9.30e-01 beta=5.07e-01 station=3.24e-03 dn=3.24e-03
# blocks (unscaled c):
#   pde_phi   : rms=6.427e-05  max=1.532e-04
#   pde_Ts    : rms=1.381e-05  max=5.277e-05
#   pde_cont  : rms=5.380e-05  max=2.358e-04
#   pde_ru    : rms=1.014e-04  max=2.934e-04
#   pde_rv    : rms=3.796e-05  max=1.107e-04
#   pde_rTf   : rms=8.722e-05  max=2.431e-04
#   bc_phi    : rms=1.433e-05  max=5.895e-05
#   bc_solid  : rms=2.609e-05  max=1.091e-04
#   bc_fluid  : rms=5.816e-05  max=5.948e-04
#   iface     : rms=5.922e-05  max=2.552e-04
#   ic        : rms=3.153e-05  max=1.707e-04
# Scaled PDE RMS on obj: phi 0.10797456030280181 Ts 0.035426861024809846 cont 0.03762559759807021 ru 0.016625858814836393 rv 0.008134367049510692 rTf 0.0013344846129804005
# [it=430] obj=1.084e-01 feas_raw=1.891e-09 alpha=1.01e+00 beta=5.02e-01 station=2.48e-03 dn=2.48e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.415e-05  max=3.223e-05
#   pde_Ts    : rms=9.426e-06  max=3.934e-05
#   pde_cont  : rms=3.959e-05  max=1.128e-04
#   pde_ru    : rms=9.681e-05  max=2.732e-04
#   pde_rv    : rms=3.720e-05  max=1.082e-04
#   pde_rTf   : rms=8.259e-05  max=2.490e-04
#   bc_phi    : rms=1.569e-05  max=5.604e-05
#   bc_solid  : rms=2.388e-05  max=9.236e-05
#   bc_fluid  : rms=4.220e-05  max=2.060e-04
#   iface     : rms=5.700e-05  max=2.505e-04
#   ic        : rms=3.318e-05  max=1.682e-04
# Scaled PDE RMS on obj: phi 0.10466566284754991 Ts 0.035129372455688986 cont 0.0365094285210539 ru 0.016517934404673695 rv 0.00798640040634522 rTf 0.0013198466626043732
# [it=440] obj=1.029e-01 feas_raw=1.672e-09 alpha=1.00e+00 beta=4.98e-01 station=2.69e-03 dn=2.69e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.080e-05  max=2.856e-05
#   pde_Ts    : rms=8.349e-06  max=3.910e-05
#   pde_cont  : rms=4.268e-05  max=1.106e-04
#   pde_ru    : rms=9.330e-05  max=2.588e-04
#   pde_rv    : rms=3.628e-05  max=9.343e-05
#   pde_rTf   : rms=7.916e-05  max=2.549e-04
#   bc_phi    : rms=1.248e-05  max=6.125e-05
#   bc_solid  : rms=2.053e-05  max=8.310e-05
#   bc_fluid  : rms=3.622e-05  max=1.989e-04
#   iface     : rms=5.575e-05  max=2.476e-04
#   ic        : rms=3.039e-05  max=1.711e-04
# Scaled PDE RMS on obj: phi 0.10155754780310612 Ts 0.03479850894763737 cont 0.03541626420976413 ru 0.01639863122372361 rv 0.007860797592823914 rTf 0.0013174275577240028
# [it=450] obj=9.860e-02 feas_raw=1.518e-09 alpha=9.94e-01 beta=4.93e-01 station=2.36e-03 dn=2.36e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.152e-05  max=5.092e-05
#   pde_Ts    : rms=5.635e-06  max=2.163e-05
#   pde_cont  : rms=2.921e-05  max=1.011e-04
#   pde_ru    : rms=9.090e-05  max=2.433e-04
#   pde_rv    : rms=3.541e-05  max=1.083e-04
#   pde_rTf   : rms=7.567e-05  max=2.535e-04
#   bc_phi    : rms=1.160e-05  max=4.322e-05
#   bc_solid  : rms=1.925e-05  max=7.117e-05
#   bc_fluid  : rms=3.319e-05  max=1.828e-04
#   iface     : rms=5.428e-05  max=2.438e-04
#   ic        : rms=2.961e-05  max=1.720e-04
# Scaled PDE RMS on obj: phi 0.09874105919575873 Ts 0.03453938138389572 cont 0.034496415919271065 ru 0.016308150535673305 rv 0.007749433469372628 rTf 0.0013204312010537786
# [it=460] obj=9.456e-02 feas_raw=1.443e-09 alpha=9.85e-01 beta=4.89e-01 station=2.57e-03 dn=2.57e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.544e-05  max=4.829e-05
#   pde_Ts    : rms=5.384e-06  max=1.462e-05
#   pde_cont  : rms=2.357e-05  max=8.698e-05
#   pde_ru    : rms=8.828e-05  max=2.264e-04
#   pde_rv    : rms=3.604e-05  max=1.171e-04
#   pde_rTf   : rms=7.276e-05  max=2.347e-04
#   bc_phi    : rms=1.207e-05  max=4.252e-05
#   bc_solid  : rms=1.794e-05  max=6.852e-05
#   bc_fluid  : rms=3.305e-05  max=1.691e-04
#   iface     : rms=5.299e-05  max=2.376e-04
#   ic        : rms=2.907e-05  max=1.657e-04
# Scaled PDE RMS on obj: phi 0.09635409000459867 Ts 0.03428545523834085 cont 0.0336730142362305 ru 0.01620327503880646 rv 0.0076553518776655855 rTf 0.001350522754080691
# [it=470] obj=9.107e-02 feas_raw=1.282e-09 alpha=9.77e-01 beta=4.84e-01 station=2.04e-03 dn=2.04e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.049e-05  max=6.474e-05
#   pde_Ts    : rms=5.803e-06  max=1.507e-05
#   pde_cont  : rms=2.147e-05  max=8.577e-05
#   pde_ru    : rms=8.550e-05  max=2.171e-04
#   pde_rv    : rms=3.420e-05  max=1.082e-04
#   pde_rTf   : rms=7.026e-05  max=2.366e-04
#   bc_phi    : rms=9.955e-06  max=3.434e-05
#   bc_solid  : rms=1.580e-05  max=5.999e-05
#   bc_fluid  : rms=2.407e-05  max=1.649e-04
#   iface     : rms=5.220e-05  max=2.341e-04
#   ic        : rms=2.770e-05  max=1.652e-04
# Scaled PDE RMS on obj: phi 0.09404394215587204 Ts 0.034010013255540816 cont 0.032876367526912614 ru 0.016130133595299377 rv 0.007567404006479332 rTf 0.001342749255660891
# [it=480] obj=8.791e-02 feas_raw=1.293e-09 alpha=9.68e-01 beta=4.80e-01 station=2.24e-03 dn=2.24e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.662e-05  max=8.122e-05
#   pde_Ts    : rms=6.192e-06  max=1.588e-05
#   pde_cont  : rms=3.282e-05  max=1.853e-04
#   pde_ru    : rms=8.317e-05  max=2.015e-04
#   pde_rv    : rms=3.403e-05  max=1.116e-04
#   pde_rTf   : rms=6.856e-05  max=2.332e-04
#   bc_phi    : rms=9.953e-06  max=3.159e-05
#   bc_solid  : rms=1.498e-05  max=5.466e-05
#   bc_fluid  : rms=2.789e-05  max=1.597e-04
#   iface     : rms=5.136e-05  max=2.250e-04
#   ic        : rms=2.716e-05  max=1.662e-04
# Scaled PDE RMS on obj: phi 0.09188632258958719 Ts 0.03382522669295815 cont 0.03221070472396539 ru 0.016064084613767415 rv 0.0075014383343262325 rTf 0.0013705040800049725
# [it=490] obj=8.493e-02 feas_raw=1.272e-09 alpha=9.59e-01 beta=4.76e-01 station=2.85e-03 dn=2.85e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.715e-05  max=1.602e-04
#   pde_Ts    : rms=7.915e-06  max=2.459e-05
#   pde_cont  : rms=2.761e-05  max=9.586e-05
#   pde_ru    : rms=8.111e-05  max=1.928e-04
#   pde_rv    : rms=3.192e-05  max=1.050e-04
#   pde_rTf   : rms=6.669e-05  max=2.411e-04
#   bc_phi    : rms=1.150e-05  max=4.018e-05
#   bc_solid  : rms=1.432e-05  max=4.974e-05
#   bc_fluid  : rms=3.123e-05  max=1.623e-04
#   iface     : rms=5.065e-05  max=2.180e-04
#   ic        : rms=2.663e-05  max=1.608e-04
# Scaled PDE RMS on obj: phi 0.08991949308531587 Ts 0.033630621863081495 cont 0.03159608422494066 ru 0.015970037677246147 rv 0.007437473964358305 rTf 0.0013855699467836854
# [it=500] obj=8.259e-02 feas_raw=1.222e-09 alpha=9.51e-01 beta=4.72e-01 station=2.85e-03 dn=2.85e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.278e-05  max=1.145e-04
#   pde_Ts    : rms=6.984e-06  max=2.303e-05
#   pde_cont  : rms=2.500e-05  max=6.506e-05
#   pde_ru    : rms=7.882e-05  max=1.864e-04
#   pde_rv    : rms=3.016e-05  max=1.053e-04
#   pde_rTf   : rms=6.484e-05  max=2.451e-04
#   bc_phi    : rms=1.056e-05  max=3.584e-05
#   bc_solid  : rms=1.326e-05  max=4.753e-05
#   bc_fluid  : rms=3.068e-05  max=1.626e-04
#   iface     : rms=5.006e-05  max=2.145e-04
#   ic        : rms=2.677e-05  max=1.588e-04
# Scaled PDE RMS on obj: phi 0.08825802702064832 Ts 0.0333873974597244 cont 0.03105048720997373 ru 0.0159045558302273 rv 0.007385735192128678 rTf 0.0014054877372166247
# [it=510] obj=7.995e-02 feas_raw=1.143e-09 alpha=1.04e+00 beta=4.68e-01 station=1.90e-03 dn=1.90e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.856e-05  max=1.138e-04
#   pde_Ts    : rms=5.255e-06  max=1.680e-05
#   pde_cont  : rms=2.355e-05  max=6.088e-05
#   pde_ru    : rms=7.746e-05  max=1.826e-04
#   pde_rv    : rms=3.046e-05  max=1.099e-04
#   pde_rTf   : rms=6.283e-05  max=2.367e-04
#   bc_phi    : rms=1.028e-05  max=3.887e-05
#   bc_solid  : rms=1.292e-05  max=4.365e-05
#   bc_fluid  : rms=2.791e-05  max=2.164e-04
#   iface     : rms=4.908e-05  max=2.092e-04
#   ic        : rms=2.601e-05  max=1.523e-04
# Scaled PDE RMS on obj: phi 0.0864890352941616 Ts 0.03313587624151009 cont 0.03051024424603754 ru 0.015832365922081666 rv 0.007321692924789764 rTf 0.0014228307316429922
# [it=520] obj=7.786e-02 feas_raw=1.183e-09 alpha=9.35e-01 beta=4.64e-01 station=2.56e-03 dn=2.56e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.041e-05  max=1.470e-04
#   pde_Ts    : rms=8.275e-06  max=2.380e-05
#   pde_cont  : rms=2.954e-05  max=1.269e-04
#   pde_ru    : rms=7.596e-05  max=1.815e-04
#   pde_rv    : rms=2.894e-05  max=1.146e-04
#   pde_rTf   : rms=6.124e-05  max=2.357e-04
#   bc_phi    : rms=1.004e-05  max=3.480e-05
#   bc_solid  : rms=1.202e-05  max=4.535e-05
#   bc_fluid  : rms=3.231e-05  max=2.088e-04
#   iface     : rms=4.863e-05  max=1.990e-04
#   ic        : rms=2.514e-05  max=1.430e-04
# Scaled PDE RMS on obj: phi 0.08481725174296001 Ts 0.032868944068210434 cont 0.03000771899829053 ru 0.015783044303583023 rv 0.0072911930821521675 rTf 0.0014452351833570726
# [it=530] obj=7.576e-02 feas_raw=1.032e-09 alpha=1.02e+00 beta=4.60e-01 station=2.09e-03 dn=2.09e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.862e-05  max=6.099e-05
#   pde_Ts    : rms=4.462e-06  max=1.859e-05
#   pde_cont  : rms=2.250e-05  max=6.412e-05
#   pde_ru    : rms=7.408e-05  max=1.801e-04
#   pde_rv    : rms=2.980e-05  max=1.182e-04
#   pde_rTf   : rms=5.920e-05  max=2.273e-04
#   bc_phi    : rms=1.020e-05  max=3.360e-05
#   bc_solid  : rms=1.160e-05  max=4.564e-05
#   bc_fluid  : rms=2.466e-05  max=1.498e-04
#   iface     : rms=4.788e-05  max=1.963e-04
#   ic        : rms=2.515e-05  max=1.371e-04
# Scaled PDE RMS on obj: phi 0.08331976684592328 Ts 0.03269830272614104 cont 0.02954933118673336 ru 0.015732581451705335 rv 0.007239221158131328 rTf 0.001473982820746095
# [it=540] obj=7.390e-02 feas_raw=9.501e-10 alpha=1.01e+00 beta=4.56e-01 station=2.04e-03 dn=2.04e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.001e-05  max=2.969e-05
#   pde_Ts    : rms=3.400e-06  max=1.057e-05
#   pde_cont  : rms=1.201e-05  max=3.564e-05
#   pde_ru    : rms=7.280e-05  max=1.752e-04
#   pde_rv    : rms=2.718e-05  max=1.135e-04
#   pde_rTf   : rms=5.927e-05  max=2.411e-04
#   bc_phi    : rms=8.073e-06  max=2.403e-05
#   bc_solid  : rms=1.140e-05  max=4.661e-05
#   bc_fluid  : rms=2.092e-05  max=1.438e-04
#   iface     : rms=4.744e-05  max=1.930e-04
#   ic        : rms=2.443e-05  max=1.302e-04
# Scaled PDE RMS on obj: phi 0.08177515475818305 Ts 0.03249519986385478 cont 0.029215599488691554 ru 0.015654101220897748 rv 0.007205598526683903 rTf 0.001499288523952918
# [it=550] obj=7.222e-02 feas_raw=9.088e-10 alpha=1.00e+00 beta=4.52e-01 station=1.54e-03 dn=1.54e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.089e-06  max=2.197e-05
#   pde_Ts    : rms=3.363e-06  max=8.191e-06
#   pde_cont  : rms=1.470e-05  max=3.657e-05
#   pde_ru    : rms=7.129e-05  max=1.773e-04
#   pde_rv    : rms=2.799e-05  max=1.159e-04
#   pde_rTf   : rms=5.696e-05  max=2.342e-04
#   bc_phi    : rms=8.745e-06  max=3.259e-05
#   bc_solid  : rms=1.090e-05  max=4.807e-05
#   bc_fluid  : rms=2.011e-05  max=1.363e-04
#   iface     : rms=4.674e-05  max=1.890e-04
#   ic        : rms=2.381e-05  max=1.228e-04
# Scaled PDE RMS on obj: phi 0.08053382549609184 Ts 0.03225897280727158 cont 0.02887649512468746 ru 0.015604833442218129 rv 0.007167197413665832 rTf 0.0015261388729929048
# [it=560] obj=7.041e-02 feas_raw=9.262e-10 alpha=9.96e-01 beta=4.49e-01 station=1.88e-03 dn=1.88e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.818e-06  max=2.348e-05
#   pde_Ts    : rms=4.630e-06  max=1.169e-05
#   pde_cont  : rms=1.474e-05  max=3.681e-05
#   pde_ru    : rms=7.010e-05  max=1.716e-04
#   pde_rv    : rms=2.678e-05  max=1.199e-04
#   pde_rTf   : rms=5.514e-05  max=2.324e-04
#   bc_phi    : rms=9.345e-06  max=3.070e-05
#   bc_solid  : rms=1.170e-05  max=5.193e-05
#   bc_fluid  : rms=2.560e-05  max=1.318e-04
#   iface     : rms=4.619e-05  max=1.837e-04
#   ic        : rms=2.398e-05  max=1.131e-04
# Scaled PDE RMS on obj: phi 0.07931196350078142 Ts 0.032091347809040105 cont 0.028510889427902912 ru 0.015555905226251556 rv 0.007127791677183559 rTf 0.0015385714429434324
# [it=570] obj=6.896e-02 feas_raw=8.632e-10 alpha=9.88e-01 beta=4.45e-01 station=1.63e-03 dn=1.63e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.580e-06  max=2.330e-05
#   pde_Ts    : rms=5.153e-06  max=1.458e-05
#   pde_cont  : rms=1.393e-05  max=3.824e-05
#   pde_ru    : rms=6.893e-05  max=1.724e-04
#   pde_rv    : rms=2.545e-05  max=1.179e-04
#   pde_rTf   : rms=5.518e-05  max=2.257e-04
#   bc_phi    : rms=8.643e-06  max=2.966e-05
#   bc_solid  : rms=1.199e-05  max=5.311e-05
#   bc_fluid  : rms=1.968e-05  max=1.245e-04
#   iface     : rms=4.565e-05  max=1.804e-04
#   ic        : rms=2.350e-05  max=1.109e-04
# Scaled PDE RMS on obj: phi 0.07799212102875967 Ts 0.03192331766150156 cont 0.028182437808004005 ru 0.015503303420063836 rv 0.007100749264447399 rTf 0.001570361781245301
# [it=580] obj=6.757e-02 feas_raw=8.469e-10 alpha=9.81e-01 beta=4.42e-01 station=1.77e-03 dn=1.77e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.563e-05  max=5.197e-05
#   pde_Ts    : rms=5.026e-06  max=1.657e-05
#   pde_cont  : rms=1.339e-05  max=5.446e-05
#   pde_ru    : rms=6.761e-05  max=1.691e-04
#   pde_rv    : rms=2.616e-05  max=1.080e-04
#   pde_rTf   : rms=5.283e-05  max=2.215e-04
#   bc_phi    : rms=9.148e-06  max=3.168e-05
#   bc_solid  : rms=1.233e-05  max=5.374e-05
#   bc_fluid  : rms=2.255e-05  max=1.203e-04
#   iface     : rms=4.478e-05  max=1.761e-04
#   ic        : rms=2.291e-05  max=1.199e-04
# Scaled PDE RMS on obj: phi 0.07686598740978033 Ts 0.03172078826146573 cont 0.02798084608630277 ru 0.01545092718586966 rv 0.007073566238826984 rTf 0.001579356762064558
# [it=590] obj=6.632e-02 feas_raw=8.524e-10 alpha=9.73e-01 beta=4.39e-01 station=1.54e-03 dn=1.54e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.328e-05  max=9.084e-05
#   pde_Ts    : rms=4.468e-06  max=1.222e-05
#   pde_cont  : rms=2.377e-05  max=7.227e-05
#   pde_ru    : rms=6.639e-05  max=1.701e-04
#   pde_rv    : rms=2.440e-05  max=1.008e-04
#   pde_rTf   : rms=5.218e-05  max=2.207e-04
#   bc_phi    : rms=8.330e-06  max=3.358e-05
#   bc_solid  : rms=1.379e-05  max=6.202e-05
#   bc_fluid  : rms=2.431e-05  max=1.258e-04
#   iface     : rms=4.450e-05  max=1.735e-04
#   ic        : rms=2.234e-05  max=1.146e-04
# Scaled PDE RMS on obj: phi 0.07574093429381304 Ts 0.03151807695507732 cont 0.02767700062107248 ru 0.01539864423499521 rv 0.00703875786796285 rTf 0.001603617244400854
# [it=600] obj=6.516e-02 feas_raw=8.324e-10 alpha=9.66e-01 beta=4.35e-01 station=2.16e-03 dn=2.16e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.621e-05  max=9.190e-05
#   pde_Ts    : rms=4.573e-06  max=1.419e-05
#   pde_cont  : rms=2.023e-05  max=5.889e-05
#   pde_ru    : rms=6.545e-05  max=1.703e-04
#   pde_rv    : rms=2.410e-05  max=1.033e-04
#   pde_rTf   : rms=5.146e-05  max=2.245e-04
#   bc_phi    : rms=8.129e-06  max=3.378e-05
#   bc_solid  : rms=1.346e-05  max=6.373e-05
#   bc_fluid  : rms=2.432e-05  max=1.081e-04
#   iface     : rms=4.405e-05  max=1.640e-04
#   ic        : rms=2.216e-05  max=1.166e-04
# Scaled PDE RMS on obj: phi 0.07462665387872193 Ts 0.03140543835518123 cont 0.027464632736916617 ru 0.015343654250500369 rv 0.007009861722531864 rTf 0.0016233389669890997
# [it=610] obj=6.406e-02 feas_raw=7.960e-10 alpha=9.59e-01 beta=4.32e-01 station=1.89e-03 dn=1.89e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.945e-05  max=1.074e-04
#   pde_Ts    : rms=5.231e-06  max=1.267e-05
#   pde_cont  : rms=2.156e-05  max=8.030e-05
#   pde_ru    : rms=6.470e-05  max=1.633e-04
#   pde_rv    : rms=2.423e-05  max=1.045e-04
#   pde_rTf   : rms=5.063e-05  max=2.205e-04
#   bc_phi    : rms=8.717e-06  max=3.430e-05
#   bc_solid  : rms=1.380e-05  max=6.148e-05
#   bc_fluid  : rms=2.110e-05  max=1.063e-04
#   iface     : rms=4.341e-05  max=1.650e-04
#   ic        : rms=2.163e-05  max=1.123e-04
# Scaled PDE RMS on obj: phi 0.07375711591510752 Ts 0.03127629060465661 cont 0.027235741400395357 ru 0.015311991880028672 rv 0.00698315732897653 rTf 0.00165589861810964
# [it=620] obj=6.288e-02 feas_raw=8.036e-10 alpha=9.52e-01 beta=4.29e-01 station=1.67e-03 dn=1.67e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.940e-05  max=1.728e-04
#   pde_Ts    : rms=5.845e-06  max=1.626e-05
#   pde_cont  : rms=1.903e-05  max=8.869e-05
#   pde_ru    : rms=6.368e-05  max=1.593e-04
#   pde_rv    : rms=2.383e-05  max=1.078e-04
#   pde_rTf   : rms=4.898e-05  max=2.158e-04
#   bc_phi    : rms=9.300e-06  max=3.385e-05
#   bc_solid  : rms=1.493e-05  max=6.723e-05
#   bc_fluid  : rms=2.263e-05  max=1.015e-04
#   iface     : rms=4.327e-05  max=1.601e-04
#   ic        : rms=2.168e-05  max=1.162e-04
# Scaled PDE RMS on obj: phi 0.07282264244757422 Ts 0.031058984404423385 cont 0.027020357734969372 ru 0.015264938923963016 rv 0.006951797849293196 rTf 0.001660616414437971
# [it=630] obj=6.183e-02 feas_raw=7.819e-10 alpha=1.04e+00 beta=4.26e-01 station=2.19e-03 dn=2.19e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.185e-05  max=1.277e-04
#   pde_Ts    : rms=5.064e-06  max=1.554e-05
#   pde_cont  : rms=2.160e-05  max=6.619e-05
#   pde_ru    : rms=6.274e-05  max=1.545e-04
#   pde_rv    : rms=2.302e-05  max=8.952e-05
#   pde_rTf   : rms=4.860e-05  max=2.126e-04
#   bc_phi    : rms=7.627e-06  max=2.904e-05
#   bc_solid  : rms=1.561e-05  max=6.787e-05
#   bc_fluid  : rms=2.377e-05  max=1.329e-04
#   iface     : rms=4.277e-05  max=1.551e-04
#   ic        : rms=2.127e-05  max=1.099e-04
# Scaled PDE RMS on obj: phi 0.07182022258716872 Ts 0.03094679941981586 cont 0.02684727743709917 ru 0.015210050230741838 rv 0.006925539786784174 rTf 0.001687050789717189
# [it=640] obj=6.082e-02 feas_raw=7.509e-10 alpha=1.03e+00 beta=4.23e-01 station=2.38e-03 dn=2.38e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.049e-05  max=6.215e-05
#   pde_Ts    : rms=4.279e-06  max=1.077e-05
#   pde_cont  : rms=1.525e-05  max=3.877e-05
#   pde_ru    : rms=6.192e-05  max=1.562e-04
#   pde_rv    : rms=2.296e-05  max=1.000e-04
#   pde_rTf   : rms=4.832e-05  max=2.217e-04
#   bc_phi    : rms=8.636e-06  max=2.996e-05
#   bc_solid  : rms=1.489e-05  max=6.552e-05
#   bc_fluid  : rms=2.580e-05  max=1.013e-04
#   iface     : rms=4.221e-05  max=1.507e-04
#   ic        : rms=2.067e-05  max=1.009e-04
# Scaled PDE RMS on obj: phi 0.07097350138140358 Ts 0.03079151156023081 cont 0.026641709411180298 ru 0.015171946883831815 rv 0.006889714210028186 rTf 0.0017042808899812296
# [it=650] obj=5.992e-02 feas_raw=7.438e-10 alpha=1.02e+00 beta=4.20e-01 station=1.52e-03 dn=1.52e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.894e-05  max=7.484e-05
#   pde_Ts    : rms=3.253e-06  max=1.042e-05
#   pde_cont  : rms=1.712e-05  max=6.119e-05
#   pde_ru    : rms=6.110e-05  max=1.480e-04
#   pde_rv    : rms=2.286e-05  max=9.624e-05
#   pde_rTf   : rms=4.778e-05  max=2.152e-04
#   bc_phi    : rms=9.048e-06  max=3.954e-05
#   bc_solid  : rms=1.563e-05  max=6.518e-05
#   bc_fluid  : rms=2.305e-05  max=1.671e-04
#   iface     : rms=4.196e-05  max=1.518e-04
#   ic        : rms=2.149e-05  max=9.423e-05
# Scaled PDE RMS on obj: phi 0.0699371513088074 Ts 0.03064942939763359 cont 0.026465252139064605 ru 0.015135229908073554 rv 0.006876440811440905 rTf 0.0017263820442374798
# [it=660] obj=5.890e-02 feas_raw=6.913e-10 alpha=1.02e+00 beta=4.17e-01 station=2.09e-03 dn=2.09e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.269e-05  max=4.444e-05
#   pde_Ts    : rms=4.995e-06  max=2.383e-05
#   pde_cont  : rms=1.452e-05  max=4.657e-05
#   pde_ru    : rms=6.023e-05  max=1.479e-04
#   pde_rv    : rms=2.259e-05  max=8.726e-05
#   pde_rTf   : rms=4.691e-05  max=2.094e-04
#   bc_phi    : rms=8.365e-06  max=2.816e-05
#   bc_solid  : rms=1.601e-05  max=6.727e-05
#   bc_fluid  : rms=2.238e-05  max=1.176e-04
#   iface     : rms=4.147e-05  max=1.444e-04
#   ic        : rms=2.015e-05  max=9.905e-05
# Scaled PDE RMS on obj: phi 0.0692114989532679 Ts 0.03052961507394507 cont 0.026283242484250482 ru 0.0150996663133953 rv 0.0068400886082405615 rTf 0.0017472087095440419
# [it=670] obj=5.817e-02 feas_raw=6.501e-10 alpha=1.01e+00 beta=4.14e-01 station=1.70e-03 dn=1.70e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.551e-06  max=2.592e-05
#   pde_Ts    : rms=3.854e-06  max=1.336e-05
#   pde_cont  : rms=1.877e-05  max=3.936e-05
#   pde_ru    : rms=5.968e-05  max=1.452e-04
#   pde_rv    : rms=2.169e-05  max=8.886e-05
#   pde_rTf   : rms=4.639e-05  max=2.100e-04
#   bc_phi    : rms=7.147e-06  max=2.184e-05
#   bc_solid  : rms=1.616e-05  max=6.621e-05
#   bc_fluid  : rms=1.708e-05  max=9.096e-05
#   iface     : rms=4.123e-05  max=1.423e-04
#   ic        : rms=1.979e-05  max=9.484e-05
# Scaled PDE RMS on obj: phi 0.06838266540666307 Ts 0.030390353376086615 cont 0.026089199499946022 ru 0.015064464654420604 rv 0.006815766253010307 rTf 0.00176193760256583
# [it=680] obj=5.734e-02 feas_raw=7.193e-10 alpha=1.00e+00 beta=4.11e-01 station=2.47e-03 dn=2.47e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.533e-06  max=2.532e-05
#   pde_Ts    : rms=3.570e-06  max=8.910e-06
#   pde_cont  : rms=2.226e-05  max=5.956e-05
#   pde_ru    : rms=5.869e-05  max=1.405e-04
#   pde_rv    : rms=2.184e-05  max=9.137e-05
#   pde_rTf   : rms=4.547e-05  max=2.075e-04
#   bc_phi    : rms=7.147e-06  max=2.654e-05
#   bc_solid  : rms=1.595e-05  max=6.804e-05
#   bc_fluid  : rms=2.763e-05  max=1.408e-04
#   iface     : rms=4.112e-05  max=1.422e-04
#   ic        : rms=2.015e-05  max=9.422e-05
# Scaled PDE RMS on obj: phi 0.06756771347881375 Ts 0.030282895440850093 cont 0.02592927125910243 ru 0.015022874084811068 rv 0.0068075811587799346 rTf 0.001787074375468121
# [it=690] obj=5.639e-02 feas_raw=6.146e-10 alpha=9.97e-01 beta=4.08e-01 station=1.78e-03 dn=1.78e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.593e-06  max=3.684e-05
#   pde_Ts    : rms=2.884e-06  max=6.042e-06
#   pde_cont  : rms=1.286e-05  max=3.704e-05
#   pde_ru    : rms=5.828e-05  max=1.406e-04
#   pde_rv    : rms=2.080e-05  max=8.739e-05
#   pde_rTf   : rms=4.448e-05  max=2.015e-04
#   bc_phi    : rms=8.339e-06  max=3.557e-05
#   bc_solid  : rms=1.640e-05  max=7.068e-05
#   bc_fluid  : rms=1.669e-05  max=8.646e-05
#   iface     : rms=4.062e-05  max=1.327e-04
#   ic        : rms=1.946e-05  max=8.671e-05
# Scaled PDE RMS on obj: phi 0.06692083090938286 Ts 0.03016083226935995 cont 0.02574083492744396 ru 0.014989403190364894 rv 0.006760925955498257 rTf 0.0017965374509563718
# [it=700] obj=5.577e-02 feas_raw=1.019e-09 alpha=9.00e-01 beta=4.06e-01 station=2.85e-03 dn=2.85e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.019e-05  max=2.905e-04
#   pde_Ts    : rms=8.128e-06  max=1.956e-05
#   pde_cont  : rms=3.771e-05  max=1.304e-04
#   pde_ru    : rms=5.785e-05  max=1.365e-04
#   pde_rv    : rms=2.131e-05  max=7.658e-05
#   pde_rTf   : rms=4.505e-05  max=1.936e-04
#   bc_phi    : rms=9.282e-06  max=4.808e-05
#   bc_solid  : rms=1.644e-05  max=6.873e-05
#   bc_fluid  : rms=4.221e-05  max=2.789e-04
#   iface     : rms=4.004e-05  max=1.300e-04
#   ic        : rms=1.957e-05  max=8.654e-05
# Scaled PDE RMS on obj: phi 0.06618146820285405 Ts 0.030021820098715468 cont 0.025651241179991513 ru 0.01494573187574244 rv 0.006738981393788544 rTf 0.0018189535816609322
# [done] elapsed=1666.68s
# Saved theta -> theta_sqp_pinn_clean.npy
