# %%
# Out:
# loaded burgers.mat: t (201,) x (512,) usol (201, 512) nu 0.003183098861837907
# Domain: x in [-1.0, 1.0], t in [0.0, 1.0]
# scale_obj (fixed anchor) = 1.0
# Constraint dimension M_CON = 1025
# [iter=10] obj_s=5.533e-01 feas_true=1.009e+00 feas_noisy=1.009e+00 station=9.519e+00 tau=4.356080e-01 alpha=3.24e-03 beta=9.62e-01 lam=1.00e-03 kkt_res=4.7e+00 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-06 sigt=1.0e-06 clipk=2.0
# [iter=20] obj_s=4.764e-01 feas_true=8.362e-01 feas_noisy=8.362e-01 station=6.575e+00 tau=4.356080e-01 alpha=9.79e-03 beta=9.27e-01 lam=1.00e-03 kkt_res=1.9e+00 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-06 sigt=1.0e-06 clipk=2.0
# [iter=30] obj_s=3.908e-01 feas_true=6.711e-01 feas_noisy=6.711e-01 station=9.047e+00 tau=4.356080e-01 alpha=7.81e-03 beta=8.94e-01 lam=1.00e-03 kkt_res=1.2e+00 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-06 sigt=1.0e-06 clipk=2.0
# ...
