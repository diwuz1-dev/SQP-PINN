# %%
# ================================
# Stochastic SQP-PINN (JAX) - POINTWISE (SIGNED) constraints + optional "K steps per sample"
#
# JITTERED sampling variant (ANTITHETIC):
#   - Base collocation points are sampled ONCE every hold_con_K steps (same as before).
#   - Each SQP iteration, we jitter those fixed base points with ±delta and AVERAGE:
#       (1/2)[ r(x+δ) + r(x-δ) ]   (same idea for BC/IC mismatches)
#   - This reduces odd-order jitter error and often reduces variance (at ~2x constraint cost).
#
# Objective: data MSE minibatch from burgers.mat
#   - optional MC objective averaging (mc_obj_batches)
#
# Constraints: POINTWISE / BIN-WISE MEAN (SIGNED, not RMS)
#   PDE cell k:    c_pde[k]    = mean_cell[ r_pde(x,t) ]   (if N=1 => r at that point)
#   BC time-bin j: c_bc_val[j] = mean_bin[ uL-uR ]
#                 c_bc_der[j] = mean_bin[ uxL-uxR ]
#   IC x-bin j:    c_ic[j]     = mean_bin[ u(x,0)-u0(x) ]
#
# Stratified sampling (fixed # points per region/bin) -> unbiased per-bin mean.
#
# IMPORTANT knobs for "iterations per sample":
#   - hold_data_K : number of SQP steps to reuse the SAME data minibatch
#   - hold_con_K  : number of SQP steps to reuse the SAME *BASE* constraint samples (Xf/XL/XR/Xic + ids)
#
# Scaling:
#   - Objective: fixed anchor scaling (computed once at theta0)
#   - Constraints: RMS+EMA scalar scaling on ||J||_rms (updated every iter)
#   - LM invariance: lam_eff = lam*(s_con^2)
#
# ================================

import os
os.environ["JAX_PLATFORM_NAME"] = "cpu"  # set BEFORE importing jax

import time, math
from functools import partial
import numpy as np
import scipy.io

import jax
import jax.numpy as jnp
from jax import random, grad, vmap, hessian

# -----------------------------
# Precision
# -----------------------------
USE_X64 = False
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = 1e-12

# -----------------------------
# Batch sizes / region structure (EDIT THESE)
# -----------------------------
B_DATA = 1000

# PDE cells
NX_PDE_MOM = 25
NT_PDE_MOM = 25
K_PDE = NX_PDE_MOM * NT_PDE_MOM
N_PDE_PER_CELL = 1
B_F_TOTAL = K_PDE * N_PDE_PER_CELL

# BC bins
K_BC = 100
N_BC_PER_BIN = 1
B_BC_TOTAL = K_BC * N_BC_PER_BIN

# IC bins
K_IC = 300
N_IC_PER_BIN = 1
B_IC_TOTAL = K_IC * N_IC_PER_BIN

# Total constraint dimension
M_CON = K_PDE + 2 * K_BC + K_IC


# -----------------------------
# 1) MLP
# -----------------------------
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params


def mlp_apply(params, x):
    h = x
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)
    return h  # (N,1)


# -----------------------------
# 2) Flatten/unflatten
# -----------------------------
def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)


def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape); idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape); idx += b_size
        params.append({"W": W, "b": b})
    return params


# -----------------------------
# 3) Load burgers.mat
# -----------------------------
def load_burgers_mat(path):
    d = scipy.io.loadmat(path)
    t = d["t"].squeeze()
    x = d["x"].squeeze()
    usol = d["usol"]  # (nt, nx)
    nu = float(np.array(d["nu"]).squeeze())
    return t, x, usol, nu


def build_full_data_points(t_np, x_np, usol_np):
    T, X = np.meshgrid(t_np, x_np, indexing="ij")
    X_data = np.stack([X.reshape(-1), T.reshape(-1)], 1)
    u_data = usol_np.reshape(-1)
    return X_data, u_data


# -----------------------------
# 4) Sampling utilities
# -----------------------------
def sample_data_batch(key, X_data, u_data, B):
    N = X_data.shape[0]
    idx = random.randint(key, (B,), 0, N)
    return X_data[idx], u_data[idx]


def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)


def sample_pde_stratified(key, x_min, x_max, t_min, t_max):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_MOM)
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_MOM)

    it, ix = jnp.meshgrid(
        jnp.arange(NT_PDE_MOM),
        jnp.arange(NX_PDE_MOM),
        indexing="ij"
    )
    it = it.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids_cell = (it * NX_PDE_MOM + ix).astype(jnp.int32)

    x0 = DTYPE(x_min) + DTYPE(ix) * dx
    t0 = DTYPE(t_min) + DTYPE(it) * dt

    u = random.uniform(key, (K_PDE, N_PDE_PER_CELL, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = x0[:, None] + u[:, :, 0] * dx
    ts = t0[:, None] + u[:, :, 1] * dt

    X_f = jnp.stack([xs, ts], axis=-1).reshape(-1, 2)
    ids = jnp.repeat(ids_cell, N_PDE_PER_CELL)
    return X_f, ids


def sample_bc_stratified(key, x_min, x_max, t_min, t_max):
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(K_BC)
    j = jnp.arange(K_BC, dtype=jnp.int32)
    t0 = DTYPE(t_min) + DTYPE(j) * dt

    u = random.uniform(key, (K_BC, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (t0[:, None] + u * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    XL = jnp.concatenate([DTYPE(x_min) * jnp.ones_like(ts), ts], axis=1)
    XR = jnp.concatenate([DTYPE(x_max) * jnp.ones_like(ts), ts], axis=1)
    return XL, XR, ids


def sample_ic_stratified(key, x_min, x_max, t0, x_grid, u0_grid):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(K_IC)
    j = jnp.arange(K_IC, dtype=jnp.int32)
    x0 = DTYPE(x_min) + DTYPE(j) * dx

    u = random.uniform(key, (K_IC, N_IC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (x0[:, None] + u * dx).reshape(-1, 1)
    ids = jnp.repeat(j, N_IC_PER_BIN)

    Xic = jnp.concatenate([xs, DTYPE(t0) * jnp.ones_like(xs)], axis=1)
    u0 = jnp.interp(xs[:, 0], x_grid, u0_grid)
    return Xic, u0, ids


# -----------------------------
# 4.5) Antithetic jitter utilities (NEW)
# -----------------------------
def _rand_pm1(key, shape, dist):
    """Return random array with mean ~0. Normal or Uniform(-1,1)."""
    if dist == "normal":
        return random.normal(key, shape, dtype=DTYPE)
    if dist == "uniform":
        return random.uniform(key, shape, minval=-1.0, maxval=1.0, dtype=DTYPE)
    raise ValueError(f"Unknown dist={dist}. Use 'normal' or 'uniform'.")

def jitter_pde_points_pair(key, X_base, sigma_x, sigma_t, x_min, x_max, t_min, t_max, dist):
    z = _rand_pm1(key, (X_base.shape[0], 2), dist)
    dx = sigma_x * z[:, 0]
    dt = sigma_t * z[:, 1]
    Xp = X_base + jnp.stack([dx, dt], axis=1)
    Xm = X_base - jnp.stack([dx, dt], axis=1)
    xp = jnp.clip(Xp[:, 0], DTYPE(x_min), DTYPE(x_max))
    tp = jnp.clip(Xp[:, 1], DTYPE(t_min), DTYPE(t_max))
    xm = jnp.clip(Xm[:, 0], DTYPE(x_min), DTYPE(x_max))
    tm = jnp.clip(Xm[:, 1], DTYPE(t_min), DTYPE(t_max))
    return jnp.stack([xp, tp], axis=1), jnp.stack([xm, tm], axis=1)

def jitter_bc_points_pair(key, XL_base, XR_base, sigma_t, t_min, t_max, dist):
    z = _rand_pm1(key, (XL_base.shape[0],), dist)
    dt = sigma_t * z
    tp = jnp.clip(XL_base[:, 1] + dt, DTYPE(t_min), DTYPE(t_max))
    tm = jnp.clip(XL_base[:, 1] - dt, DTYPE(t_min), DTYPE(t_max))
    XLp = jnp.stack([XL_base[:, 0], tp], axis=1)
    XRp = jnp.stack([XR_base[:, 0], tp], axis=1)
    XLm = jnp.stack([XL_base[:, 0], tm], axis=1)
    XRm = jnp.stack([XR_base[:, 0], tm], axis=1)
    return XLp, XRp, XLm, XRm

def jitter_ic_points_pair(key, Xic_base, sigma_x, x_min, x_max, x_grid, u0_grid, dist):
    z = _rand_pm1(key, (Xic_base.shape[0],), dist)
    dx = sigma_x * z
    xp = jnp.clip(Xic_base[:, 0] + dx, DTYPE(x_min), DTYPE(x_max))
    xm = jnp.clip(Xic_base[:, 0] - dx, DTYPE(x_min), DTYPE(x_max))
    Xp = jnp.stack([xp, Xic_base[:, 1]], axis=1)
    Xm = jnp.stack([xm, Xic_base[:, 1]], axis=1)
    u0p = jnp.interp(xp, x_grid, u0_grid)
    u0m = jnp.interp(xm, x_grid, u0_grid)
    return Xp, u0p, Xm, u0m


# -----------------------------
# 5) PDE residual
# -----------------------------
def pde_residual_unscaled(params, X_f, nu):
    def u_fun(xt):
        return mlp_apply(params, xt[None, :])[0, 0]

    u = vmap(u_fun)(X_f)
    du = vmap(grad(u_fun))(X_f)
    H = vmap(hessian(u_fun))(X_f)

    u_x = du[:, 0]
    u_t = du[:, 1]
    u_xx = H[:, 0, 0]
    return u_t + u * u_x - DTYPE(nu) * u_xx


# -----------------------------
# 6) Objective: data MSE + anchor scaling
# -----------------------------
def data_mse_unscaled(params, Xb, ub):
    pred = mlp_apply(params, Xb)[:, 0]
    return jnp.mean((pred - ub) ** 2)


@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_data_scaled_batch(theta, shapes, Xb, ub, scale_obj):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        return data_mse_unscaled(params, Xb, ub)

    val, g = jax.value_and_grad(obj_theta)(theta)
    return scale_obj * val, scale_obj * g


def compute_scale_obj_data_anchor(theta0, shapes, X_anchor, u_anchor, target=100.0):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        return data_mse_unscaled(params, X_anchor, u_anchor)

    g0 = grad(obj_theta)(theta0)
    ginf = jnp.linalg.norm(g0, jnp.inf)
    return (DTYPE(target) / jnp.maximum(DTYPE(target), ginf + DTYPE(EPS))).astype(DTYPE)


# -----------------------------
# 7) BC helper u, ux
# -----------------------------
@jax.jit
def u_and_ux(params, X):
    def u_fun(xt):
        return mlp_apply(params, xt[None, :])[0, 0]

    u = vmap(u_fun)(X)
    du = vmap(grad(u_fun))(X)
    ux = du[:, 0]
    return u, ux


# -----------------------------
# 8) POINTWISE/SIGNED (mean) constraints + Jacobian
# -----------------------------
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector_cells_unscaled(theta, shapes,
                                     X_f, ids_f,
                                     X_bc_L, X_bc_R, ids_bc,
                                     X_ic, u0_ic, ids_ic,
                                     nu):
    params = unflatten_params(theta, shapes)

    # PDE signed residual
    r = pde_residual_unscaled(params, X_f, nu)
    c_pde = segment_sum(r, ids_f, K_PDE) / DTYPE(N_PDE_PER_CELL)

    # BC signed differences
    uL, uxL = u_and_ux(params, X_bc_L)
    uR, uxR = u_and_ux(params, X_bc_R)
    dv = (uL - uR)
    dd = (uxL - uxR)
    c_bc_val = segment_sum(dv, ids_bc, K_BC) / DTYPE(N_BC_PER_BIN)
    c_bc_der = segment_sum(dd, ids_bc, K_BC) / DTYPE(N_BC_PER_BIN)

    # IC signed mismatch
    u_ic = mlp_apply(params, X_ic)[:, 0]
    di = (u_ic - u0_ic)
    c_ic = segment_sum(di, ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)

    return jnp.concatenate([c_pde, c_bc_val, c_bc_der, c_ic], axis=0)


@partial(jax.jit, static_argnames=("shapes",))
def C_and_J_cells_unscaled(theta, shapes,
                           X_f, ids_f,
                           X_bc_L, X_bc_R, ids_bc,
                           X_ic, u0_ic, ids_ic,
                           nu):
    def c_fun(th):
        return constraint_vector_cells_unscaled(
            th, shapes, X_f, ids_f,
            X_bc_L, X_bc_R, ids_bc,
            X_ic, u0_ic, ids_ic,
            nu
        )

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J_un, c_un = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c_un, J_un


# -----------------------------
# 9) RMS+EMA scaling (for Jacobian magnitude)
# -----------------------------
def ema_update(old, new, alpha):
    return (DTYPE(1.0) - DTYPE(alpha)) * old + DTYPE(alpha) * new


def scalar_scale_from_mag(mag, target):
    return DTYPE(target) / jnp.maximum(DTYPE(target), mag + DTYPE(EPS))


# -----------------------------
# 10) KKT solve (LM proxy), lam_eff = lam*(s^2)
# -----------------------------
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, lam_eff):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)

    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -lam_eff * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)

    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y


def cal_d_and_y(H, Jac, Grad, Cons, s_con,
               ridge_init=1e-6, eta_up=10.0, eta_down=0.25,
               lam_min=1e-3, lam_max=1, res_tol=1e-6):
    lam = float(jnp.clip(DTYPE(ridge_init), DTYPE(lam_min), DTYPE(lam_max)))
    s2 = float(s_con * s_con)

    for _ in range(12):
        lam_eff = DTYPE(lam * s2)
        d, y = kkt_solve_once(H, Jac, Grad, Cons, lam_eff)
        res_vec = jnp.concatenate([H @ d + Jac.T @ y + Grad, Jac @ d + Cons])
        res = float(jnp.linalg.norm(res_vec, 2))
        if res <= res_tol:
            lam_next = float(jnp.clip(DTYPE(lam) * DTYPE(eta_down), DTYPE(lam_min), DTYPE(lam_max)))
            return d, y, lam_next, res
        lam = float(jnp.clip(DTYPE(lam) * DTYPE(eta_up), DTYPE(lam_min), DTYPE(lam_max)))

    lam_eff = DTYPE(lam * s2)
    d, y = kkt_solve_once(H, Jac, Grad, Cons, lam_eff)
    res_vec = jnp.concatenate([H @ d + Jac.T @ y + Grad, Jac @ d + Cons])
    res = float(jnp.linalg.norm(res_vec, 2))
    return d, y, lam, res


# -----------------------------
# 11) tau/ksi/alpha (Zhou-style)
# -----------------------------
def cal_tau(H, d, sigma, tau_pre, eps_tau, g, c):
    denom = float(g @ d + 0.5 * (d @ (H @ d)))
    if denom <= 1e-12:
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * float(jnp.linalg.norm(c, 1)) / denom

    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)


def cal_ksi(d, tau, ksi_old, eps_ksi, g, c):
    denom = tau * float(jnp.linalg.norm(d) ** 2)
    if denom <= 1e-18:
        return ksi_old

    top = -tau * float(g @ d) + float(jnp.linalg.norm(c, 1))
    ksi_trial = top / denom

    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)


def phi(alpha, eta, beta, tau, g, d, c, L, Gamma):
    normC1 = float(jnp.linalg.norm(c, 1))
    gd = float(g @ d)
    d2 = float(d @ d)

    term1 = (eta - 1.0) * alpha * beta * (-tau * gd + normC1)
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * normC1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3


def cal_alpha(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0

    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)

    while (phi(1.1 * a, eta, beta, tau, g, d, c, L, Gamma) < 0.0
           and (1.1 * a < alpha_min + theta_val * beta)):
        a *= 1.1
    return float(a)


# -----------------------------
# 12) Training loop with:
#     - hold_data_K steps per data minibatch
#     - hold_con_K  steps per BASE constraint sample set
#     - antithetic jitter every iteration around base points (NEW)
# -----------------------------
def train_sqp_cellwise_pointwise(theta0, shapes,
                                 X_data, u_data, x_grid, u0_grid, nu,
                                 x_min, x_max, t_min, t_max,
                                 scale_obj,
                                 con_scale_target=100.0, con_ema_alpha=0.05,
                                 L=100.0, Gamma=100.0,
                                 max_iters=5000, print_every=10,
                                 beta0=1.0, beta_shift=200.0, beta_power=0.8,
                                 alpha_cap=1.0,
                                 seed=0,
                                 mc_con_batches=1,
                                 mc_obj_batches=1,
                                 obj_resample_each_mc=False,
                                 hold_data_K=1,      # <-- iterations per DATA sample
                                 hold_con_K=1,       # <-- iterations per BASE constraint sample
                                 jitter_dist="normal",
                                 jitter_frac_pde_x=0.25,
                                 jitter_frac_pde_t=0.25,
                                 jitter_frac_bc_t=0.25,
                                 jitter_frac_ic_x=0.25):

    key = random.PRNGKey(seed)
    theta = theta0
    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 5.0, 1.0
    lam_prev = 1e-6

    Jmag_ema = DTYPE(0.0)
    s_con = DTYPE(1.0)

    # cached samples
    Xb = ub = None

    # cached BASE constraint samples (without jitter)
    Xf_base = ids_f = None
    XL_base = XR_base = ids_bc = None
    Xic_base = u0ic_base = ids_ic = None

    # fixed jitter scales (computed from bin/cell widths)
    pde_dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_MOM)
    pde_dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_MOM)
    bc_dt  = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(K_BC)
    ic_dx  = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(K_IC)

    sig_pde_x = DTYPE(jitter_frac_pde_x) * pde_dx
    sig_pde_t = DTYPE(jitter_frac_pde_t) * pde_dt
    sig_bc_t  = DTYPE(jitter_frac_bc_t)  * bc_dt
    sig_ic_x  = DTYPE(jitter_frac_ic_x)  * ic_dx

    t0_wall = time.time()
    for k in range(1, max_iters + 1):
        beta_k = float(min(1.0, beta0 * (beta_shift / (beta_shift + k)) ** beta_power))

        # -----------------------------
        # (A) DATA sampling (held for hold_data_K steps)
        # -----------------------------
        if (k == 1) or ((k - 1) % int(hold_data_K) == 0) or (Xb is None):
            key, k_data = random.split(key, 2)
            Xb, ub = sample_data_batch(k_data, X_data, u_data, B_DATA)

        # Objective MC average (optionally reuse same batch)
        S_obj = int(mc_obj_batches)
        obj_acc = DTYPE(0.0)
        obj2_acc = DTYPE(0.0)
        g_acc = jnp.zeros((n,), dtype=DTYPE)

        for _ in range(S_obj):
            if obj_resample_each_mc:
                key, k_data_i = random.split(key, 2)
                Xb_i, ub_i = sample_data_batch(k_data_i, X_data, u_data, B_DATA)
            else:
                Xb_i, ub_i = Xb, ub

            obj_i, g_i = F_and_g_data_scaled_batch(theta, shapes, Xb_i, ub_i, scale_obj)
            obj_acc = obj_acc + obj_i
            obj2_acc = obj2_acc + obj_i * obj_i
            g_acc = g_acc + g_i

        obj_s = obj_acc / DTYPE(S_obj)
        g_s = g_acc / DTYPE(S_obj)

        obj_var = jnp.maximum(obj2_acc / DTYPE(S_obj) - obj_s * obj_s, DTYPE(0.0))
        obj_std = float(jnp.sqrt(obj_var + DTYPE(EPS)))
        obj_std_mean = float(obj_std / jnp.sqrt(DTYPE(S_obj) + DTYPE(EPS)))

        # -----------------------------
        # (B) BASE CONSTRAINT sampling (held for hold_con_K steps)
        # -----------------------------
        if (k == 1) or ((k - 1) % int(hold_con_K) == 0) or (Xf_base is None):
            key, k_f, k_bc, k_ic = random.split(key, 4)
            Xf_base, ids_f = sample_pde_stratified(k_f, x_min, x_max, t_min, t_max)
            XL_base, XR_base, ids_bc = sample_bc_stratified(k_bc, x_min, x_max, t_min, t_max)
            Xic_base, u0ic_base, ids_ic = sample_ic_stratified(k_ic, x_min, x_max, t_min, x_grid, u0_grid)

        # -----------------------------
        # (B.1) Constraints/J MC average over *antithetic jitter only* (NO new base points)
        # -----------------------------
        S_con = int(mc_con_batches)
        c_acc = jnp.zeros((M_CON,), dtype=DTYPE)
        J_acc = jnp.zeros((M_CON, n), dtype=DTYPE)

        c_list = []

        # keep last jittered samples for diagnostics (pair)
        Xf_last_p = Xf_last_m = None
        XL_last_p = XR_last_p = None
        XL_last_m = XR_last_m = None
        Xic_last_p = Xic_last_m = None
        u0ic_last_p = u0ic_last_m = None

        for s in range(S_con):
            key, k_jpde, k_jbc, k_jic = random.split(key, 4)

            Xf_p, Xf_m = jitter_pde_points_pair(k_jpde, Xf_base, sig_pde_x, sig_pde_t, x_min, x_max, t_min, t_max, jitter_dist)
            XL_p, XR_p, XL_m, XR_m = jitter_bc_points_pair(k_jbc, XL_base, XR_base, sig_bc_t, t_min, t_max, jitter_dist)
            Xic_p, u0ic_p, Xic_m, u0ic_m = jitter_ic_points_pair(k_jic, Xic_base, sig_ic_x, x_min, x_max, x_grid, u0_grid, jitter_dist)

            c_p, J_p = C_and_J_cells_unscaled(
                theta, shapes,
                Xf_p, ids_f,
                XL_p, XR_p, ids_bc,
                Xic_p, u0ic_p, ids_ic,
                nu
            )
            c_m, J_m = C_and_J_cells_unscaled(
                theta, shapes,
                Xf_m, ids_f,
                XL_m, XR_m, ids_bc,
                Xic_m, u0ic_m, ids_ic,
                nu
            )

            c_tmp = DTYPE(0.5) * (c_p + c_m)
            J_tmp = DTYPE(0.5) * (J_p + J_m)

            c_acc = c_acc + c_tmp
            J_acc = J_acc + J_tmp
            c_list.append(c_tmp)

            Xf_last_p, Xf_last_m = Xf_p, Xf_m
            XL_last_p, XR_last_p = XL_p, XR_p
            XL_last_m, XR_last_m = XL_m, XR_m
            Xic_last_p, Xic_last_m = Xic_p, Xic_m
            u0ic_last_p, u0ic_last_m = u0ic_p, u0ic_m

        c_un = c_acc / DTYPE(S_con)
        J_un = J_acc / DTYPE(S_con)

        # -----------------------------
        # (C) RMS+EMA scaling on J magnitude
        # -----------------------------
        J_rms = jnp.sqrt(jnp.mean(J_un ** 2) + DTYPE(EPS))
        if k == 1 and float(Jmag_ema) == 0.0:
            Jmag_ema = J_rms
        else:
            Jmag_ema = ema_update(Jmag_ema, J_rms, con_ema_alpha)

        s_con = scalar_scale_from_mag(Jmag_ema, con_scale_target)
        s_con = jax.lax.stop_gradient(s_con)

        Cons = s_con * c_un
        Jac = s_con * J_un

        # -----------------------------
        # (D) KKT direction
        # -----------------------------
        d, y, lam_prev, kkt_res = cal_d_and_y(H, Jac, g_s, Cons, s_con, ridge_init=lam_prev)

        # -----------------------------
        # (E) Step size
        # -----------------------------
        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-10:
            tau_k = cal_tau(H, d, sigma, tau_k, eps_tau, g_s, Cons)
            ksi_k = cal_ksi(d, tau_k, ksi_k, eps_ksi, g_s, Cons)
            alpha = cal_alpha(d, eta, beta_k, ksi_k, tau_k, L, Gamma, theta_val, g_s, Cons)
        else:
            alpha = 2.0 * (1.0 - eta) * beta_k * ksi_k * tau_k / (tau_k * L + Gamma)

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d

        # -----------------------------
        # Prints
        # -----------------------------
        if k % print_every == 0:
            feas = float(jnp.mean(Cons ** 2))
            station = float(jnp.linalg.norm(g_s + Jac.T @ y, jnp.inf))

            # group split (SIGNED constraints)
            c_pde = c_un[:K_PDE]
            c_bc_val = c_un[K_PDE: K_PDE + K_BC]
            c_bc_der = c_un[K_PDE + K_BC: K_PDE + 2 * K_BC]
            c_ic = c_un[K_PDE + 2 * K_BC:]

            def rms(x):    return float(jnp.sqrt(jnp.mean(x ** 2) + DTYPE(EPS)))
            def maxabs(x): return float(jnp.max(jnp.abs(x)))

            pde_rms, pde_max = rms(c_pde), maxabs(c_pde)
            bcV_rms, bcV_max = rms(c_bc_val), maxabs(c_bc_val)
            bcD_rms, bcD_max = rms(c_bc_der), maxabs(c_bc_der)
            ic_rms, ic_max = rms(c_ic), maxabs(c_ic)

            # pointwise RMS of effective (antithetic-averaged) raw quantities on last MC batch
            params_tmp = unflatten_params(theta, shapes)

            r_p = pde_residual_unscaled(params_tmp, Xf_last_p, nu)
            r_m = pde_residual_unscaled(params_tmp, Xf_last_m, nu)
            r_pts = DTYPE(0.5) * (r_p + r_m)

            uL_p, uxL_p = u_and_ux(params_tmp, XL_last_p)
            uR_p, uxR_p = u_and_ux(params_tmp, XR_last_p)
            dv_p = (uL_p - uR_p)
            dd_p = (uxL_p - uxR_p)

            uL_m, uxL_m = u_and_ux(params_tmp, XL_last_m)
            uR_m, uxR_m = u_and_ux(params_tmp, XR_last_m)
            dv_m = (uL_m - uR_m)
            dd_m = (uxL_m - uxR_m)

            dv_pts = DTYPE(0.5) * (dv_p + dv_m)
            dd_pts = DTYPE(0.5) * (dd_p + dd_m)

            di_p = (mlp_apply(params_tmp, Xic_last_p)[:, 0] - u0ic_last_p)
            di_m = (mlp_apply(params_tmp, Xic_last_m)[:, 0] - u0ic_last_m)
            di_pts = DTYPE(0.5) * (di_p + di_m)

            pde_pt_rms = float(jnp.sqrt(jnp.mean(r_pts ** 2) + DTYPE(EPS)))
            bcV_pt_rms = float(jnp.sqrt(jnp.mean(dv_pts ** 2) + DTYPE(EPS)))
            bcD_pt_rms = float(jnp.sqrt(jnp.mean(dd_pts ** 2) + DTYPE(EPS)))
            ic_pt_rms = float(jnp.sqrt(jnp.mean(di_pts ** 2) + DTYPE(EPS)))

            # If S_con>1, show constraint noise across the MC batches in this iteration
            if S_con > 1:
                c_stack = jnp.stack(c_list, axis=0)  # (S_con, M_CON)
                c_mean = jnp.mean(c_stack, axis=0)
                c_var = jnp.maximum(jnp.mean((c_stack - c_mean[None, :]) ** 2, axis=0), DTYPE(0.0))
                c_std = jnp.sqrt(c_var + DTYPE(EPS))
                c_std_mean = c_std / jnp.sqrt(DTYPE(S_con) + DTYPE(EPS))
                con_std_max = float(jnp.max(c_std))
                con_std_mean_max = float(jnp.max(c_std_mean))
            else:
                con_std_max = 0.0
                con_std_mean_max = 0.0

            print(
                f"[iter={k}] obj_s={float(obj_s):.3e} (obj_std={obj_std:.2e}, obj_std_mean={obj_std_mean:.2e}, Sobj={S_obj}) "
                f"feas={feas:.3e} station={station:.3e} "
                f"alpha={alpha:.2e} beta={beta_k:.2e} lam={lam_prev:.2e} kkt_res={kkt_res:.1e} s={float(s_con):.2e} "
                f"| constraints RMS/max: PDE=({pde_rms:.2e},{pde_max:.2e}) "
                f"BCv=({bcV_rms:.2e},{bcV_max:.2e}) "
                f"BCd=({bcD_rms:.2e},{bcD_max:.2e}) "
                f"IC=({ic_rms:.2e},{ic_max:.2e}) "
                f"| pointwise_rms(held): PDE={pde_pt_rms:.2e} BCv={bcV_pt_rms:.2e} BCd={bcD_pt_rms:.2e} IC={ic_pt_rms:.2e} "
                f"| mc_con={S_con} (std_max={con_std_max:.2e}, stdmean_max={con_std_mean_max:.2e}) "
                f"| hold_data_K={int(hold_data_K)} hold_con_K={int(hold_con_K)}"
            )

    print(f"[done] elapsed={time.time() - t0_wall:.2f}s")
    return theta


# -----------------------------
# 13) Eval helpers
# -----------------------------
def make_grid_points(x_np, t_np):
    T, X = np.meshgrid(t_np, x_np, indexing="ij")
    X_grid = np.stack([X.reshape(-1), T.reshape(-1)], axis=1)
    return X_grid, T.shape


@partial(jax.jit, static_argnames=("shapes",))
def predict_u(theta, shapes, X):
    params = unflatten_params(theta, shapes)
    return mlp_apply(params, X)[:, 0]


def eval_full_grid(theta, shapes, x_np, t_np, usol_np):
    X_grid_np, grid_shape = make_grid_points(x_np, t_np)
    X_grid = jnp.array(X_grid_np, dtype=DTYPE)
    u_pred = np.array(predict_u(theta, shapes, X_grid)).reshape(grid_shape)
    u_true = usol_np
    mse = float(np.mean((u_pred - u_true) ** 2))
    rel_l2 = float(np.linalg.norm(u_pred - u_true) / (np.linalg.norm(u_true) + 1e-12))
    return mse, rel_l2, u_pred


def plot_heatmaps(x_np, t_np, u_true, u_pred):
    import matplotlib.pyplot as plt
    err = u_pred - u_true

    plt.figure()
    plt.pcolormesh(x_np, t_np, u_true, shading="auto")
    plt.colorbar()
    plt.title("u_true")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.show()

    plt.figure()
    plt.pcolormesh(x_np, t_np, u_pred, shading="auto")
    plt.colorbar()
    plt.title("u_pred")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.show()

    plt.figure()
    plt.pcolormesh(x_np, t_np, err, shading="auto")
    plt.colorbar()
    plt.title("u_pred - u_true")
    plt.xlabel("x")
    plt.ylabel("t")
    plt.show()


# -----------------------------
# 14) main
# -----------------------------
def main():
    t_np, x_np, usol_np, nu = load_burgers_mat("data/burgers.mat")
    print("loaded burgers.mat:", "t", t_np.shape, "x", x_np.shape, "usol", usol_np.shape, "nu", nu)

    x_min, x_max = float(x_np.min()), float(x_np.max())
    t_min, t_max = float(t_np.min()), float(t_np.max())
    print(f"Domain: x in [{x_min}, {x_max}], t in [{t_min}, {t_max}]")

    X_data_np, u_data_np = build_full_data_points(t_np, x_np, usol_np)
    X_data = jnp.array(X_data_np, dtype=DTYPE)
    u_data = jnp.array(u_data_np, dtype=DTYPE)

    x_grid = jnp.array(x_np, dtype=DTYPE)
    u0_grid = jnp.array(usol_np[0, :], dtype=DTYPE)

    hidden_dim = 30
    num_hidden = 3
    layer_sizes = [2] + [hidden_dim] * num_hidden + [1]
    key = random.PRNGKey(0)
    key, key_params = random.split(key)
    params0 = init_mlp_params(key_params, layer_sizes)
    theta0, shapes = flatten_params(params0)

    # objective anchor scaling
    key_anchor = random.PRNGKey(123)
    X_anchor, u_anchor = sample_data_batch(key_anchor, X_data, u_data, B=512)
    scale_obj = compute_scale_obj_data_anchor(theta0, shapes, X_anchor, u_anchor, target=100.0)

    print("scale_obj (fixed anchor) =", float(scale_obj))
    print("Constraint dimension M_CON =", M_CON, " (= K_PDE + 2*K_BC + K_IC )")
    print(f"Total PDE samples per iter: {B_F_TOTAL} (= {K_PDE} cells * {N_PDE_PER_CELL} each)")
    print(f"Total BC samples  per iter: {B_BC_TOTAL} (= {K_BC} bins * {N_BC_PER_BIN} each)")
    print(f"Total IC samples  per iter: {B_IC_TOTAL} (= {K_IC} bins * {N_IC_PER_BIN} each)")

    theta_star = train_sqp_cellwise_pointwise(
        theta0, shapes,
        X_data, u_data, x_grid, u0_grid, nu,
        x_min=x_min, x_max=x_max, t_min=t_min, t_max=t_max,
        scale_obj=scale_obj,

        con_scale_target=100.0, con_ema_alpha=0.05,
        L=100.0, Gamma=100.0,

        max_iters=2000, print_every=5,

        beta0=1.0, beta_shift=200.0, beta_power=0.8,
        alpha_cap=1e1,

        seed=0,

        mc_con_batches=1,
        mc_obj_batches=1,
        obj_resample_each_mc=False,

        # ---- THIS is your "iterations per sample" control ----
        hold_data_K=2000,   # keep SAME data batch for all steps
        hold_con_K=2000,    # keep SAME BASE constraint points for all steps

        # ---- JITTER knobs ----
        jitter_dist="normal",      # "normal" or "uniform"
        jitter_frac_pde_x=0.01,    # σx = frac * (cell width in x)
        jitter_frac_pde_t=0.01,    # σt = frac * (cell width in t)
        jitter_frac_bc_t=0.01,     # σt = frac * (BC bin width in t)
        jitter_frac_ic_x=0.02      # σx = frac * (IC bin width in x)
    )

    np.save("theta_star_pointwise_jitter_antithetic.npy", np.array(theta_star))
    print("Saved theta -> theta_star_pointwise_jitter_antithetic.npy")

    mse, rel_l2, u_pred = eval_full_grid(theta_star, shapes, x_np, t_np, usol_np)
    print(f"[EVAL] full-grid MSE={mse:.3e}, relL2={rel_l2:.3e}")

    plot_heatmaps(x_np, t_np, usol_np, u_pred)


if __name__ == "__main__":
    main()
# Out:
# loaded burgers.mat: t (201,) x (512,) usol (201, 512) nu 0.003183098861837907
# Domain: x in [-1.0, 1.0], t in [0.0, 1.0]
# scale_obj (fixed anchor) = 1.0
# Constraint dimension M_CON = 1125  (= K_PDE + 2*K_BC + K_IC )
# Total PDE samples per iter: 625 (= 625 cells * 1 each)
# Total BC samples  per iter: 100 (= 100 bins * 1 each)
# Total IC samples  per iter: 300 (= 300 bins * 1 each)
# [iter=5] obj_s=1.191e-01 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.057e-01 station=3.191e-01 alpha=2.59e-01 beta=9.80e-01 lam=1.00e+00 kkt_res=6.2e+00 s=1.00e+00 | constraints RMS/max: PDE=(3.70e-01,9.77e-01) BCv=(3.48e-01,5.92e-01) BCd=(1.21e-01,1.88e-01) IC=(2.58e-01,4.02e-01) | pointwise_rms(held): PDE=3.29e-01 BCv=2.92e-01 BCd=8.49e-02 IC=2.51e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=10] obj_s=1.022e-01 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=6.124e-02 station=3.072e-01 alpha=2.79e-01 beta=9.62e-01 lam=1.00e+00 kkt_res=5.5e+00 s=1.00e+00 | constraints RMS/max: PDE=(2.75e-01,6.22e-01) BCv=(7.38e-02,2.33e-01) BCd=(4.93e-02,6.19e-02) IC=(2.63e-01,4.01e-01) | pointwise_rms(held): PDE=2.75e-01 BCv=7.29e-02 BCd=6.11e-02 IC=2.56e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=15] obj_s=8.430e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=4.930e-02 station=1.880e-01 alpha=5.87e-01 beta=9.44e-01 lam=1.00e+00 kkt_res=5.7e+00 s=1.00e+00 | constraints RMS/max: PDE=(2.40e-01,9.02e-01) BCv=(5.04e-02,1.29e-01) BCd=(3.30e-02,4.90e-02) IC=(2.52e-01,4.60e-01) | pointwise_rms(held): PDE=1.71e-01 BCv=2.17e-02 BCd=4.24e-02 IC=2.77e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=20] obj_s=8.025e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.346e-02 station=1.861e-01 alpha=3.25e-01 beta=9.27e-01 lam=1.00e+00 kkt_res=5.3e+00 s=1.00e+00 | constraints RMS/max: PDE=(1.57e-01,1.84e+00) BCv=(3.84e-02,4.89e-02) BCd=(2.40e-02,3.00e-02) IC=(2.71e-01,4.81e-01) | pointwise_rms(held): PDE=1.51e-01 BCv=3.38e-02 BCd=1.39e-02 IC=2.68e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=25] obj_s=7.096e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.567e-02 station=2.018e-01 alpha=2.40e-01 beta=9.10e-01 lam=1.00e+00 kkt_res=4.8e+00 s=1.00e+00 | constraints RMS/max: PDE=(1.28e-01,5.43e-01) BCv=(1.72e-02,3.18e-02) BCd=(9.60e-03,3.72e-02) IC=(2.49e-01,4.56e-01) | pointwise_rms(held): PDE=1.23e-01 BCv=1.45e-02 BCd=1.07e-02 IC=2.44e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=30] obj_s=6.781e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.001e-02 station=2.461e-01 alpha=1.47e-01 beta=8.94e-01 lam=1.00e+00 kkt_res=4.1e+00 s=1.00e+00 | constraints RMS/max: PDE=(1.05e-01,4.62e-01) BCv=(6.73e-03,2.07e-02) BCd=(1.03e-02,2.57e-02) IC=(2.28e-01,4.20e-01) | pointwise_rms(held): PDE=1.02e-01 BCv=5.96e-03 BCd=9.39e-03 IC=2.22e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=35] obj_s=6.366e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.550e-02 station=2.891e-01 alpha=1.19e-01 beta=8.79e-01 lam=1.00e+00 kkt_res=3.4e+00 s=1.00e+00 | constraints RMS/max: PDE=(9.51e-02,4.20e-01) BCv=(6.21e-03,2.38e-02) BCd=(7.71e-03,1.90e-02) IC=(1.98e-01,3.86e-01) | pointwise_rms(held): PDE=9.27e-02 BCv=6.29e-03 BCd=7.72e-03 IC=1.93e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=40] obj_s=6.217e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.161e-02 station=2.086e-01 alpha=1.42e-01 beta=8.64e-01 lam=1.00e+00 kkt_res=3.0e+00 s=1.00e+00 | constraints RMS/max: PDE=(8.17e-02,5.13e-01) BCv=(7.99e-03,1.84e-02) BCd=(7.66e-03,1.89e-02) IC=(1.72e-01,3.64e-01) | pointwise_rms(held): PDE=7.90e-02 BCv=8.09e-03 BCd=7.67e-03 IC=1.67e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=45] obj_s=6.241e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=8.380e-03 station=2.887e-01 alpha=1.27e-01 beta=8.50e-01 lam=1.00e+00 kkt_res=2.5e+00 s=1.00e+00 | constraints RMS/max: PDE=(6.91e-02,3.91e-01) BCv=(7.60e-03,1.10e-02) BCd=(7.39e-03,1.79e-02) IC=(1.46e-01,3.34e-01) | pointwise_rms(held): PDE=6.70e-02 BCv=7.51e-03 BCd=7.16e-03 IC=1.42e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=50] obj_s=6.269e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=5.996e-03 station=1.991e-01 alpha=1.37e-01 beta=8.37e-01 lam=1.00e+00 kkt_res=2.1e+00 s=1.00e+00 | constraints RMS/max: PDE=(5.92e-02,3.82e-01) BCv=(7.01e-03,1.02e-02) BCd=(6.04e-03,1.64e-02) IC=(1.23e-01,3.04e-01) | pointwise_rms(held): PDE=5.73e-02 BCv=6.78e-03 BCd=5.79e-03 IC=1.19e-01 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=55] obj_s=6.296e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=4.265e-03 station=1.845e-01 alpha=1.23e-01 beta=8.23e-01 lam=1.00e+00 kkt_res=1.6e+00 s=1.00e+00 | constraints RMS/max: PDE=(5.09e-02,3.53e-01) BCv=(6.51e-03,1.05e-02) BCd=(5.25e-03,1.67e-02) IC=(1.03e-01,2.67e-01) | pointwise_rms(held): PDE=4.95e-02 BCv=6.46e-03 BCd=5.21e-03 IC=9.88e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=60] obj_s=6.301e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.038e-03 station=1.655e-01 alpha=1.33e-01 beta=8.11e-01 lam=1.00e+00 kkt_res=1.2e+00 s=1.00e+00 | constraints RMS/max: PDE=(4.71e-02,3.82e-01) BCv=(5.61e-03,9.55e-03) BCd=(4.74e-03,1.47e-02) IC=(8.22e-02,2.21e-01) | pointwise_rms(held): PDE=4.48e-02 BCv=5.24e-03 BCd=4.56e-03 IC=7.79e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=65] obj_s=6.314e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.031e-03 station=1.043e-01 alpha=2.32e-01 beta=7.98e-01 lam=1.00e+00 kkt_res=8.5e-01 s=1.00e+00 | constraints RMS/max: PDE=(4.55e-02,5.53e-01) BCv=(4.11e-03,7.06e-03) BCd=(4.23e-03,1.12e-02) IC=(5.74e-02,1.46e-01) | pointwise_rms(held): PDE=3.96e-02 BCv=3.78e-03 BCd=4.37e-03 IC=5.15e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=70] obj_s=6.339e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.045e-03 station=3.692e-02 alpha=5.92e-01 beta=7.87e-01 lam=1.00e+00 kkt_res=6.5e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.76e-02,5.72e-01) BCv=(2.23e-03,6.62e-03) BCd=(4.57e-03,9.48e-03) IC=(3.10e-02,8.44e-02) | pointwise_rms(held): PDE=2.70e-02 BCv=2.70e-03 BCd=4.47e-03 IC=2.90e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=75] obj_s=6.523e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.660e-03 station=2.659e-02 alpha=1.14e+00 beta=7.75e-01 lam=1.00e+00 kkt_res=5.3e-01 s=1.00e+00 | constraints RMS/max: PDE=(6.70e-02,1.51e+00) BCv=(1.44e-03,5.88e-03) BCd=(3.38e-03,8.08e-03) IC=(2.50e-02,8.06e-02) | pointwise_rms(held): PDE=1.66e-02 BCv=1.73e-03 BCd=3.35e-03 IC=2.42e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=80] obj_s=6.478e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.209e-02 station=1.825e-02 alpha=1.12e+00 beta=7.64e-01 lam=1.00e+00 kkt_res=4.7e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.47e-01,3.56e+00) BCv=(2.34e-03,5.98e-03) BCd=(3.00e-03,9.69e-03) IC=(2.31e-02,8.73e-02) | pointwise_rms(held): PDE=3.33e-02 BCv=8.71e-04 BCd=2.81e-03 IC=2.27e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=85] obj_s=6.459e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=4.306e-03 station=1.462e-02 alpha=1.22e+00 beta=7.53e-01 lam=1.00e+00 kkt_res=4.5e-01 s=1.00e+00 | constraints RMS/max: PDE=(8.67e-02,2.09e+00) BCv=(9.16e-04,3.61e-03) BCd=(2.63e-03,1.04e-02) IC=(2.18e-02,8.40e-02) | pointwise_rms(held): PDE=2.54e-02 BCv=8.54e-04 BCd=2.52e-03 IC=2.15e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=90] obj_s=6.412e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.476e-03 station=1.308e-02 alpha=1.20e+00 beta=7.43e-01 lam=1.00e+00 kkt_res=4.3e-01 s=1.00e+00 | constraints RMS/max: PDE=(4.95e-02,1.10e+00) BCv=(7.29e-04,2.96e-03) BCd=(2.25e-03,9.83e-03) IC=(2.05e-02,7.91e-02) | pointwise_rms(held): PDE=1.41e-02 BCv=8.53e-04 BCd=2.23e-03 IC=2.00e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=95] obj_s=6.369e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.719e-04 station=1.086e-02 alpha=1.18e+00 beta=7.33e-01 lam=1.00e+00 kkt_res=4.0e-01 s=1.00e+00 | constraints RMS/max: PDE=(2.20e-02,2.77e-01) BCv=(1.41e-03,2.59e-03) BCd=(1.97e-03,8.80e-03) IC=(1.95e-02,7.49e-02) | pointwise_rms(held): PDE=9.98e-03 BCv=7.37e-04 BCd=1.91e-03 IC=1.92e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=100] obj_s=6.328e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.100e-03 station=1.157e-02 alpha=1.17e+00 beta=7.23e-01 lam=1.00e+00 kkt_res=3.8e-01 s=1.00e+00 | constraints RMS/max: PDE=(6.02e-02,1.01e+00) BCv=(1.01e-03,2.08e-03) BCd=(1.89e-03,1.03e-02) IC=(1.81e-02,6.97e-02) | pointwise_rms(held): PDE=1.40e-02 BCv=7.90e-04 BCd=1.83e-03 IC=1.78e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=105] obj_s=6.254e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.683e-03 station=6.158e-02 alpha=6.50e-01 beta=7.13e-01 lam=1.00e+00 kkt_res=3.9e-01 s=1.00e+00 | constraints RMS/max: PDE=(8.06e-02,1.43e+00) BCv=(8.19e-04,1.80e-03) BCd=(1.86e-03,1.02e-02) IC=(1.70e-02,6.49e-02) | pointwise_rms(held): PDE=3.73e-02 BCv=1.19e-03 BCd=2.00e-03 IC=1.72e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=110] obj_s=6.284e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.188e-03 station=1.934e-02 alpha=1.14e+00 beta=7.04e-01 lam=1.00e+00 kkt_res=3.4e-01 s=1.00e+00 | constraints RMS/max: PDE=(4.49e-02,9.83e-01) BCv=(7.89e-04,1.63e-03) BCd=(1.85e-03,9.55e-03) IC=(1.57e-02,5.97e-02) | pointwise_rms(held): PDE=1.32e-02 BCv=8.28e-04 BCd=1.90e-03 IC=1.53e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=115] obj_s=6.234e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=7.724e-03 station=1.690e-02 alpha=1.12e+00 beta=6.95e-01 lam=1.00e+00 kkt_res=3.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.18e-01,2.29e+00) BCv=(9.33e-04,1.90e-03) BCd=(1.97e-03,1.12e-02) IC=(1.39e-02,5.16e-02) | pointwise_rms(held): PDE=2.09e-02 BCv=7.53e-04 BCd=2.01e-03 IC=1.39e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=120] obj_s=6.197e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.754e-03 station=1.460e-02 alpha=1.22e+00 beta=6.87e-01 lam=1.00e+00 kkt_res=2.8e-01 s=1.00e+00 | constraints RMS/max: PDE=(5.55e-02,1.12e+00) BCv=(8.12e-04,2.19e-03) BCd=(2.07e-03,1.03e-02) IC=(1.25e-02,4.38e-02) | pointwise_rms(held): PDE=1.53e-02 BCv=7.05e-04 BCd=2.10e-03 IC=1.21e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=125] obj_s=6.197e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=7.656e-04 station=4.338e-02 alpha=9.95e-01 beta=6.78e-01 lam=1.00e+00 kkt_res=2.6e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.64e-02,5.42e-01) BCv=(7.90e-04,2.17e-03) BCd=(2.25e-03,1.13e-02) IC=(1.05e-02,3.32e-02) | pointwise_rms(held): PDE=2.59e-02 BCv=1.21e-03 BCd=2.57e-03 IC=1.03e-02 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=130] obj_s=6.166e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.101e-03 station=6.672e-02 alpha=4.17e-01 beta=6.70e-01 lam=1.00e+00 kkt_res=2.6e-01 s=1.00e+00 | constraints RMS/max: PDE=(6.12e-02,1.01e+00) BCv=(7.61e-04,1.78e-03) BCd=(2.32e-03,1.12e-02) IC=(9.01e-03,2.91e-02) | pointwise_rms(held): PDE=3.98e-02 BCv=9.30e-04 BCd=2.55e-03 IC=9.03e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=135] obj_s=6.138e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=6.317e-04 station=2.635e-02 alpha=1.07e+00 beta=6.62e-01 lam=1.00e+00 kkt_res=2.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.32e-02,4.53e-01) BCv=(8.80e-04,1.47e-03) BCd=(2.39e-03,1.18e-02) IC=(7.98e-03,2.82e-02) | pointwise_rms(held): PDE=1.22e-02 BCv=8.27e-04 BCd=2.29e-03 IC=7.94e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=140] obj_s=6.096e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.669e-03 station=9.683e-03 alpha=1.16e+00 beta=6.54e-01 lam=1.00e+00 kkt_res=1.9e-01 s=1.00e+00 | constraints RMS/max: PDE=(5.46e-02,1.31e+00) BCv=(7.09e-04,1.35e-03) BCd=(2.30e-03,1.09e-02) IC=(7.11e-03,3.09e-02) | pointwise_rms(held): PDE=1.11e-02 BCv=7.05e-04 BCd=2.28e-03 IC=6.89e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=145] obj_s=6.125e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=6.748e-03 station=1.458e-02 alpha=1.15e+00 beta=6.47e-01 lam=1.00e+00 kkt_res=1.8e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.10e-01,2.66e+00) BCv=(8.49e-04,1.63e-03) BCd=(2.32e-03,1.02e-02) IC=(6.31e-03,3.17e-02) | pointwise_rms(held): PDE=2.16e-02 BCv=7.13e-04 BCd=2.34e-03 IC=6.04e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=150] obj_s=6.077e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=6.824e-03 station=1.136e-02 alpha=1.13e+00 beta=6.39e-01 lam=1.00e+00 kkt_res=1.6e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.11e-01,2.70e+00) BCv=(9.42e-04,1.70e-03) BCd=(2.39e-03,9.60e-03) IC=(5.74e-03,2.82e-02) | pointwise_rms(held): PDE=1.83e-02 BCv=7.64e-04 BCd=2.27e-03 IC=5.48e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=155] obj_s=6.041e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.265e-03 station=1.270e-02 alpha=1.12e+00 beta=6.32e-01 lam=1.00e+00 kkt_res=1.6e-01 s=1.00e+00 | constraints RMS/max: PDE=(6.37e-02,1.32e+00) BCv=(7.66e-04,1.24e-03) BCd=(2.25e-03,1.03e-02) IC=(5.01e-03,2.55e-02) | pointwise_rms(held): PDE=9.77e-03 BCv=7.21e-04 BCd=2.15e-03 IC=4.93e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=160] obj_s=6.021e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.688e-03 station=1.075e-02 alpha=1.11e+00 beta=6.25e-01 lam=1.00e+00 kkt_res=1.5e-01 s=1.00e+00 | constraints RMS/max: PDE=(6.95e-02,1.34e+00) BCv=(7.85e-04,1.51e-03) BCd=(2.20e-03,9.07e-03) IC=(4.60e-03,2.47e-02) | pointwise_rms(held): PDE=1.14e-02 BCv=6.64e-04 BCd=2.12e-03 IC=4.46e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=165] obj_s=5.949e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=9.804e-03 station=1.371e-02 alpha=1.10e+00 beta=6.18e-01 lam=1.00e+00 kkt_res=1.5e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.33e-01,3.07e+00) BCv=(8.94e-04,1.63e-03) BCd=(2.26e-03,1.01e-02) IC=(4.05e-03,1.91e-02) | pointwise_rms(held): PDE=1.54e-02 BCv=8.05e-04 BCd=2.07e-03 IC=4.11e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=170] obj_s=5.919e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=8.245e-04 station=4.374e-03 alpha=1.19e+00 beta=6.11e-01 lam=1.00e+00 kkt_res=1.3e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.84e-02,6.99e-01) BCv=(6.28e-04,1.19e-03) BCd=(2.00e-03,8.67e-03) IC=(3.91e-03,2.29e-02) | pointwise_rms(held): PDE=9.13e-03 BCv=5.98e-04 BCd=1.99e-03 IC=3.79e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=175] obj_s=5.873e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.794e-04 station=1.262e-02 alpha=1.07e+00 beta=6.05e-01 lam=1.00e+00 kkt_res=1.4e-01 s=1.00e+00 | constraints RMS/max: PDE=(2.60e-02,4.33e-01) BCv=(4.97e-04,8.95e-04) BCd=(1.94e-03,8.03e-03) IC=(3.69e-03,2.05e-02) | pointwise_rms(held): PDE=1.00e-02 BCv=5.71e-04 BCd=1.97e-03 IC=3.68e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=180] obj_s=5.827e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.175e-04 station=3.926e-03 alpha=1.17e+00 beta=5.98e-01 lam=1.00e+00 kkt_res=1.2e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.43e-02,2.51e-01) BCv=(6.30e-04,1.42e-03) BCd=(1.87e-03,7.27e-03) IC=(3.53e-03,1.91e-02) | pointwise_rms(held): PDE=4.60e-03 BCv=4.94e-04 BCd=1.84e-03 IC=3.38e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=185] obj_s=5.792e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.012e-04 station=2.110e-03 alpha=1.16e+00 beta=5.92e-01 lam=1.00e+00 kkt_res=1.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.33e-02,2.53e-01) BCv=(4.88e-04,9.83e-04) BCd=(1.79e-03,7.41e-03) IC=(3.25e-03,2.12e-02) | pointwise_rms(held): PDE=4.44e-03 BCv=4.86e-04 BCd=1.77e-03 IC=3.16e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=190] obj_s=5.764e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.061e-03 station=4.550e-03 alpha=1.14e+00 beta=5.86e-01 lam=1.00e+00 kkt_res=1.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(4.36e-02,9.45e-01) BCv=(4.23e-04,9.37e-04) BCd=(1.67e-03,7.25e-03) IC=(3.27e-03,1.89e-02) | pointwise_rms(held): PDE=7.94e-03 BCv=4.38e-04 BCd=1.67e-03 IC=3.11e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=195] obj_s=5.746e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.309e-04 station=6.035e-03 alpha=1.13e+00 beta=5.80e-01 lam=1.00e+00 kkt_res=1.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(1.52e-02,2.10e-01) BCv=(4.38e-04,9.68e-04) BCd=(1.62e-03,7.00e-03) IC=(2.89e-03,1.71e-02) | pointwise_rms(held): PDE=4.41e-03 BCv=4.62e-04 BCd=1.61e-03 IC=2.86e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=200] obj_s=5.734e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=8.409e-04 station=3.121e-03 alpha=1.23e+00 beta=5.74e-01 lam=1.00e+00 kkt_res=1.0e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.89e-02,8.52e-01) BCv=(4.53e-04,1.02e-03) BCd=(1.60e-03,6.56e-03) IC=(2.82e-03,1.42e-02) | pointwise_rms(held): PDE=9.69e-03 BCv=4.52e-04 BCd=1.58e-03 IC=2.71e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=205] obj_s=5.726e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.151e-04 station=3.792e-03 alpha=1.22e+00 beta=5.69e-01 lam=1.00e+00 kkt_res=9.9e-02 s=1.00e+00 | constraints RMS/max: PDE=(2.37e-02,5.25e-01) BCv=(4.55e-04,9.89e-04) BCd=(1.51e-03,6.17e-03) IC=(2.69e-03,1.61e-02) | pointwise_rms(held): PDE=5.79e-03 BCv=4.53e-04 BCd=1.46e-03 IC=2.66e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=210] obj_s=5.676e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=6.711e-04 station=1.358e-02 alpha=1.00e+00 beta=5.63e-01 lam=1.00e+00 kkt_res=1.1e-01 s=1.00e+00 | constraints RMS/max: PDE=(3.47e-02,7.67e-01) BCv=(5.16e-04,1.19e-03) BCd=(1.44e-03,6.20e-03) IC=(2.72e-03,1.53e-02) | pointwise_rms(held): PDE=7.55e-03 BCv=5.15e-04 BCd=1.49e-03 IC=2.79e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=215] obj_s=5.682e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=5.445e-05 station=2.064e-03 alpha=1.20e+00 beta=5.58e-01 lam=1.00e+00 kkt_res=9.2e-02 s=1.00e+00 | constraints RMS/max: PDE=(9.73e-03,1.55e-01) BCv=(4.16e-04,8.82e-04) BCd=(1.35e-03,5.68e-03) IC=(2.53e-03,1.83e-02) | pointwise_rms(held): PDE=3.78e-03 BCv=4.62e-04 BCd=1.35e-03 IC=2.45e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=220] obj_s=5.670e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=9.813e-04 station=7.044e-03 alpha=1.19e+00 beta=5.52e-01 lam=1.00e+00 kkt_res=9.1e-02 s=1.00e+00 | constraints RMS/max: PDE=(4.20e-02,9.03e-01) BCv=(4.15e-04,8.76e-04) BCd=(1.30e-03,5.50e-03) IC=(2.49e-03,1.61e-02) | pointwise_rms(held): PDE=8.34e-03 BCv=4.67e-04 BCd=1.34e-03 IC=2.35e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=225] obj_s=5.661e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=4.619e-04 station=4.102e-03 alpha=1.18e+00 beta=5.47e-01 lam=1.00e+00 kkt_res=8.7e-02 s=1.00e+00 | constraints RMS/max: PDE=(2.88e-02,4.19e-01) BCv=(4.56e-04,8.76e-04) BCd=(1.26e-03,5.26e-03) IC=(2.37e-03,1.44e-02) | pointwise_rms(held): PDE=5.92e-03 BCv=4.97e-04 BCd=1.27e-03 IC=2.45e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=230] obj_s=5.653e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.264e-04 station=1.728e-03 alpha=1.16e+00 beta=5.42e-01 lam=1.00e+00 kkt_res=8.4e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.50e-02,1.97e-01) BCv=(4.32e-04,9.08e-04) BCd=(1.22e-03,5.08e-03) IC=(2.37e-03,1.36e-02) | pointwise_rms(held): PDE=3.83e-03 BCv=4.36e-04 BCd=1.21e-03 IC=2.32e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=235] obj_s=5.644e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.066e-03 station=4.475e-03 alpha=1.15e+00 beta=5.37e-01 lam=1.00e+00 kkt_res=8.3e-02 s=1.00e+00 | constraints RMS/max: PDE=(4.38e-02,1.07e+00) BCv=(4.61e-04,1.03e-03) BCd=(1.18e-03,4.88e-03) IC=(2.22e-03,1.46e-02) | pointwise_rms(held): PDE=7.17e-03 BCv=4.37e-04 BCd=1.20e-03 IC=2.29e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=240] obj_s=5.630e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=9.181e-04 station=3.984e-03 alpha=1.14e+00 beta=5.32e-01 lam=1.00e+00 kkt_res=8.2e-02 s=1.00e+00 | constraints RMS/max: PDE=(4.06e-02,9.82e-01) BCv=(4.64e-04,1.03e-03) BCd=(1.13e-03,4.59e-03) IC=(2.32e-03,1.74e-02) | pointwise_rms(held): PDE=6.10e-03 BCv=4.56e-04 BCd=1.14e-03 IC=2.21e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=245] obj_s=5.628e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=8.022e-05 station=1.959e-03 alpha=1.13e+00 beta=5.27e-01 lam=1.00e+00 kkt_res=7.8e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.19e-02,2.29e-01) BCv=(4.47e-04,9.23e-04) BCd=(1.12e-03,4.56e-03) IC=(2.13e-03,1.40e-02) | pointwise_rms(held): PDE=3.21e-03 BCv=4.45e-04 BCd=1.11e-03 IC=2.15e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=250] obj_s=5.613e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=7.301e-05 station=4.866e-03 alpha=1.12e+00 beta=5.23e-01 lam=1.00e+00 kkt_res=7.8e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.14e-02,1.70e-01) BCv=(4.10e-04,7.96e-04) BCd=(1.09e-03,4.51e-03) IC=(2.17e-03,1.72e-02) | pointwise_rms(held): PDE=3.08e-03 BCv=4.35e-04 BCd=1.09e-03 IC=2.11e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=255] obj_s=5.620e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.927e-04 station=4.458e-03 alpha=1.11e+00 beta=5.18e-01 lam=1.00e+00 kkt_res=7.6e-02 s=1.00e+00 | constraints RMS/max: PDE=(2.29e-02,5.01e-01) BCv=(4.53e-04,9.26e-04) BCd=(1.04e-03,4.46e-03) IC=(2.08e-03,1.37e-02) | pointwise_rms(held): PDE=6.29e-03 BCv=4.97e-04 BCd=1.07e-03 IC=2.05e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=260] obj_s=5.596e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.885e-04 station=6.139e-03 alpha=1.10e+00 beta=5.14e-01 lam=1.00e+00 kkt_res=7.4e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.84e-02,2.98e-01) BCv=(4.20e-04,8.42e-04) BCd=(1.03e-03,4.25e-03) IC=(2.05e-03,1.23e-02) | pointwise_rms(held): PDE=3.89e-03 BCv=4.75e-04 BCd=1.02e-03 IC=1.97e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=265] obj_s=5.571e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.109e-03 station=3.823e-03 alpha=1.09e+00 beta=5.09e-01 lam=1.00e+00 kkt_res=7.3e-02 s=1.00e+00 | constraints RMS/max: PDE=(4.47e-02,1.00e+00) BCv=(4.68e-04,1.02e-03) BCd=(9.78e-04,4.21e-03) IC=(2.06e-03,1.13e-02) | pointwise_rms(held): PDE=4.85e-03 BCv=4.37e-04 BCd=1.01e-03 IC=1.95e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=270] obj_s=5.571e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=5.294e-04 station=4.335e-03 alpha=1.19e+00 beta=5.05e-01 lam=1.00e+00 kkt_res=7.2e-02 s=1.00e+00 | constraints RMS/max: PDE=(3.08e-02,5.64e-01) BCv=(4.33e-04,8.54e-04) BCd=(9.72e-04,4.15e-03) IC=(1.90e-03,1.15e-02) | pointwise_rms(held): PDE=5.95e-03 BCv=3.79e-04 BCd=9.77e-04 IC=1.92e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=275] obj_s=5.561e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.455e-04 station=3.554e-03 alpha=1.18e+00 beta=5.01e-01 lam=1.00e+00 kkt_res=7.0e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.61e-02,2.11e-01) BCv=(4.19e-04,8.95e-04) BCd=(9.50e-04,4.14e-03) IC=(1.89e-03,1.05e-02) | pointwise_rms(held): PDE=3.77e-03 BCv=3.88e-04 BCd=9.75e-04 IC=1.91e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=280] obj_s=5.554e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=3.026e-04 station=1.864e-03 alpha=1.17e+00 beta=4.96e-01 lam=1.00e+00 kkt_res=6.9e-02 s=1.00e+00 | constraints RMS/max: PDE=(2.33e-02,5.10e-01) BCv=(4.15e-04,8.45e-04) BCd=(9.14e-04,4.18e-03) IC=(1.90e-03,1.01e-02) | pointwise_rms(held): PDE=4.77e-03 BCv=4.02e-04 BCd=9.07e-04 IC=1.88e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=285] obj_s=5.534e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.956e-04 station=6.273e-03 alpha=1.06e+00 beta=4.92e-01 lam=1.00e+00 kkt_res=7.0e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.87e-02,2.98e-01) BCv=(4.63e-04,9.98e-04) BCd=(9.30e-04,4.18e-03) IC=(1.87e-03,9.97e-03) | pointwise_rms(held): PDE=3.00e-03 BCv=3.63e-04 BCd=9.07e-04 IC=1.93e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=290] obj_s=5.528e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=1.716e-04 station=3.100e-03 alpha=1.15e+00 beta=4.88e-01 lam=1.00e+00 kkt_res=6.9e-02 s=1.00e+00 | constraints RMS/max: PDE=(1.75e-02,3.18e-01) BCv=(3.96e-04,7.90e-04) BCd=(8.60e-04,3.74e-03) IC=(1.79e-03,9.61e-03) | pointwise_rms(held): PDE=4.17e-03 BCv=3.87e-04 BCd=8.63e-04 IC=1.94e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=295] obj_s=5.523e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.961e-03 station=7.622e-03 alpha=1.14e+00 beta=4.84e-01 lam=1.00e+00 kkt_res=6.9e-02 s=1.00e+00 | constraints RMS/max: PDE=(7.30e-02,1.76e+00) BCv=(3.87e-04,7.69e-04) BCd=(8.44e-04,3.59e-03) IC=(1.78e-03,1.01e-02) | pointwise_rms(held): PDE=1.09e-02 BCv=3.98e-04 BCd=8.73e-04 IC=1.85e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
# [iter=300] obj_s=5.523e-02 (obj_std=1.00e-06, obj_std_mean=1.00e-06, Sobj=1) feas=2.340e-03 station=6.288e-03 alpha=1.14e+00 beta=4.80e-01 lam=1.00e+00 kkt_res=6.6e-02 s=1.00e+00 | constraints RMS/max: PDE=(6.49e-02,1.51e+00) BCv=(4.08e-04,8.47e-04) BCd=(8.95e-04,3.44e-03) IC=(1.84e-03,9.69e-03) | pointwise_rms(held): PDE=9.91e-03 BCv=4.25e-04 BCd=8.01e-04 IC=1.76e-03 | mc_con=1 (std_max=0.00e+00, stdmean_max=0.00e+00) | hold_data_K=2000 hold_con_K=2000
