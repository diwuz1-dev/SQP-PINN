# %%
# ============================================================
# STOCHASTIC SQP-PINN (JAX) FOR NUCLEAR THERMAL COUPLING
# One NN outputs: [phi, Ts, u, v, p, Tf]
#
# NOTES:
#   - phi BC/IC match neutron MOOSE input exactly
#   - right fluid boundary uses MOOSE VALUE targets:
#         u=u_M, v=v_M, p=p_M, Tf=Tf_M
#   - old fluid case:
#         u(x,y,0)=1, v(x,y,0)=1e-12, Tf(x,y,0)=560
#         inlet: u=0, v=0.4, Tf=560
# ============================================================

import os
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "1")
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_FLAGS"] = "--xla_gpu_enable_command_buffer="

import time
import math
from functools import partial
import numpy as np

import jax
import jax.numpy as jnp
from jax import random, vmap, jacrev, hessian

# ============================================================
# Precision / dtype
# ============================================================
USE_X64 = True
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = DTYPE(1e-12)

# ============================================================
# USER SETTINGS / BENCHMARK
# ============================================================
Ls = DTYPE(0.0076)
Lf = DTYPE(0.0114)
Ly = DTYPE(0.75)
T_end = DTYPE(5.0)

x_min, x_max = DTYPE(0.0), DTYPE(Ls + Lf)
y_min, y_max = DTYPE(0.0), DTYPE(Ly)
t_min, t_max = DTYPE(0.0), DTYPE(T_end)

rho_f = DTYPE(11096.0)
rho_s = DTYPE(16020.0)

V_INLET_BC = DTYPE(0.4)
T_INLET = DTYPE(560.0)
P_OUTLET = DTYPE(0.0)
POWER_COEF = DTYPE(5e7)

# old fluid case
FLUID_U_IC = DTYPE(1.0)
FLUID_V_IC = DTYPE(1e-12)
FLUID_T_IC = DTYPE(560.0)

v_neu   = DTYPE(2.416)
D_fuel  = DTYPE(0.008249)
D_fluid = DTYPE(0.01)

# phi from neutron MOOSE file
PHI_TOPBOT_VAL = DTYPE(0.5)
PHI_RIGHT_VAL  = DTYPE(0.0)

MU_DAMP_FIXED = DTYPE(1e-4)

PHI_TXT_PATH = "./phi.txt"
TFLUID_PATH  = "/projects/549120ce-e7e0-45e0-a453-c9903649fea2/sqp/moose/output/nft_Tfluid.npy"

X_MARGIN = DTYPE(2e-5)

# ============================================================
# OUTPUT SCALES
# ============================================================
# IMPORTANT: phi can be much larger than 7 in the solution field
PHI_OUT_SCALE = DTYPE(15.0)
TS_OUT_SCALE  = DTYPE(350.0)
TF_OUT_SCALE  = DTYPE(250.0)
U_OUT_SCALE   = DTYPE(1.0)
V_OUT_SCALE   = DTYPE(0.5)
P_OUT_SCALE   = DTYPE(7.0)

PHI_VAL_SCALE = PHI_OUT_SCALE
TS_VAL_SCALE  = TS_OUT_SCALE
TF_VAL_SCALE  = TF_OUT_SCALE
U_VAL_SCALE   = U_OUT_SCALE
V_VAL_SCALE   = V_OUT_SCALE
P_VAL_SCALE   = P_OUT_SCALE
T_IF_VAL_SCALE = jnp.maximum(TS_VAL_SCALE, TF_VAL_SCALE)

# ============================================================
# SAMPLE COUNTS
# ============================================================
NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI = 20, 20, 10
NX_OBJ_S,   NY_OBJ_S,   NT_OBJ_S   = 20, 20, 10
NX_OBJ_F,   NY_OBJ_F,   NT_OBJ_F   = 20, 20, 10

NX_CON_PHI, NY_CON_PHI, NT_CON_PHI = 4, 4, 4
NX_CON_S,   NY_CON_S,   NT_CON_S   = 4, 4, 4
NX_CON_F,   NY_CON_F,   NT_CON_F   = 5, 5, 5

K_CON_PHI = NX_CON_PHI * NY_CON_PHI * NT_CON_PHI
K_CON_S   = NX_CON_S   * NY_CON_S   * NT_CON_S
K_CON_F   = NX_CON_F   * NY_CON_F   * NT_CON_F

N_PER_CELL = 1
N_BC_PER_BIN = 1
N_IC_PER_BIN = 1
N_IF_PER_BIN = 1

# separate BC counts
K_BC_PHI_LEFT   = 60
K_BC_PHI_RIGHT  = 30
K_BC_PHI_Y0     = 30
K_BC_PHI_Y1     = 30

K_BC_TS_X0      = 40

K_BC_F_INLET    = 40
K_BC_F_OUTLET   = 40
K_BC_F_RIGHT    = 0

NX_IC, NY_IC = 15, 20
K_IC = NX_IC * NY_IC

NY_IF, NT_IF = 10, 10
K_IF = NY_IF * NT_IF

# ============================================================
# BLOCK SIZES
# ============================================================
N_PDE_PHI = K_CON_PHI
N_PDE_TS  = K_CON_S
N_PDE_FLD = 4 * K_CON_F  # cont, ru, rv, rTf

N_BC_PHI = K_BC_PHI_LEFT + K_BC_PHI_RIGHT + K_BC_PHI_Y0 + K_BC_PHI_Y1
N_BC_SOL = K_BC_TS_X0
N_BC_FLD = 3 * K_BC_F_INLET + K_BC_F_OUTLET + 4 * K_BC_F_RIGHT
N_IF     = 2 * K_IF
N_IC     = 5 * K_IC

M_CON = N_PDE_PHI + N_PDE_TS + N_PDE_FLD + N_BC_PHI + N_BC_SOL + N_BC_FLD + N_IF + N_IC

# ============================================================
# LOAD phi.txt
# ============================================================
def load_phi_piecewise_multilinear(path: str):
    with open(path, "r") as f:
        lines = [ln.strip() for ln in f if ln.strip()]

    iy = lines.index("AXIS Y")
    it = lines.index("AXIS T")
    idata = lines.index("DATA")

    y_tokens = []
    k = iy + 1
    while k < len(lines) and lines[k] != "AXIS T":
        for tok in lines[k].split():
            try:
                float(tok)
                y_tokens.append(tok)
            except Exception:
                pass
        k += 1
    y = np.array([float(s) for s in y_tokens], dtype=np.float64)

    t_tokens = []
    k = it + 1
    while k < len(lines) and lines[k] != "DATA":
        for tok in lines[k].split():
            try:
                float(tok)
                t_tokens.append(tok)
            except Exception:
                pass
        k += 1
    t = np.array([float(s) for s in t_tokens], dtype=np.float64)

    Ny = len(y)
    Nt = len(t)

    data_tokens = []
    for ln in lines[idata + 1:]:
        for tok in ln.split():
            data_tokens.append(float(tok))
    data = np.array(data_tokens, dtype=np.float64)

    if data.size != Ny * Nt:
        raise ValueError(f"phi.txt DATA size mismatch: got {data.size}, expected {Ny * Nt}")

    Z_t_y = data.reshape(Nt, Ny)
    Z_y_t = Z_t_y.T
    return y, t, Z_y_t

y_np, t_np, Z_np = load_phi_piecewise_multilinear(PHI_TXT_PATH)
PHI_Y = jnp.array(y_np, dtype=DTYPE)
PHI_T = jnp.array(t_np, dtype=DTYPE)
PHI_Z = jnp.array(Z_np, dtype=DTYPE)

print("Loaded phi.txt:", y_np.shape, t_np.shape, Z_np.shape, "range=", float(Z_np.min()), float(Z_np.max()))

@jax.jit
def interp_yt(y, t, y_grid, t_grid, Z):
    y = jnp.asarray(y, dtype=DTYPE)
    t = jnp.asarray(t, dtype=DTYPE)

    Ny = y_grid.shape[0]
    Nt = t_grid.shape[0]

    iy = jnp.clip(jnp.searchsorted(y_grid, y, side="right") - 1, 0, Ny - 2)
    it = jnp.clip(jnp.searchsorted(t_grid, t, side="right") - 1, 0, Nt - 2)

    y0 = y_grid[iy]
    y1 = y_grid[iy + 1]
    t0 = t_grid[it]
    t1 = t_grid[it + 1]

    wy = (y - y0) / (y1 - y0 + EPS)
    wt = (t - t0) / (t1 - t0 + EPS)

    z00 = Z[iy, it]
    z10 = Z[iy + 1, it]
    z01 = Z[iy, it + 1]
    z11 = Z[iy + 1, it + 1]

    z0 = z00 + wy * (z10 - z00)
    z1 = z01 + wy * (z11 - z01)
    return z0 + wt * (z1 - z0)

def phi_left_target(y, t):
    t_clip = jnp.clip(t, PHI_T[0], PHI_T[-1])
    return interp_yt(y, t_clip, PHI_Y, PHI_T, PHI_Z)

# ============================================================
# LOAD MOOSE FLUID TRUTH
# ============================================================
SYNC_TIMES = np.array([
    0.0, 0.3125, 0.625, 0.9375, 1.25, 1.5625, 1.875, 2.1875,
    2.5, 2.8125, 3.125, 3.4375, 3.75, 4.0625, 4.375, 4.6875, 5.0
], dtype=np.float64)

def load_tfluid_truth(path: str, case_idx: int = 0):
    arr = np.load(path)

    # saved as (Ncase, 4, Nt, Nx_f, Ny)
    if arr.ndim == 5:
        arr = arr[case_idx]

    if arr.ndim != 4 or arr.shape[0] != 4:
        raise ValueError(f"Expected shape (4, Nt, Nx_f, Ny), got {arr.shape}")

    return arr

tfluid_np = load_tfluid_truth(TFLUID_PATH)
print("Loaded tfluid truth:", tfluid_np.shape)

# read order from exporter: [T_fluid, pressure, vel_x, vel_y]
Tf_true_np = tfluid_np[0]   # (Nt, Nx_f, Ny)
p_true_np  = tfluid_np[1]
u_true_np  = tfluid_np[2]
v_true_np  = tfluid_np[3]

Nt_true, Nx_f_true, Ny_true = u_true_np.shape
if Nt_true != len(SYNC_TIMES):
    raise ValueError(f"SYNC_TIMES length {len(SYNC_TIMES)} != Nt_true {Nt_true}")

Y_FLUID_np = np.linspace(0.0, float(Ly), Ny_true, dtype=np.float64)

# right boundary values: shape (Nt, Ny)
U_RIGHT_VAL_np  = u_true_np[:, -1, :]
V_RIGHT_VAL_np  = v_true_np[:, -1, :]
P_RIGHT_VAL_np  = p_true_np[:, -1, :]
TF_RIGHT_VAL_np = Tf_true_np[:, -1, :]

Y_FLUID = jnp.array(Y_FLUID_np, dtype=DTYPE)
T_SYNC  = jnp.array(SYNC_TIMES, dtype=DTYPE)

# store as (Ny, Nt) for interpolation
U_RIGHT_VAL  = jnp.array(U_RIGHT_VAL_np.T,  dtype=DTYPE)
V_RIGHT_VAL  = jnp.array(V_RIGHT_VAL_np.T,  dtype=DTYPE)
P_RIGHT_VAL  = jnp.array(P_RIGHT_VAL_np.T,  dtype=DTYPE)
TF_RIGHT_VAL = jnp.array(TF_RIGHT_VAL_np.T, dtype=DTYPE)

def u_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, U_RIGHT_VAL)

def v_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, V_RIGHT_VAL)

def p_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, P_RIGHT_VAL)

def Tf_right_target(y, t):
    return interp_yt(y, jnp.clip(t, T_SYNC[0], T_SYNC[-1]), Y_FLUID, T_SYNC, TF_RIGHT_VAL)

# ============================================================
# MATERIAL LAWS
# ============================================================
def safe_T(T):
    return jnp.clip(T, DTYPE(300.0), DTYPE(1200.0))

def mu_f_fun(T):
    T = safe_T(T)
    return DTYPE(4.94e-4) * jnp.exp(DTYPE(754.1) / (T + EPS))

def k_f_fun(T):
    T = safe_T(T)
    return DTYPE(3.61) + DTYPE(1.517e-2) * T - DTYPE(1.741e-6) * T * T

def cp_f_fun(T):
    T = safe_T(T)
    return DTYPE(159.0) - DTYPE(2.72e-2) * T + DTYPE(7.12e-6) * T * T

def cp_s_fun(T):
    T = safe_T(T)
    return (DTYPE(1.359) + DTYPE(0.05812) * T + DTYPE(1.086e6) / (T * T + EPS)) * DTYPE(5.0)

def k_s_fun(T):
    T = safe_T(T)
    c0 = DTYPE(17.5) * (DTYPE(1.0) - DTYPE(0.223)) / (DTYPE(1.0) + DTYPE(0.161))
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c0 + c1 * T + c2 * T * T

def sigma_af_fuel(T):
    T = safe_T(T)
    return (
        DTYPE(2.416) * DTYPE(583.5) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
        - (DTYPE(13.47) * (T - DTYPE(560.0)) / (DTYPE(900.0) - DTYPE(560.0)) + DTYPE(7.53))
        * DTYPE(2.1479) * DTYPE(1.602)
        + DTYPE(0.185) * DTYPE(6.6072) * DTYPE(0.1)
        - DTYPE(680.9) * DTYPE(1.305) * DTYPE(1.602) * DTYPE(0.1)
    )

def sigma_af_fluid(T):
    T = safe_T(T)
    return -(DTYPE(20.0) + DTYPE(20.0) * (T - DTYPE(560.0)) / (DTYPE(800.0) - DTYPE(560.0)))

def dk_s_dT(T):
    T = safe_T(T)
    c1 = DTYPE(1.54e-2) * (DTYPE(1.0) + DTYPE(0.0061)) / (DTYPE(1.0) + DTYPE(0.161))
    c2 = DTYPE(9.38e-6)
    return c1 + DTYPE(2.0) * c2 * T

def dk_f_dT(T):
    T = safe_T(T)
    a = DTYPE(1.517e-2)
    b = DTYPE(1.741e-6)
    return a - DTYPE(2.0) * b * T

def dmu_f_dT(T):
    T = safe_T(T)
    mu = mu_f_fun(T)
    return mu * (-DTYPE(754.1)) / (T * T + EPS)

def div_k_grad_scalar(k, dk_dT_fun, T, Tx, Ty, Txx, Tyy):
    return k * (Txx + Tyy) + dk_dT_fun(T) * (Tx * Tx + Ty * Ty)

def div_mu_grad_component(mu, dmu_dT_fun, Tf, Tfx, Tfy, ux, uy, uxx, uyy):
    return mu * (uxx + uyy) + dmu_dT_fun(Tf) * (Tfx * ux + Tfy * uy)

# ============================================================
# SCALES
# ============================================================
Lx       = (x_max - x_min) + EPS
Ly_len   = (y_max - y_min) + EPS
Lx_fluid = (x_max - Ls) + EPS
Lx_solid = (Ls - x_min) + EPS
Lmin     = jnp.minimum(Lx, Ly_len)

GRAD_TSX_SCALE = TS_VAL_SCALE / (Lx_solid + EPS)

D_MAX    = jnp.maximum(D_fuel, D_fluid)
SIG_REF  = jnp.maximum(jnp.abs(sigma_af_fuel(T_INLET)), jnp.abs(sigma_af_fluid(T_INLET)))
K_S_REF  = k_s_fun(T_INLET)
K_F_REF  = k_f_fun(T_INLET)
CP_S_REF = cp_s_fun(T_INLET)
CP_F_REF = cp_f_fun(T_INLET)
MU_REF   = mu_f_fun(T_INLET)

FLUX_SCALE = jnp.maximum(
    K_S_REF * TS_VAL_SCALE / (Lx_solid + EPS),
    K_F_REF * TF_VAL_SCALE / (Lx_fluid + EPS),
) + EPS

PHI_TIME_REF  = PHI_VAL_SCALE / (v_neu * (T_end + EPS))
PHI_DIFF_REF  = D_MAX * PHI_VAL_SCALE / (Lmin**2 + EPS)
PHI_REAC_REF  = SIG_REF * PHI_VAL_SCALE
PHI_RES_SCALE = PHI_TIME_REF + PHI_DIFF_REF + PHI_REAC_REF + EPS

TS_TIME_REF  = rho_s * CP_S_REF * TS_VAL_SCALE / (T_end + EPS)
TS_DIFF_REF  = K_S_REF * TS_VAL_SCALE / (Lx_solid**2 + EPS)
TS_SRC_REF   = POWER_COEF * PHI_VAL_SCALE
TS_RES_SCALE = TS_TIME_REF + TS_DIFF_REF + TS_SRC_REF + EPS

CONT_SCALE = jnp.maximum(
    U_VAL_SCALE / (Lx_fluid + EPS),
    V_VAL_SCALE / (Ly_len + EPS),
) + EPS

MOMX_TIME_REF  = rho_f * U_VAL_SCALE / (T_end + EPS)
MOMX_ADV_REF   = rho_f * (
    U_VAL_SCALE * U_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * U_VAL_SCALE / (Ly_len + EPS)
)
MOMX_P_REF     = P_VAL_SCALE / (Lx_fluid + EPS)
MOMX_VIS_REF   = MU_REF * (
    U_VAL_SCALE / (Lx_fluid**2 + EPS)
    + U_VAL_SCALE / (Ly_len**2 + EPS)
)
MOMX_RES_SCALE = MOMX_TIME_REF + MOMX_ADV_REF + MOMX_P_REF + MOMX_VIS_REF + EPS

MOMY_TIME_REF  = rho_f * V_VAL_SCALE / (T_end + EPS)
MOMY_ADV_REF   = rho_f * (
    U_VAL_SCALE * V_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * V_VAL_SCALE / (Ly_len + EPS)
)
MOMY_P_REF     = P_VAL_SCALE / (Ly_len + EPS)
MOMY_VIS_REF   = MU_REF * (
    V_VAL_SCALE / (Lx_fluid**2 + EPS)
    + V_VAL_SCALE / (Ly_len**2 + EPS)
)
MOMY_RES_SCALE = MOMY_TIME_REF + MOMY_ADV_REF + MOMY_P_REF + MOMY_VIS_REF + EPS

TF_TIME_REF  = rho_f * CP_F_REF * TF_VAL_SCALE / (T_end + EPS)
TF_ADV_REF   = rho_f * CP_F_REF * (
    U_VAL_SCALE * TF_VAL_SCALE / (Lx_fluid + EPS)
    + V_VAL_SCALE * TF_VAL_SCALE / (Ly_len + EPS)
)
TF_DIFF_REF  = K_F_REF * TF_VAL_SCALE * (
    1.0 / (Lx_fluid**2 + EPS)
    + 1.0 / (Ly_len**2 + EPS)
)
TF_RES_SCALE = TF_TIME_REF + TF_ADV_REF + TF_DIFF_REF + EPS

# ============================================================
# TARGETS / ICS
# ============================================================
@jax.jit
def phi_ic(y):
    # correct from MOOSE
    return DTYPE(2.0) * jnp.cos(DTYPE(3.14) * (y - DTYPE(0.375)) / DTYPE(0.75))

def inlet_v_profile(x):
    return DTYPE(0.4) * jnp.ones_like(x)

# ============================================================
# NETWORK
# ============================================================
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params

def normalize_xyt(X):
    x = X[:, 0:1]
    y = X[:, 1:2]
    t = X[:, 2:3]

    x_n = 2.0 * (x - x_min) / (x_max - x_min + EPS) - 1.0
    y_n = 2.0 * (y - y_min) / (y_max - y_min + EPS) - 1.0
    t_n = 2.0 * (t - t_min) / (t_max - t_min + EPS) - 1.0
    return jnp.concatenate([x_n, y_n, t_n], axis=1)

def mlp_apply(params, X):
    h = normalize_xyt(X)
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)

    phi_hat = h[:, 0:1]
    Ts_hat  = h[:, 1:2]
    u_hat   = h[:, 2:3]
    v_hat   = h[:, 3:4]
    p_hat   = h[:, 4:5]
    Tf_hat  = h[:, 5:6]

    phi = PHI_OUT_SCALE * phi_hat
    Ts  = T_INLET + TS_OUT_SCALE * Ts_hat
    u   = U_OUT_SCALE * u_hat
    v   = V_OUT_SCALE * v_hat
    p   = P_OUT_SCALE * p_hat
    Tf  = T_INLET + TF_OUT_SCALE * Tf_hat

    return jnp.concatenate([phi, Ts, u, v, p, Tf], axis=1)

def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)

def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape)
        idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape)
        idx += b_size
        params.append({"W": W, "b": b})
    return params

# ============================================================
# UTILITIES
# ============================================================
def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)

# ============================================================
# STRATIFIED SAMPLING
# ============================================================
def sample_stratified_3d(key, x0, x1, y0, y1, t0, t1, NX, NY, NT):
    dx = (DTYPE(x1) - DTYPE(x0)) / DTYPE(NX)
    dy = (DTYPE(y1) - DTYPE(y0)) / DTYPE(NY)
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(NT)

    it, iy, ix = jnp.meshgrid(jnp.arange(NT), jnp.arange(NY), jnp.arange(NX), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids = (it * (NY * NX) + iy * NX + ix).astype(jnp.int32)

    xb = DTYPE(x0) + DTYPE(ix) * dx
    yb = DTYPE(y0) + DTYPE(iy) * dy
    tb = DTYPE(t0) + DTYPE(it) * dt

    K = NX * NY * NT
    u = random.uniform(key, (K, 3), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = xb + u[:, 0] * dx
    ys = yb + u[:, 1] * dy
    ts = tb + u[:, 2] * dt
    X = jnp.stack([xs, ys, ts], axis=1)
    return X, ids

def sample_bc_time_binned(key, K, *, x_fixed=None, y_fixed=None, t0=t_min, t1=t_max,
                          x_lo=None, x_hi=None, y_lo=None, y_hi=None):
    dt = (DTYPE(t1) - DTYPE(t0)) / DTYPE(K)
    j = jnp.arange(K, dtype=jnp.int32)
    tb = DTYPE(t0) + DTYPE(j) * dt

    key, kt, kr = random.split(key, 3)
    u_t = random.uniform(kt, (K, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (tb[:, None] + u_t * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    if x_fixed is not None:
        lo = DTYPE(y_min if y_lo is None else y_lo)
        hi = DTYPE(y_max if y_hi is None else y_hi)
        y = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        x = DTYPE(x_fixed) * jnp.ones_like(y)
        return jnp.concatenate([x, y, ts], axis=1), ids

    if y_fixed is not None:
        lo = DTYPE(x_min if x_lo is None else x_lo)
        hi = DTYPE(x_max if x_hi is None else x_hi)
        x = random.uniform(kr, (ts.shape[0], 1), minval=lo, maxval=hi, dtype=DTYPE)
        y = DTYPE(y_fixed) * jnp.ones_like(x)
        return jnp.concatenate([x, y, ts], axis=1), ids

    raise ValueError("Provide x_fixed or y_fixed")

def sample_ic_xy(key):
    y0 = DTYPE(0.02)
    y1 = y_max - DTYPE(0.02)

    dx = (x_max - x_min) / DTYPE(NX_IC)
    dy = (y1 - y0) / DTYPE(NY_IC)

    iy, ix = jnp.meshgrid(jnp.arange(NY_IC), jnp.arange(NX_IC), indexing="ij")
    iy = iy.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids0 = (iy * NX_IC + ix).astype(jnp.int32)

    xb = x_min + DTYPE(ix) * dx
    yb = y0 + DTYPE(iy) * dy

    u = random.uniform(key, (K_IC, N_IC_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (xb[:, None] + u[:, :, 0] * dx).reshape(-1, 1)
    ys = (yb[:, None] + u[:, :, 1] * dy).reshape(-1, 1)
    ts = t_min * jnp.ones_like(xs)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IC_PER_BIN)
    return X, ids

def sample_interface_yt(key):
    dy = (y_max - y_min) / DTYPE(NY_IF)
    dt = (t_max - t_min) / DTYPE(NT_IF)

    it, iy = jnp.meshgrid(jnp.arange(NT_IF), jnp.arange(NY_IF), indexing="ij")
    it = it.reshape(-1).astype(jnp.int32)
    iy = iy.reshape(-1).astype(jnp.int32)
    ids0 = (it * NY_IF + iy).astype(jnp.int32)

    yb = y_min + DTYPE(iy) * dy
    tb = t_min + DTYPE(it) * dt

    u = random.uniform(key, (NY_IF * NT_IF, N_IF_PER_BIN, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    ys = (yb[:, None] + u[:, :, 0] * dy).reshape(-1, 1)
    ts = (tb[:, None] + u[:, :, 1] * dt).reshape(-1, 1)
    xs = Ls * jnp.ones_like(ys)

    X = jnp.concatenate([xs, ys, ts], axis=1)
    ids = jnp.repeat(ids0, N_IF_PER_BIN)
    return X, ids

# ============================================================
# JITTER + PROJECTIONS
# ============================================================
def jitter_xyt(key, X, sx, sy, st, clip_k=2.0):
    if X.shape[0] == 0 or ((sx <= 0) and (sy <= 0) and (st <= 0)):
        return X

    key, kx, ky, kt = random.split(key, 4)
    dx = DTYPE(sx) * random.normal(kx, (X.shape[0],), dtype=DTYPE)
    dy = DTYPE(sy) * random.normal(ky, (X.shape[0],), dtype=DTYPE)
    dt = DTYPE(st) * random.normal(kt, (X.shape[0],), dtype=DTYPE)

    k = DTYPE(clip_k)
    dx = jnp.clip(dx, -k * DTYPE(sx), k * DTYPE(sx))
    dy = jnp.clip(dy, -k * DTYPE(sy), k * DTYPE(sy))
    dt = jnp.clip(dt, -k * DTYPE(st), k * DTYPE(st))

    x = jnp.clip(X[:, 0] + dx, x_min, x_max)
    y = jnp.clip(X[:, 1] + dy, y_min, y_max)
    t = jnp.clip(X[:, 2] + dt, t_min, t_max)
    return jnp.stack([x, y, t], axis=1)

def project_x_fixed(X, x_fixed):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        DTYPE(x_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE),
        X[:, 1],
        X[:, 2],
    ], axis=1)

def project_y_fixed(X, y_fixed, *, x_lo=None, x_hi=None):
    if X.shape[0] == 0:
        return X
    x = X[:, 0]
    if (x_lo is not None) or (x_hi is not None):
        lo = DTYPE(x_lo if x_lo is not None else x_min)
        hi = DTYPE(x_hi if x_hi is not None else x_max)
        x = jnp.clip(x, lo, hi)
    y = DTYPE(y_fixed) * jnp.ones((X.shape[0],), dtype=DTYPE)
    return jnp.stack([x, y, X[:, 2]], axis=1)

def project_t0(X):
    if X.shape[0] == 0:
        return X
    return jnp.stack([
        X[:, 0],
        X[:, 1],
        t_min * jnp.ones((X.shape[0],), dtype=DTYPE),
    ], axis=1)

def project_interface(X):
    return project_x_fixed(X, Ls)

# ============================================================
# PDE RESIDUALS
# ============================================================
def forward6(params, xyt):
    return mlp_apply(params, xyt[None, :])[0, :]

def eval_fields_and_derivs(params, X):
    out = vmap(lambda z: forward6(params, z))(X)
    J   = vmap(jacrev(lambda z: forward6(params, z)))(X)
    H   = vmap(hessian(lambda z: forward6(params, z)))(X)
    return out, J, H

def residuals_all(params, X):
    out, J, H = eval_fields_and_derivs(params, X)

    phi = out[:, 0]
    Ts  = out[:, 1]
    u   = out[:, 2]
    v   = out[:, 3]
    p   = out[:, 4]
    Tf  = out[:, 5]

    x = X[:, 0]
    is_solid = (x <= Ls)

    phi_t  = J[:, 0, 2]
    phi_xx = H[:, 0, 0, 0]
    phi_yy = H[:, 0, 1, 1]
    lap_phi = phi_xx + phi_yy

    Ts_x  = J[:, 1, 0]
    Ts_y  = J[:, 1, 1]
    Ts_t  = J[:, 1, 2]
    Ts_xx = H[:, 1, 0, 0]
    Ts_yy = H[:, 1, 1, 1]

    u_x, u_y, u_t = J[:, 2, 0], J[:, 2, 1], J[:, 2, 2]
    v_x, v_y, v_t = J[:, 3, 0], J[:, 3, 1], J[:, 3, 2]
    p_x, p_y      = J[:, 4, 0], J[:, 4, 1]
    Tf_x, Tf_y, Tf_t = J[:, 5, 0], J[:, 5, 1], J[:, 5, 2]

    u_xx, u_yy   = H[:, 2, 0, 0], H[:, 2, 1, 1]
    v_xx, v_yy   = H[:, 3, 0, 0], H[:, 3, 1, 1]
    Tf_xx, Tf_yy = H[:, 5, 0, 0], H[:, 5, 1, 1]

    T_for_sigma = jnp.where(is_solid, Ts, Tf)
    D_here      = jnp.where(is_solid, D_fuel, D_fluid)
    sig_here    = jnp.where(is_solid, sigma_af_fuel(T_for_sigma), sigma_af_fluid(T_for_sigma))

    r_phi_raw = (DTYPE(1.0) / v_neu) * phi_t - D_here * lap_phi - sig_here * phi
    r_phi = r_phi_raw / PHI_RES_SCALE

    div_k_grad_Ts = div_k_grad_scalar(k_s_fun(Ts), dk_s_dT, Ts, Ts_x, Ts_y, Ts_xx, Ts_yy)
    r_Ts_raw = rho_s * cp_s_fun(Ts) * Ts_t - div_k_grad_Ts - POWER_COEF * phi
    r_Ts = r_Ts_raw / TS_RES_SCALE

    r_cont_raw = u_x + v_y
    r_cont = r_cont_raw / CONT_SCALE

    mu_here = mu_f_fun(Tf)
    visc_u = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, u_x, u_y, u_xx, u_yy)
    visc_v = div_mu_grad_component(mu_here, dmu_f_dT, Tf, Tf_x, Tf_y, v_x, v_y, v_xx, v_yy)

    r_u_raw = rho_f * (u_t + u * u_x + v * u_y) + p_x - visc_u
    r_v_raw = rho_f * (v_t + u * v_x + v * v_y) + p_y - visc_v

    cp_here = cp_f_fun(Tf)
    div_k_grad_Tf = div_k_grad_scalar(k_f_fun(Tf), dk_f_dT, Tf, Tf_x, Tf_y, Tf_xx, Tf_yy)
    r_Tf_raw = rho_f * cp_here * (Tf_t + u * Tf_x + v * Tf_y) - div_k_grad_Tf

    r_u  = r_u_raw / MOMX_RES_SCALE
    r_v  = r_v_raw / MOMY_RES_SCALE
    r_Tf = r_Tf_raw / TF_RES_SCALE

    return r_phi, r_Ts, r_cont, r_u, r_v, r_Tf

# ============================================================
# OBJECTIVE
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_obj(theta, shapes, X_obj_phi, X_obj_s, X_obj_f,
                w_obj_phi, w_obj_Ts, w_obj_cont, w_obj_ru, w_obj_rv, w_obj_rTf):
    def obj_theta(th):
        params = unflatten_params(th, shapes)

        r_phi_obj, _, _, _, _, _ = residuals_all(params, X_obj_phi)
        _, r_Ts_obj, _, _, _, _  = residuals_all(params, X_obj_s)
        _, _, r_cont_obj, r_u_obj, r_v_obj, r_Tf_obj = residuals_all(params, X_obj_f)

        return (
            w_obj_phi  * jnp.mean(r_phi_obj ** 2)
            + w_obj_Ts * jnp.mean(r_Ts_obj ** 2)
            + w_obj_cont * jnp.mean(r_cont_obj ** 2)
            + w_obj_ru   * jnp.mean(r_u_obj ** 2)
            + w_obj_rv   * jnp.mean(r_v_obj ** 2)
            + w_obj_rTf  * jnp.mean(r_Tf_obj ** 2)
        )

    val, g = jax.value_and_grad(obj_theta)(theta)
    return val, g

# ============================================================
# CONSTRAINT VECTOR
# ============================================================
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector(theta, shapes,
                      X_con_phi, ids_con_phi,
                      X_con_s, ids_con_s,
                      X_con_f, ids_con_f,
                      X_phi_left, ids_phi_left,
                      X_phi_right, ids_phi_right,
                      X_phi_y0, ids_phi_y0,
                      X_phi_y1, ids_phi_y1,
                      X_Ts_x0, ids_Ts_x0,
                      X_f_inlet, ids_f_inlet,
                      X_f_outlet, ids_f_outlet,
                      X_f_right, ids_f_right,
                      X_if, ids_if,
                      X_ic, ids_ic):
    params = unflatten_params(theta, shapes)

    # PDE hard constraints
    r_phi, _, _, _, _, _ = residuals_all(params, X_con_phi)
    _, r_Ts, _, _, _, _  = residuals_all(params, X_con_s)
    _, _, r_cont, r_u, r_v, r_Tf = residuals_all(params, X_con_f)

    c_pde_phi  = segment_sum(r_phi,  ids_con_phi, K_CON_PHI) / DTYPE(N_PER_CELL)
    c_pde_Ts   = segment_sum(r_Ts,   ids_con_s,   K_CON_S)   / DTYPE(N_PER_CELL)
    c_pde_cont = segment_sum(r_cont, ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_ru   = segment_sum(r_u,    ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_rv   = segment_sum(r_v,    ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)
    c_pde_rTf  = segment_sum(r_Tf,   ids_con_f,   K_CON_F)   / DTYPE(N_PER_CELL)

    # phi BCs
    phiL = mlp_apply(params, X_phi_left)[:, 0]
    yL, tL = X_phi_left[:, 1], X_phi_left[:, 2]
    c_phi_left = segment_sum((phiL - phi_left_target(yL, tL)) / PHI_VAL_SCALE, ids_phi_left, K_BC_PHI_LEFT) / DTYPE(N_BC_PER_BIN)

    phiR = mlp_apply(params, X_phi_right)[:, 0]
    c_phi_right = segment_sum((phiR - PHI_RIGHT_VAL) / PHI_VAL_SCALE, ids_phi_right, K_BC_PHI_RIGHT) / DTYPE(N_BC_PER_BIN)

    phiB = mlp_apply(params, X_phi_y0)[:, 0]
    c_phi_y0 = segment_sum((phiB - PHI_TOPBOT_VAL) / PHI_VAL_SCALE, ids_phi_y0, K_BC_PHI_Y0) / DTYPE(N_BC_PER_BIN)

    phiT = mlp_apply(params, X_phi_y1)[:, 0]
    c_phi_y1 = segment_sum((phiT - PHI_TOPBOT_VAL) / PHI_VAL_SCALE, ids_phi_y1, K_BC_PHI_Y1) / DTYPE(N_BC_PER_BIN)

    c_bc_phi = jnp.concatenate([c_phi_left, c_phi_right, c_phi_y0, c_phi_y1], axis=0)

    # solid BC
    def Ts_fun(z):
        return forward6(params, z)[1]

    Tsx_x0 = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_Ts_x0)
    c_bc_sol = segment_sum(Tsx_x0 / GRAD_TSX_SCALE, ids_Ts_x0, K_BC_TS_X0) / DTYPE(N_BC_PER_BIN)

    # fluid BCs
    out_in = mlp_apply(params, X_f_inlet)
    u_in, v_in, Tf_in = out_in[:, 2], out_in[:, 3], out_in[:, 5]
    x_in = X_f_inlet[:, 0]
    v_tar = inlet_v_profile(x_in)

    c_in_u  = segment_sum((u_in - DTYPE(0.0)) / U_VAL_SCALE, ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)
    c_in_v  = segment_sum((v_in - v_tar) / V_VAL_SCALE,      ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)
    c_in_Tf = segment_sum((Tf_in - T_INLET) / TF_VAL_SCALE,  ids_f_inlet, K_BC_F_INLET) / DTYPE(N_BC_PER_BIN)

    p_out = mlp_apply(params, X_f_outlet)[:, 4]
    c_out_p = segment_sum((p_out - P_OUTLET) / P_VAL_SCALE, ids_f_outlet, K_BC_F_OUTLET) / DTYPE(N_BC_PER_BIN)

    out_right = mlp_apply(params, X_f_right)
    u_right  = out_right[:, 2]
    v_right  = out_right[:, 3]
    p_right  = out_right[:, 4]
    Tf_right = out_right[:, 5]

    y_r = X_f_right[:, 1]
    t_r = X_f_right[:, 2]

    u_tar_right  = u_right_target(y_r, t_r)
    v_tar_right  = v_right_target(y_r, t_r)
    p_tar_right  = p_right_target(y_r, t_r)
    Tf_tar_right = Tf_right_target(y_r, t_r)

    c_r_u  = segment_sum((u_right  - u_tar_right)  / U_VAL_SCALE,  ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)
    c_r_v  = segment_sum((v_right  - v_tar_right)  / V_VAL_SCALE,  ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)
    c_r_p  = segment_sum((p_right  - p_tar_right)  / P_VAL_SCALE,  ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)
    c_r_Tf = segment_sum((Tf_right - Tf_tar_right) / TF_VAL_SCALE, ids_f_right, K_BC_F_RIGHT) / DTYPE(N_BC_PER_BIN)

    c_bc_fld = jnp.concatenate([
        c_in_u, c_in_v, c_in_Tf,
        c_out_p,
        c_r_u, c_r_v, c_r_p, c_r_Tf
    ], axis=0)

    # interface
    out_if = mlp_apply(params, X_if)
    Ts_if, Tf_if = out_if[:, 1], out_if[:, 5]

    c_if_T = segment_sum((Ts_if - Tf_if) / T_IF_VAL_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    Tsx_if = vmap(lambda z: jacrev(Ts_fun)(z)[0])(X_if)

    def Tf_fun(z):
        return forward6(params, z)[5]

    Tfx_if = vmap(lambda z: jacrev(Tf_fun)(z)[0])(X_if)

    flux_jump = -k_s_fun(Ts_if) * Tsx_if + k_f_fun(Tf_if) * Tfx_if
    c_if_q = segment_sum(flux_jump / FLUX_SCALE, ids_if, K_IF) / DTYPE(N_IF_PER_BIN)

    c_if = jnp.concatenate([c_if_T, c_if_q], axis=0)

    # IC
    out0 = mlp_apply(params, X_ic)
    phi0 = out0[:, 0]
    Ts0  = out0[:, 1]
    u0   = out0[:, 2]
    v0   = out0[:, 3]
    Tf0  = out0[:, 5]

    x0 = X_ic[:, 0]
    y0 = X_ic[:, 1]

    m_s0 = (x0 <= Ls).astype(DTYPE)
    m_f0 = (x0 >  Ls).astype(DTYPE)

    c_ic_phi = segment_sum((phi0 - phi_ic(y0)) / PHI_VAL_SCALE, ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Ts  = segment_sum(m_s0 * ((Ts0 - T_INLET) / TS_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_u   = segment_sum(m_f0 * ((u0 - FLUID_U_IC) / U_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_v   = segment_sum(m_f0 * ((v0 - FLUID_V_IC) / V_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)
    c_ic_Tf  = segment_sum(m_f0 * ((Tf0 - FLUID_T_IC) / TF_VAL_SCALE), ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)

    c_ic = jnp.concatenate([c_ic_phi, c_ic_Ts, c_ic_u, c_ic_v, c_ic_Tf], axis=0)

    return jnp.concatenate([
        c_pde_phi,
        c_pde_Ts,
        c_pde_cont, c_pde_ru, c_pde_rv, c_pde_rTf,
        c_bc_phi,
        c_bc_sol,
        c_bc_fld,
        c_if,
        c_ic
    ], axis=0)

@partial(jax.jit, static_argnames=("shapes",))
def C_and_J(theta, shapes, *args):
    def c_fun(th):
        return constraint_vector(th, shapes, *args)

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J, c = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c, J

@partial(jax.jit, static_argnames=("shapes",))
def C_only(theta, shapes, *args):
    return constraint_vector(theta, shapes, *args)

# ============================================================
# KKT solve
# ============================================================
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, mu_damp):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)
    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -mu_damp * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)
    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y

# ============================================================
# STEP HELPERS
# ============================================================
def cal_tau_mu(H, d, sigma, tau_pre, eps_tau, g, c, mu_eff, y):
    denom = float(g @ d + 0.5 * (d @ (H @ d)))
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    if (denom <= 1e-12) or (delta_c <= 0.0):
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * delta_c / denom
    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)

def cal_ksi_mu(d, tau, ksi_old, eps_ksi, g, c, mu_eff, y):
    d2 = float(jnp.linalg.norm(d) ** 2)
    if d2 <= 1e-18 or tau <= 1e-18:
        return ksi_old
    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    ksi_trial = Dl / (tau * d2)
    ksi_trial = max(0.0, ksi_trial)
    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)

def phi_mu(alpha, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma):
    gd = float(g @ d)
    d2 = float(d @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(mu_eff * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    term1 = (eta - 1.0) * alpha * beta * Dl
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * c1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3

def cal_alpha_mu(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c, mu_eff, y):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0
    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)
    while (
        phi_mu(1.1 * a, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma) < 0.0
        and (1.1 * a < alpha_min + theta_val * beta)
    ):
        a *= 1.1
    return float(a)

# ============================================================
# BLOCK SLICES / ROW SCALING
# ============================================================
def _block_slices():
    s = {}
    i = 0

    s["pde_phi"]  = slice(i, i + K_CON_PHI); i += K_CON_PHI
    s["pde_Ts"]   = slice(i, i + K_CON_S);   i += K_CON_S
    s["pde_cont"] = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_ru"]   = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_rv"]   = slice(i, i + K_CON_F);   i += K_CON_F
    s["pde_rTf"]  = slice(i, i + K_CON_F);   i += K_CON_F

    s["bc_phi"]   = slice(i, i + N_BC_PHI); i += N_BC_PHI
    s["bc_solid"] = slice(i, i + N_BC_SOL); i += N_BC_SOL
    s["bc_fluid"] = slice(i, i + N_BC_FLD); i += N_BC_FLD

    s["iface"]    = slice(i, i + N_IF); i += N_IF
    s["ic"]       = slice(i, i + N_IC); i += N_IC

    assert i == M_CON, (i, M_CON)
    return s

BLOCKS = _block_slices()

S_TARGET_PDE = DTYPE(1.0)
S_TARGET_BC  = DTYPE(1.0)
S_TARGET_IF  = DTYPE(1.0)
S_TARGET_IC  = DTYPE(1.0)
S_ROW_MIN    = DTYPE(1e-6)
S_ROW_MAX    = DTYPE(1.0)

@jax.jit
def row_rms(J_rows):
    return jnp.sqrt(jnp.mean(J_rows * J_rows, axis=1) + EPS)

@jax.jit
def make_block_row_scales(J, target_pde, target_bc, target_if, target_ic):
    s = jnp.ones((M_CON,), dtype=DTYPE)

    def set_block(name, target):
        sl = BLOCKS[name]
        rr = row_rms(J[sl, :])
        sb = target / jnp.maximum(target, rr)
        sb = jnp.clip(sb, S_ROW_MIN, S_ROW_MAX)
        return rr, sb

    rr_phi, sb_phi   = set_block("pde_phi", target_pde)
    rr_Ts, sb_Ts     = set_block("pde_Ts", target_pde)
    rr_cont, sb_cont = set_block("pde_cont", target_pde)
    rr_ru, sb_ru     = set_block("pde_ru", target_pde)
    rr_rv, sb_rv     = set_block("pde_rv", target_pde)
    rr_rTf, sb_rTf   = set_block("pde_rTf", target_pde)

    s = s.at[BLOCKS["pde_phi"]].set(sb_phi)
    s = s.at[BLOCKS["pde_Ts"]].set(sb_Ts)
    s = s.at[BLOCKS["pde_cont"]].set(sb_cont)
    s = s.at[BLOCKS["pde_ru"]].set(sb_ru)
    s = s.at[BLOCKS["pde_rv"]].set(sb_rv)
    s = s.at[BLOCKS["pde_rTf"]].set(sb_rTf)

    rr_bcphi, sb_bcphi = set_block("bc_phi", target_bc)
    rr_bcsol, sb_bcsol = set_block("bc_solid", target_bc)
    rr_bcfld, sb_bcfld = set_block("bc_fluid", target_bc)

    s = s.at[BLOCKS["bc_phi"]].set(sb_bcphi)
    s = s.at[BLOCKS["bc_solid"]].set(sb_bcsol)
    s = s.at[BLOCKS["bc_fluid"]].set(sb_bcfld)

    rr_if, sb_if = set_block("iface", target_if)
    rr_ic, sb_ic = set_block("ic", target_ic)

    s = s.at[BLOCKS["iface"]].set(sb_if)
    s = s.at[BLOCKS["ic"]].set(sb_ic)

    return s

@jax.jit
def apply_row_scale(c, J, s_row):
    return s_row * c, s_row[:, None] * J

def _rms(x):
    return float(jnp.sqrt(jnp.mean(x * x) + 1e-30))

def _maxabs(x):
    return float(jnp.max(jnp.abs(x)))

def print_block_stats(prefix, c):
    def pr(name):
        sl = BLOCKS[name]
        v = c[sl]
        print(f"  {name:10s}: rms={_rms(v):.3e}  max={_maxabs(v):.3e}")
    print(prefix)
    pr("pde_phi")
    pr("pde_Ts")
    pr("pde_cont")
    pr("pde_ru")
    pr("pde_rv")
    pr("pde_rTf")
    pr("bc_phi")
    pr("bc_solid")
    pr("bc_fluid")
    pr("iface")
    pr("ic")

# ============================================================
# TRAIN SQP
# ============================================================
def train_sqp(
    seed=0,
    hidden_dim=30,
    num_hidden=3,
    max_iters=1000,
    print_every=10,
    beta_shift=400.0,
    beta_power=0.6,
    alpha_cap=1e1,
    L_lip=60.0,
    Gamma_lip=60.0,
    jitter_every_iter=True,
    sx=1e-4,
    sy=1e-4,
    st=1e-4,
    sx_ic=1e-4,
    sy_ic=1e-4,
    sy_if=1e-4,
    st_if=1e-4,
    w_obj_phi=20.0,
    w_obj_Ts=10.0,
    w_obj_cont=20.0,
    w_obj_ru=40.0,
    w_obj_rv=40.0,
    w_obj_rTf=10.0,
):
    key = random.PRNGKey(seed)

    layer_sizes = [3] + [hidden_dim] * num_hidden + [6]
    key, k0 = random.split(key)
    params0 = init_mlp_params(k0, layer_sizes)
    theta, shapes = flatten_params(params0)

    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    # objective sets
    key, k_obj_phi, k_obj_s, k_obj_f = random.split(key, 4)
    X_obj_phi, _ = sample_stratified_3d(k_obj_phi, x_min, x_max, y_min, y_max, t_min, t_max, NX_OBJ_PHI, NY_OBJ_PHI, NT_OBJ_PHI)
    X_obj_s, _   = sample_stratified_3d(k_obj_s, x_min, Ls, y_min, y_max, t_min, t_max, NX_OBJ_S, NY_OBJ_S, NT_OBJ_S)
    X_obj_f, _   = sample_stratified_3d(k_obj_f, Ls, x_max, y_min, y_max, t_min, t_max, NX_OBJ_F, NY_OBJ_F, NT_OBJ_F)

    # constraint sets
    key, k_con_phi, k_con_s, k_con_f = random.split(key, 4)
    X_con_phi, ids_con_phi = sample_stratified_3d(k_con_phi, x_min, x_max, y_min, y_max, t_min, t_max, NX_CON_PHI, NY_CON_PHI, NT_CON_PHI)
    X_con_s, ids_con_s     = sample_stratified_3d(k_con_s,   x_min, Ls,    y_min, y_max, t_min, t_max, NX_CON_S,   NY_CON_S,   NT_CON_S)
    X_con_f, ids_con_f     = sample_stratified_3d(k_con_f,   Ls,    x_max, y_min, y_max, t_min, t_max, NX_CON_F,   NY_CON_F,   NT_CON_F)

    key, k1, k2, k3, k4, k5, k6, k7, k8, k9, k_ic = random.split(key, 11)

    X_phi_left,  ids_phi_left  = sample_bc_time_binned(k1, K_BC_PHI_LEFT,  x_fixed=x_min, y_lo=y_min, y_hi=y_max)
    X_phi_right, ids_phi_right = sample_bc_time_binned(k2, K_BC_PHI_RIGHT, x_fixed=x_max, y_lo=y_min, y_hi=y_max)
    X_phi_y0,    ids_phi_y0    = sample_bc_time_binned(k3, K_BC_PHI_Y0,    y_fixed=y_min, x_lo=x_min, x_hi=x_max)
    X_phi_y1,    ids_phi_y1    = sample_bc_time_binned(k4, K_BC_PHI_Y1,    y_fixed=y_max, x_lo=x_min, x_hi=x_max)

    X_Ts_x0, ids_Ts_x0 = sample_bc_time_binned(k5, K_BC_TS_X0, x_fixed=x_min, y_lo=y_min, y_hi=y_max)

    xL = float(Ls + X_MARGIN)
    xR = float(x_max - X_MARGIN)

    X_f_inlet,  ids_f_inlet  = sample_bc_time_binned(k6, K_BC_F_INLET,  y_fixed=y_min, x_lo=xL, x_hi=xR)
    X_f_outlet, ids_f_outlet = sample_bc_time_binned(k7, K_BC_F_OUTLET, y_fixed=y_max, x_lo=xL, x_hi=xR)
    X_f_right,  ids_f_right  = sample_bc_time_binned(k8, K_BC_F_RIGHT,  x_fixed=x_max, y_lo=y_min, y_hi=y_max)

    X_if, ids_if = sample_interface_yt(k9)
    X_ic, ids_ic = sample_ic_xy(k_ic)

    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 1.0, 1.0

    print("M_CON =", int(M_CON), "n_params =", int(n))

    s_row_anchor = None
    t0_clock = time.time()

    for it in range(1, max_iters + 1):
        k_beta = (it // 10) * 10
        beta_k = float(min(1.0, (beta_shift / (beta_shift + k_beta)) ** beta_power))

        if jitter_every_iter:
            key, *ks = random.split(key, 16)
            (kj_obj_phi, kj_obj_s, kj_obj_f,
             kj_con_phi, kj_con_s, kj_con_f,
             kjL, kjR, kjB, kjT,
             kjSx, kjIn, kjOut, kjRight, kjIf) = ks[:15]
            key, kjIc = random.split(key)

            X_obj_phi_use = jitter_xyt(kj_obj_phi, X_obj_phi, sx, sy, st)
            X_obj_s_use   = jitter_xyt(kj_obj_s,   X_obj_s,   sx, sy, st)
            X_obj_f_use   = jitter_xyt(kj_obj_f,   X_obj_f,   sx, sy, st)

            X_con_phi_use = jitter_xyt(kj_con_phi, X_con_phi, sx, sy, st)
            X_con_s_use   = jitter_xyt(kj_con_s,   X_con_s,   sx, sy, st)
            X_con_f_use   = jitter_xyt(kj_con_f,   X_con_f,   sx, sy, st)

            X_phi_left_use  = project_x_fixed(jitter_xyt(kjL, X_phi_left,  0.0, sy, st), x_min)
            X_phi_right_use = project_x_fixed(jitter_xyt(kjR, X_phi_right, 0.0, sy, st), x_max)
            X_phi_y0_use    = project_y_fixed(jitter_xyt(kjB, X_phi_y0, sx, 0.0, st), y_min)
            X_phi_y1_use    = project_y_fixed(jitter_xyt(kjT, X_phi_y1, sx, 0.0, st), y_max)

            X_Ts_x0_use = project_x_fixed(jitter_xyt(kjSx, X_Ts_x0, 0.0, sy, st), x_min)

            X_f_inlet_use  = project_y_fixed(jitter_xyt(kjIn,    X_f_inlet,  sx, 0.0, st), y_min, x_lo=xL, x_hi=xR)
            X_f_outlet_use = project_y_fixed(jitter_xyt(kjOut,   X_f_outlet, sx, 0.0, st), y_max, x_lo=xL, x_hi=xR)
            X_f_right_use  = project_x_fixed(jitter_xyt(kjRight, X_f_right,  0.0, sy, st), x_max)

            X_if_use = project_interface(jitter_xyt(kjIf, X_if, 0.0, sy_if, st_if))
            X_ic_use = project_t0(jitter_xyt(kjIc, X_ic, sx_ic, sy_ic, 0.0))
        else:
            X_obj_phi_use = X_obj_phi
            X_obj_s_use   = X_obj_s
            X_obj_f_use   = X_obj_f
            X_con_phi_use = X_con_phi
            X_con_s_use   = X_con_s
            X_con_f_use   = X_con_f
            X_phi_left_use, X_phi_right_use, X_phi_y0_use, X_phi_y1_use = X_phi_left, X_phi_right, X_phi_y0, X_phi_y1
            X_Ts_x0_use = X_Ts_x0
            X_f_inlet_use, X_f_outlet_use, X_f_right_use = X_f_inlet, X_f_outlet, X_f_right
            X_if_use, X_ic_use = X_if, X_ic

        obj_val, g = F_and_g_obj(
            theta, shapes,
            X_obj_phi_use, X_obj_s_use, X_obj_f_use,
            DTYPE(w_obj_phi), DTYPE(w_obj_Ts), DTYPE(w_obj_cont),
            DTYPE(w_obj_ru), DTYPE(w_obj_rv), DTYPE(w_obj_rTf)
        )

        args = (
            X_con_phi_use, ids_con_phi,
            X_con_s_use, ids_con_s,
            X_con_f_use, ids_con_f,
            X_phi_left_use, ids_phi_left,
            X_phi_right_use, ids_phi_right,
            X_phi_y0_use, ids_phi_y0,
            X_phi_y1_use, ids_phi_y1,
            X_Ts_x0_use, ids_Ts_x0,
            X_f_inlet_use, ids_f_inlet,
            X_f_outlet_use, ids_f_outlet,
            X_f_right_use, ids_f_right,
            X_if_use, ids_if,
            X_ic_use, ids_ic,
        )

        c, J = C_and_J(theta, shapes, *args)

        if s_row_anchor is None:
            s_row_anchor = make_block_row_scales(J, S_TARGET_PDE, S_TARGET_BC, S_TARGET_IF, S_TARGET_IC)

        c_s, J_s = apply_row_scale(c, J, s_row_anchor)

        d, y_s = kkt_solve_once(H, J_s, g, c_s, MU_DAMP_FIXED)
        y = s_row_anchor * y_s

        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-12:
            tau_k = cal_tau_mu(H, d, sigma, tau_k, eps_tau, g, c_s, MU_DAMP_FIXED, y_s)
            ksi_k = cal_ksi_mu(d, tau_k, ksi_k, eps_ksi, g, c_s, MU_DAMP_FIXED, y_s)
            alpha = cal_alpha_mu(d, eta, beta_k, ksi_k, tau_k, L_lip, Gamma_lip, theta_val, g, c_s, MU_DAMP_FIXED, y_s)
        else:
            alpha = 0.0

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d

        if it % int(print_every) == 0:
            c_now = C_only(theta, shapes, *args)
            feas_raw = float(jnp.mean(c_now ** 2))
            station  = float(jnp.linalg.norm(g + J.T @ y, jnp.inf))

            print(f"[it={it}] obj={float(obj_val):.3e} feas_raw={feas_raw:.3e} alpha={alpha:.2e} beta={beta_k:.2e} station={station:.2e} dn={dn:.2e}")
            print_block_stats("blocks (unscaled c):", c_now)

            params_now = unflatten_params(theta, shapes)
            r_phi_obj, _, _, _, _, _ = residuals_all(params_now, X_obj_phi_use)
            _, r_Ts_obj, _, _, _, _  = residuals_all(params_now, X_obj_s_use)
            _, _, r_cont_obj, r_u_obj, r_v_obj, r_Tf_obj = residuals_all(params_now, X_obj_f_use)
            print(
                "Scaled PDE RMS on obj:",
                "phi", _rms(r_phi_obj),
                "Ts", _rms(r_Ts_obj),
                "cont", _rms(r_cont_obj),
                "ru", _rms(r_u_obj),
                "rv", _rms(r_v_obj),
                "rTf", _rms(r_Tf_obj),
            )

    print(f"[done] elapsed={time.time() - t0_clock:.2f}s")
    return theta

# ============================================================
# MAIN
# ============================================================
def main():
    theta = train_sqp(
        seed=0,
        hidden_dim=35,
        num_hidden=3,
        max_iters=20000,
        print_every=10,
        beta_shift=200.0,
        beta_power=0.6,
        alpha_cap=1e1,
        L_lip=40.0,
        Gamma_lip=40.0,
        jitter_every_iter=True,
        sx=1e-5,
        sy=1e-5,
        st=1e-5,
        sx_ic=1e-5,
        sy_ic=1e-5,
        sy_if=1e-5,
        st_if=1e-5,
        w_obj_phi=5.0,
        w_obj_Ts=5.0,
        w_obj_cont=20.0,
        w_obj_ru=60.0,
        w_obj_rv=60.0,
        w_obj_rTf=5.0,
    )

    np.save("theta_sqp_pinn_clean.npy", np.array(theta))
    print("Saved theta -> theta_sqp_pinn_clean.npy")

if __name__ == "__main__":
    main()
# Out:
# Loaded phi.txt: (65,) (16,) (65, 16) range= 0.5 6.2
# Loaded tfluid truth: (4, 17, 12, 64)
# M_CON = 2678 n_params = 2876
# [it=10] obj=5.048e+01 feas_raw=6.785e-01 alpha=4.16e-03 beta=9.71e-01 station=1.70e+01 dn=1.70e+01
# blocks (unscaled c):
#   pde_phi   : rms=1.475e+00  max=4.265e+00
#   pde_Ts    : rms=3.597e-01  max=9.623e-01
#   pde_cont  : rms=5.715e-01  max=1.336e+00
#   pde_ru    : rms=5.310e-01  max=1.674e+00
#   pde_rv    : rms=4.753e-01  max=1.653e+00
#   pde_rTf   : rms=3.374e-01  max=9.391e-01
#   bc_phi    : rms=8.170e-01  max=1.883e+00
#   bc_solid  : rms=2.029e-01  max=3.764e-01
#   bc_fluid  : rms=1.015e+00  max=2.388e+00
#   iface     : rms=7.666e-01  max=1.439e+00
#   ic        : rms=8.820e-01  max=2.716e+00
# Scaled PDE RMS on obj: phi 1.4381722157252064 Ts 0.3560635440717489 cont 0.5810499641812321 ru 0.5383208782659771 rv 0.48664653463342633 rTf 0.3311931291573071
# [it=20] obj=4.469e+01 feas_raw=5.782e-01 alpha=1.69e-02 beta=9.44e-01 station=5.60e+00 dn=5.60e+00
# blocks (unscaled c):
#   pde_phi   : rms=1.334e+00  max=3.870e+00
#   pde_Ts    : rms=3.326e-01  max=8.810e-01
#   pde_cont  : rms=5.495e-01  max=1.249e+00
#   pde_ru    : rms=5.107e-01  max=1.629e+00
#   pde_rv    : rms=4.239e-01  max=1.462e+00
#   pde_rTf   : rms=3.174e-01  max=8.866e-01
#   bc_phi    : rms=7.476e-01  max=1.716e+00
#   bc_solid  : rms=1.863e-01  max=3.485e-01
#   bc_fluid  : rms=9.076e-01  max=2.150e+00
#   iface     : rms=7.011e-01  max=1.336e+00
#   ic        : rms=8.193e-01  max=2.518e+00
# Scaled PDE RMS on obj: phi 1.3145025908672048 Ts 0.32912173750018936 cont 0.5696443619375783 ru 0.5285480335895314 rv 0.43051301675599496 rTf 0.310399428434617
# [it=30] obj=1.996e+01 feas_raw=9.196e-02 alpha=2.87e-01 beta=9.20e-01 station=6.72e-01 dn=6.72e-01
# blocks (unscaled c):
#   pde_phi   : rms=4.310e-01  max=1.164e+00
#   pde_Ts    : rms=1.158e-01  max=2.977e-01
#   pde_cont  : rms=2.401e-01  max=6.293e-01
#   pde_ru    : rms=2.344e-01  max=7.553e-01
#   pde_rv    : rms=2.803e-01  max=7.585e-01
#   pde_rTf   : rms=1.174e-01  max=3.724e-01
#   bc_phi    : rms=2.520e-01  max=5.773e-01
#   bc_solid  : rms=5.367e-02  max=1.334e-01
#   bc_fluid  : rms=4.341e-01  max=8.358e-01
#   iface     : rms=2.312e-01  max=4.317e-01
#   ic        : rms=3.239e-01  max=1.043e+00
# Scaled PDE RMS on obj: phi 0.5084196701308175 Ts 0.12077655924882329 cont 0.3914411534629548 ru 0.3083617058309358 rv 0.33565745909970074 rTf 0.11479777699532713
# [it=40] obj=2.700e+00 feas_raw=4.707e-04 alpha=2.31e-01 beta=8.96e-01 station=1.81e-01 dn=1.81e-01
# blocks (unscaled c):
#   pde_phi   : rms=3.323e-02  max=1.088e-01
#   pde_Ts    : rms=6.875e-03  max=1.625e-02
#   pde_cont  : rms=4.178e-02  max=1.482e-01
#   pde_ru    : rms=3.315e-02  max=1.327e-01
#   pde_rv    : rms=3.122e-02  max=1.848e-01
#   pde_rTf   : rms=6.164e-03  max=2.461e-02
#   bc_phi    : rms=1.309e-02  max=3.025e-02
#   bc_solid  : rms=3.132e-03  max=6.360e-03
#   bc_fluid  : rms=2.430e-02  max=5.561e-02
#   iface     : rms=1.175e-02  max=2.369e-02
#   ic        : rms=1.926e-02  max=6.248e-02
# Scaled PDE RMS on obj: phi 0.32523496830638277 Ts 0.03500249287779396 cont 0.1837332736464443 ru 0.08643647031948513 rv 0.09740757998938337 rTf 0.018824150369834244
# [it=50] obj=7.941e-01 feas_raw=2.183e-06 alpha=2.25e-01 beta=8.75e-01 station=6.18e-02 dn=6.18e-02
# blocks (unscaled c):
#   pde_phi   : rms=2.519e-03  max=7.591e-03
#   pde_Ts    : rms=4.950e-04  max=1.347e-03
#   pde_cont  : rms=3.690e-03  max=1.076e-02
#   pde_ru    : rms=2.503e-03  max=9.215e-03
#   pde_rv    : rms=1.943e-03  max=6.823e-03
#   pde_rTf   : rms=4.331e-04  max=1.476e-03
#   bc_phi    : rms=6.402e-04  max=2.312e-03
#   bc_solid  : rms=2.740e-04  max=1.014e-03
#   bc_fluid  : rms=1.616e-03  max=5.434e-03
#   iface     : rms=3.535e-04  max=1.189e-03
#   ic        : rms=1.136e-03  max=4.340e-03
# Scaled PDE RMS on obj: phi 0.2584505072010891 Ts 0.030430724693855632 cont 0.0964617370315064 ru 0.042246529653878734 rv 0.04443897889378224 rTf 0.009245336116143187
# [it=60] obj=5.658e-01 feas_raw=2.505e-07 alpha=1.50e-01 beta=8.54e-01 station=3.45e-02 dn=3.45e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.387e-03  max=5.511e-03
#   pde_Ts    : rms=1.347e-04  max=2.865e-04
#   pde_cont  : rms=1.219e-03  max=3.877e-03
#   pde_ru    : rms=5.465e-04  max=2.545e-03
#   pde_rv    : rms=4.969e-04  max=2.653e-03
#   pde_rTf   : rms=1.861e-04  max=5.825e-04
#   bc_phi    : rms=1.931e-04  max=1.027e-03
#   bc_solid  : rms=1.716e-04  max=7.666e-04
#   bc_fluid  : rms=4.384e-04  max=1.574e-03
#   iface     : rms=1.998e-04  max=5.964e-04
#   ic        : rms=4.023e-04  max=1.811e-03
# Scaled PDE RMS on obj: phi 0.23783325913673334 Ts 0.029985187111371096 cont 0.08032235489574997 ru 0.033650772164697466 rv 0.034049061900680674 rTf 0.006484035132831032
# [it=70] obj=4.749e-01 feas_raw=1.674e-07 alpha=1.47e-01 beta=8.35e-01 station=2.43e-02 dn=2.43e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.088e-03  max=3.297e-03
#   pde_Ts    : rms=1.218e-04  max=5.656e-04
#   pde_cont  : rms=1.296e-03  max=1.214e-02
#   pde_ru    : rms=3.541e-04  max=2.031e-03
#   pde_rv    : rms=2.071e-04  max=1.612e-03
#   pde_rTf   : rms=1.594e-04  max=6.438e-04
#   bc_phi    : rms=1.328e-04  max=8.624e-04
#   bc_solid  : rms=1.593e-04  max=6.841e-04
#   bc_fluid  : rms=2.643e-04  max=1.188e-03
#   iface     : rms=1.730e-04  max=5.748e-04
#   ic        : rms=2.790e-04  max=1.063e-03
# Scaled PDE RMS on obj: phi 0.22530083543293467 Ts 0.02981186044489826 cont 0.0727315596633047 ru 0.0295339137118954 rv 0.0294587370229869 rTf 0.0053225433965959955
# [it=80] obj=4.172e-01 feas_raw=8.872e-08 alpha=1.44e-01 beta=8.17e-01 station=1.74e-02 dn=1.74e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.188e-03  max=6.050e-03
#   pde_Ts    : rms=1.050e-04  max=4.816e-04
#   pde_cont  : rms=7.196e-04  max=4.211e-03
#   pde_ru    : rms=2.313e-04  max=9.831e-04
#   pde_rv    : rms=1.591e-04  max=1.006e-03
#   pde_rTf   : rms=1.409e-04  max=5.418e-04
#   bc_phi    : rms=1.208e-04  max=7.657e-04
#   bc_solid  : rms=1.519e-04  max=6.619e-04
#   bc_fluid  : rms=1.933e-04  max=1.019e-03
#   iface     : rms=1.562e-04  max=5.440e-04
#   ic        : rms=1.924e-04  max=7.554e-04
# Scaled PDE RMS on obj: phi 0.215053226958361 Ts 0.029729246775470237 cont 0.06753776520708395 ru 0.026864109497834753 rv 0.026610352917246775 rTf 0.004687987861351067
# [it=90] obj=3.782e-01 feas_raw=8.460e-08 alpha=1.55e-01 beta=8.00e-01 station=1.42e-02 dn=1.42e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.016e-03  max=4.621e-03
#   pde_Ts    : rms=1.137e-04  max=4.086e-04
#   pde_cont  : rms=9.282e-04  max=8.731e-03
#   pde_ru    : rms=2.353e-04  max=1.360e-03
#   pde_rv    : rms=1.851e-04  max=1.438e-03
#   pde_rTf   : rms=1.376e-04  max=5.679e-04
#   bc_phi    : rms=1.146e-04  max=6.949e-04
#   bc_solid  : rms=1.447e-04  max=6.376e-04
#   bc_fluid  : rms=1.959e-04  max=1.414e-03
#   iface     : rms=1.443e-04  max=5.145e-04
#   ic        : rms=1.297e-04  max=5.409e-04
# Scaled PDE RMS on obj: phi 0.2069961260166725 Ts 0.029745985662626186 cont 0.06419430803642184 ru 0.02504315383548014 rv 0.024635698026600147 rTf 0.0043140128346386575
# [it=100] obj=3.481e-01 feas_raw=7.150e-08 alpha=1.67e-01 beta=7.84e-01 station=1.23e-02 dn=1.23e-02
# blocks (unscaled c):
#   pde_phi   : rms=1.323e-03  max=5.904e-03
#   pde_Ts    : rms=1.257e-04  max=4.553e-04
#   pde_cont  : rms=6.036e-04  max=5.302e-03
#   pde_ru    : rms=1.763e-04  max=8.945e-04
#   pde_rv    : rms=1.068e-04  max=7.613e-04
#   pde_rTf   : rms=1.226e-04  max=4.810e-04
#   bc_phi    : rms=1.048e-04  max=6.362e-04
#   bc_solid  : rms=1.368e-04  max=6.034e-04
#   bc_fluid  : rms=1.926e-04  max=1.080e-03
#   iface     : rms=1.354e-04  max=4.905e-04
#   ic        : rms=9.573e-05  max=4.196e-04
# Scaled PDE RMS on obj: phi 0.19984936375124324 Ts 0.029789984722127967 cont 0.06115923327624692 ru 0.02369747392866993 rv 0.023176404675796108 rTf 0.0040605545091784885
# [it=110] obj=3.233e-01 feas_raw=3.739e-08 alpha=1.49e-01 beta=7.69e-01 station=9.79e-03 dn=9.79e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.102e-04  max=3.163e-03
#   pde_Ts    : rms=1.327e-04  max=6.009e-04
#   pde_cont  : rms=4.867e-04  max=3.388e-03
#   pde_ru    : rms=1.894e-04  max=1.012e-03
#   pde_rv    : rms=8.814e-05  max=4.226e-04
#   pde_rTf   : rms=1.240e-04  max=4.555e-04
#   bc_phi    : rms=1.003e-04  max=5.905e-04
#   bc_solid  : rms=1.279e-04  max=5.615e-04
#   bc_fluid  : rms=2.064e-04  max=1.352e-03
#   iface     : rms=1.280e-04  max=4.658e-04
#   ic        : rms=7.194e-05  max=4.058e-04
# Scaled PDE RMS on obj: phi 0.19340483108672005 Ts 0.02987751501635817 cont 0.05877940152539875 ru 0.02283412276640141 rv 0.022121650830564058 rTf 0.0038828465331244713
# [it=120] obj=3.041e-01 feas_raw=5.976e-08 alpha=1.61e-01 beta=7.54e-01 station=8.88e-03 dn=8.88e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.023e-03  max=5.564e-03
#   pde_Ts    : rms=9.048e-05  max=3.571e-04
#   pde_cont  : rms=7.476e-04  max=7.712e-03
#   pde_ru    : rms=1.799e-04  max=1.030e-03
#   pde_rv    : rms=8.274e-05  max=6.598e-04
#   pde_rTf   : rms=1.205e-04  max=5.217e-04
#   bc_phi    : rms=9.345e-05  max=5.461e-04
#   bc_solid  : rms=1.191e-04  max=5.222e-04
#   bc_fluid  : rms=1.853e-04  max=1.523e-03
#   iface     : rms=1.217e-04  max=4.429e-04
#   ic        : rms=6.103e-05  max=3.845e-04
# Scaled PDE RMS on obj: phi 0.18756027432187747 Ts 0.030013963856790872 cont 0.05685776216737155 ru 0.02235270029970161 rv 0.0214060475419864 rTf 0.003757993827468317
# [it=130] obj=2.861e-01 feas_raw=6.739e-08 alpha=2.10e-01 beta=7.40e-01 station=7.82e-03 dn=7.82e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.930e-04  max=4.016e-03
#   pde_Ts    : rms=9.349e-05  max=3.521e-04
#   pde_cont  : rms=9.280e-04  max=8.185e-03
#   pde_ru    : rms=1.633e-04  max=1.010e-03
#   pde_rv    : rms=1.029e-04  max=6.352e-04
#   pde_rTf   : rms=1.141e-04  max=5.002e-04
#   bc_phi    : rms=8.664e-05  max=5.047e-04
#   bc_solid  : rms=1.097e-04  max=4.756e-04
#   bc_fluid  : rms=1.856e-04  max=1.440e-03
#   iface     : rms=1.155e-04  max=4.158e-04
#   ic        : rms=5.853e-05  max=3.607e-04
# Scaled PDE RMS on obj: phi 0.18147648761264873 Ts 0.030202573667784453 cont 0.05488864081982342 ru 0.021970518686525813 rv 0.020788042092691073 rTf 0.003641251311174942
# [it=140] obj=2.703e-01 feas_raw=8.587e-08 alpha=2.06e-01 beta=7.27e-01 station=8.36e-03 dn=8.36e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.190e-04  max=2.404e-03
#   pde_Ts    : rms=9.873e-05  max=3.589e-04
#   pde_cont  : rms=1.246e-03  max=9.494e-03
#   pde_ru    : rms=1.568e-04  max=6.960e-04
#   pde_rv    : rms=1.217e-04  max=1.074e-03
#   pde_rTf   : rms=1.019e-04  max=3.862e-04
#   bc_phi    : rms=8.167e-05  max=4.617e-04
#   bc_solid  : rms=9.940e-05  max=4.264e-04
#   bc_fluid  : rms=1.457e-04  max=9.458e-04
#   iface     : rms=1.101e-04  max=3.890e-04
#   ic        : rms=5.517e-05  max=3.601e-04
# Scaled PDE RMS on obj: phi 0.17575041583360385 Ts 0.030450030874284797 cont 0.053186290981091046 ru 0.021603863153346226 rv 0.020208530772706765 rTf 0.00354663355230107
# [it=150] obj=2.525e-01 feas_raw=4.622e-08 alpha=2.70e-01 beta=7.15e-01 station=7.80e-03 dn=7.80e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.117e-04  max=4.210e-03
#   pde_Ts    : rms=1.025e-04  max=3.788e-04
#   pde_cont  : rms=7.194e-04  max=5.834e-03
#   pde_ru    : rms=1.486e-04  max=6.931e-04
#   pde_rv    : rms=1.040e-04  max=7.026e-04
#   pde_rTf   : rms=1.025e-04  max=3.810e-04
#   bc_phi    : rms=7.571e-05  max=4.178e-04
#   bc_solid  : rms=8.918e-05  max=3.742e-04
#   bc_fluid  : rms=1.392e-04  max=8.771e-04
#   iface     : rms=1.043e-04  max=3.584e-04
#   ic        : rms=5.396e-05  max=3.261e-04
# Scaled PDE RMS on obj: phi 0.16950667935124242 Ts 0.030718051554189756 cont 0.051072324271872915 ru 0.02123505970248712 rv 0.01965609428855894 rTf 0.0034608225365538154
# [it=160] obj=2.372e-01 feas_raw=3.226e-08 alpha=2.65e-01 beta=7.03e-01 station=6.79e-03 dn=6.79e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.112e-04  max=4.201e-03
#   pde_Ts    : rms=1.554e-04  max=9.279e-04
#   pde_cont  : rms=5.407e-04  max=3.795e-03
#   pde_ru    : rms=1.207e-04  max=6.371e-04
#   pde_rv    : rms=9.786e-05  max=6.881e-04
#   pde_rTf   : rms=9.701e-05  max=3.622e-04
#   bc_phi    : rms=7.529e-05  max=3.723e-04
#   bc_solid  : rms=7.824e-05  max=3.254e-04
#   bc_fluid  : rms=1.665e-04  max=1.069e-03
#   iface     : rms=9.911e-05  max=3.300e-04
#   ic        : rms=5.308e-05  max=3.236e-04
# Scaled PDE RMS on obj: phi 0.16365775655978407 Ts 0.03109987917740586 cont 0.049379239339621156 ru 0.020729039870667074 rv 0.019053169534896858 rTf 0.003392641850925896
# [it=170] obj=2.223e-01 feas_raw=3.070e-08 alpha=2.87e-01 beta=6.91e-01 station=6.19e-03 dn=6.19e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.675e-04  max=2.496e-03
#   pde_Ts    : rms=8.469e-05  max=2.909e-04
#   pde_cont  : rms=6.271e-04  max=5.668e-03
#   pde_ru    : rms=1.317e-04  max=6.610e-04
#   pde_rv    : rms=6.498e-05  max=4.002e-04
#   pde_rTf   : rms=9.872e-05  max=4.017e-04
#   bc_phi    : rms=6.837e-05  max=3.258e-04
#   bc_solid  : rms=6.874e-05  max=2.778e-04
#   bc_fluid  : rms=1.041e-04  max=6.911e-04
#   iface     : rms=9.425e-05  max=3.108e-04
#   ic        : rms=4.945e-05  max=2.976e-04
# Scaled PDE RMS on obj: phi 0.15802700441388698 Ts 0.0315673371841505 cont 0.04794484221916509 ru 0.020339070217845933 rv 0.018513377144465635 rTf 0.003357241753200283
# [it=180] obj=2.081e-01 feas_raw=1.770e-08 alpha=3.11e-01 beta=6.80e-01 station=5.00e-03 dn=5.00e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.056e-04  max=1.885e-03
#   pde_Ts    : rms=1.442e-04  max=8.400e-04
#   pde_cont  : rms=4.519e-04  max=3.754e-03
#   pde_ru    : rms=1.107e-04  max=5.471e-04
#   pde_rv    : rms=5.960e-05  max=3.851e-04
#   pde_rTf   : rms=9.343e-05  max=3.478e-04
#   bc_phi    : rms=5.899e-05  max=2.973e-04
#   bc_solid  : rms=5.925e-05  max=2.304e-04
#   bc_fluid  : rms=1.011e-04  max=7.730e-04
#   iface     : rms=8.961e-05  max=2.852e-04
#   ic        : rms=4.498e-05  max=2.746e-04
# Scaled PDE RMS on obj: phi 0.15201141125530915 Ts 0.032066504847813176 cont 0.04620428824247934 ru 0.020028934612307918 rv 0.0180462039774895 rTf 0.003335818756884124
# [it=190] obj=1.949e-01 feas_raw=1.472e-08 alpha=3.70e-01 beta=6.70e-01 station=5.03e-03 dn=5.03e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.823e-04  max=2.748e-03
#   pde_Ts    : rms=1.233e-04  max=5.759e-04
#   pde_cont  : rms=3.491e-04  max=2.516e-03
#   pde_ru    : rms=1.036e-04  max=4.960e-04
#   pde_rv    : rms=5.930e-05  max=3.951e-04
#   pde_rTf   : rms=8.755e-05  max=3.401e-04
#   bc_phi    : rms=5.479e-05  max=2.701e-04
#   bc_solid  : rms=5.021e-05  max=1.860e-04
#   bc_fluid  : rms=8.088e-05  max=3.800e-04
#   iface     : rms=8.530e-05  max=2.605e-04
#   ic        : rms=4.113e-05  max=2.663e-04
# Scaled PDE RMS on obj: phi 0.14593578541302696 Ts 0.03261057831376978 cont 0.044478362935317005 ru 0.019751391349466987 rv 0.017628898850174567 rTf 0.0033200524490521258
# [it=200] obj=1.834e-01 feas_raw=1.190e-08 alpha=4.01e-01 beta=6.60e-01 station=4.62e-03 dn=4.62e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.085e-04  max=1.657e-03
#   pde_Ts    : rms=1.119e-04  max=4.835e-04
#   pde_cont  : rms=3.146e-04  max=1.897e-03
#   pde_ru    : rms=1.029e-04  max=5.475e-04
#   pde_rv    : rms=3.513e-05  max=1.512e-04
#   pde_rTf   : rms=8.590e-05  max=3.361e-04
#   bc_phi    : rms=4.514e-05  max=2.394e-04
#   bc_solid  : rms=4.296e-05  max=1.490e-04
#   bc_fluid  : rms=1.017e-04  max=7.989e-04
#   iface     : rms=8.171e-05  max=2.415e-04
#   ic        : rms=3.862e-05  max=2.447e-04
# Scaled PDE RMS on obj: phi 0.14055179116358318 Ts 0.03315860833861622 cont 0.043059764205347385 ru 0.01952602793121519 rv 0.017278849810783065 rTf 0.003333326137686666
# [it=210] obj=1.722e-01 feas_raw=2.184e-08 alpha=4.35e-01 beta=6.50e-01 station=4.52e-03 dn=4.52e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.321e-04  max=2.868e-03
#   pde_Ts    : rms=1.689e-04  max=1.244e-03
#   pde_cont  : rms=4.945e-04  max=3.620e-03
#   pde_ru    : rms=1.089e-04  max=4.526e-04
#   pde_rv    : rms=5.321e-05  max=3.143e-04
#   pde_rTf   : rms=8.853e-05  max=3.308e-04
#   bc_phi    : rms=3.937e-05  max=1.957e-04
#   bc_solid  : rms=3.667e-05  max=1.213e-04
#   bc_fluid  : rms=9.720e-05  max=6.843e-04
#   iface     : rms=7.848e-05  max=2.194e-04
#   ic        : rms=3.775e-05  max=2.323e-04
# Scaled PDE RMS on obj: phi 0.13507571016581632 Ts 0.0337564504698356 cont 0.041655057380695436 ru 0.01929456093446294 rv 0.016938672028427255 rTf 0.0033536762366746307
# [it=220] obj=1.626e-01 feas_raw=2.488e-08 alpha=5.18e-01 beta=6.41e-01 station=4.41e-03 dn=4.41e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.847e-04  max=1.455e-03
#   pde_Ts    : rms=9.390e-05  max=4.273e-04
#   pde_cont  : rms=6.262e-04  max=6.813e-03
#   pde_ru    : rms=9.741e-05  max=4.407e-04
#   pde_rv    : rms=6.357e-05  max=6.230e-04
#   pde_rTf   : rms=8.274e-05  max=3.270e-04
#   bc_phi    : rms=3.658e-05  max=1.640e-04
#   bc_solid  : rms=3.081e-05  max=1.069e-04
#   bc_fluid  : rms=1.063e-04  max=9.014e-04
#   iface     : rms=7.576e-05  max=2.128e-04
#   ic        : rms=3.493e-05  max=2.061e-04
# Scaled PDE RMS on obj: phi 0.1298336599479239 Ts 0.03438440577510277 cont 0.04022709398987111 ru 0.019081986362915096 rv 0.016610617234982108 rTf 0.0033489631934762497
# [it=230] obj=1.524e-01 feas_raw=1.260e-08 alpha=5.62e-01 beta=6.32e-01 station=3.72e-03 dn=3.72e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.141e-04  max=1.316e-03
#   pde_Ts    : rms=5.366e-05  max=1.742e-04
#   pde_cont  : rms=4.197e-04  max=4.263e-03
#   pde_ru    : rms=8.049e-05  max=3.504e-04
#   pde_rv    : rms=3.494e-05  max=2.060e-04
#   pde_rTf   : rms=7.724e-05  max=3.121e-04
#   bc_phi    : rms=3.304e-05  max=1.430e-04
#   bc_solid  : rms=2.550e-05  max=9.054e-05
#   bc_fluid  : rms=5.960e-05  max=4.421e-04
#   iface     : rms=7.287e-05  max=2.041e-04
#   ic        : rms=3.359e-05  max=1.964e-04
# Scaled PDE RMS on obj: phi 0.12451023665288277 Ts 0.0349976949180028 cont 0.03876709570503734 ru 0.018862942090262593 rv 0.016290797979952056 rTf 0.003361648182224534
# [it=240] obj=1.428e-01 feas_raw=2.043e-08 alpha=5.04e-01 beta=6.23e-01 station=4.77e-03 dn=4.77e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.763e-04  max=3.028e-03
#   pde_Ts    : rms=9.109e-05  max=5.598e-04
#   pde_cont  : rms=4.586e-04  max=4.301e-03
#   pde_ru    : rms=9.344e-05  max=5.133e-04
#   pde_rv    : rms=4.704e-05  max=3.730e-04
#   pde_rTf   : rms=8.028e-05  max=2.955e-04
#   bc_phi    : rms=2.755e-05  max=1.168e-04
#   bc_solid  : rms=2.281e-05  max=8.968e-05
#   bc_fluid  : rms=1.018e-04  max=8.711e-04
#   iface     : rms=7.029e-05  max=2.029e-04
#   ic        : rms=3.350e-05  max=1.888e-04
# Scaled PDE RMS on obj: phi 0.11952075612972415 Ts 0.03565797751509582 cont 0.03784188525068479 ru 0.018663241327368053 rv 0.015987493731098572 rTf 0.0034012088040093974
# [it=250] obj=1.345e-01 feas_raw=1.037e-08 alpha=5.47e-01 beta=6.15e-01 station=3.75e-03 dn=3.75e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.785e-04  max=9.806e-04
#   pde_Ts    : rms=5.413e-05  max=1.475e-04
#   pde_cont  : rms=3.708e-04  max=3.690e-03
#   pde_ru    : rms=8.252e-05  max=4.078e-04
#   pde_rv    : rms=4.140e-05  max=2.877e-04
#   pde_rTf   : rms=7.356e-05  max=2.792e-04
#   bc_phi    : rms=2.600e-05  max=1.181e-04
#   bc_solid  : rms=1.928e-05  max=7.350e-05
#   bc_fluid  : rms=9.054e-05  max=6.088e-04
#   iface     : rms=6.777e-05  max=1.949e-04
#   ic        : rms=3.004e-05  max=1.932e-04
# Scaled PDE RMS on obj: phi 0.11465679501780696 Ts 0.03627761766316194 cont 0.03657497564930346 ru 0.018452028053421773 rv 0.015662302796860695 rTf 0.0033952513488733536
# [it=260] obj=1.265e-01 feas_raw=1.147e-08 alpha=6.53e-01 beta=6.07e-01 station=3.92e-03 dn=3.92e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.800e-04  max=1.127e-03
#   pde_Ts    : rms=4.895e-05  max=1.638e-04
#   pde_cont  : rms=4.122e-04  max=4.275e-03
#   pde_ru    : rms=7.590e-05  max=2.891e-04
#   pde_rv    : rms=3.844e-05  max=3.552e-04
#   pde_rTf   : rms=6.912e-05  max=2.588e-04
#   bc_phi    : rms=2.126e-05  max=1.022e-04
#   bc_solid  : rms=1.583e-05  max=5.772e-05
#   bc_fluid  : rms=6.092e-05  max=5.001e-04
#   iface     : rms=6.537e-05  max=1.955e-04
#   ic        : rms=2.922e-05  max=1.880e-04
# Scaled PDE RMS on obj: phi 0.11012806720863748 Ts 0.03677285748686443 cont 0.03491467319365095 ru 0.018248009482352327 rv 0.015361067276572906 rTf 0.003380782577756885
# [it=270] obj=1.186e-01 feas_raw=1.497e-09 alpha=9.44e-01 beta=5.99e-01 station=3.55e-03 dn=3.55e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.332e-05  max=1.945e-04
#   pde_Ts    : rms=1.102e-05  max=2.962e-05
#   pde_cont  : rms=6.684e-05  max=4.867e-04
#   pde_ru    : rms=6.578e-05  max=2.198e-04
#   pde_rv    : rms=1.499e-05  max=5.207e-05
#   pde_rTf   : rms=6.344e-05  max=2.277e-04
#   bc_phi    : rms=1.804e-05  max=9.566e-05
#   bc_solid  : rms=1.306e-05  max=4.570e-05
#   bc_fluid  : rms=2.678e-05  max=1.290e-04
#   iface     : rms=6.267e-05  max=2.049e-04
#   ic        : rms=2.937e-05  max=1.745e-04
# Scaled PDE RMS on obj: phi 0.10509618126436329 Ts 0.03729114242659204 cont 0.03368888468003211 ru 0.018020173958177777 rv 0.015012551063046697 rTf 0.003393178991472218
# [it=280] obj=1.116e-01 feas_raw=1.868e-09 alpha=8.48e-01 beta=5.91e-01 station=3.68e-03 dn=3.68e-03
# blocks (unscaled c):
#   pde_phi   : rms=9.572e-05  max=3.328e-04
#   pde_Ts    : rms=2.270e-05  max=8.239e-05
#   pde_cont  : rms=1.083e-04  max=8.653e-04
#   pde_ru    : rms=6.116e-05  max=1.964e-04
#   pde_rv    : rms=1.518e-05  max=6.950e-05
#   pde_rTf   : rms=5.762e-05  max=1.990e-04
#   bc_phi    : rms=1.763e-05  max=8.719e-05
#   bc_solid  : rms=1.206e-05  max=3.922e-05
#   bc_fluid  : rms=3.141e-05  max=1.958e-04
#   iface     : rms=5.981e-05  max=2.179e-04
#   ic        : rms=2.681e-05  max=1.783e-04
# Scaled PDE RMS on obj: phi 0.10064229949690735 Ts 0.03766517022895168 cont 0.03223026425543923 ru 0.017801352855026806 rv 0.014691476031759023 rTf 0.0033929832242016456
# [it=290] obj=1.046e-01 feas_raw=1.119e-09 alpha=9.21e-01 beta=5.84e-01 station=3.11e-03 dn=3.11e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.186e-05  max=1.357e-04
#   pde_Ts    : rms=1.407e-05  max=5.135e-05
#   pde_cont  : rms=4.049e-05  max=2.241e-04
#   pde_ru    : rms=6.050e-05  max=2.024e-04
#   pde_rv    : rms=1.381e-05  max=5.568e-05
#   pde_rTf   : rms=5.412e-05  max=1.774e-04
#   bc_phi    : rms=1.472e-05  max=6.917e-05
#   bc_solid  : rms=9.070e-06  max=2.712e-05
#   bc_fluid  : rms=2.785e-05  max=1.519e-04
#   iface     : rms=5.696e-05  max=2.222e-04
#   ic        : rms=2.517e-05  max=1.636e-04
# Scaled PDE RMS on obj: phi 0.09657109662092872 Ts 0.03791612476727734 cont 0.03097865837404509 ru 0.017609474925651465 rv 0.014378188416203785 rTf 0.0033795834518778748
# [it=300] obj=9.967e-02 feas_raw=9.611e-10 alpha=1.00e+00 beta=5.77e-01 station=3.13e-03 dn=3.13e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.554e-05  max=5.053e-05
#   pde_Ts    : rms=5.362e-06  max=1.535e-05
#   pde_cont  : rms=2.667e-05  max=9.052e-05
#   pde_ru    : rms=5.838e-05  max=1.840e-04
#   pde_rv    : rms=1.277e-05  max=4.876e-05
#   pde_rTf   : rms=5.028e-05  max=1.540e-04
#   bc_phi    : rms=1.389e-05  max=7.015e-05
#   bc_solid  : rms=8.222e-06  max=2.994e-05
#   bc_fluid  : rms=3.259e-05  max=1.478e-04
#   iface     : rms=5.444e-05  max=2.262e-04
#   ic        : rms=2.464e-05  max=1.634e-04
# Scaled PDE RMS on obj: phi 0.09321633411898961 Ts 0.03808985502200665 cont 0.029951516579047207 ru 0.017421882887067232 rv 0.014088784080149576 rTf 0.0033686292217383956
# [it=310] obj=9.509e-02 feas_raw=1.630e-09 alpha=8.99e-01 beta=5.70e-01 station=3.15e-03 dn=3.15e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.719e-05  max=3.158e-04
#   pde_Ts    : rms=1.600e-05  max=5.918e-05
#   pde_cont  : rms=1.114e-04  max=1.107e-03
#   pde_ru    : rms=5.633e-05  max=1.695e-04
#   pde_rv    : rms=1.409e-05  max=6.818e-05
#   pde_rTf   : rms=4.840e-05  max=1.513e-04
#   bc_phi    : rms=1.408e-05  max=6.502e-05
#   bc_solid  : rms=7.634e-06  max=2.568e-05
#   bc_fluid  : rms=3.805e-05  max=1.380e-04
#   iface     : rms=5.237e-05  max=2.230e-04
#   ic        : rms=2.437e-05  max=1.544e-04
# Scaled PDE RMS on obj: phi 0.09011106577681456 Ts 0.038160205374138174 cont 0.029035592266035977 ru 0.017280030808571722 rv 0.013834641180400562 rTf 0.003370064790127664
# [it=320] obj=9.063e-02 feas_raw=7.790e-10 alpha=9.78e-01 beta=5.64e-01 station=1.78e-03 dn=1.78e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.672e-05  max=5.502e-05
#   pde_Ts    : rms=4.686e-06  max=1.931e-05
#   pde_cont  : rms=1.883e-05  max=1.335e-04
#   pde_ru    : rms=5.478e-05  max=1.623e-04
#   pde_rv    : rms=1.141e-05  max=4.018e-05
#   pde_rTf   : rms=4.423e-05  max=1.359e-04
#   bc_phi    : rms=1.237e-05  max=5.709e-05
#   bc_solid  : rms=6.290e-06  max=2.175e-05
#   bc_fluid  : rms=1.964e-05  max=1.151e-04
#   iface     : rms=4.966e-05  max=2.179e-04
#   ic        : rms=2.320e-05  max=1.599e-04
# Scaled PDE RMS on obj: phi 0.08723177612429248 Ts 0.03822445850109106 cont 0.028179389331439646 ru 0.017144709400950295 rv 0.013592312990992129 rTf 0.0033799999024841255
# [it=330] obj=8.683e-02 feas_raw=8.731e-10 alpha=9.66e-01 beta=5.57e-01 station=3.13e-03 dn=3.13e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.350e-05  max=1.326e-04
#   pde_Ts    : rms=9.861e-06  max=4.770e-05
#   pde_cont  : rms=4.029e-05  max=2.750e-04
#   pde_ru    : rms=5.518e-05  max=1.929e-04
#   pde_rv    : rms=1.286e-05  max=4.504e-05
#   pde_rTf   : rms=4.288e-05  max=1.211e-04
#   bc_phi    : rms=1.259e-05  max=4.936e-05
#   bc_solid  : rms=6.620e-06  max=2.113e-05
#   bc_fluid  : rms=2.437e-05  max=1.300e-04
#   iface     : rms=4.791e-05  max=2.093e-04
#   ic        : rms=2.376e-05  max=1.549e-04
# Scaled PDE RMS on obj: phi 0.08501003821909804 Ts 0.03820332841574456 cont 0.027735060473189826 ru 0.017013922759262258 rv 0.013367672625128536 rTf 0.003394974812372931
# [it=340] obj=8.396e-02 feas_raw=7.746e-10 alpha=9.56e-01 beta=5.51e-01 station=2.59e-03 dn=2.59e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.695e-05  max=2.025e-04
#   pde_Ts    : rms=9.436e-06  max=2.753e-05
#   pde_cont  : rms=3.220e-05  max=2.088e-04
#   pde_ru    : rms=5.329e-05  max=1.440e-04
#   pde_rv    : rms=1.050e-05  max=3.809e-05
#   pde_rTf   : rms=4.005e-05  max=1.138e-04
#   bc_phi    : rms=1.171e-05  max=5.618e-05
#   bc_solid  : rms=7.137e-06  max=2.574e-05
#   bc_fluid  : rms=2.276e-05  max=9.531e-05
#   iface     : rms=4.595e-05  max=2.065e-04
#   ic        : rms=2.243e-05  max=1.462e-04
# Scaled PDE RMS on obj: phi 0.08277642694010472 Ts 0.03811696912610289 cont 0.026804034191626278 ru 0.016907295165716478 rv 0.013165103156048583 rTf 0.00337928079325425
# [it=350] obj=8.112e-02 feas_raw=7.203e-10 alpha=9.45e-01 beta=5.45e-01 station=2.12e-03 dn=2.12e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.261e-05  max=2.048e-04
#   pde_Ts    : rms=1.267e-05  max=7.451e-05
#   pde_cont  : rms=2.374e-05  max=1.566e-04
#   pde_ru    : rms=5.336e-05  max=1.501e-04
#   pde_rv    : rms=1.146e-05  max=4.786e-05
#   pde_rTf   : rms=3.907e-05  max=1.111e-04
#   bc_phi    : rms=1.108e-05  max=5.320e-05
#   bc_solid  : rms=6.661e-06  max=2.043e-05
#   bc_fluid  : rms=2.043e-05  max=1.141e-04
#   iface     : rms=4.411e-05  max=1.921e-04
#   ic        : rms=2.149e-05  max=1.480e-04
# Scaled PDE RMS on obj: phi 0.08071856655537259 Ts 0.038127266028341836 cont 0.026509182300242275 ru 0.016798800784622387 rv 0.01296318269691642 rTf 0.003395142547241828
# [it=360] obj=7.827e-02 feas_raw=7.154e-10 alpha=1.03e+00 beta=5.39e-01 station=3.72e-03 dn=3.72e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.202e-05  max=8.552e-05
#   pde_Ts    : rms=7.569e-06  max=1.820e-05
#   pde_cont  : rms=4.087e-05  max=3.256e-04
#   pde_ru    : rms=5.225e-05  max=1.639e-04
#   pde_rv    : rms=1.084e-05  max=4.364e-05
#   pde_rTf   : rms=3.721e-05  max=1.143e-04
#   bc_phi    : rms=1.235e-05  max=5.083e-05
#   bc_solid  : rms=4.968e-06  max=1.893e-05
#   bc_fluid  : rms=1.991e-05  max=1.018e-04
#   iface     : rms=4.203e-05  max=1.835e-04
#   ic        : rms=2.164e-05  max=1.390e-04
# Scaled PDE RMS on obj: phi 0.07888752481153091 Ts 0.03792260889202484 cont 0.025952153842957387 ru 0.016705350927108217 rv 0.012782739669318395 rTf 0.0033969141770404812
# [it=370] obj=7.604e-02 feas_raw=6.304e-10 alpha=1.02e+00 beta=5.33e-01 station=2.16e-03 dn=2.16e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.837e-05  max=6.378e-05
#   pde_Ts    : rms=7.115e-06  max=2.115e-05
#   pde_cont  : rms=2.452e-05  max=1.012e-04
#   pde_ru    : rms=5.097e-05  max=1.382e-04
#   pde_rv    : rms=1.080e-05  max=4.905e-05
#   pde_rTf   : rms=3.496e-05  max=1.147e-04
#   bc_phi    : rms=1.244e-05  max=5.156e-05
#   bc_solid  : rms=5.436e-06  max=1.918e-05
#   bc_fluid  : rms=2.106e-05  max=8.102e-05
#   iface     : rms=4.052e-05  max=1.744e-04
#   ic        : rms=2.117e-05  max=1.308e-04
# Scaled PDE RMS on obj: phi 0.0771050536304599 Ts 0.03781896783741371 cont 0.025268068481263464 ru 0.01660369467139705 rv 0.01258435493992084 rTf 0.0033819269266526873
# [it=380] obj=7.351e-02 feas_raw=5.339e-10 alpha=1.01e+00 beta=5.28e-01 station=1.90e-03 dn=1.90e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.001e-06  max=2.580e-05
#   pde_Ts    : rms=3.224e-06  max=1.026e-05
#   pde_cont  : rms=1.384e-05  max=8.677e-05
#   pde_ru    : rms=5.045e-05  max=1.430e-04
#   pde_rv    : rms=1.037e-05  max=4.508e-05
#   pde_rTf   : rms=3.274e-05  max=1.110e-04
#   bc_phi    : rms=9.571e-06  max=4.731e-05
#   bc_solid  : rms=4.600e-06  max=1.348e-05
#   bc_fluid  : rms=1.491e-05  max=7.009e-05
#   iface     : rms=3.874e-05  max=1.634e-04
#   ic        : rms=1.975e-05  max=1.326e-04
# Scaled PDE RMS on obj: phi 0.07529899700891318 Ts 0.03768061313755798 cont 0.02461733520106821 ru 0.016530497600485968 rv 0.012411165005814746 rTf 0.003401773123735442
# [it=390] obj=7.154e-02 feas_raw=5.530e-10 alpha=9.97e-01 beta=5.23e-01 station=3.10e-03 dn=3.10e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.908e-05  max=6.488e-05
#   pde_Ts    : rms=5.189e-06  max=1.260e-05
#   pde_cont  : rms=1.535e-05  max=5.030e-05
#   pde_ru    : rms=5.076e-05  max=1.331e-04
#   pde_rv    : rms=1.089e-05  max=4.298e-05
#   pde_rTf   : rms=3.128e-05  max=1.107e-04
#   bc_phi    : rms=1.039e-05  max=4.841e-05
#   bc_solid  : rms=5.071e-06  max=1.328e-05
#   bc_fluid  : rms=1.771e-05  max=7.180e-05
#   iface     : rms=3.742e-05  max=1.544e-04
#   ic        : rms=2.032e-05  max=1.298e-04
# Scaled PDE RMS on obj: phi 0.07367767704489357 Ts 0.03751473470957017 cont 0.024167708086671093 ru 0.016455675687895365 rv 0.012249954077176457 rTf 0.003395558210683681
# [it=400] obj=6.927e-02 feas_raw=4.641e-10 alpha=9.87e-01 beta=5.17e-01 station=2.72e-03 dn=2.72e-03
# blocks (unscaled c):
#   pde_phi   : rms=7.957e-06  max=2.119e-05
#   pde_Ts    : rms=3.375e-06  max=1.070e-05
#   pde_cont  : rms=1.018e-05  max=4.471e-05
#   pde_ru    : rms=4.762e-05  max=1.318e-04
#   pde_rv    : rms=1.049e-05  max=4.957e-05
#   pde_rTf   : rms=2.910e-05  max=1.089e-04
#   bc_phi    : rms=9.388e-06  max=5.131e-05
#   bc_solid  : rms=4.201e-06  max=1.173e-05
#   bc_fluid  : rms=1.431e-05  max=7.100e-05
#   iface     : rms=3.543e-05  max=1.425e-04
#   ic        : rms=1.870e-05  max=1.245e-04
# Scaled PDE RMS on obj: phi 0.07215427135983386 Ts 0.037268482362720796 cont 0.023519817690871313 ru 0.016382458677685483 rv 0.01209849679123848 rTf 0.0033952429584221907
# [it=410] obj=6.760e-02 feas_raw=4.735e-10 alpha=9.77e-01 beta=5.12e-01 station=1.59e-03 dn=1.59e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.547e-05  max=1.549e-04
#   pde_Ts    : rms=4.892e-06  max=1.548e-05
#   pde_cont  : rms=1.176e-05  max=7.947e-05
#   pde_ru    : rms=4.855e-05  max=1.468e-04
#   pde_rv    : rms=1.040e-05  max=4.518e-05
#   pde_rTf   : rms=2.951e-05  max=1.107e-04
#   bc_phi    : rms=9.923e-06  max=4.986e-05
#   bc_solid  : rms=4.161e-06  max=1.207e-05
#   bc_fluid  : rms=1.331e-05  max=6.588e-05
#   iface     : rms=3.405e-05  max=1.358e-04
#   ic        : rms=1.853e-05  max=1.197e-04
# Scaled PDE RMS on obj: phi 0.07094081230008029 Ts 0.03712888839657555 cont 0.02331179678780111 ru 0.016316773818526063 rv 0.011946532239437169 rTf 0.0033933217571899227
# [it=420] obj=6.579e-02 feas_raw=1.008e-09 alpha=8.80e-01 beta=5.07e-01 station=4.52e-03 dn=4.52e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.369e-05  max=3.820e-04
#   pde_Ts    : rms=2.072e-05  max=8.078e-05
#   pde_cont  : rms=8.245e-05  max=7.330e-04
#   pde_ru    : rms=4.961e-05  max=1.932e-04
#   pde_rv    : rms=1.255e-05  max=5.360e-05
#   pde_rTf   : rms=2.963e-05  max=1.237e-04
#   bc_phi    : rms=1.183e-05  max=5.019e-05
#   bc_solid  : rms=5.444e-06  max=1.735e-05
#   bc_fluid  : rms=3.212e-05  max=2.298e-04
#   iface     : rms=3.296e-05  max=1.214e-04
#   ic        : rms=1.886e-05  max=1.171e-04
# Scaled PDE RMS on obj: phi 0.06970606132001693 Ts 0.0369344262493081 cont 0.022859598679711303 ru 0.016258971688155082 rv 0.011818071957747969 rTf 0.003412266364009968
# [it=430] obj=6.439e-02 feas_raw=4.456e-10 alpha=9.58e-01 beta=5.02e-01 station=1.64e-03 dn=1.64e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.090e-05  max=1.611e-04
#   pde_Ts    : rms=7.838e-06  max=4.235e-05
#   pde_cont  : rms=1.902e-05  max=1.667e-04
#   pde_ru    : rms=4.562e-05  max=1.245e-04
#   pde_rv    : rms=1.020e-05  max=4.979e-05
#   pde_rTf   : rms=2.693e-05  max=1.069e-04
#   bc_phi    : rms=9.060e-06  max=4.235e-05
#   bc_solid  : rms=3.888e-06  max=1.153e-05
#   bc_fluid  : rms=1.373e-05  max=4.400e-05
#   iface     : rms=3.161e-05  max=1.166e-04
#   ic        : rms=1.782e-05  max=1.100e-04
# Scaled PDE RMS on obj: phi 0.06845270513257974 Ts 0.03673106686636043 cont 0.02236252244918704 ru 0.01619314250062938 rv 0.011670691302396856 rTf 0.0034022219058166383
# [it=440] obj=6.306e-02 feas_raw=5.341e-10 alpha=9.49e-01 beta=4.98e-01 station=2.83e-03 dn=2.83e-03
# blocks (unscaled c):
#   pde_phi   : rms=4.119e-05  max=2.411e-04
#   pde_Ts    : rms=8.247e-06  max=2.618e-05
#   pde_cont  : rms=4.505e-05  max=4.186e-04
#   pde_ru    : rms=4.394e-05  max=1.243e-04
#   pde_rv    : rms=9.381e-06  max=4.073e-05
#   pde_rTf   : rms=2.614e-05  max=1.054e-04
#   bc_phi    : rms=9.044e-06  max=4.219e-05
#   bc_solid  : rms=5.962e-06  max=2.630e-05
#   bc_fluid  : rms=1.746e-05  max=4.981e-05
#   iface     : rms=3.035e-05  max=1.074e-04
#   ic        : rms=1.788e-05  max=1.119e-04
# Scaled PDE RMS on obj: phi 0.06739567970552164 Ts 0.03653350510218219 cont 0.022018822559956665 ru 0.016136353776432136 rv 0.011545793608779997 rTf 0.0034095406657113415
# [it=450] obj=6.154e-02 feas_raw=5.335e-10 alpha=9.41e-01 beta=4.93e-01 station=2.78e-03 dn=2.78e-03
# blocks (unscaled c):
#   pde_phi   : rms=3.602e-05  max=1.521e-04
#   pde_Ts    : rms=1.281e-05  max=6.537e-05
#   pde_cont  : rms=4.462e-05  max=3.345e-04
#   pde_ru    : rms=4.496e-05  max=1.459e-04
#   pde_rv    : rms=1.015e-05  max=4.900e-05
#   pde_rTf   : rms=2.494e-05  max=1.015e-04
#   bc_phi    : rms=1.004e-05  max=4.373e-05
#   bc_solid  : rms=5.115e-06  max=1.582e-05
#   bc_fluid  : rms=2.140e-05  max=8.731e-05
#   iface     : rms=2.932e-05  max=9.875e-05
#   ic        : rms=1.792e-05  max=1.118e-04
# Scaled PDE RMS on obj: phi 0.06628900367744542 Ts 0.03641313245785546 cont 0.02178093584446038 ru 0.016098704619511333 rv 0.011422718907666623 rTf 0.003406364300829263
# [it=460] obj=6.053e-02 feas_raw=3.912e-10 alpha=1.03e+00 beta=4.89e-01 station=2.77e-03 dn=2.77e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.192e-05  max=4.748e-05
#   pde_Ts    : rms=6.627e-06  max=3.280e-05
#   pde_cont  : rms=1.782e-05  max=1.089e-04
#   pde_ru    : rms=4.647e-05  max=1.906e-04
#   pde_rv    : rms=1.011e-05  max=4.966e-05
#   pde_rTf   : rms=2.539e-05  max=1.025e-04
#   bc_phi    : rms=9.757e-06  max=4.536e-05
#   bc_solid  : rms=4.349e-06  max=1.586e-05
#   bc_fluid  : rms=1.280e-05  max=4.893e-05
#   iface     : rms=2.807e-05  max=9.263e-05
#   ic        : rms=1.701e-05  max=1.050e-04
# Scaled PDE RMS on obj: phi 0.06542674873912765 Ts 0.036171490781815016 cont 0.021520626783885156 ru 0.016046090189556675 rv 0.011298360046818624 rTf 0.0034035438754708917
# [it=470] obj=5.924e-02 feas_raw=3.372e-10 alpha=1.02e+00 beta=4.84e-01 station=1.65e-03 dn=1.65e-03
# blocks (unscaled c):
#   pde_phi   : rms=9.773e-06  max=4.058e-05
#   pde_Ts    : rms=2.890e-06  max=1.160e-05
#   pde_cont  : rms=7.915e-06  max=2.971e-05
#   pde_ru    : rms=4.261e-05  max=1.167e-04
#   pde_rv    : rms=8.747e-06  max=4.780e-05
#   pde_rTf   : rms=2.223e-05  max=9.285e-05
#   bc_phi    : rms=8.394e-06  max=5.040e-05
#   bc_solid  : rms=5.120e-06  max=2.025e-05
#   bc_fluid  : rms=1.065e-05  max=4.311e-05
#   iface     : rms=2.715e-05  max=8.654e-05
#   ic        : rms=1.659e-05  max=1.034e-04
# Scaled PDE RMS on obj: phi 0.06444936373805445 Ts 0.03593824718680847 cont 0.02108034794325441 ru 0.016002451604145453 rv 0.011184552482845587 rTf 0.003408759419822358
# [it=480] obj=5.833e-02 feas_raw=3.501e-10 alpha=1.01e+00 beta=4.80e-01 station=2.22e-03 dn=2.22e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.657e-06  max=4.466e-05
#   pde_Ts    : rms=4.437e-06  max=1.457e-05
#   pde_cont  : rms=8.899e-06  max=2.066e-05
#   pde_ru    : rms=4.474e-05  max=1.484e-04
#   pde_rv    : rms=9.476e-06  max=4.212e-05
#   pde_rTf   : rms=2.249e-05  max=9.010e-05
#   bc_phi    : rms=9.072e-06  max=4.843e-05
#   bc_solid  : rms=3.473e-06  max=9.266e-06
#   bc_fluid  : rms=1.526e-05  max=5.531e-05
#   iface     : rms=2.651e-05  max=8.282e-05
#   ic        : rms=1.646e-05  max=9.864e-05
# Scaled PDE RMS on obj: phi 0.06353607560805463 Ts 0.03581090517894283 cont 0.020986279813924227 ru 0.01597576794423483 rv 0.011079416937625921 rTf 0.0034232807536199276
# [it=490] obj=5.708e-02 feas_raw=3.713e-10 alpha=9.98e-01 beta=4.76e-01 station=3.07e-03 dn=3.07e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.400e-05  max=4.627e-05
#   pde_Ts    : rms=6.342e-06  max=1.516e-05
#   pde_cont  : rms=2.606e-05  max=1.186e-04
#   pde_ru    : rms=4.128e-05  max=1.140e-04
#   pde_rv    : rms=1.008e-05  max=4.346e-05
#   pde_rTf   : rms=2.352e-05  max=8.987e-05
#   bc_phi    : rms=1.042e-05  max=3.955e-05
#   bc_solid  : rms=5.708e-06  max=2.003e-05
#   bc_fluid  : rms=1.829e-05  max=6.577e-05
#   iface     : rms=2.549e-05  max=7.684e-05
#   ic        : rms=1.630e-05  max=1.035e-04
# Scaled PDE RMS on obj: phi 0.06263743114413528 Ts 0.03554534803347047 cont 0.02058142846508785 ru 0.01590181704249453 rv 0.010952180538880089 rTf 0.0034052270362905823
# [it=500] obj=5.599e-02 feas_raw=3.145e-10 alpha=9.90e-01 beta=4.72e-01 station=2.05e-03 dn=2.05e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.091e-05  max=4.188e-05
#   pde_Ts    : rms=4.021e-06  max=1.289e-05
#   pde_cont  : rms=1.048e-05  max=4.521e-05
#   pde_ru    : rms=4.108e-05  max=1.127e-04
#   pde_rv    : rms=8.674e-06  max=4.200e-05
#   pde_rTf   : rms=2.036e-05  max=8.292e-05
#   bc_phi    : rms=8.315e-06  max=4.661e-05
#   bc_solid  : rms=4.898e-06  max=1.380e-05
#   bc_fluid  : rms=1.107e-05  max=3.555e-05
#   iface     : rms=2.434e-05  max=7.506e-05
#   ic        : rms=1.630e-05  max=9.444e-05
# Scaled PDE RMS on obj: phi 0.06184396324283687 Ts 0.0353750462595607 cont 0.020317699825420938 ru 0.015877319718085318 rv 0.010854131075528536 rTf 0.0034124640261433614
# [it=510] obj=5.501e-02 feas_raw=2.985e-10 alpha=9.81e-01 beta=4.68e-01 station=1.42e-03 dn=1.42e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.046e-05  max=2.887e-05
#   pde_Ts    : rms=5.364e-06  max=1.868e-05
#   pde_cont  : rms=1.075e-05  max=5.395e-05
#   pde_ru    : rms=4.044e-05  max=1.056e-04
#   pde_rv    : rms=8.469e-06  max=3.602e-05
#   pde_rTf   : rms=1.986e-05  max=8.413e-05
#   bc_phi    : rms=8.158e-06  max=4.280e-05
#   bc_solid  : rms=4.312e-06  max=1.079e-05
#   bc_fluid  : rms=1.051e-05  max=4.348e-05
#   iface     : rms=2.371e-05  max=7.075e-05
#   ic        : rms=1.576e-05  max=9.338e-05
# Scaled PDE RMS on obj: phi 0.061037377320970344 Ts 0.03518354845150289 cont 0.02012235353955404 ru 0.01583772738616885 rv 0.010746306286789952 rTf 0.003428098126483593
# [it=520] obj=5.423e-02 feas_raw=2.934e-10 alpha=9.73e-01 beta=4.64e-01 station=1.77e-03 dn=1.77e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.471e-05  max=6.742e-05
#   pde_Ts    : rms=7.708e-06  max=3.174e-05
#   pde_cont  : rms=1.027e-05  max=6.484e-05
#   pde_ru    : rms=4.012e-05  max=1.111e-04
#   pde_rv    : rms=8.419e-06  max=3.536e-05
#   pde_rTf   : rms=2.041e-05  max=7.870e-05
#   bc_phi    : rms=8.995e-06  max=4.151e-05
#   bc_solid  : rms=4.858e-06  max=1.352e-05
#   bc_fluid  : rms=1.168e-05  max=3.863e-05
#   iface     : rms=2.283e-05  max=7.504e-05
#   ic        : rms=1.536e-05  max=9.098e-05
# Scaled PDE RMS on obj: phi 0.06035019845151888 Ts 0.03500247348018835 cont 0.019914494298732557 ru 0.01579894584461238 rv 0.010645558353708234 rTf 0.00340892877731954
# [it=530] obj=5.342e-02 feas_raw=6.243e-09 alpha=6.59e-01 beta=4.60e-01 station=3.36e-03 dn=3.36e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.198e-04  max=1.271e-03
#   pde_Ts    : rms=4.653e-05  max=1.634e-04
#   pde_cont  : rms=3.172e-04  max=3.185e-03
#   pde_ru    : rms=3.965e-05  max=1.039e-04
#   pde_rv    : rms=1.321e-05  max=5.958e-05
#   pde_rTf   : rms=2.553e-05  max=1.472e-04
#   bc_phi    : rms=1.531e-05  max=8.501e-05
#   bc_solid  : rms=5.129e-06  max=1.634e-05
#   bc_fluid  : rms=2.818e-05  max=1.583e-04
#   iface     : rms=2.201e-05  max=6.976e-05
#   ic        : rms=1.527e-05  max=9.038e-05
# Scaled PDE RMS on obj: phi 0.059564258381126854 Ts 0.03479600725457558 cont 0.019627221005149676 ru 0.01576624112110973 rv 0.010543987957066148 rTf 0.003406538314521199
# [it=540] obj=5.260e-02 feas_raw=3.177e-10 alpha=9.57e-01 beta=4.56e-01 station=2.09e-03 dn=2.09e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.141e-05  max=8.118e-05
#   pde_Ts    : rms=6.610e-06  max=2.434e-05
#   pde_cont  : rms=3.094e-05  max=2.934e-04
#   pde_ru    : rms=3.842e-05  max=1.041e-04
#   pde_rv    : rms=8.630e-06  max=3.950e-05
#   pde_rTf   : rms=1.920e-05  max=7.410e-05
#   bc_phi    : rms=8.205e-06  max=5.015e-05
#   bc_solid  : rms=4.477e-06  max=1.633e-05
#   bc_fluid  : rms=1.126e-05  max=5.905e-05
#   iface     : rms=2.134e-05  max=6.912e-05
#   ic        : rms=1.499e-05  max=9.090e-05
# Scaled PDE RMS on obj: phi 0.05894995223058518 Ts 0.03468370598095761 cont 0.01955726646341752 ru 0.015729347726091192 rv 0.010445643342497866 rTf 0.003423197019968965
# [it=550] obj=5.180e-02 feas_raw=2.866e-10 alpha=1.04e+00 beta=4.52e-01 station=1.23e-03 dn=1.23e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.973e-05  max=1.588e-04
#   pde_Ts    : rms=7.023e-06  max=2.858e-05
#   pde_cont  : rms=1.583e-05  max=1.326e-04
#   pde_ru    : rms=3.809e-05  max=1.025e-04
#   pde_rv    : rms=7.845e-06  max=4.322e-05
#   pde_rTf   : rms=1.755e-05  max=6.422e-05
#   bc_phi    : rms=8.318e-06  max=4.029e-05
#   bc_solid  : rms=4.403e-06  max=1.684e-05
#   bc_fluid  : rms=1.021e-05  max=3.219e-05
#   iface     : rms=2.089e-05  max=7.185e-05
#   ic        : rms=1.492e-05  max=8.751e-05
# Scaled PDE RMS on obj: phi 0.05828647628205036 Ts 0.03446633947099379 cont 0.01930696990537545 ru 0.0157059591430981 rv 0.010357144299850452 rTf 0.0034202870822573443
# [it=560] obj=5.096e-02 feas_raw=2.549e-10 alpha=1.04e+00 beta=4.49e-01 station=1.57e-03 dn=1.57e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.037e-05  max=8.184e-05
#   pde_Ts    : rms=6.595e-06  max=3.180e-05
#   pde_cont  : rms=1.029e-05  max=6.262e-05
#   pde_ru    : rms=3.756e-05  max=9.774e-05
#   pde_rv    : rms=7.633e-06  max=3.631e-05
#   pde_rTf   : rms=1.753e-05  max=5.912e-05
#   bc_phi    : rms=7.083e-06  max=3.564e-05
#   bc_solid  : rms=4.354e-06  max=1.557e-05
#   bc_fluid  : rms=8.563e-06  max=2.875e-05
#   iface     : rms=2.001e-05  max=6.912e-05
#   ic        : rms=1.456e-05  max=8.697e-05
# Scaled PDE RMS on obj: phi 0.05764916624419338 Ts 0.034277510206478345 cont 0.019145698188875095 ru 0.01566797235437977 rv 0.010260729286581232 rTf 0.0034349576340858418
# [it=570] obj=5.017e-02 feas_raw=3.531e-10 alpha=9.35e-01 beta=4.45e-01 station=2.89e-03 dn=2.89e-03
# blocks (unscaled c):
#   pde_phi   : rms=2.746e-05  max=8.880e-05
#   pde_Ts    : rms=1.350e-05  max=7.001e-05
#   pde_cont  : rms=3.817e-05  max=2.668e-04
#   pde_ru    : rms=3.856e-05  max=1.008e-04
#   pde_rv    : rms=8.327e-06  max=3.744e-05
#   pde_rTf   : rms=1.842e-05  max=6.532e-05
#   bc_phi    : rms=7.825e-06  max=3.047e-05
#   bc_solid  : rms=4.347e-06  max=1.163e-05
#   bc_fluid  : rms=1.775e-05  max=5.744e-05
#   iface     : rms=1.972e-05  max=6.754e-05
#   ic        : rms=1.480e-05  max=8.569e-05
# Scaled PDE RMS on obj: phi 0.05699331651251366 Ts 0.03411031707973406 cont 0.019027090565569907 ru 0.015640247646690367 rv 0.010158164019098033 rTf 0.003431166300854895
# [it=580] obj=4.966e-02 feas_raw=2.512e-10 alpha=1.02e+00 beta=4.42e-01 station=1.91e-03 dn=1.91e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.460e-05  max=6.598e-05
#   pde_Ts    : rms=3.565e-06  max=1.041e-05
#   pde_cont  : rms=1.841e-05  max=1.487e-04
#   pde_ru    : rms=3.670e-05  max=9.512e-05
#   pde_rv    : rms=8.070e-06  max=3.797e-05
#   pde_rTf   : rms=1.695e-05  max=5.418e-05
#   bc_phi    : rms=7.693e-06  max=4.121e-05
#   bc_solid  : rms=5.427e-06  max=1.986e-05
#   bc_fluid  : rms=8.254e-06  max=2.765e-05
#   iface     : rms=1.878e-05  max=6.582e-05
#   ic        : rms=1.442e-05  max=7.965e-05
# Scaled PDE RMS on obj: phi 0.05640382784653753 Ts 0.033950315095537816 cont 0.01877750614929628 ru 0.015605476069453209 rv 0.010074351436967402 rTf 0.0034073213793480634
# [it=590] obj=4.887e-02 feas_raw=8.329e-10 alpha=8.37e-01 beta=4.39e-01 station=3.29e-03 dn=3.29e-03
# blocks (unscaled c):
#   pde_phi   : rms=9.748e-05  max=5.390e-04
#   pde_Ts    : rms=2.007e-05  max=8.473e-05
#   pde_cont  : rms=8.207e-05  max=6.273e-04
#   pde_ru    : rms=3.952e-05  max=1.447e-04
#   pde_rv    : rms=8.951e-06  max=3.531e-05
#   pde_rTf   : rms=1.955e-05  max=9.821e-05
#   bc_phi    : rms=9.007e-06  max=3.607e-05
#   bc_solid  : rms=3.810e-06  max=1.405e-05
#   bc_fluid  : rms=2.223e-05  max=1.091e-04
#   iface     : rms=1.865e-05  max=6.630e-05
#   ic        : rms=1.506e-05  max=8.144e-05
# Scaled PDE RMS on obj: phi 0.05584229900400565 Ts 0.033792088885905076 cont 0.018744919417773093 ru 0.01558603388251639 rv 0.009989363088707749 rTf 0.0034267006846644393
# [it=600] obj=4.822e-02 feas_raw=2.235e-10 alpha=1.00e+00 beta=4.35e-01 station=1.39e-03 dn=1.39e-03
# blocks (unscaled c):
#   pde_phi   : rms=5.567e-06  max=1.758e-05
#   pde_Ts    : rms=2.540e-06  max=1.209e-05
#   pde_cont  : rms=1.187e-05  max=5.507e-05
#   pde_ru    : rms=3.574e-05  max=9.517e-05
#   pde_rv    : rms=7.426e-06  max=2.998e-05
#   pde_rTf   : rms=1.638e-05  max=4.888e-05
#   bc_phi    : rms=6.777e-06  max=3.585e-05
#   bc_solid  : rms=3.732e-06  max=1.275e-05
#   bc_fluid  : rms=9.147e-06  max=3.367e-05
#   iface     : rms=1.809e-05  max=6.236e-05
#   ic        : rms=1.395e-05  max=7.611e-05
# Scaled PDE RMS on obj: phi 0.05519473734037777 Ts 0.03363579458461914 cont 0.01851380129890866 ru 0.015551956122071015 rv 0.009895582373461602 rTf 0.0034290650537440646
# [it=610] obj=4.754e-02 feas_raw=2.238e-10 alpha=9.97e-01 beta=4.32e-01 station=1.70e-03 dn=1.70e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.785e-06  max=3.865e-05
#   pde_Ts    : rms=3.315e-06  max=9.431e-06
#   pde_cont  : rms=1.164e-05  max=3.704e-05
#   pde_ru    : rms=3.532e-05  max=9.144e-05
#   pde_rv    : rms=8.500e-06  max=3.914e-05
#   pde_rTf   : rms=1.739e-05  max=5.304e-05
#   bc_phi    : rms=8.509e-06  max=4.125e-05
#   bc_solid  : rms=4.386e-06  max=1.884e-05
#   bc_fluid  : rms=9.914e-06  max=3.044e-05
#   iface     : rms=1.740e-05  max=6.410e-05
#   ic        : rms=1.381e-05  max=7.769e-05
# Scaled PDE RMS on obj: phi 0.05461891653719441 Ts 0.033458540380643345 cont 0.01830723010821198 ru 0.015523351256032521 rv 0.009809134490806356 rTf 0.0034282187613105396
# [it=620] obj=4.702e-02 feas_raw=2.138e-10 alpha=9.90e-01 beta=4.29e-01 station=1.23e-03 dn=1.23e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.332e-06  max=4.285e-05
#   pde_Ts    : rms=3.650e-06  max=1.584e-05
#   pde_cont  : rms=6.829e-06  max=3.466e-05
#   pde_ru    : rms=3.530e-05  max=9.330e-05
#   pde_rv    : rms=7.641e-06  max=3.923e-05
#   pde_rTf   : rms=1.633e-05  max=5.405e-05
#   bc_phi    : rms=7.049e-06  max=3.221e-05
#   bc_solid  : rms=3.982e-06  max=1.122e-05
#   bc_fluid  : rms=9.593e-06  max=3.551e-05
#   iface     : rms=1.704e-05  max=6.039e-05
#   ic        : rms=1.376e-05  max=7.610e-05
# Scaled PDE RMS on obj: phi 0.054124418505124915 Ts 0.03333028065354966 cont 0.018217174549928716 ru 0.015498618087716213 rv 0.009719318075095903 rTf 0.0034160170851539953
# [it=630] obj=4.643e-02 feas_raw=2.341e-10 alpha=9.83e-01 beta=4.26e-01 station=2.04e-03 dn=2.04e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.156e-05  max=4.449e-05
#   pde_Ts    : rms=3.798e-06  max=1.139e-05
#   pde_cont  : rms=1.595e-05  max=6.380e-05
#   pde_ru    : rms=3.496e-05  max=8.988e-05
#   pde_rv    : rms=7.953e-06  max=2.996e-05
#   pde_rTf   : rms=1.604e-05  max=5.129e-05
#   bc_phi    : rms=7.650e-06  max=3.045e-05
#   bc_solid  : rms=3.721e-06  max=9.774e-06
#   bc_fluid  : rms=1.429e-05  max=6.049e-05
#   iface     : rms=1.657e-05  max=5.802e-05
#   ic        : rms=1.404e-05  max=7.701e-05
# ...
#   iface     : rms=3.936e-06  max=1.978e-05
#   ic        : rms=4.825e-06  max=2.151e-05
# Scaled PDE RMS on obj: phi 0.02155425459209907 Ts 0.014787809288195695 cont 0.00856997447924624 ru 0.005017626528087334 rv 0.0023946355585959906 rTf 0.004752956908549893
# [it=9810] obj=6.863e-03 feas_raw=7.139e-11 alpha=9.22e-01 beta=9.56e-02 station=6.43e-04 dn=6.43e-04
# blocks (unscaled c):
#   pde_phi   : rms=4.451e-05  max=3.089e-04
#   pde_Ts    : rms=4.816e-06  max=1.307e-05
#   pde_cont  : rms=3.750e-06  max=3.053e-05
#   pde_ru    : rms=9.976e-06  max=3.442e-05
#   pde_rv    : rms=4.753e-06  max=2.715e-05
#   pde_rTf   : rms=4.821e-06  max=2.378e-05
#   bc_phi    : rms=1.997e-06  max=7.652e-06
#   bc_solid  : rms=1.041e-06  max=3.014e-06
#   bc_fluid  : rms=5.246e-06  max=3.036e-05
#   iface     : rms=3.859e-06  max=2.018e-05
#   ic        : rms=4.827e-06  max=2.215e-05
# Scaled PDE RMS on obj: phi 0.021587685101095416 Ts 0.014790269875216654 cont 0.008571856250041483 ru 0.005009932999297299 rv 0.0023932773315131755 rTf 0.004746817558248168
# [it=9820] obj=6.844e-03 feas_raw=4.438e-10 alpha=5.72e-01 beta=9.55e-02 station=7.26e-04 dn=7.26e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.167e-04  max=4.507e-04
#   pde_Ts    : rms=2.433e-05  max=1.009e-04
#   pde_cont  : rms=3.012e-05  max=3.049e-04
#   pde_ru    : rms=1.070e-05  max=3.424e-05
#   pde_rv    : rms=5.230e-06  max=2.588e-05
#   pde_rTf   : rms=1.473e-05  max=1.310e-04
#   bc_phi    : rms=8.702e-06  max=5.375e-05
#   bc_solid  : rms=1.237e-06  max=4.003e-06
#   bc_fluid  : rms=2.102e-05  max=1.564e-04
#   iface     : rms=3.955e-06  max=1.952e-05
#   ic        : rms=4.826e-06  max=2.193e-05
# Scaled PDE RMS on obj: phi 0.021540271699753085 Ts 0.014790118283549945 cont 0.008556901788275636 ru 0.005007687791314869 rv 0.0023919483416176197 rTf 0.004745904991668848
# [it=9830] obj=6.839e-03 feas_raw=3.709e-11 alpha=9.21e-01 beta=9.55e-02 station=6.21e-04 dn=6.21e-04
# blocks (unscaled c):
#   pde_phi   : rms=2.081e-05  max=9.460e-05
#   pde_Ts    : rms=5.362e-06  max=1.922e-05
#   pde_cont  : rms=5.352e-06  max=4.158e-05
#   pde_ru    : rms=1.004e-05  max=3.486e-05
#   pde_rv    : rms=4.744e-06  max=2.714e-05
#   pde_rTf   : rms=4.604e-06  max=2.307e-05
#   bc_phi    : rms=2.029e-06  max=7.470e-06
#   bc_solid  : rms=1.577e-06  max=8.373e-06
#   bc_fluid  : rms=7.607e-06  max=5.032e-05
#   iface     : rms=3.908e-06  max=2.069e-05
#   ic        : rms=4.835e-06  max=2.193e-05
# Scaled PDE RMS on obj: phi 0.021556710049850072 Ts 0.01477690031820056 cont 0.008569080186310639 ru 0.004996767000031657 rv 0.00239334627699691 rTf 0.004740632653004554
# [it=9840] obj=6.834e-03 feas_raw=2.222e-10 alpha=7.60e-01 beta=9.54e-02 station=6.73e-04 dn=6.73e-04
# blocks (unscaled c):
#   pde_phi   : rms=8.442e-05  max=3.763e-04
#   pde_Ts    : rms=1.533e-05  max=7.210e-05
#   pde_cont  : rms=8.944e-06  max=3.479e-05
#   pde_ru    : rms=1.005e-05  max=3.635e-05
#   pde_rv    : rms=5.033e-06  max=2.636e-05
#   pde_rTf   : rms=5.931e-06  max=2.279e-05
#   bc_phi    : rms=5.012e-06  max=3.223e-05
#   bc_solid  : rms=1.160e-06  max=4.782e-06
#   bc_fluid  : rms=1.802e-05  max=1.973e-04
#   iface     : rms=3.884e-06  max=2.035e-05
#   ic        : rms=4.823e-06  max=2.088e-05
# Scaled PDE RMS on obj: phi 0.02155435857709071 Ts 0.014776994366818588 cont 0.008558049172264652 ru 0.004998376484187506 rv 0.002390961846341653 rTf 0.004743720236506459
# [it=9850] obj=6.826e-03 feas_raw=6.997e-11 alpha=8.36e-01 beta=9.53e-02 station=6.23e-04 dn=6.23e-04
# blocks (unscaled c):
#   pde_phi   : rms=4.104e-05  max=1.973e-04
#   pde_Ts    : rms=6.989e-06  max=1.910e-05
#   pde_cont  : rms=7.597e-06  max=5.985e-05
#   pde_ru    : rms=1.009e-05  max=3.431e-05
#   pde_rv    : rms=4.805e-06  max=2.803e-05
#   pde_rTf   : rms=5.634e-06  max=2.511e-05
#   bc_phi    : rms=2.827e-06  max=1.506e-05
#   bc_solid  : rms=2.001e-06  max=1.060e-05
#   bc_fluid  : rms=8.018e-06  max=3.688e-05
#   iface     : rms=3.855e-06  max=2.058e-05
#   ic        : rms=4.834e-06  max=2.193e-05
# Scaled PDE RMS on obj: phi 0.021544758347477645 Ts 0.014776561202844207 cont 0.008559555706263045 ru 0.0049875992911062135 rv 0.0023908642065023065 rTf 0.004742579506619962
# [it=9860] obj=6.819e-03 feas_raw=5.737e-10 alpha=5.71e-01 beta=9.53e-02 station=8.21e-04 dn=8.21e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.380e-04  max=7.453e-04
#   pde_Ts    : rms=2.598e-05  max=1.357e-04
#   pde_cont  : rms=3.546e-05  max=3.373e-04
#   pde_ru    : rms=1.028e-05  max=3.281e-05
#   pde_rv    : rms=6.007e-06  max=2.764e-05
#   pde_rTf   : rms=1.094e-05  max=7.148e-05
#   bc_phi    : rms=6.863e-06  max=2.659e-05
#   bc_solid  : rms=2.888e-06  max=1.712e-05
#   bc_fluid  : rms=1.571e-05  max=8.626e-05
#   iface     : rms=3.916e-06  max=1.980e-05
#   ic        : rms=4.815e-06  max=2.112e-05
# Scaled PDE RMS on obj: phi 0.021539251896360214 Ts 0.01475481528592534 cont 0.008549705618154074 ru 0.004987122969324803 rv 0.0023920212942692047 rTf 0.00473474615405381
# [it=9870] obj=6.819e-03 feas_raw=3.255e-10 alpha=6.90e-01 beta=9.52e-02 station=8.01e-04 dn=8.01e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.052e-04  max=5.335e-04
#   pde_Ts    : rms=2.225e-05  max=8.766e-05
#   pde_cont  : rms=1.909e-05  max=1.641e-04
#   pde_ru    : rms=9.981e-06  max=3.503e-05
#   pde_rv    : rms=5.497e-06  max=3.258e-05
#   pde_rTf   : rms=6.598e-06  max=2.747e-05
#   bc_phi    : rms=4.044e-06  max=2.126e-05
#   bc_solid  : rms=2.229e-06  max=1.342e-05
#   bc_fluid  : rms=1.221e-05  max=6.139e-05
#   iface     : rms=3.842e-06  max=2.000e-05
#   ic        : rms=4.822e-06  max=2.136e-05
# Scaled PDE RMS on obj: phi 0.02155747853660158 Ts 0.014762414262518843 cont 0.008556556018256528 ru 0.004977322738688531 rv 0.002388627073389013 rTf 0.004726468764897155
# [it=9880] obj=6.810e-03 feas_raw=3.057e-10 alpha=5.18e-01 beta=9.52e-02 station=1.21e-03 dn=1.21e-03
# blocks (unscaled c):
#   pde_phi   : rms=8.107e-05  max=2.394e-04
#   pde_Ts    : rms=2.431e-05  max=8.164e-05
#   pde_cont  : rms=2.970e-05  max=2.539e-04
#   pde_ru    : rms=1.175e-05  max=5.539e-05
#   pde_rv    : rms=6.664e-06  max=3.153e-05
#   pde_rTf   : rms=2.183e-05  max=2.211e-04
#   bc_phi    : rms=1.030e-05  max=6.016e-05
#   bc_solid  : rms=1.201e-06  max=3.831e-06
#   bc_fluid  : rms=2.668e-05  max=2.234e-04
#   iface     : rms=3.922e-06  max=2.019e-05
#   ic        : rms=4.807e-06  max=2.251e-05
# Scaled PDE RMS on obj: phi 0.021547985019294988 Ts 0.014756805307459315 cont 0.008545484302506545 ru 0.004972883971076403 rv 0.0023927304329414904 rTf 0.004734217339034199
# [it=9890] obj=6.795e-03 feas_raw=1.341e-09 alpha=5.70e-01 beta=9.51e-02 station=9.43e-04 dn=9.43e-04
# blocks (unscaled c):
#   pde_phi   : rms=2.238e-04  max=1.441e-03
#   pde_Ts    : rms=3.238e-05  max=1.812e-04
#   pde_cont  : rms=1.714e-05  max=8.504e-05
#   pde_ru    : rms=1.024e-05  max=3.357e-05
#   pde_rv    : rms=6.187e-06  max=2.959e-05
#   pde_rTf   : rms=8.906e-06  max=4.745e-05
#   bc_phi    : rms=6.988e-06  max=3.880e-05
#   bc_solid  : rms=1.138e-06  max=3.394e-06
#   bc_fluid  : rms=3.607e-05  max=3.663e-04
#   iface     : rms=3.913e-06  max=2.026e-05
#   ic        : rms=4.817e-06  max=2.207e-05
# Scaled PDE RMS on obj: phi 0.02153512706707951 Ts 0.014751508000142308 cont 0.008535344716933832 ru 0.0049718891762992705 rv 0.00238893624497513 rTf 0.004732101064661856
# [it=9900] obj=6.795e-03 feas_raw=7.388e-10 alpha=5.17e-01 beta=9.51e-02 station=8.66e-04 dn=8.66e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.551e-04  max=7.679e-04
#   pde_Ts    : rms=2.722e-05  max=1.080e-04
#   pde_cont  : rms=3.636e-05  max=3.668e-04
#   pde_ru    : rms=1.009e-05  max=3.529e-05
#   pde_rv    : rms=5.836e-06  max=2.788e-05
#   pde_rTf   : rms=1.107e-05  max=7.059e-05
#   bc_phi    : rms=1.061e-05  max=5.479e-05
#   bc_solid  : rms=2.172e-06  max=1.231e-05
#   bc_fluid  : rms=2.947e-05  max=3.082e-04
#   iface     : rms=3.875e-06  max=2.081e-05
#   ic        : rms=4.799e-06  max=2.197e-05
# Scaled PDE RMS on obj: phi 0.021510023101093168 Ts 0.014744826714944906 cont 0.008529130883746893 ru 0.00496820289372856 rv 0.0023904844917212735 rTf 0.004723062382829002
# [it=9910] obj=6.804e-03 feas_raw=3.583e-11 alpha=9.16e-01 beta=9.50e-02 station=6.25e-04 dn=6.25e-04
# blocks (unscaled c):
#   pde_phi   : rms=2.164e-05  max=1.027e-04
#   pde_Ts    : rms=5.907e-06  max=2.163e-05
#   pde_cont  : rms=5.647e-06  max=4.041e-05
#   pde_ru    : rms=9.920e-06  max=3.233e-05
#   pde_rv    : rms=4.902e-06  max=2.621e-05
#   pde_rTf   : rms=4.379e-06  max=2.327e-05
#   bc_phi    : rms=2.269e-06  max=1.029e-05
#   bc_solid  : rms=6.340e-07  max=2.213e-06
#   bc_fluid  : rms=4.812e-06  max=2.851e-05
#   iface     : rms=3.892e-06  max=2.006e-05
#   ic        : rms=4.799e-06  max=2.152e-05
# Scaled PDE RMS on obj: phi 0.02159024217068428 Ts 0.01474607406687563 cont 0.008530651486345285 ru 0.004962580647128015 rv 0.002389443581254823 rTf 0.0047258251945555465
# [it=9920] obj=6.779e-03 feas_raw=5.376e-10 alpha=5.17e-01 beta=9.50e-02 station=8.22e-04 dn=8.22e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.119e-04  max=5.378e-04
#   pde_Ts    : rms=4.201e-05  max=1.873e-04
#   pde_cont  : rms=3.994e-05  max=3.803e-04
#   pde_ru    : rms=1.212e-05  max=7.406e-05
#   pde_rv    : rms=6.346e-06  max=2.916e-05
#   pde_rTf   : rms=2.814e-05  max=2.919e-04
#   bc_phi    : rms=7.256e-06  max=3.620e-05
#   bc_solid  : rms=2.865e-06  max=1.675e-05
#   bc_fluid  : rms=3.144e-05  max=3.298e-04
#   iface     : rms=3.880e-06  max=2.057e-05
#   ic        : rms=4.796e-06  max=2.189e-05
# Scaled PDE RMS on obj: phi 0.02149906935653604 Ts 0.014736362640986746 cont 0.008522825107641688 ru 0.00495703106893185 rv 0.002386975666624303 rTf 0.0047247661365851495
# [it=9930] obj=6.780e-03 feas_raw=3.372e-10 alpha=6.25e-01 beta=9.49e-02 station=7.81e-04 dn=7.81e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.041e-04  max=4.151e-04
#   pde_Ts    : rms=2.082e-05  max=8.891e-05
#   pde_cont  : rms=2.313e-05  max=1.960e-04
#   pde_ru    : rms=1.014e-05  max=3.439e-05
#   pde_rv    : rms=5.485e-06  max=2.618e-05
#   pde_rTf   : rms=9.485e-06  max=5.645e-05
#   bc_phi    : rms=6.533e-06  max=2.886e-05
#   bc_solid  : rms=1.328e-06  max=4.080e-06
#   bc_fluid  : rms=1.631e-05  max=7.597e-05
#   iface     : rms=3.821e-06  max=2.020e-05
#   ic        : rms=4.795e-06  max=2.107e-05
# Scaled PDE RMS on obj: phi 0.021518422399920915 Ts 0.014740475192197327 cont 0.008519251735792752 ru 0.004952823849908449 rv 0.0023890714948118195 rTf 0.0047313384571065
# [it=9940] obj=6.779e-03 feas_raw=2.100e-10 alpha=6.87e-01 beta=9.48e-02 station=7.14e-04 dn=7.14e-04
# blocks (unscaled c):
#   pde_phi   : rms=7.879e-05  max=3.130e-04
#   pde_Ts    : rms=2.253e-05  max=9.931e-05
#   pde_cont  : rms=1.199e-05  max=6.353e-05
#   pde_ru    : rms=1.010e-05  max=3.467e-05
#   pde_rv    : rms=5.582e-06  max=2.926e-05
#   pde_rTf   : rms=7.881e-06  max=4.265e-05
#   bc_phi    : rms=5.201e-06  max=2.856e-05
#   bc_solid  : rms=1.615e-06  max=8.536e-06
#   bc_fluid  : rms=1.740e-05  max=1.317e-04
#   iface     : rms=3.870e-06  max=1.994e-05
#   ic        : rms=4.801e-06  max=2.093e-05
# Scaled PDE RMS on obj: phi 0.021516943461732416 Ts 0.014733724451787509 cont 0.008519245007224292 ru 0.004948626911797131 rv 0.00238924113477721 rTf 0.004723906623773415
# [it=9950] obj=6.771e-03 feas_raw=7.119e-10 alpha=4.69e-01 beta=9.48e-02 station=9.12e-04 dn=9.12e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.537e-04  max=8.255e-04
#   pde_Ts    : rms=3.596e-05  max=1.720e-04
#   pde_cont  : rms=3.365e-05  max=3.026e-04
#   pde_ru    : rms=1.100e-05  max=4.473e-05
#   pde_rv    : rms=6.024e-06  max=2.967e-05
#   pde_rTf   : rms=9.652e-06  max=4.976e-05
#   bc_phi    : rms=9.472e-06  max=4.863e-05
#   bc_solid  : rms=2.502e-06  max=1.199e-05
#   bc_fluid  : rms=2.354e-05  max=1.240e-04
#   iface     : rms=3.841e-06  max=2.032e-05
#   ic        : rms=4.798e-06  max=2.186e-05
# Scaled PDE RMS on obj: phi 0.02150819470879419 Ts 0.014726652590865466 cont 0.008515867185400077 ru 0.00494599372468325 rv 0.002389096866259237 rTf 0.0047257531358499485
# [it=9960] obj=6.763e-03 feas_raw=7.499e-10 alpha=5.16e-01 beta=9.47e-02 station=1.30e-03 dn=1.30e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.615e-04  max=6.498e-04
#   pde_Ts    : rms=3.760e-05  max=1.523e-04
#   pde_cont  : rms=2.746e-05  max=2.615e-04
#   pde_ru    : rms=1.028e-05  max=3.385e-05
#   pde_rv    : rms=6.379e-06  max=2.809e-05
#   pde_rTf   : rms=1.207e-05  max=6.727e-05
#   bc_phi    : rms=8.073e-06  max=7.192e-05
#   bc_solid  : rms=4.708e-06  max=2.872e-05
#   bc_fluid  : rms=2.083e-05  max=1.349e-04
#   iface     : rms=3.902e-06  max=2.058e-05
#   ic        : rms=4.790e-06  max=2.216e-05
# Scaled PDE RMS on obj: phi 0.0215148753870334 Ts 0.014723732245023963 cont 0.008517721493999092 ru 0.004934068155286073 rv 0.0023861982378536794 rTf 0.00472059949489904
# [it=9970] obj=6.761e-03 feas_raw=9.102e-10 alpha=6.24e-01 beta=9.47e-02 station=1.01e-03 dn=1.01e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.806e-04  max=9.752e-04
#   pde_Ts    : rms=2.636e-05  max=1.253e-04
#   pde_cont  : rms=2.132e-05  max=1.984e-04
#   pde_ru    : rms=1.016e-05  max=3.283e-05
#   pde_rv    : rms=5.526e-06  max=2.762e-05
#   pde_rTf   : rms=9.073e-06  max=7.104e-05
#   bc_phi    : rms=5.569e-06  max=3.107e-05
#   bc_solid  : rms=3.233e-06  max=1.894e-05
#   bc_fluid  : rms=3.353e-05  max=3.735e-04
#   iface     : rms=3.829e-06  max=1.978e-05
#   ic        : rms=4.805e-06  max=2.202e-05
# Scaled PDE RMS on obj: phi 0.02153199282084287 Ts 0.014720399087856745 cont 0.008507433424757918 ru 0.004936696654080926 rv 0.002388414312446683 rTf 0.004712653429752981
# [it=9980] obj=6.750e-03 feas_raw=7.313e-10 alpha=5.15e-01 beta=9.46e-02 station=1.50e-03 dn=1.50e-03
# blocks (unscaled c):
#   pde_phi   : rms=1.594e-04  max=7.265e-04
#   pde_Ts    : rms=3.196e-05  max=1.547e-04
#   pde_cont  : rms=3.009e-05  max=2.290e-04
#   pde_ru    : rms=1.021e-05  max=3.448e-05
#   pde_rv    : rms=5.786e-06  max=2.737e-05
#   pde_rTf   : rms=8.430e-06  max=3.789e-05
#   bc_phi    : rms=9.225e-06  max=7.531e-05
#   bc_solid  : rms=1.489e-06  max=5.592e-06
#   bc_fluid  : rms=2.211e-05  max=1.240e-04
#   iface     : rms=3.839e-06  max=2.033e-05
#   ic        : rms=4.800e-06  max=2.209e-05
# Scaled PDE RMS on obj: phi 0.02147529562534611 Ts 0.014714675259692191 cont 0.008504411553058694 ru 0.0049339952255848885 rv 0.0023893354982097294 rTf 0.004718443396026208
# [it=9990] obj=6.739e-03 feas_raw=5.999e-11 alpha=8.29e-01 beta=9.46e-02 station=6.08e-04 dn=6.08e-04
# blocks (unscaled c):
#   pde_phi   : rms=3.453e-05  max=1.674e-04
#   pde_Ts    : rms=1.149e-05  max=4.995e-05
#   pde_cont  : rms=7.965e-06  max=6.389e-05
#   pde_ru    : rms=9.912e-06  max=3.409e-05
#   pde_rv    : rms=4.957e-06  max=2.768e-05
#   pde_rTf   : rms=5.060e-06  max=2.374e-05
#   bc_phi    : rms=3.908e-06  max=2.163e-05
#   bc_solid  : rms=1.614e-06  max=9.187e-06
#   bc_fluid  : rms=7.753e-06  max=4.023e-05
#   iface     : rms=3.893e-06  max=2.049e-05
#   ic        : rms=4.788e-06  max=2.140e-05
# Scaled PDE RMS on obj: phi 0.02145741838050953 Ts 0.014713666189536817 cont 0.008499116385935987 ru 0.004924105831465066 rv 0.0023864453649960846 rTf 0.004720186784736014
# [it=10000] obj=6.747e-03 feas_raw=3.350e-10 alpha=6.22e-01 beta=9.45e-02 station=8.60e-04 dn=8.60e-04
# blocks (unscaled c):
#   pde_phi   : rms=1.063e-04  max=5.238e-04
#   pde_Ts    : rms=2.450e-05  max=1.053e-04
#   pde_cont  : rms=1.299e-05  max=7.567e-05
#   pde_ru    : rms=1.010e-05  max=3.427e-05
#   pde_rv    : rms=5.553e-06  max=2.858e-05
#   pde_rTf   : rms=6.737e-06  max=3.417e-05
#   bc_phi    : rms=6.262e-06  max=3.960e-05
#   bc_solid  : rms=4.014e-06  max=2.451e-05
#   bc_fluid  : rms=1.727e-05  max=8.477e-05
#   iface     : rms=3.821e-06  max=2.075e-05
#   ic        : rms=4.782e-06  max=2.254e-05
# Scaled PDE RMS on obj: phi 0.02150822730366504 Ts 0.01470446547307421 cont 0.008485974152359181 ru 0.004926237928331524 rv 0.002389528887959718 rTf 0.004716412678752127
# [done] elapsed=21531.76s
# Saved theta -> theta_sqp_pinn_clean.npy
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pkill -9 -u $(whoami) python
