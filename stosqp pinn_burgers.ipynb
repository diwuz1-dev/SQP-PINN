# %%
# ================================
# Stochastic SQP-PINN (JAX) - POINTWISE (SIGNED) constraints
# + "HOLD K steps per sample" AND "JITTER every iteration"
#
# Goal:
#   - You can hold the BASE collocation points for many iterations (hold_con_K large),
#     BUT each iteration you apply fresh random perturbations:
#         (x,t) -> (x + noise_x, t + noise_t)
#     so constraints remain stochastic and you don't memorize fixed points.
#
# Jitter:
#   - kind="gaussian" or "uniform"
#   - optional clipped Gaussian: clip noise to [-k*sigma, +k*sigma]
#   - always clip final points to the domain
#
# Constraints:
#   POINTWISE / BIN-WISE SIGNED MEANS (not RMS):
#     PDE cell k:    mean_cell[r(x,t)]  (N=1 => pointwise)
#     BC bin j:      mean_bin[uL-uR], mean_bin[uxL-uxR]
#     IC bin j:      mean_bin[u(x,0)-u0(x)]
#
# Scaling:
#   - Objective: fixed anchor scaling at theta0
#   - Constraints: scalar RMS+EMA scaling on ||J||_rms
#   - LM invariance: lam_eff = lam*(s_con^2)
#
# IMPORTANT: lambda bounds fixed in cal_d_and_y:
#   lam_min=1e-2, lam_max=1
# ================================

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# 0 = disable autotune (fastest compile), 1 = light autotune, 2 = default-ish
os.environ["XLA_FLAGS"] = "--xla_gpu_autotune_level=0"

# reduce noisy logs (optional)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"


import time, math
from functools import partial
import numpy as np
import scipy.io

import jax
jax.config.update("jax_default_matmul_precision", "tensorfloat32")  # fastest on NVIDIA
# or if you want safer numerics:
# jax.config.update("jax_default_matmul_precision", "highest")

import jax.numpy as jnp
from jax import random, grad, vmap, hessian

# -----------------------------
# Precision
# -----------------------------
USE_X64 = True
jax.config.update("jax_enable_x64", USE_X64)
DTYPE = jnp.float64 if USE_X64 else jnp.float32
EPS = 1e-12

# -----------------------------
# Batch sizes / region structure
# -----------------------------
B_DATA = 0

# PDE cells
NX_PDE_MOM = 30
NT_PDE_MOM = 30
K_PDE = NX_PDE_MOM * NT_PDE_MOM
N_PDE_PER_CELL = 1
B_F_TOTAL = K_PDE * N_PDE_PER_CELL

# BC bins
K_BC = 100
N_BC_PER_BIN = 1
B_BC_TOTAL = K_BC * N_BC_PER_BIN

# IC bins
K_IC = 200
N_IC_PER_BIN = 1
B_IC_TOTAL = K_IC * N_IC_PER_BIN

M_CON = K_PDE + 2 * K_BC + K_IC

# -----------------------------
# PDE Objective sampling (separate from constraints)
# -----------------------------
NX_PDE_OBJ = 80
NT_PDE_OBJ = 80
K_PDE_OBJ = NX_PDE_OBJ * NT_PDE_OBJ   # 3200 base points (1 per cell)


# -----------------------------
# 1) MLP
# -----------------------------
def init_mlp_params(key, layer_sizes):
    params = []
    keys = random.split(key, len(layer_sizes) - 1)
    for k, (m, n) in zip(keys, zip(layer_sizes[:-1], layer_sizes[1:])):
        W = random.normal(k, (m, n), dtype=DTYPE) * jnp.sqrt(DTYPE(2.0) / DTYPE(m))
        b = jnp.zeros((n,), dtype=DTYPE)
        params.append({"W": W, "b": b})
    return params


def mlp_apply(params, x):
    h = x
    for i, layer in enumerate(params):
        W, b = layer["W"], layer["b"]
        h = h @ W + b
        if i < len(params) - 1:
            h = jnp.tanh(h)
    return h  # (N,1)


# -----------------------------
# 2) Flatten/unflatten
# -----------------------------
def flatten_params(params):
    flat_parts = []
    shapes = []
    for layer in params:
        W, b = layer["W"], layer["b"]
        flat_parts.append(W.reshape(-1))
        flat_parts.append(b.reshape(-1))
        shapes.append((W.shape, b.shape))
    theta = jnp.concatenate(flat_parts).astype(DTYPE)
    return theta, tuple(shapes)


def unflatten_params(theta, shapes):
    params = []
    idx = 0
    for W_shape, b_shape in shapes:
        W_size = math.prod(W_shape)
        b_size = math.prod(b_shape)
        W = theta[idx: idx + W_size].reshape(W_shape); idx += W_size
        b = theta[idx: idx + b_size].reshape(b_shape); idx += b_size
        params.append({"W": W, "b": b})
    return params


# -----------------------------
# 3) Load burgers.mat
# -----------------------------
def load_burgers_mat(path):
    d = scipy.io.loadmat(path)
    t = d["t"].squeeze()
    x = d["x"].squeeze()
    usol = d["usol"]  # (nt, nx)
    nu = float(np.array(d["nu"]).squeeze())
    return t, x, usol, nu


def build_full_data_points(t_np, x_np, usol_np):
    T, X = np.meshgrid(t_np, x_np, indexing="ij")
    X_data = np.stack([X.reshape(-1), T.reshape(-1)], 1)
    u_data = usol_np.reshape(-1)
    return X_data, u_data


# -----------------------------
# 4) Sampling utilities
# -----------------------------
def sample_data_batch(key, X_data, u_data, B):
    N = X_data.shape[0]
    idx = random.randint(key, (B,), 0, N)
    return X_data[idx], u_data[idx]


def segment_sum(values, segment_ids, num_segments):
    out = jnp.zeros((num_segments,), dtype=values.dtype)
    return out.at[segment_ids].add(values)

def sample_pde_obj_base_stratified(key, x_min, x_max, t_min, t_max):
    """
    Returns base points X_base of shape (K_PDE_OBJ, 2), one point per cell
    on an NX_PDE_OBJ x NT_PDE_OBJ partition.
    """
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_OBJ)
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_OBJ)

    it, ix = jnp.meshgrid(
        jnp.arange(NT_PDE_OBJ),
        jnp.arange(NX_PDE_OBJ),
        indexing="ij"
    )
    it = it.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)

    x0 = DTYPE(x_min) + DTYPE(ix) * dx
    t0 = DTYPE(t_min) + DTYPE(it) * dt

    u = random.uniform(key, (K_PDE_OBJ, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = x0 + u[:, 0] * dx
    ts = t0 + u[:, 1] * dt
    return jnp.stack([xs, ts], axis=1)  # (K_PDE_OBJ, 2)


def sample_pde_stratified(key, x_min, x_max, t_min, t_max):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(NX_PDE_MOM)
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(NT_PDE_MOM)

    it, ix = jnp.meshgrid(
        jnp.arange(NT_PDE_MOM),
        jnp.arange(NX_PDE_MOM),
        indexing="ij"
    )
    it = it.reshape(-1).astype(jnp.int32)
    ix = ix.reshape(-1).astype(jnp.int32)
    ids_cell = (it * NX_PDE_MOM + ix).astype(jnp.int32)

    x0 = DTYPE(x_min) + DTYPE(ix) * dx
    t0 = DTYPE(t_min) + DTYPE(it) * dt

    u = random.uniform(key, (K_PDE, N_PDE_PER_CELL, 2), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = x0[:, None] + u[:, :, 0] * dx
    ts = t0[:, None] + u[:, :, 1] * dt

    X_f = jnp.stack([xs, ts], axis=-1).reshape(-1, 2)
    ids = jnp.repeat(ids_cell, N_PDE_PER_CELL)
    return X_f, ids


def sample_bc_stratified(key, x_min, x_max, t_min, t_max):
    dt = (DTYPE(t_max) - DTYPE(t_min)) / DTYPE(K_BC)
    j = jnp.arange(K_BC, dtype=jnp.int32)
    t0 = DTYPE(t_min) + DTYPE(j) * dt

    u = random.uniform(key, (K_BC, N_BC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    ts = (t0[:, None] + u * dt).reshape(-1, 1)
    ids = jnp.repeat(j, N_BC_PER_BIN)

    XL = jnp.concatenate([DTYPE(x_min) * jnp.ones_like(ts), ts], axis=1)
    XR = jnp.concatenate([DTYPE(x_max) * jnp.ones_like(ts), ts], axis=1)
    return XL, XR, ids


def sample_ic_stratified(key, x_min, x_max, t0, x_grid, u0_grid):
    dx = (DTYPE(x_max) - DTYPE(x_min)) / DTYPE(K_IC)
    j = jnp.arange(K_IC, dtype=jnp.int32)
    x0 = DTYPE(x_min) + DTYPE(j) * dx

    u = random.uniform(key, (K_IC, N_IC_PER_BIN), minval=0.0, maxval=1.0, dtype=DTYPE)
    xs = (x0[:, None] + u * dx).reshape(-1, 1)
    ids = jnp.repeat(j, N_IC_PER_BIN)

    Xic = jnp.concatenate([xs, DTYPE(t0) * jnp.ones_like(xs)], axis=1)
    u0 = jnp.interp(xs[:, 0], x_grid, u0_grid)
    return Xic, u0, ids


# -----------------------------
# 4.5) Jitter (x,t) -> (x+noise, t+noise)
# -----------------------------
def jitter_points(key, X, x_min, x_max, t_min, t_max,
                  sigma_x, sigma_t,
                  kind="gaussian",
                  clip_k=None):
    """
    X: (N,2) [x,t]
    kind:
      - "gaussian": dx ~ N(0, sigma_x^2), dt ~ N(0, sigma_t^2)
      - "uniform":  dx ~ U[-sigma_x, +sigma_x], dt ~ U[-sigma_t, +sigma_t]
    clip_k:
      - if not None and kind=="gaussian", clip dx,dt to [-k*sigma, +k*sigma] before adding.
    Always clips final (x,t) to domain.
    """
    if (sigma_x <= 0.0) and (sigma_t <= 0.0):
        return X

    key, kx, kt = random.split(key, 3)

    if kind == "gaussian":
        dx = DTYPE(sigma_x) * random.normal(kx, (X.shape[0],), dtype=DTYPE)
        dt = DTYPE(sigma_t) * random.normal(kt, (X.shape[0],), dtype=DTYPE)
        if clip_k is not None:
            k = DTYPE(clip_k)
            if sigma_x > 0:
                dx = jnp.clip(dx, -k * DTYPE(sigma_x), +k * DTYPE(sigma_x))
            if sigma_t > 0:
                dt = jnp.clip(dt, -k * DTYPE(sigma_t), +k * DTYPE(sigma_t))
    elif kind == "uniform":
        dx = DTYPE(sigma_x) * (2.0 * random.uniform(kx, (X.shape[0],), dtype=DTYPE) - 1.0)
        dt = DTYPE(sigma_t) * (2.0 * random.uniform(kt, (X.shape[0],), dtype=DTYPE) - 1.0)
    else:
        raise ValueError("kind must be 'gaussian' or 'uniform'")

    x = jnp.clip(X[:, 0] + dx, DTYPE(x_min), DTYPE(x_max))
    t = jnp.clip(X[:, 1] + dt, DTYPE(t_min), DTYPE(t_max))
    return jnp.stack([x, t], axis=1)
def pde_mse_on_points(theta, shapes, X_pts, nu):
    params = unflatten_params(theta, shapes)
    r = pde_residual_unscaled(params, X_pts, nu)
    return jnp.mean(r**2)

# -----------------------------
# 5) PDE residual
# -----------------------------
def pde_residual_unscaled(params, X_f, nu):
    def u_fun(xt):
        return mlp_apply(params, xt[None, :])[0, 0]

    u = vmap(u_fun)(X_f)
    du = vmap(grad(u_fun))(X_f)
    H = vmap(hessian(u_fun))(X_f)

    u_x = du[:, 0]
    u_t = du[:, 1]
    u_xx = H[:, 0, 0]
    return u_t + u * u_x - DTYPE(nu) * u_xx


# -----------------------------
# 6) Objective: data MSE + anchor scaling
# -----------------------------
def data_mse_unscaled(params, Xb, ub):
    pred = mlp_apply(params, Xb)[:, 0]
    return jnp.mean((pred - ub) ** 2)


@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_data_scaled_batch(theta, shapes, Xb, ub, scale_obj):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        return data_mse_unscaled(params, Xb, ub)

    val, g = jax.value_and_grad(obj_theta)(theta)
    return scale_obj * val, scale_obj * g


def compute_scale_obj_data_anchor(theta0, shapes, X_anchor, u_anchor, target=100.0):
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        return data_mse_unscaled(params, X_anchor, u_anchor)

    g0 = grad(obj_theta)(theta0)
    ginf = jnp.linalg.norm(g0, jnp.inf)
    return (DTYPE(target) / jnp.maximum(DTYPE(target), ginf + DTYPE(EPS))).astype(DTYPE)

@partial(jax.jit, static_argnames=("shapes",))
def F_and_g_pde_obj(theta, shapes, X_obj, nu, w_pde):
    """
    PDE objective: w_pde * mean( r(x,t)^2 ) evaluated on X_obj
    """
    def obj_theta(th):
        params = unflatten_params(th, shapes)
        r = pde_residual_unscaled(params, X_obj, nu)
        return DTYPE(w_pde) * jnp.mean(r**2)

    val, g = jax.value_and_grad(obj_theta)(theta)
    return val, g

# -----------------------------
# 7) BC helper u, ux
# -----------------------------
@jax.jit
def u_and_ux(params, X):
    def u_fun(xt):
        return mlp_apply(params, xt[None, :])[0, 0]

    u = vmap(u_fun)(X)
    du = vmap(grad(u_fun))(X)
    ux = du[:, 0]
    return u, ux


# -----------------------------
# 8) POINTWISE/SIGNED constraints + Jacobian
# -----------------------------
@partial(jax.jit, static_argnames=("shapes",))
def constraint_vector_cells_unscaled(theta, shapes,
                                     X_f, ids_f,
                                     X_bc_L, X_bc_R, ids_bc,
                                     X_ic, u0_ic, ids_ic,
                                     nu):
    params = unflatten_params(theta, shapes)

    # PDE signed residual (pointwise if N=1)
    r = pde_residual_unscaled(params, X_f, nu)
    c_pde = segment_sum(r, ids_f, K_PDE) / DTYPE(N_PDE_PER_CELL)

    # BC signed differences
    uL, uxL = u_and_ux(params, X_bc_L)
    uR, uxR = u_and_ux(params, X_bc_R)
    dv = (uL - uR)
    dd = (uxL - uxR)
    c_bc_val = segment_sum(dv, ids_bc, K_BC) / DTYPE(N_BC_PER_BIN)
    c_bc_der = segment_sum(dd, ids_bc, K_BC) / DTYPE(N_BC_PER_BIN)

    # IC signed mismatch
    u_ic = mlp_apply(params, X_ic)[:, 0]
    di = (u_ic - u0_ic)
    c_ic = segment_sum(di, ids_ic, K_IC) / DTYPE(N_IC_PER_BIN)

    return jnp.concatenate([c_pde, c_bc_val, c_bc_der, c_ic], axis=0)



@partial(jax.jit, static_argnames=("shapes",))
def C_and_J_cells_unscaled(theta, shapes,
                           X_f, ids_f,
                           X_bc_L, X_bc_R, ids_bc,
                           X_ic, u0_ic, ids_ic,
                           nu):
    def c_fun(th):
        return constraint_vector_cells_unscaled(
            th, shapes, X_f, ids_f, X_bc_L, X_bc_R, ids_bc, X_ic, u0_ic, ids_ic, nu
        )

    def c_fun_aux(th):
        c = c_fun(th)
        return c, c

    J_un, c_un = jax.jacrev(c_fun_aux, has_aux=True)(theta)
    return c_un, J_un
@partial(jax.jit, static_argnames=("shapes",))
def C_cells_unscaled(theta, shapes,
                     X_f, ids_f,
                     X_bc_L, X_bc_R, ids_bc,
                     X_ic, u0_ic, ids_ic,
                     nu):
    # C-only (no Jacobian) for cheap feasibility evaluation
    return constraint_vector_cells_unscaled(
        theta, shapes,
        X_f, ids_f,
        X_bc_L, X_bc_R, ids_bc,
        X_ic, u0_ic, ids_ic,
        nu
    )


# -----------------------------
# 9) RMS+EMA scaling on ||J||_rms (scalar)
# -----------------------------
def ema_update(old, new, alpha):
    return (DTYPE(1.0) - DTYPE(alpha)) * old + DTYPE(alpha) * new


def scalar_scale_from_mag(mag, target):
    return DTYPE(target) / jnp.maximum(DTYPE(target), mag + DTYPE(EPS))


# -----------------------------
# 10) KKT solve (LM proxy), lam_eff = lam*(s^2)
#     DO NOT CHANGE bounds: lam_min=1e-2, lam_max=1
# -----------------------------
@jax.jit
def kkt_solve_once(H, Jac, Grad, Cons, lam_eff):
    n = H.shape[0]
    m = Cons.shape[0]
    I_m = jnp.eye(m, dtype=H.dtype)

    top = jnp.concatenate([H, Jac.T], axis=1)
    bottom = jnp.concatenate([Jac, -lam_eff * I_m], axis=1)
    KKT = jnp.concatenate([top, bottom], axis=0)

    rhs = -jnp.concatenate([Grad, Cons])
    sol = jnp.linalg.solve(KKT, rhs)
    d = sol[:n]
    y = sol[n:]
    return d, y


def cal_d_and_y(H, Jac, Grad, Cons, s_con,
               ridge_init=1e-6, eta_up=10.0, eta_down=0.25,
               lam_min=1e-9, lam_max=1e-4, res_tol=1e-6):
    lam = float(jnp.clip(DTYPE(ridge_init), DTYPE(lam_min), DTYPE(lam_max)))
    s2 = float(s_con * s_con)

    for _ in range(12):
        lam_eff = DTYPE(lam * s2)
        d, y = kkt_solve_once(H, Jac, Grad, Cons, lam_eff)

        # keep your old residual definition if you insist (undamped):
        res_vec = jnp.concatenate([H @ d + Jac.T @ y + Grad, Jac @ d + Cons])
        res = float(jnp.linalg.norm(res_vec, 2))

        if res <= res_tol:
            lam_next = float(jnp.clip(DTYPE(lam) * DTYPE(eta_down), DTYPE(lam_min), DTYPE(lam_max)))
            return d, y, lam_next, float(lam_eff), res

        lam = float(jnp.clip(DTYPE(lam) * DTYPE(eta_up), DTYPE(lam_min), DTYPE(lam_max)))

    # fallback (no lam_next available): return current lam
    lam_eff = DTYPE(lam * s2)
    d, y = kkt_solve_once(H, Jac, Grad, Cons, lam_eff)
    res_vec = jnp.concatenate([H @ d + Jac.T @ y + Grad, Jac @ d + Cons])
    res = float(jnp.linalg.norm(res_vec, 2))
    return d, y, lam, float(lam_eff), res




# -----------------------------
# 11) tau/ksi/alpha (Zhou-style)
# -----------------------------


def cal_tau_mu(H, d, sigma, tau_pre, eps_tau, g, c, mu_eff, y):
    """
    Tau update consistent with damped KKT (bottom-right -mu I).

    Uses delta_c = ||c||_1 - ||mu*y||_1 (since c+Jd = mu*y).
    """
    denom = float(g @ d + 0.5 * (d @ (H @ d)))

    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(DTYPE(mu_eff) * y, 1))
    delta_c = c1 - mu_y1

    if (denom <= 1e-12) or (delta_c <= 0.0):
        tau_trial = float("inf")
    else:
        tau_trial = (1.0 - sigma) * delta_c / denom

    if tau_pre <= tau_trial:
        return tau_pre
    return min(tau_trial, (1.0 - eps_tau) * tau_pre)
def model_reduction_from_muy(tau, g, d, c, mu_eff, y):
    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(DTYPE(mu_eff) * y, 1))
    delta_c = c1 - mu_y1
    Dl = -tau * gd + delta_c
    return Dl, c1, mu_y1, delta_c, gd


def cal_ksi_mu(d, tau, ksi_old, eps_ksi, g, c, mu_eff, y):
    d2 = float(jnp.linalg.norm(d)**2)
    if d2 <= 1e-18 or tau <= 1e-18:
        return ksi_old

    gd = float(g @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(DTYPE(mu_eff) * y, 1))
    delta_c = c1 - mu_y1

    Dl = -tau * gd + delta_c   # damped model reduction

    ksi_trial = Dl / (tau * d2)

    # practical safety (optional but recommended):
    ksi_trial = max(0.0, ksi_trial)

    if ksi_old <= ksi_trial:
        return ksi_old
    return min(ksi_trial, (1.0 - eps_ksi) * ksi_old)




def phi_mu(alpha, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma):
    gd = float(g @ d)
    d2 = float(d @ d)
    c1 = float(jnp.linalg.norm(c, 1))
    mu_y1 = float(jnp.linalg.norm(DTYPE(mu_eff) * y, 1))
    delta_c = c1 - mu_y1

    Dl = -tau * gd + delta_c

    term1 = (eta - 1.0) * alpha * beta * Dl
    term2 = (abs(1.0 - alpha) - 1.0 + alpha) * c1
    term3 = 0.5 * (tau * L + Gamma) * (alpha ** 2) * d2
    return term1 + term2 + term3




def cal_alpha_mu(d, eta, beta, ksi, tau, L, Gamma, theta_val, g, c, mu_eff, y):
    denom = (tau * L + Gamma)
    if denom <= 1e-12:
        return 0.0

    alpha_min = 2.0 * (1.0 - eta) * beta * ksi * tau / denom
    a = max(alpha_min, 0.0)

    while (phi_mu(1.1 * a, eta, beta, tau, g, d, c, mu_eff, y, L, Gamma) < 0.0
           and (1.1 * a < alpha_min + theta_val * beta)):
        a *= 1.1

    return float(a)




# -----------------------------
# 12) Training loop (HOLD + JITTER)
# -----------------------------
def train_sqp_cellwise_pointwise(theta0, shapes,
                                 X_data, u_data, x_grid, u0_grid, nu,
                                 x_min, x_max, t_min, t_max,
                                 scale_obj,
                                 con_scale_target=100.0, con_ema_alpha=0.05,
                                 L=100.0, Gamma=100.0,
                                 max_iters=2000, print_every=10,
                                 beta0=1.0, beta_shift=200.0, beta_power=0.8,
                                 alpha_cap=10.0,
                                 seed=0,
                                 mc_con_batches=1,
                                 mc_obj_batches=1,
                                 obj_resample_each_mc=False,
                                 hold_data_K=1,
                                 hold_con_K=1,
                                 # ---- JITTER controls ----
                                 jitter_every_iter=True,
                                 jitter_kind="gaussian",   # "gaussian" or "uniform"
                                 jitter_sigma_x=1e-4,
                                 jitter_sigma_t=1e-4,
                                                                  # ---- PDE objective controls (NEW) ----
                                 w_pde_obj=1.0,
                                 NX_OBJ=64, NT_OBJ=50,   # (optional) if you want runtime override; we keep globals above
                                 hold_obj_K=1,
                                 mc_pde_obj_jitter=2,     # S in Option B (average of S jitters)
                                 jitter_obj_sigma_x=1e-3,
                                 jitter_obj_sigma_t=1e-3,

                                 jitter_clip_k=2.0):
    key = random.PRNGKey(seed)
    theta = theta0
    n = theta.shape[0]
    H = jnp.eye(n, dtype=DTYPE)

    eta, sigma = 0.25, 0.1
    eps_tau, eps_ksi = 1e-2, 1e-2
    theta_val = 10.0
    tau_k, ksi_k = 5.0, 1.0
    lam_prev = 1e-6

    Jmag_ema = DTYPE(0.0)
    s_con = DTYPE(1.0)

    # cached base samples (held)
    Xb = ub = None
    Xf = ids_f = None
    XL = XR = ids_bc = None
    Xic = u0ic = ids_ic = None
    X_obj_base = None
    
    H_beta=10
    t0_wall = time.time()
    for k in range(1, max_iters + 1):
        k_beta = (k // H_beta) * H_beta 
        beta_k = float(min(1.0, beta0 * (beta_shift / (beta_shift + k_beta)) ** beta_power))

        # ---- DATA sampling (held) ----
        if (k == 1) or ((k - 1) % int(hold_data_K) == 0) or (Xb is None):
            key, k_data = random.split(key, 2)
            Xb, ub = sample_data_batch(k_data, X_data, u_data, B_DATA)

        if (k == 1) or ((k - 1) % int(hold_obj_K) == 0) or (X_obj_base is None):
            key, k_objbase = random.split(key, 2)
            X_obj_base = sample_pde_obj_base_stratified(k_objbase, x_min, x_max, t_min, t_max)
        # ---- JITTER every iteration (fresh perturbations) ----

                # Objective MC (data + PDE objective)
        S_obj = int(mc_obj_batches)
        obj_acc = DTYPE(0.0)
        g_acc = jnp.zeros((n,), dtype=DTYPE)

        for _ in range(S_obj):
            # ---- data part (same as before) ----
            if obj_resample_each_mc:
                key, k_data_i = random.split(key, 2)
                Xb_i, ub_i = sample_data_batch(k_data_i, X_data, u_data, B_DATA)
            else:
                Xb_i, ub_i = Xb, ub

            obj_d, g_d = F_and_g_data_scaled_batch(theta, shapes, Xb_i, ub_i, scale_obj)

            # ---- PDE objective part: Option B (average of S jitters) ----
            S_jit = int(mc_pde_obj_jitter)
            obj_r_acc = DTYPE(0.0)
            g_r_acc = jnp.zeros((n,), dtype=DTYPE)

            for s in range(S_jit):
                key, kj = random.split(key, 2)
                X_obj_use = jitter_points(
                    kj, X_obj_base, x_min, x_max, t_min, t_max,
                    jitter_obj_sigma_x, jitter_obj_sigma_t,
                    kind=jitter_kind, clip_k=jitter_clip_k
                )
                obj_r_s, g_r_s = F_and_g_pde_obj(theta, shapes, X_obj_use, nu, w_pde_obj)
                obj_r_acc = obj_r_acc + obj_r_s
                g_r_acc = g_r_acc + g_r_s

            obj_r = obj_r_acc / DTYPE(S_jit)
            g_r   = g_r_acc   / DTYPE(S_jit)

            obj_i = obj_d + obj_r
            g_i   = g_d   + g_r

            obj_acc = obj_acc + obj_i
            g_acc = g_acc + g_i

        obj_s = obj_acc / DTYPE(S_obj)
        g_s   = g_acc   / DTYPE(S_obj)


        # ---- BASE constraint sampling (held) ----
        if (k == 1) or ((k - 1) % int(hold_con_K) == 0) or (Xf is None):
            key, k_f, k_bc, k_ic = random.split(key, 4)
            Xf, ids_f = sample_pde_stratified(k_f, x_min, x_max, t_min, t_max)
            XL, XR, ids_bc = sample_bc_stratified(k_bc, x_min, x_max, t_min, t_max)
            Xic, u0ic, ids_ic = sample_ic_stratified(k_ic, x_min, x_max, t_min, x_grid, u0_grid)
       

       
        if jitter_every_iter:
            key, kj1, kj2, kj3 = random.split(key, 4)

            Xf_use = jitter_points(kj1, Xf, x_min, x_max, t_min, t_max,
                                   jitter_sigma_x, jitter_sigma_t,
                                   kind=jitter_kind, clip_k=jitter_clip_k)

            # BC: jitter only t; keep x at boundaries
            XL_use = jitter_points(kj2, XL, x_min, x_max, t_min, t_max,
                                   0.0, jitter_sigma_t,
                                   kind=jitter_kind, clip_k=jitter_clip_k)
            XR_use = jitter_points(kj2, XR, x_min, x_max, t_min, t_max,
                                   0.0, jitter_sigma_t,
                                   kind=jitter_kind, clip_k=jitter_clip_k)

            # IC: jitter only x; keep t at t_min
            Xic_use = jitter_points(kj3, Xic, x_min, x_max, t_min, t_max,
                                    jitter_sigma_x, 0.0,
                                    kind=jitter_kind, clip_k=jitter_clip_k)
            # recompute u0 at jittered x
            u0ic_use = jnp.interp(Xic_use[:, 0], x_grid, u0_grid)
        else:
            Xf_use, XL_use, XR_use, Xic_use, u0ic_use = Xf, XL, XR, Xic, u0ic

        # ---- Constraints/J MC average ----
        S_con = int(mc_con_batches)
        c_acc = jnp.zeros((M_CON,), dtype=DTYPE)
        J_acc = jnp.zeros((M_CON, n), dtype=DTYPE)

        for _ in range(S_con):
            c_tmp, J_tmp = C_and_J_cells_unscaled(
                theta, shapes,
                Xf_use, ids_f,
                XL_use, XR_use, ids_bc,
                Xic_use, u0ic_use, ids_ic,
                nu
            )
            c_acc = c_acc + c_tmp
            J_acc = J_acc + J_tmp

        c_un = c_acc / DTYPE(S_con)
        J_un = J_acc / DTYPE(S_con)

        # ---- RMS+EMA scaling on J magnitude ----
        # ---- shrink-only row scaling (SAFE) ----
        Cons = c_un
        Jac  = J_un
        s_con = DTYPE(1.0)


        # ---- KKT direction ----
        d, y, lam_prev, mu_eff, kkt_res= cal_d_and_y(H, Jac, g_s, Cons, s_con, ridge_init=lam_prev)

        # ---- Step size ----
        dn = float(jnp.linalg.norm(d, jnp.inf))
        if dn > 1e-10:
            tau_k = cal_tau_mu(H, d, sigma, tau_k, eps_tau, g_s, Cons, mu_eff, y)
            ksi_k = cal_ksi_mu(d, tau_k, ksi_k, eps_ksi, g_s, Cons, mu_eff, y)
            alpha = cal_alpha_mu(d, eta, beta_k, ksi_k, tau_k, L, Gamma, theta_val, g_s, Cons, mu_eff, y)

        else:
            alpha = 2.0 * (1.0 - eta) * beta_k * ksi_k * tau_k / (tau_k * L + Gamma)

        alpha = float(min(alpha, alpha_cap))
        theta = theta + DTYPE(alpha) * d
        # ---- RMS/max per constraint type (UNSCALED, using c_un) ----
        c_pde    = c_un[:K_PDE]
        c_bc_val = c_un[K_PDE : K_PDE + K_BC]
        c_bc_der = c_un[K_PDE + K_BC : K_PDE + 2*K_BC]
        c_ic     = c_un[K_PDE + 2*K_BC :]

        def rms(x):
            return float(jnp.sqrt(jnp.mean(x**2) + DTYPE(EPS)))

        def maxabs(x):
            return float(jnp.max(jnp.abs(x)))

        pde_rms, pde_max = rms(c_pde), maxabs(c_pde)
        bcv_rms, bcv_max = rms(c_bc_val), maxabs(c_bc_val)
        bcd_rms, bcd_max = rms(c_bc_der), maxabs(c_bc_der)
        ic_rms,  ic_max  = rms(c_ic), maxabs(c_ic)



        # ---- PDE objective MSE diagnostics (Option B: average over S jitters) ----
        pde_obj_mse_acc = DTYPE(0.0)
        for s in range(int(mc_pde_obj_jitter)):
            key, kj_dbg = random.split(key, 2)
            X_obj_dbg = jitter_points(
            kj_dbg, X_obj_base, x_min, x_max, t_min, t_max,
            jitter_obj_sigma_x, jitter_obj_sigma_t,
            kind=jitter_kind, clip_k=jitter_clip_k
        )
            pde_obj_mse_acc = pde_obj_mse_acc + pde_mse_on_points(theta, shapes, X_obj_dbg, nu)
        pde_obj_mse = float(pde_obj_mse_acc / DTYPE(int(mc_pde_obj_jitter)))

    
        if k % print_every == 0:
            station = float(jnp.linalg.norm(g_s + Jac.T @ y, jnp.inf))

    # Recompute feasibility at UPDATED theta (theta_{k+1})
            """c_noisy_un = C_cells_unscaled(
                theta, shapes,
                Xf_use, ids_f,
                XL_use, XR_use, ids_bc,
                Xic_use, u0ic_use, ids_ic,
                nu
                )
            feas_noisy = float(jnp.mean((s_con * c_noisy_un) ** 2))"""

            c_base_un = C_cells_unscaled(
                theta, shapes,
                Xf, ids_f,
                XL, XR, ids_bc,
                Xic, u0ic, ids_ic,
                nu
                )
            feas_true = float(jnp.mean((s_con * c_base_un) ** 2))
            d_inf  = float(jnp.linalg.norm(d, jnp.inf))
            # ---- Direction diagnostics ----

            d_l2  = float(jnp.linalg.norm(d, 2))

            #JJt = Jac @ Jac.T
            #eig_min = float(jnp.min(jnp.linalg.eigvalsh(JJt)))
            #eig_max = float(jnp.max(jnp.linalg.eigvalsh(JJt)))
            #print("JJt eig min/max:", eig_min, eig_max, "cond~", eig_max/max(eig_min,1e-12))
            params_now = unflatten_params(theta, shapes)
            data_mse_true = float(data_mse_unscaled(params_now, Xb, ub))

            c1 = float(jnp.linalg.norm(Cons, 1))
            mu_y1 = float(jnp.linalg.norm(DTYPE(mu_eff) * y, 1))
            print("tau delta_c:", c1 - mu_y1, "ratio:", mu_y1/(c1+1e-18),"miuy1:", mu_y1, "c1:", c1)
            print(
                f"[iter={k}] obj_s={float(obj_s):.3e} PDE_obj_MSE={pde_obj_mse:.3e} data_lossmse={data_mse_true:.3e}feas_true={feas_true:.3e}  station={station:.3e} tau={tau_k:3e} "
                f"alpha={alpha:.2e} beta={beta_k:.2e} lam={lam_prev:.2e} kkt_res={kkt_res:.1e} s={float(s_con):.2e} "
                f"| hold_data_K={int(hold_data_K)} hold_con_K={int(hold_con_K)} "
                f"| jitter={jitter_kind} sigx={jitter_sigma_x:.1e} sigt={jitter_sigma_t:.1e} clipk={jitter_clip_k}"
                f"| RMS/max: PDE=({pde_rms:.2e},{pde_max:.2e}) "
                f"BCv=({bcv_rms:.2e},{bcv_max:.2e}) "
                f"BCd=({bcd_rms:.2e},{bcd_max:.2e}) "
                f"IC=({ic_rms:.2e},{ic_max:.2e}) "
                f"| ||d||_inf={d_inf:.2e}"
                f"| ||d||_l2={d_l2:.2e}")
            


    print(f"[done] elapsed={time.time() - t0_wall:.2f}s")
    return theta


# -----------------------------
# 13) Eval helpers
# -----------------------------
def make_grid_points(x_np, t_np):
    T, X = np.meshgrid(t_np, x_np, indexing="ij")
    X_grid = np.stack([X.reshape(-1), T.reshape(-1)], axis=1)
    return X_grid, T.shape


@partial(jax.jit, static_argnames=("shapes",))
def predict_u(theta, shapes, X):
    params = unflatten_params(theta, shapes)
    return mlp_apply(params, X)[:, 0]


def eval_full_grid(theta, shapes, x_np, t_np, usol_np):
    X_grid_np, grid_shape = make_grid_points(x_np, t_np)
    X_grid = jnp.array(X_grid_np, dtype=DTYPE)
    u_pred = np.array(predict_u(theta, shapes, X_grid)).reshape(grid_shape)
    u_true = usol_np
    mse = float(np.mean((u_pred - u_true) ** 2))
    rel_l2 = float(np.linalg.norm(u_pred - u_true) / (np.linalg.norm(u_true) + 1e-12))
    return mse, rel_l2, u_pred


def plot_heatmaps(x_np, t_np, u_true, u_pred):
    import matplotlib.pyplot as plt
    err = u_pred - u_true

    plt.figure(); plt.pcolormesh(x_np, t_np, u_true, shading="auto"); plt.colorbar(); plt.title("u_true"); plt.xlabel("x"); plt.ylabel("t"); plt.show()
    plt.figure(); plt.pcolormesh(x_np, t_np, u_pred, shading="auto"); plt.colorbar(); plt.title("u_pred"); plt.xlabel("x"); plt.ylabel("t"); plt.show()
    plt.figure(); plt.pcolormesh(x_np, t_np, err, shading="auto"); plt.colorbar(); plt.title("u_pred - u_true"); plt.xlabel("x"); plt.ylabel("t"); plt.show()


# -----------------------------
# 14) main
# -----------------------------
def main():
    t_np, x_np, usol_np, nu = load_burgers_mat("data/burgers.mat")
    print("loaded burgers.mat:", "t", t_np.shape, "x", x_np.shape, "usol", usol_np.shape, "nu", nu)

    x_min, x_max = float(x_np.min()), float(x_np.max())
    t_min, t_max = float(t_np.min()), float(t_np.max())
    print(f"Domain: x in [{x_min}, {x_max}], t in [{t_min}, {t_max}]")

    X_data_np, u_data_np = build_full_data_points(t_np, x_np, usol_np)
    X_data = jnp.array(X_data_np, dtype=DTYPE)
    u_data = jnp.array(u_data_np, dtype=DTYPE)

    x_grid = jnp.array(x_np, dtype=DTYPE)
    u0_grid = jnp.array(usol_np[0, :], dtype=DTYPE)

    # network
    hidden_dim = 30
    num_hidden = 3
    layer_sizes = [2] + [hidden_dim] * num_hidden + [1]

    key = random.PRNGKey(0)
    key, key_params = random.split(key)
    params0 = init_mlp_params(key_params, layer_sizes)
    theta0, shapes = flatten_params(params0)

    # objective anchor scaling
    key_anchor = random.PRNGKey(123)
    X_anchor, u_anchor = sample_data_batch(key_anchor, X_data, u_data, B=512)
    scale_obj = compute_scale_obj_data_anchor(theta0, shapes, X_anchor, u_anchor, target=100.0)

    print("scale_obj (fixed anchor) =", float(scale_obj))
    print("Constraint dimension M_CON =", M_CON)

    theta_star = train_sqp_cellwise_pointwise(
        theta0, shapes,
        X_data, u_data, x_grid, u0_grid, nu,
        x_min=x_min, x_max=x_max, t_min=t_min, t_max=t_max,
        scale_obj=scale_obj,

        con_scale_target=100.0, con_ema_alpha=0.06,
        L=80.0, Gamma=80.0,

        max_iters=10000, print_every=10,

        beta0=1.0, beta_shift=200.0, beta_power=0.6,
        alpha_cap=1e1,

        seed=0,

        mc_con_batches=1,
        mc_obj_batches=1,
        obj_resample_each_mc=False,

        # HOLD base samples, but jitter makes constraints stochastic every iter
        hold_data_K=10000,
        hold_con_K=10000,

        # JITTER SETTINGS (edit)
        jitter_every_iter=True,
        jitter_kind="gaussian",   # or "uniform"
        jitter_sigma_x=1e-5,
        jitter_sigma_t=1e-5,
        jitter_clip_k=2.0,
        w_pde_obj=10,             # try 1.0 first (don’t start with 1e-3 unless you WANT weak PDE)
        hold_obj_K=10000,              # resample base points each iter (or keep >1 for stability)
        mc_pde_obj_jitter=16,       # S=2 (Option B). Try 1,2,4.
        jitter_obj_sigma_x=1e-5,   # choose 1e-3 / 1e-4 / 1e-5
        jitter_obj_sigma_t=1e-5,   # same

    )

    np.save("theta_star_pointwise_jitter_1e-5.npz", np.array(theta_star))
    print("Saved theta -> theta_star_pointwise_jitter_1e-5.npz")

    mse, rel_l2, u_pred = eval_full_grid(theta_star, shapes, x_np, t_np, usol_np)
    print(f"[EVAL] full-grid MSE={mse:.3e}, relL2={rel_l2:.3e}")

    plot_heatmaps(x_np, t_np, usol_np, u_pred)


if __name__ == "__main__":
    main()
# Out:
# loaded burgers.mat: t (201,) x (512,) usol (201, 512) nu 0.003183098861837907
# Domain: x in [-1.0, 1.0], t in [0.0, 1.0]
# scale_obj (fixed anchor) = 1.0
# Constraint dimension M_CON = 1300
# tau delta_c: 491.04371235652707 ratio: 0.021964581984445227 miuy1: 11.027790690735234 c1: 502.0715030472623
# [iter=10] obj_s=nan PDE_obj_MSE=2.664e-01 data_lossmse=nanfeas_true=2.429e-01  station=5.357e+00 tau=4.576036e-01 alpha=7.48e-03 beta=9.71e-01 lam=1.00e-04 kkt_res=4.6e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(5.23e-01,1.25e+00) BCv=(3.08e-01,4.95e-01) BCd=(4.40e-01,7.32e-01) IC=(4.90e-01,7.29e-01) | ||d||_inf=5.36e+00| ||d||_l2=2.87e+01
# tau delta_c: 417.0539089232772 ratio: 0.012963199611563165 miuy1: 5.4773571441586775 c1: 422.5312660674359
# [iter=20] obj_s=nan PDE_obj_MSE=1.912e-01 data_lossmse=nanfeas_true=1.760e-01  station=6.166e+00 tau=4.576036e-01 alpha=1.29e-02 beta=9.44e-01 lam=1.00e-04 kkt_res=2.5e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.42e-01,1.05e+00) BCv=(2.78e-01,4.59e-01) BCd=(3.57e-01,5.99e-01) IC=(4.31e-01,6.60e-01) | ||d||_inf=6.17e+00| ||d||_l2=1.96e+01
# tau delta_c: 374.5439849029245 ratio: 0.011855385322769932 miuy1: 4.4936370601992355 c1: 379.03762196312374
# [iter=30] obj_s=nan PDE_obj_MSE=1.574e-01 data_lossmse=nanfeas_true=1.437e-01  station=5.533e+00 tau=4.576036e-01 alpha=9.43e-03 beta=9.20e-01 lam=1.00e-04 kkt_res=2.3e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.01e-01,9.77e-01) BCv=(2.63e-01,4.40e-01) BCd=(3.10e-01,5.19e-01) IC=(3.80e-01,5.88e-01) | ||d||_inf=5.53e+00| ||d||_l2=2.07e+01
# tau delta_c: 336.8771165240795 ratio: 0.011329962089349848 miuy1: 3.8605447850461214 c1: 340.7376613091256
# [iter=40] obj_s=nan PDE_obj_MSE=1.260e-01 data_lossmse=nanfeas_true=1.155e-01  station=3.799e+00 tau=4.576036e-01 alpha=1.48e-02 beta=8.96e-01 lam=1.00e-04 kkt_res=2.1e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.62e-01,8.90e-01) BCv=(2.40e-01,4.04e-01) BCd=(2.82e-01,4.71e-01) IC=(3.43e-01,5.30e-01) | ||d||_inf=3.80e+00| ||d||_l2=1.59e+01
# tau delta_c: 297.7186698391172 ratio: 0.014932368888689871 miuy1: 4.513035311161715 c1: 302.2317051502789
# [iter=50] obj_s=nan PDE_obj_MSE=9.884e-02 data_lossmse=nanfeas_true=9.163e-02  station=5.559e+00 tau=4.576036e-01 alpha=6.74e-03 beta=8.75e-01 lam=1.00e-04 kkt_res=2.4e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.17e-01,7.85e-01) BCv=(2.15e-01,3.62e-01) BCd=(2.54e-01,4.23e-01) IC=(3.11e-01,4.80e-01) | ||d||_inf=5.56e+00| ||d||_l2=2.22e+01
# tau delta_c: 277.8087826631074 ratio: 0.011975235141516109 miuy1: 3.3671478844415006 c1: 281.17593054754894
# [iter=60] obj_s=nan PDE_obj_MSE=8.403e-02 data_lossmse=nanfeas_true=7.802e-02  station=3.017e+00 tau=4.576036e-01 alpha=8.76e-03 beta=8.54e-01 lam=1.00e-04 kkt_res=1.8e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.92e-01,7.24e-01) BCv=(2.08e-01,3.49e-01) BCd=(2.39e-01,3.98e-01) IC=(2.86e-01,4.46e-01) | ||d||_inf=3.02e+00| ||d||_l2=1.80e+01
# tau delta_c: 255.85680393105824 ratio: 0.011036639346128179 miuy1: 2.855312321553664 c1: 258.7121162526119
# [iter=70] obj_s=nan PDE_obj_MSE=6.802e-02 data_lossmse=nanfeas_true=6.289e-02  station=3.267e+00 tau=4.576036e-01 alpha=1.14e-02 beta=8.35e-01 lam=1.00e-04 kkt_res=1.6e-01 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.63e-01,6.31e-01) BCv=(1.95e-01,3.24e-01) BCd=(2.14e-01,3.57e-01) IC=(2.53e-01,3.96e-01) | ||d||_inf=3.27e+00| ||d||_l2=1.49e+01
# tau delta_c: 224.9823726898577 ratio: 0.006843206133908029 miuy1: 1.5502091536011804 c1: 226.53258184345887
# [iter=80] obj_s=nan PDE_obj_MSE=5.227e-02 data_lossmse=nanfeas_true=4.584e-02  station=2.297e+00 tau=4.576036e-01 alpha=2.89e-02 beta=8.17e-01 lam=1.00e-04 kkt_res=6.8e-02 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.28e-01,5.40e-01) BCv=(1.77e-01,2.91e-01) BCd=(1.92e-01,3.20e-01) IC=(2.16e-01,3.37e-01) | ||d||_inf=2.30e+00| ||d||_l2=8.96e+00
# tau delta_c: 182.79235936956155 ratio: 0.007255449084487946 miuy1: 1.3359334535920784 c1: 184.12829282315363
# [iter=90] obj_s=nan PDE_obj_MSE=4.202e-02 data_lossmse=nanfeas_true=3.073e-02  station=2.003e+00 tau=4.576036e-01 alpha=2.34e-02 beta=8.00e-01 lam=1.00e-04 kkt_res=5.6e-02 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.86e-01,5.58e-01) BCv=(1.46e-01,2.44e-01) BCd=(1.53e-01,2.59e-01) IC=(1.73e-01,2.72e-01) | ||d||_inf=2.00e+00| ||d||_l2=8.86e+00
# tau delta_c: 102.04625052956234 ratio: 0.004772516929001012 miuy1: 0.48935290320823177 c1: 102.53560343277057
# [iter=100] obj_s=nan PDE_obj_MSE=2.156e-02 data_lossmse=nanfeas_true=7.740e-03  station=8.183e-01 tau=4.576036e-01 alpha=1.28e-01 beta=7.84e-01 lam=1.00e-04 kkt_res=2.2e-02 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.07e-01,9.05e-01) BCv=(5.89e-02,9.69e-02) BCd=(7.22e-02,9.66e-02) IC=(9.55e-02,1.59e-01) | ||d||_inf=8.18e-01| ||d||_l2=2.82e+00
# tau delta_c: 5.425357938299598 ratio: 0.015624415203204333 miuy1: 0.08611351842040271 c1: 5.511471456720001
# [iter=110] obj_s=nan PDE_obj_MSE=1.168e-02 data_lossmse=nanfeas_true=7.285e-05  station=3.858e-02 tau=4.576036e-01 alpha=6.95e-01 beta=7.69e-01 lam=1.00e-04 kkt_res=3.5e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.10e-02,1.30e-01) BCv=(4.62e-03,7.44e-03) BCd=(6.77e-03,1.22e-02) IC=(1.97e-03,5.13e-03) | ||d||_inf=3.86e-02| ||d||_l2=2.67e-01
# tau delta_c: 0.2274129518817603 ratio: 0.1692661697541632 miuy1: 0.04633652551036975 c1: 0.27374947739213007
# [iter=120] obj_s=nan PDE_obj_MSE=6.124e-03 data_lossmse=nanfeas_true=2.149e-07  station=1.929e-02 tau=4.576036e-01 alpha=3.85e-01 beta=7.54e-01 lam=1.00e-04 kkt_res=1.9e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.09e-03,2.84e-02) BCv=(1.99e-04,3.13e-04) BCd=(3.76e-04,4.74e-04) IC=(8.45e-05,2.58e-04) | ||d||_inf=1.93e-02| ||d||_l2=7.59e-02
# tau delta_c: 0.06746614671868592 ratio: 0.3815778775822244 miuy1: 0.04162785925723405 c1: 0.10909400597591998
# [iter=130] obj_s=nan PDE_obj_MSE=5.345e-03 data_lossmse=nanfeas_true=3.411e-08  station=1.521e-02 tau=4.576036e-01 alpha=1.60e-01 beta=7.40e-01 lam=1.00e-04 kkt_res=1.7e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.28e-04,6.02e-03) BCv=(7.28e-05,1.32e-04) BCd=(1.18e-04,1.72e-04) IC=(4.20e-05,1.33e-04) | ||d||_inf=1.52e-02| ||d||_l2=6.24e-02
# tau delta_c: 0.05026984845140994 ratio: 0.4416473755190013 miuy1: 0.03976259027516879 c1: 0.09003243872657873
# [iter=140] obj_s=nan PDE_obj_MSE=4.937e-03 data_lossmse=nanfeas_true=8.568e-09  station=1.301e-02 tau=4.576036e-01 alpha=1.30e-01 beta=7.27e-01 lam=1.00e-04 kkt_res=1.6e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.57e-04,6.86e-03) BCv=(4.27e-05,8.66e-05) BCd=(6.37e-05,1.03e-04) IC=(3.57e-05,1.02e-04) | ||d||_inf=1.30e-02| ||d||_l2=5.82e-02
# tau delta_c: 0.041996223286003005 ratio: 0.4747140812131059 miuy1: 0.037953042026476584 c1: 0.07994926531247959
# [iter=150] obj_s=nan PDE_obj_MSE=4.627e-03 data_lossmse=nanfeas_true=1.703e-08  station=1.150e-02 tau=4.576036e-01 alpha=1.28e-01 beta=7.15e-01 lam=1.00e-04 kkt_res=1.5e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.60e-04,7.37e-03) BCv=(3.11e-05,6.88e-05) BCd=(4.24e-05,7.41e-05) IC=(3.38e-05,8.95e-05) | ||d||_inf=1.15e-02| ||d||_l2=5.46e-02
# tau delta_c: 0.04309039855181091 ratio: 0.46076772539588384 miuy1: 0.036820245861018876 c1: 0.07991064441282979
# [iter=160] obj_s=nan PDE_obj_MSE=4.370e-03 data_lossmse=nanfeas_true=9.077e-09  station=1.049e-02 tau=4.576036e-01 alpha=1.52e-01 beta=7.03e-01 lam=1.00e-04 kkt_res=1.5e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.85e-04,6.03e-03) BCv=(2.54e-05,6.01e-05) BCd=(3.26e-05,6.06e-05) IC=(3.29e-05,8.28e-05) | ||d||_inf=1.05e-02| ||d||_l2=5.05e-02
# tau delta_c: 0.05924600674476304 ratio: 0.37507799676576997 miuy1: 0.03555943527542577 c1: 0.09480544202018881
# [iter=170] obj_s=nan PDE_obj_MSE=4.095e-03 data_lossmse=nanfeas_true=1.400e-08  station=9.834e-03 tau=4.576036e-01 alpha=2.19e-01 beta=6.91e-01 lam=1.00e-04 kkt_res=1.4e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(8.22e-04,2.17e-02) BCv=(2.37e-05,5.86e-05) BCd=(3.08e-05,5.79e-05) IC=(3.24e-05,7.99e-05) | ||d||_inf=9.83e-03| ||d||_l2=4.74e-02
# tau delta_c: 0.03321389097002626 ratio: 0.5096736526809725 miuy1: 0.0345244452454981 c1: 0.06773833621552436
# [iter=180] obj_s=nan PDE_obj_MSE=3.859e-03 data_lossmse=nanfeas_true=6.206e-09  station=8.802e-03 tau=4.576036e-01 alpha=1.47e-01 beta=6.80e-01 lam=1.00e-04 kkt_res=1.4e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.41e-04,7.81e-03) BCv=(2.08e-05,5.41e-05) BCd=(2.58e-05,5.01e-05) IC=(3.19e-05,7.47e-05) | ||d||_inf=8.80e-03| ||d||_l2=4.48e-02
# tau delta_c: 0.026236803100333134 ratio: 0.5609132728000832 miuy1: 0.033516319631585564 c1: 0.0597531227319187
# [iter=190] obj_s=nan PDE_obj_MSE=3.650e-03 data_lossmse=nanfeas_true=5.767e-09  station=7.892e-03 tau=4.576036e-01 alpha=1.20e-01 beta=6.70e-01 lam=1.00e-04 kkt_res=1.3e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.46e-04,4.58e-03) BCv=(1.81e-05,4.93e-05) BCd=(2.15e-05,4.31e-05) IC=(3.14e-05,7.08e-05) | ||d||_inf=7.89e-03| ||d||_l2=4.33e-02
# tau delta_c: 0.033577704618775406 ratio: 0.492511412165511 miuy1: 0.03258674798902658 c1: 0.06616445260780199
# [iter=200] obj_s=nan PDE_obj_MSE=3.409e-03 data_lossmse=nanfeas_true=8.027e-09  station=7.145e-03 tau=4.576036e-01 alpha=1.73e-01 beta=6.60e-01 lam=1.00e-04 kkt_res=1.3e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.51e-04,7.39e-03) BCv=(1.71e-05,4.83e-05) BCd=(2.04e-05,4.13e-05) IC=(3.10e-05,7.19e-05) | ||d||_inf=7.14e-03| ||d||_l2=4.05e-02
# tau delta_c: 0.031126065046172192 ratio: 0.5026388353457255 miuy1: 0.031456354447333155 c1: 0.06258241949350535
# [iter=210] obj_s=nan PDE_obj_MSE=3.169e-03 data_lossmse=nanfeas_true=7.535e-09  station=6.484e-03 tau=4.576036e-01 alpha=1.70e-01 beta=6.50e-01 lam=1.00e-04 kkt_res=1.3e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.18e-04,1.08e-02) BCv=(1.68e-05,4.78e-05) BCd=(1.94e-05,3.99e-05) IC=(3.05e-05,7.30e-05) | ||d||_inf=6.48e-03| ||d||_l2=3.79e-02
# tau delta_c: 0.034437405218799025 ratio: 0.4703578310223507 miuy1: 0.030582729573852403 c1: 0.06502013479265142
# [iter=220] obj_s=nan PDE_obj_MSE=2.975e-03 data_lossmse=nanfeas_true=1.353e-08  station=5.833e-03 tau=4.576036e-01 alpha=2.03e-01 beta=6.41e-01 lam=1.00e-04 kkt_res=1.2e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.58e-04,6.90e-03) BCv=(1.44e-05,4.23e-05) BCd=(1.57e-05,3.29e-05) IC=(3.01e-05,7.06e-05) | ||d||_inf=5.83e-03| ||d||_l2=3.60e-02
# tau delta_c: 0.027950898762455666 ratio: 0.5153413081067183 miuy1: 0.02972040524999821 c1: 0.05767130401245388
# [iter=230] obj_s=nan PDE_obj_MSE=2.797e-03 data_lossmse=nanfeas_true=1.386e-08  station=5.107e-03 tau=4.576036e-01 alpha=1.82e-01 beta=6.32e-01 lam=1.00e-04 kkt_res=1.2e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.02e-04,6.51e-03) BCv=(1.33e-05,3.94e-05) BCd=(1.34e-05,2.83e-05) IC=(2.96e-05,6.91e-05) | ||d||_inf=5.11e-03| ||d||_l2=3.43e-02
# tau delta_c: 0.022521054252045505 ratio: 0.5619647876529411 miuy1: 0.028892744495717926 c1: 0.05141379874776343
# [iter=240] obj_s=nan PDE_obj_MSE=2.631e-03 data_lossmse=nanfeas_true=1.469e-08  station=5.156e-03 tau=4.576036e-01 alpha=1.63e-01 beta=6.23e-01 lam=1.00e-04 kkt_res=1.1e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.07e-04,3.47e-03) BCv=(1.28e-05,3.82e-05) BCd=(1.21e-05,2.54e-05) IC=(2.91e-05,6.75e-05) | ||d||_inf=5.16e-03| ||d||_l2=3.34e-02
# tau delta_c: 0.03967656879403022 ratio: 0.4146112598044294 miuy1: 0.02810158625004324 c1: 0.06777815504407346
# [iter=250] obj_s=nan PDE_obj_MSE=2.468e-03 data_lossmse=nanfeas_true=4.889e-09  station=4.954e-03 tau=4.576036e-01 alpha=2.85e-01 beta=6.15e-01 lam=1.00e-04 kkt_res=1.1e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(6.09e-04,1.71e-02) BCv=(1.24e-05,3.69e-05) BCd=(1.12e-05,2.31e-05) IC=(2.86e-05,6.55e-05) | ||d||_inf=4.95e-03| ||d||_l2=3.28e-02
# tau delta_c: 0.022211214537557013 ratio: 0.54989914044737 miuy1: 0.027135979688273762 c1: 0.049347194225830775
# [iter=260] obj_s=nan PDE_obj_MSE=2.303e-03 data_lossmse=nanfeas_true=6.833e-09  station=4.249e-03 tau=4.576036e-01 alpha=2.12e-01 beta=6.07e-01 lam=1.00e-04 kkt_res=1.1e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.15e-04,3.74e-03) BCv=(1.19e-05,3.53e-05) BCd=(1.06e-05,2.15e-05) IC=(2.80e-05,6.29e-05) | ||d||_inf=4.25e-03| ||d||_l2=2.86e-02
# tau delta_c: 0.0238960316021879 ratio: 0.5253149890034354 miuy1: 0.02644478609504679 c1: 0.05034081769723469
# [iter=270] obj_s=nan PDE_obj_MSE=2.182e-03 data_lossmse=nanfeas_true=3.525e-09  station=4.232e-03 tau=4.576036e-01 alpha=2.30e-01 beta=5.99e-01 lam=1.00e-04 kkt_res=1.0e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.68e-04,4.74e-03) BCv=(1.16e-05,3.44e-05) BCd=(9.69e-06,1.80e-05) IC=(2.75e-05,6.23e-05) | ||d||_inf=4.23e-03| ||d||_l2=2.73e-02
# tau delta_c: 0.02513135184584591 ratio: 0.5054256164132327 miuy1: 0.025682747468371625 c1: 0.050814099314217535
# [iter=280] obj_s=nan PDE_obj_MSE=2.044e-03 data_lossmse=nanfeas_true=1.000e-08  station=4.040e-03 tau=4.576036e-01 alpha=2.27e-01 beta=5.91e-01 lam=1.00e-04 kkt_res=1.0e-03 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.33e-04,7.97e-03) BCv=(1.15e-05,3.39e-05) BCd=(9.55e-06,1.80e-05) IC=(2.67e-05,6.19e-05) | ||d||_inf=4.04e-03| ||d||_l2=2.78e-02
# tau delta_c: 0.026356390231369712 ratio: 0.4853315215339438 miuy1: 0.024854032271915554 c1: 0.051210422503285266
# [iter=290] obj_s=nan PDE_obj_MSE=1.930e-03 data_lossmse=nanfeas_true=1.091e-08  station=3.417e-03 tau=4.576036e-01 alpha=3.28e-01 beta=5.84e-01 lam=1.00e-04 kkt_res=9.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.65e-04,4.66e-03) BCv=(1.14e-05,3.41e-05) BCd=(9.37e-06,1.66e-05) IC=(2.61e-05,6.10e-05) | ||d||_inf=3.42e-03| ||d||_l2=2.42e-02
# tau delta_c: 0.029493892940554062 ratio: 0.449468141727284 miuy1: 0.02407956061595878 c1: 0.05357345355651284
# [iter=300] obj_s=nan PDE_obj_MSE=1.807e-03 data_lossmse=nanfeas_true=1.299e-08  station=3.008e-03 tau=4.576036e-01 alpha=3.92e-01 beta=5.77e-01 lam=1.00e-04 kkt_res=9.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.37e-04,7.87e-03) BCv=(1.11e-05,3.54e-05) BCd=(9.56e-06,1.80e-05) IC=(2.54e-05,6.10e-05) | ||d||_inf=3.01e-03| ||d||_l2=2.27e-02
# tau delta_c: 0.018983925946480476 ratio: 0.5502432060152234 miuy1: 0.02322538851053036 c1: 0.04220931445701084
# [iter=310] obj_s=nan PDE_obj_MSE=1.691e-03 data_lossmse=nanfeas_true=8.498e-09  station=2.802e-03 tau=4.576036e-01 alpha=3.20e-01 beta=5.70e-01 lam=1.00e-04 kkt_res=9.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.72e-04,2.65e-03) BCv=(1.15e-05,3.28e-05) BCd=(9.44e-06,1.68e-05) IC=(2.46e-05,5.86e-05) | ||d||_inf=2.80e-03| ||d||_l2=2.07e-02
# tau delta_c: 0.024777559094816264 ratio: 0.4766601531468207 miuy1: 0.022567505959569897 c1: 0.04734506505438616
# [iter=320] obj_s=nan PDE_obj_MSE=1.595e-03 data_lossmse=nanfeas_true=7.484e-09  station=3.181e-03 tau=4.576036e-01 alpha=3.83e-01 beta=5.64e-01 lam=1.00e-04 kkt_res=8.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.47e-04,4.40e-03) BCv=(1.12e-05,3.20e-05) BCd=(9.48e-06,1.68e-05) IC=(2.37e-05,5.75e-05) | ||d||_inf=3.18e-03| ||d||_l2=2.16e-02
# tau delta_c: 0.02035099865764536 ratio: 0.5184802497030012 miuy1: 0.021913100883636124 c1: 0.042264099541281484
# [iter=330] obj_s=nan PDE_obj_MSE=1.520e-03 data_lossmse=nanfeas_true=6.955e-09  station=2.969e-03 tau=4.576036e-01 alpha=3.13e-01 beta=5.57e-01 lam=1.00e-04 kkt_res=8.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.20e-04,4.48e-03) BCv=(1.09e-05,3.37e-05) BCd=(9.51e-06,1.63e-05) IC=(2.30e-05,5.72e-05) | ||d||_inf=2.97e-03| ||d||_l2=2.15e-02
# tau delta_c: 0.018348746208267312 ratio: 0.5384327396743301 miuy1: 0.021404390085067088 c1: 0.0397531362933344
# [iter=340] obj_s=nan PDE_obj_MSE=1.449e-03 data_lossmse=nanfeas_true=4.488e-09  station=5.760e-03 tau=4.576036e-01 alpha=1.44e-01 beta=5.51e-01 lam=1.00e-04 kkt_res=8.2e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.70e-04,2.49e-03) BCv=(1.08e-05,3.26e-05) BCd=(9.70e-06,1.78e-05) IC=(2.24e-05,5.56e-05) | ||d||_inf=5.76e-03| ||d||_l2=2.95e-02
# tau delta_c: 0.02350461165568036 ratio: 0.4694559549450972 miuy1: 0.020798235345925335 c1: 0.044302847001605694
# [iter=350] obj_s=nan PDE_obj_MSE=1.379e-03 data_lossmse=nanfeas_true=4.772e-09  station=3.428e-03 tau=4.576036e-01 alpha=3.70e-01 beta=5.45e-01 lam=1.00e-04 kkt_res=8.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.10e-04,3.65e-03) BCv=(1.08e-05,3.13e-05) BCd=(9.84e-06,1.83e-05) IC=(2.18e-05,5.32e-05) | ||d||_inf=3.43e-03| ||d||_l2=2.04e-02
# tau delta_c: 0.031050028427523982 ratio: 0.3948714964200369 miuy1: 0.02026143392110253 c1: 0.05131146234862651
# [iter=360] obj_s=nan PDE_obj_MSE=1.326e-03 data_lossmse=nanfeas_true=1.203e-08  station=7.229e-03 tau=4.576036e-01 alpha=2.50e-01 beta=5.39e-01 lam=1.00e-04 kkt_res=7.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.37e-04,6.12e-03) BCv=(1.07e-05,3.02e-05) BCd=(9.83e-06,1.85e-05) IC=(2.13e-05,5.32e-05) | ||d||_inf=7.23e-03| ||d||_l2=2.90e-02
# tau delta_c: 0.02526662283463043 ratio: 0.4394225778874131 miuy1: 0.019805871771753948 c1: 0.04507249460638438
# [iter=370] obj_s=nan PDE_obj_MSE=1.282e-03 data_lossmse=nanfeas_true=7.561e-09  station=6.166e-03 tau=4.576036e-01 alpha=1.86e-01 beta=5.33e-01 lam=1.00e-04 kkt_res=7.6e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.66e-04,5.47e-03) BCv=(1.06e-05,2.96e-05) BCd=(9.82e-06,1.83e-05) IC=(2.09e-05,5.13e-05) | ||d||_inf=6.17e-03| ||d||_l2=3.02e-02
# tau delta_c: 0.02137810801234754 ratio: 0.4772277597815721 miuy1: 0.019515624224496576 c1: 0.040893732236844116
# [iter=380] obj_s=nan PDE_obj_MSE=1.246e-03 data_lossmse=nanfeas_true=1.251e-08  station=7.140e-03 tau=4.576036e-01 alpha=1.84e-01 beta=5.28e-01 lam=1.00e-04 kkt_res=7.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.97e-04,3.61e-03) BCv=(1.05e-05,3.07e-05) BCd=(9.92e-06,1.97e-05) IC=(2.05e-05,4.97e-05) | ||d||_inf=7.14e-03| ||d||_l2=2.80e-02
# tau delta_c: 0.019857476059135574 ratio: 0.4895395852665629 miuy1: 0.01904363259882993 c1: 0.038901108657965505
# [iter=390] obj_s=nan PDE_obj_MSE=1.205e-03 data_lossmse=nanfeas_true=4.447e-09  station=2.393e-03 tau=4.576036e-01 alpha=5.72e-01 beta=5.23e-01 lam=1.00e-04 kkt_res=7.2e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.21e-04,5.38e-03) BCv=(9.95e-06,2.88e-05) BCd=(9.83e-06,1.92e-05) IC=(2.02e-05,5.03e-05) | ||d||_inf=2.39e-03| ||d||_l2=1.51e-02
# tau delta_c: 0.015063382792144642 ratio: 0.553113169334856 miuy1: 0.01864399401670959 c1: 0.03370737680885423
# [iter=400] obj_s=nan PDE_obj_MSE=1.175e-03 data_lossmse=nanfeas_true=6.229e-09  station=2.470e-03 tau=4.576036e-01 alpha=5.15e-01 beta=5.17e-01 lam=1.00e-04 kkt_res=7.1e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.38e-04,2.95e-03) BCv=(9.86e-06,2.77e-05) BCd=(9.61e-06,1.76e-05) IC=(1.99e-05,4.89e-05) | ||d||_inf=2.47e-03| ||d||_l2=1.36e-02
# tau delta_c: 0.014011425322435381 ratio: 0.5654047322743164 miuy1: 0.018228744700031104 c1: 0.032240170022466486
# [iter=410] obj_s=nan PDE_obj_MSE=1.123e-03 data_lossmse=nanfeas_true=2.162e-08  station=1.920e-03 tau=4.576036e-01 alpha=5.10e-01 beta=5.12e-01 lam=1.00e-04 kkt_res=6.9e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.15e-04,1.41e-03) BCv=(9.88e-06,3.11e-05) BCd=(1.12e-05,2.35e-05) IC=(1.98e-05,5.17e-05) | ||d||_inf=1.92e-03| ||d||_l2=1.30e-02
# tau delta_c: 0.02465952105461115 ratio: 0.4221237280275063 miuy1: 0.018013144792075348 c1: 0.0426726658466865
# [iter=420] obj_s=nan PDE_obj_MSE=1.088e-03 data_lossmse=nanfeas_true=1.087e-08  station=1.085e-02 tau=4.576036e-01 alpha=1.10e-01 beta=5.07e-01 lam=1.00e-04 kkt_res=6.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.64e-04,5.99e-03) BCv=(9.38e-06,2.54e-05) BCd=(9.87e-06,2.07e-05) IC=(1.91e-05,5.04e-05) | ||d||_inf=1.09e-02| ||d||_l2=3.73e-02
# tau delta_c: 0.011414506489022206 ratio: 0.6072878680746289 miuy1: 0.017651329682271216 c1: 0.02906583617129342
# [iter=430] obj_s=nan PDE_obj_MSE=1.058e-03 data_lossmse=nanfeas_true=8.907e-09  station=9.693e-03 tau=4.576036e-01 alpha=6.14e-02 beta=5.02e-01 lam=1.00e-04 kkt_res=6.6e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.33e-05,1.50e-03) BCv=(8.92e-06,2.71e-05) BCd=(9.42e-06,2.07e-05) IC=(1.88e-05,4.86e-05) | ||d||_inf=9.69e-03| ||d||_l2=3.51e-02
# tau delta_c: 0.02187051104158549 ratio: 0.44085497139759233 miuy1: 0.01724368996678473 c1: 0.03911420100837022
# [iter=440] obj_s=nan PDE_obj_MSE=1.039e-03 data_lossmse=nanfeas_true=6.734e-09  station=5.268e-03 tau=4.576036e-01 alpha=3.38e-01 beta=4.98e-01 lam=1.00e-04 kkt_res=6.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.65e-04,2.65e-03) BCv=(8.83e-06,2.47e-05) BCd=(9.39e-06,1.89e-05) IC=(1.87e-05,4.90e-05) | ||d||_inf=5.27e-03| ||d||_l2=1.96e-02
# tau delta_c: 0.019868943321506842 ratio: 0.46095453005400017 miuy1: 0.016990550782946465 c1: 0.03685949410445331
# [iter=450] obj_s=nan PDE_obj_MSE=1.014e-03 data_lossmse=nanfeas_true=1.560e-08  station=3.691e-03 tau=4.576036e-01 alpha=4.91e-01 beta=4.93e-01 lam=1.00e-04 kkt_res=6.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.67e-04,3.80e-03) BCv=(8.74e-06,2.48e-05) BCd=(1.09e-05,2.26e-05) IC=(1.87e-05,5.26e-05) | ||d||_inf=3.69e-03| ||d||_l2=1.57e-02
# tau delta_c: 0.02118173201115959 ratio: 0.44122859057511715 miuy1: 0.016725955558182855 c1: 0.037907687569342444
# [iter=460] obj_s=nan PDE_obj_MSE=9.928e-04 data_lossmse=nanfeas_true=3.904e-09  station=4.885e-03 tau=4.576036e-01 alpha=3.65e-01 beta=4.89e-01 lam=1.00e-04 kkt_res=6.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.09e-04,3.77e-03) BCv=(8.44e-06,2.26e-05) BCd=(9.13e-06,2.10e-05) IC=(1.82e-05,4.86e-05) | ||d||_inf=4.89e-03| ||d||_l2=1.86e-02
# tau delta_c: 0.022156773994215985 ratio: 0.42773478327097564 miuy1: 0.01656089282617986 c1: 0.038717666820395846
# [iter=470] obj_s=nan PDE_obj_MSE=9.716e-04 data_lossmse=nanfeas_true=4.051e-09  station=5.383e-03 tau=4.576036e-01 alpha=2.72e-01 beta=4.84e-01 lam=1.00e-04 kkt_res=6.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.66e-04,2.57e-03) BCv=(8.54e-06,2.50e-05) BCd=(1.02e-05,2.03e-05) IC=(1.82e-05,5.07e-05) | ||d||_inf=5.38e-03| ||d||_l2=2.19e-02
# tau delta_c: 0.01726852489745991 ratio: 0.4857570215828385 miuy1: 0.016311952857651853 c1: 0.03358047775511176
# [iter=480] obj_s=nan PDE_obj_MSE=9.456e-04 data_lossmse=nanfeas_true=3.614e-09  station=3.539e-03 tau=4.576036e-01 alpha=4.34e-01 beta=4.80e-01 lam=1.00e-04 kkt_res=6.2e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.45e-04,2.36e-03) BCv=(8.17e-06,2.24e-05) BCd=(9.20e-06,2.13e-05) IC=(1.80e-05,4.94e-05) | ||d||_inf=3.54e-03| ||d||_l2=1.54e-02
# tau delta_c: 0.020122176272026546 ratio: 0.44731447156044174 miuy1: 0.016285826537164268 c1: 0.03640800280919081
# [iter=490] obj_s=nan PDE_obj_MSE=9.244e-04 data_lossmse=nanfeas_true=8.801e-09  station=8.944e-03 tau=4.576036e-01 alpha=1.37e-01 beta=4.76e-01 lam=1.00e-04 kkt_res=6.1e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.75e-04,2.59e-03) BCv=(7.96e-06,2.13e-05) BCd=(8.88e-06,2.17e-05) IC=(1.77e-05,4.93e-05) | ||d||_inf=8.94e-03| ||d||_l2=3.00e-02
# tau delta_c: 0.01540249378144233 ratio: 0.5079328077897804 miuy1: 0.015899113042330874 c1: 0.031301606823773205
# [iter=500] obj_s=nan PDE_obj_MSE=9.079e-04 data_lossmse=nanfeas_true=2.909e-09  station=2.308e-03 tau=4.576036e-01 alpha=6.87e-01 beta=4.72e-01 lam=1.00e-04 kkt_res=6.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.16e-04,1.69e-03) BCv=(7.94e-06,2.21e-05) BCd=(8.81e-06,2.08e-05) IC=(1.76e-05,4.97e-05) | ||d||_inf=2.31e-03| ||d||_l2=1.16e-02
# tau delta_c: 0.017023546102351954 ratio: 0.47926581032468923 miuy1: 0.01566788541852919 c1: 0.032691431520881144
# [iter=510] obj_s=nan PDE_obj_MSE=8.825e-04 data_lossmse=nanfeas_true=3.678e-09  station=4.348e-03 tau=4.576036e-01 alpha=4.23e-01 beta=4.68e-01 lam=1.00e-04 kkt_res=5.9e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.47e-04,2.54e-03) BCv=(7.53e-06,2.05e-05) BCd=(9.02e-06,2.43e-05) IC=(1.75e-05,5.18e-05) | ||d||_inf=4.35e-03| ||d||_l2=1.53e-02
# tau delta_c: 0.01661622207274779 ratio: 0.48138860318062493 miuy1: 0.015423610014735207 c1: 0.032039832087483
# [iter=520] obj_s=nan PDE_obj_MSE=8.571e-04 data_lossmse=nanfeas_true=5.073e-09  station=2.433e-03 tau=4.576036e-01 alpha=6.76e-01 beta=4.64e-01 lam=1.00e-04 kkt_res=5.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.42e-04,2.09e-03) BCv=(7.59e-06,2.01e-05) BCd=(8.75e-06,2.32e-05) IC=(1.73e-05,5.10e-05) | ||d||_inf=2.43e-03| ||d||_l2=1.21e-02
# tau delta_c: 0.019730173139081115 ratio: 0.43591531626892643 miuy1: 0.015247151557236011 c1: 0.034977324696317126
# [iter=530] obj_s=nan PDE_obj_MSE=8.219e-04 data_lossmse=nanfeas_true=8.932e-09  station=9.561e-03 tau=4.576036e-01 alpha=1.21e-01 beta=4.60e-01 lam=1.00e-04 kkt_res=5.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.07e-04,4.43e-03) BCv=(7.29e-06,1.98e-05) BCd=(8.87e-06,2.17e-05) IC=(1.72e-05,5.07e-05) | ||d||_inf=9.56e-03| ||d||_l2=3.08e-02
# tau delta_c: 0.01531119121481893 ratio: 0.4944164549622951 miuy1: 0.014973004869286351 c1: 0.03028419608410528
# [iter=540] obj_s=nan PDE_obj_MSE=8.130e-04 data_lossmse=nanfeas_true=7.922e-09  station=1.766e-03 tau=4.576036e-01 alpha=8.85e-01 beta=4.56e-01 lam=1.00e-04 kkt_res=5.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.41e-04,2.17e-03) BCv=(7.17e-06,1.82e-05) BCd=(8.58e-06,2.32e-05) IC=(1.70e-05,5.16e-05) | ||d||_inf=1.77e-03| ||d||_l2=9.88e-03
# tau delta_c: 0.017183420606137055 ratio: 0.46679996192999756 miuy1: 0.015043547471988043 c1: 0.0322269680781251
# [iter=550] obj_s=nan PDE_obj_MSE=7.900e-04 data_lossmse=nanfeas_true=4.763e-09  station=7.781e-03 tau=4.576036e-01 alpha=1.58e-01 beta=4.52e-01 lam=1.00e-04 kkt_res=5.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.49e-04,2.57e-03) BCv=(7.16e-06,1.92e-05) BCd=(8.60e-06,2.19e-05) IC=(1.69e-05,5.13e-05) | ||d||_inf=7.78e-03| ||d||_l2=2.49e-02
# tau delta_c: 0.014906966687952125 ratio: 0.4956516633319823 miuy1: 0.0146499200987381 c1: 0.029556886786690224
# [iter=560] obj_s=nan PDE_obj_MSE=7.803e-04 data_lossmse=nanfeas_true=3.831e-09  station=2.182e-03 tau=4.576036e-01 alpha=6.54e-01 beta=4.49e-01 lam=1.00e-04 kkt_res=5.6e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.35e-04,2.43e-03) BCv=(6.95e-06,1.81e-05) BCd=(8.39e-06,2.17e-05) IC=(1.68e-05,5.00e-05) | ||d||_inf=2.18e-03| ||d||_l2=1.11e-02
# tau delta_c: 0.013265707982397866 ratio: 0.5220842823663288 miuy1: 0.01449171344764225 c1: 0.027757421430040116
# [iter=570] obj_s=nan PDE_obj_MSE=7.586e-04 data_lossmse=nanfeas_true=6.792e-09  station=2.621e-03 tau=4.576036e-01 alpha=7.85e-01 beta=4.45e-01 lam=1.00e-04 kkt_res=5.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.37e-04,2.57e-03) BCv=(6.74e-06,1.81e-05) BCd=(8.33e-06,2.29e-05) IC=(1.67e-05,5.07e-05) | ||d||_inf=2.62e-03| ||d||_l2=9.52e-03
# tau delta_c: 0.014550131907669305 ratio: 0.4970354585071599 miuy1: 0.01437861099035551 c1: 0.028928742898024815
# [iter=580] obj_s=nan PDE_obj_MSE=7.380e-04 data_lossmse=nanfeas_true=3.450e-09  station=1.398e-03 tau=4.576036e-01 alpha=9.43e-01 beta=4.42e-01 lam=1.00e-04 kkt_res=5.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.11e-04,2.38e-03) BCv=(7.32e-06,2.14e-05) BCd=(8.77e-06,2.15e-05) IC=(1.66e-05,5.09e-05) | ||d||_inf=1.40e-03| ||d||_l2=7.76e-03
# tau delta_c: 0.01625188917523826 ratio: 0.47001091884559043 miuy1: 0.014412684403973567 c1: 0.03066457357921183
# [iter=590] obj_s=nan PDE_obj_MSE=7.232e-04 data_lossmse=nanfeas_true=2.338e-09  station=9.375e-03 tau=4.576036e-01 alpha=1.39e-01 beta=4.39e-01 lam=1.00e-04 kkt_res=5.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.58e-04,2.87e-03) BCv=(6.51e-06,1.86e-05) BCd=(8.22e-06,2.19e-05) IC=(1.64e-05,5.03e-05) | ||d||_inf=9.38e-03| ||d||_l2=2.58e-02
# tau delta_c: 0.021029725362165883 ratio: 0.40220463307795024 miuy1: 0.01414907749548169 c1: 0.03517880285764757
# [iter=600] obj_s=nan PDE_obj_MSE=7.046e-04 data_lossmse=nanfeas_true=8.167e-09  station=9.054e-03 tau=4.576036e-01 alpha=1.38e-01 beta=4.35e-01 lam=1.00e-04 kkt_res=5.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.91e-04,3.32e-03) BCv=(6.38e-06,1.90e-05) BCd=(8.18e-06,2.13e-05) IC=(1.63e-05,4.96e-05) | ||d||_inf=9.05e-03| ||d||_l2=2.85e-02
# tau delta_c: 0.012625312225718012 ratio: 0.5244132256534855 miuy1: 0.013921498801703779 c1: 0.02654681102742179
# [iter=610] obj_s=nan PDE_obj_MSE=6.889e-04 data_lossmse=nanfeas_true=4.198e-09  station=5.683e-03 tau=4.576036e-01 alpha=1.66e-01 beta=4.32e-01 lam=1.00e-04 kkt_res=5.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.73e-05,1.62e-03) BCv=(6.24e-06,1.98e-05) BCd=(8.06e-06,2.17e-05) IC=(1.61e-05,4.97e-05) | ||d||_inf=5.68e-03| ||d||_l2=1.98e-02
# tau delta_c: 0.014007114589862221 ratio: 0.4979703635351284 miuy1: 0.013893856931452215 c1: 0.027900971521314436
# [iter=620] obj_s=nan PDE_obj_MSE=6.735e-04 data_lossmse=nanfeas_true=2.440e-09  station=6.493e-03 tau=4.576036e-01 alpha=1.81e-01 beta=4.29e-01 lam=1.00e-04 kkt_res=5.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.15e-04,1.82e-03) BCv=(6.19e-06,2.03e-05) BCd=(8.11e-06,2.08e-05) IC=(1.60e-05,5.04e-05) | ||d||_inf=6.49e-03| ||d||_l2=1.99e-02
# tau delta_c: 0.016144907549805698 ratio: 0.45952359313675856 miuy1: 0.013726715604858476 c1: 0.029871623154664174
# [iter=630] obj_s=nan PDE_obj_MSE=6.606e-04 data_lossmse=nanfeas_true=2.678e-09  station=8.295e-03 tau=4.576036e-01 alpha=1.23e-01 beta=4.26e-01 lam=1.00e-04 kkt_res=5.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.63e-04,3.08e-03) BCv=(6.18e-06,2.09e-05) BCd=(8.11e-06,2.14e-05) IC=(1.59e-05,4.90e-05) | ||d||_inf=8.29e-03| ||d||_l2=2.69e-02
# tau delta_c: 0.01381512718670791 ratio: 0.49503797652313525 miuy1: 0.01354361771768164 c1: 0.02735874490438955
# [iter=640] obj_s=nan PDE_obj_MSE=6.482e-04 data_lossmse=nanfeas_true=7.355e-09  station=3.083e-03 tau=4.576036e-01 alpha=4.63e-01 beta=4.23e-01 lam=1.00e-04 kkt_res=5.2e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.34e-04,2.95e-03) BCv=(6.06e-06,2.06e-05) BCd=(7.94e-06,2.29e-05) IC=(1.57e-05,5.08e-05) | ||d||_inf=3.08e-03| ||d||_l2=1.22e-02
# tau delta_c: 0.01361077984119943 ratio: 0.49728511154868144 miuy1: 0.013463771070012457 c1: 0.027074550911211887
# [iter=650] obj_s=nan PDE_obj_MSE=6.311e-04 data_lossmse=nanfeas_true=5.809e-09  station=6.375e-03 tau=4.576036e-01 alpha=2.14e-01 beta=4.20e-01 lam=1.00e-04 kkt_res=5.1e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.25e-04,2.01e-03) BCv=(5.94e-06,2.15e-05) BCd=(8.01e-06,2.14e-05) IC=(1.56e-05,4.81e-05) | ||d||_inf=6.38e-03| ||d||_l2=1.82e-02
# tau delta_c: 0.015027449830557456 ratio: 0.46825291141760844 miuy1: 0.013233071295415814 c1: 0.02826052112597327
# [iter=660] obj_s=nan PDE_obj_MSE=6.236e-04 data_lossmse=nanfeas_true=4.300e-09  station=3.191e-03 tau=4.576036e-01 alpha=6.68e-01 beta=4.17e-01 lam=1.00e-04 kkt_res=5.1e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.42e-04,2.42e-03) BCv=(5.66e-06,1.95e-05) BCd=(7.78e-06,2.10e-05) IC=(1.54e-05,4.87e-05) | ||d||_inf=3.19e-03| ||d||_l2=1.05e-02
# tau delta_c: 0.01461218586875697 ratio: 0.4737255623971929 miuy1: 0.013153148764093207 c1: 0.027765334632850178
# [iter=670] obj_s=nan PDE_obj_MSE=6.082e-04 data_lossmse=nanfeas_true=2.879e-09  station=2.845e-03 tau=4.576036e-01 alpha=5.48e-01 beta=4.14e-01 lam=1.00e-04 kkt_res=5.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.15e-04,2.14e-03) BCv=(5.95e-06,2.25e-05) BCd=(7.82e-06,2.10e-05) IC=(1.53e-05,4.77e-05) | ||d||_inf=2.85e-03| ||d||_l2=1.16e-02
# tau delta_c: 0.013976542419361443 ratio: 0.48326739741940994 miuy1: 0.013071378206435821 c1: 0.027047920625797264
# [iter=680] obj_s=nan PDE_obj_MSE=5.978e-04 data_lossmse=nanfeas_true=1.241e-09  station=6.031e-03 tau=4.576036e-01 alpha=2.54e-01 beta=4.11e-01 lam=1.00e-04 kkt_res=5.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.16e-04,1.99e-03) BCv=(6.02e-06,2.31e-05) BCd=(7.74e-06,2.08e-05) IC=(1.51e-05,4.63e-05) | ||d||_inf=6.03e-03| ||d||_l2=1.67e-02
# tau delta_c: 0.01117016162574384 ratio: 0.5361969729551799 miuy1: 0.012913686418362175 c1: 0.024083848044106015
# [iter=690] obj_s=nan PDE_obj_MSE=5.943e-04 data_lossmse=nanfeas_true=2.524e-09  station=1.565e-03 tau=4.576036e-01 alpha=7.20e-01 beta=4.08e-01 lam=1.00e-04 kkt_res=5.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(7.71e-05,1.42e-03) BCv=(6.11e-06,2.38e-05) BCd=(7.77e-06,2.01e-05) IC=(1.51e-05,4.67e-05) | ||d||_inf=1.56e-03| ||d||_l2=8.69e-03
# tau delta_c: 0.015621936481173946 ratio: 0.4528965251775271 miuy1: 0.012931960907693921 c1: 0.028553897388867867
# [iter=700] obj_s=nan PDE_obj_MSE=5.814e-04 data_lossmse=nanfeas_true=1.394e-09  station=6.798e-03 tau=4.576036e-01 alpha=2.28e-01 beta=4.06e-01 lam=1.00e-04 kkt_res=5.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.48e-04,2.65e-03) BCv=(5.64e-06,2.23e-05) BCd=(7.62e-06,1.98e-05) IC=(1.49e-05,4.53e-05) | ||d||_inf=6.80e-03| ||d||_l2=1.89e-02
# tau delta_c: 0.014795105550652705 ratio: 0.4665224089414784 miuy1: 0.01293821595830962 c1: 0.027733321508962325
# [iter=710] obj_s=nan PDE_obj_MSE=5.724e-04 data_lossmse=nanfeas_true=1.281e-09  station=9.769e-03 tau=4.576036e-01 alpha=1.16e-01 beta=4.03e-01 lam=1.00e-04 kkt_res=5.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.52e-04,2.91e-03) BCv=(5.60e-06,2.23e-05) BCd=(7.61e-06,2.01e-05) IC=(1.48e-05,4.48e-05) | ||d||_inf=9.77e-03| ||d||_l2=2.54e-02
# tau delta_c: 0.010378619362211034 ratio: 0.5492369002768754 miuy1: 0.012645934707511991 c1: 0.023024554069723025
# [iter=720] obj_s=nan PDE_obj_MSE=5.645e-04 data_lossmse=nanfeas_true=2.682e-09  station=3.046e-03 tau=4.576036e-01 alpha=4.82e-01 beta=4.00e-01 lam=1.00e-04 kkt_res=4.9e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.01e-04,2.14e-03) BCv=(5.40e-06,2.21e-05) BCd=(7.67e-06,2.00e-05) IC=(1.46e-05,4.57e-05) | ||d||_inf=3.05e-03| ||d||_l2=1.02e-02
# tau delta_c: 0.011623887565563706 ratio: 0.518726108549819 miuy1: 0.012528446005946797 c1: 0.024152333571510504
# [iter=730] obj_s=nan PDE_obj_MSE=5.531e-04 data_lossmse=nanfeas_true=3.906e-09  station=9.015e-04 tau=4.576036e-01 alpha=1.03e+00 beta=3.98e-01 lam=1.00e-04 kkt_res=4.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.19e-04,2.36e-03) BCv=(5.34e-06,2.19e-05) BCd=(7.44e-06,1.94e-05) IC=(1.45e-05,4.47e-05) | ||d||_inf=9.01e-04| ||d||_l2=5.66e-03
# tau delta_c: 0.013076683731447547 ratio: 0.49082854365659623 miuy1: 0.012605595918235242 c1: 0.02568227964968279
# [iter=740] obj_s=nan PDE_obj_MSE=5.458e-04 data_lossmse=nanfeas_true=4.052e-09  station=9.658e-03 tau=4.576036e-01 alpha=1.04e-01 beta=3.95e-01 lam=1.00e-04 kkt_res=4.8e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.19e-04,2.38e-03) BCv=(5.20e-06,2.16e-05) BCd=(7.50e-06,1.94e-05) IC=(1.43e-05,4.43e-05) | ||d||_inf=9.66e-03| ||d||_l2=2.51e-02
# tau delta_c: 0.010983580966550738 ratio: 0.5292389139257367 miuy1: 0.012347958728338278 c1: 0.023331539694889016
# [iter=750] obj_s=nan PDE_obj_MSE=5.379e-04 data_lossmse=nanfeas_true=1.426e-09  station=4.969e-03 tau=4.576036e-01 alpha=3.23e-01 beta=3.93e-01 lam=1.00e-04 kkt_res=4.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.70e-05,2.02e-03) BCv=(5.35e-06,2.28e-05) BCd=(7.38e-06,1.93e-05) IC=(1.42e-05,4.25e-05) | ||d||_inf=4.97e-03| ||d||_l2=1.31e-02
# tau delta_c: 0.00955303799172279 ratio: 0.5620765838845604 miuy1: 0.012261365258192816 c1: 0.021814403249915605
# [iter=760] obj_s=nan PDE_obj_MSE=5.287e-04 data_lossmse=nanfeas_true=4.286e-09  station=9.325e-04 tau=4.576036e-01 alpha=1.01e+00 beta=3.90e-01 lam=1.00e-04 kkt_res=4.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.02e-05,1.78e-03) BCv=(5.17e-06,2.20e-05) BCd=(7.31e-06,1.97e-05) IC=(1.41e-05,4.29e-05) | ||d||_inf=9.33e-04| ||d||_l2=6.19e-03
# tau delta_c: 0.009694244111006436 ratio: 0.5556334819551004 miuy1: 0.012121630211970597 c1: 0.021815874322977033
# [iter=770] obj_s=nan PDE_obj_MSE=5.187e-04 data_lossmse=nanfeas_true=6.873e-09  station=9.299e-04 tau=4.576036e-01 alpha=1.00e+00 beta=3.88e-01 lam=1.00e-04 kkt_res=4.7e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.00e-05,1.92e-03) BCv=(5.18e-06,2.25e-05) BCd=(7.26e-06,1.91e-05) IC=(1.39e-05,4.23e-05) | ||d||_inf=9.30e-04| ||d||_l2=5.72e-03
# tau delta_c: 0.01029766274968284 ratio: 0.5391054854308558 miuy1: 0.012045112927110264 c1: 0.022342775676793103
# [iter=780] obj_s=nan PDE_obj_MSE=5.111e-04 data_lossmse=nanfeas_true=1.519e-09  station=5.766e-03 tau=4.576036e-01 alpha=1.63e-01 beta=3.85e-01 lam=1.00e-04 kkt_res=4.6e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.74e-05,2.31e-03) BCv=(5.07e-06,2.26e-05) BCd=(7.17e-06,1.83e-05) IC=(1.38e-05,4.19e-05) | ||d||_inf=5.77e-03| ||d||_l2=1.75e-02
# tau delta_c: 0.0130079512070621 ratio: 0.4790943733912053 miuy1: 0.01196384894750064 c1: 0.02497180015456274
# [iter=790] obj_s=nan PDE_obj_MSE=5.027e-04 data_lossmse=nanfeas_true=2.382e-09  station=6.879e-03 tau=4.576036e-01 alpha=1.47e-01 beta=3.83e-01 lam=1.00e-04 kkt_res=4.6e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.10e-04,2.19e-03) BCv=(5.36e-06,2.40e-05) BCd=(7.19e-06,1.90e-05) IC=(1.37e-05,4.04e-05) | ||d||_inf=6.88e-03| ||d||_l2=2.09e-02
# tau delta_c: 0.0167407962914251 ratio: 0.41401971965070605 miuy1: 0.011828076847865809 c1: 0.02856887313929091
# [iter=800] obj_s=nan PDE_obj_MSE=5.016e-04 data_lossmse=nanfeas_true=2.972e-09  station=3.474e-03 tau=4.576036e-01 alpha=5.55e-01 beta=3.81e-01 lam=1.00e-04 kkt_res=4.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.56e-04,2.81e-03) BCv=(5.45e-06,2.50e-05) BCd=(7.26e-06,1.87e-05) IC=(1.35e-05,4.01e-05) | ||d||_inf=3.47e-03| ||d||_l2=1.20e-02
# tau delta_c: 0.010423944646958512 ratio: 0.5292250129417543 miuy1: 0.01171815069267522 c1: 0.02214209533963373
# [iter=810] obj_s=nan PDE_obj_MSE=4.912e-04 data_lossmse=nanfeas_true=2.999e-09  station=3.825e-03 tau=4.576036e-01 alpha=3.42e-01 beta=3.78e-01 lam=1.00e-04 kkt_res=4.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(7.90e-05,1.42e-03) BCv=(5.14e-06,2.42e-05) BCd=(7.08e-06,1.89e-05) IC=(1.33e-05,4.09e-05) | ||d||_inf=3.82e-03| ||d||_l2=1.18e-02
# tau delta_c: 0.009991597142568798 ratio: 0.5378337006185197 miuy1: 0.011627454605558678 c1: 0.021619051748127477
# [iter=820] obj_s=nan PDE_obj_MSE=4.856e-04 data_lossmse=nanfeas_true=2.425e-09  station=3.547e-03 tau=4.576036e-01 alpha=4.98e-01 beta=3.76e-01 lam=1.00e-04 kkt_res=4.5e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.22e-04,2.32e-03) BCv=(4.91e-06,2.27e-05) BCd=(7.11e-06,1.84e-05) IC=(1.31e-05,3.88e-05) | ||d||_inf=3.55e-03| ||d||_l2=9.47e-03
# tau delta_c: 0.00993742687788416 ratio: 0.535984006045922 miuy1: 0.011478703185226619 c1: 0.02141613006311078
# [iter=830] obj_s=nan PDE_obj_MSE=4.737e-04 data_lossmse=nanfeas_true=5.941e-09  station=7.561e-04 tau=4.576036e-01 alpha=9.65e-01 beta=3.74e-01 lam=1.00e-04 kkt_res=4.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(9.51e-05,1.73e-03) BCv=(4.79e-06,2.21e-05) BCd=(7.00e-06,1.91e-05) IC=(1.30e-05,3.89e-05) | ||d||_inf=7.56e-04| ||d||_l2=4.78e-03
# tau delta_c: 0.010654006058697318 ratio: 0.5174485752079812 miuy1: 0.01142448239108651 c1: 0.02207848844978383
# [iter=840] obj_s=nan PDE_obj_MSE=4.689e-04 data_lossmse=nanfeas_true=9.346e-09  station=1.017e-03 tau=4.576036e-01 alpha=9.60e-01 beta=3.72e-01 lam=1.00e-04 kkt_res=4.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(8.90e-05,1.77e-03) BCv=(4.97e-06,2.37e-05) BCd=(6.94e-06,1.78e-05) IC=(1.28e-05,3.77e-05) | ||d||_inf=1.02e-03| ||d||_l2=6.47e-03
# tau delta_c: 0.011528018213298621 ratio: 0.496435385506311 miuy1: 0.011364809998805821 c1: 0.022892828212104442
# [iter=850] obj_s=nan PDE_obj_MSE=4.616e-04 data_lossmse=nanfeas_true=3.466e-09  station=5.710e-03 tau=4.576036e-01 alpha=1.72e-01 beta=3.70e-01 lam=1.00e-04 kkt_res=4.4e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.01e-04,2.03e-03) BCv=(4.73e-06,2.28e-05) BCd=(6.87e-06,1.75e-05) IC=(1.27e-05,3.73e-05) | ||d||_inf=5.71e-03| ||d||_l2=1.75e-02
# tau delta_c: 0.008219563441315199 ratio: 0.5782618083834302 miuy1: 0.01127016645440207 c1: 0.01948972989571727
# [iter=860] obj_s=nan PDE_obj_MSE=4.560e-04 data_lossmse=nanfeas_true=3.154e-09  station=3.663e-03 tau=4.576036e-01 alpha=3.02e-01 beta=3.68e-01 lam=1.00e-04 kkt_res=4.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(7.52e-05,1.32e-03) BCv=(4.62e-06,2.17e-05) BCd=(6.85e-06,1.88e-05) IC=(1.25e-05,3.68e-05) | ||d||_inf=3.66e-03| ||d||_l2=1.09e-02
# tau delta_c: 0.01099901892612731 ratio: 0.5035517336711296 miuy1: 0.011156399215349385 c1: 0.022155418141476695
# [iter=870] obj_s=nan PDE_obj_MSE=4.520e-04 data_lossmse=nanfeas_true=3.386e-09  station=1.547e-03 tau=4.576036e-01 alpha=9.44e-01 beta=3.66e-01 lam=1.00e-04 kkt_res=4.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(1.15e-04,2.28e-03) BCv=(4.73e-06,2.34e-05) BCd=(6.81e-06,1.78e-05) IC=(1.24e-05,3.63e-05) | ||d||_inf=1.55e-03| ||d||_l2=6.59e-03
# tau delta_c: 0.006724819210052066 ratio: 0.6246661041537271 miuy1: 0.011192079009037584 c1: 0.01791689821908965
# [iter=880] obj_s=nan PDE_obj_MSE=4.452e-04 data_lossmse=nanfeas_true=1.207e-09  station=6.224e-03 tau=4.576036e-01 alpha=9.53e-02 beta=3.64e-01 lam=1.00e-04 kkt_res=4.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(6.25e-05,1.17e-03) BCv=(4.63e-06,2.28e-05) BCd=(6.83e-06,1.77e-05) IC=(1.22e-05,3.50e-05) | ||d||_inf=6.22e-03| ||d||_l2=1.75e-02
# tau delta_c: 0.009089209364667528 ratio: 0.5488996744277146 miuy1: 0.011059766039277398 c1: 0.020148975403944926
# [iter=890] obj_s=nan PDE_obj_MSE=4.394e-04 data_lossmse=nanfeas_true=3.293e-09  station=4.437e-03 tau=4.576036e-01 alpha=2.23e-01 beta=3.62e-01 lam=1.00e-04 kkt_res=4.3e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(8.60e-05,1.65e-03) BCv=(4.52e-06,2.22e-05) BCd=(6.79e-06,1.80e-05) IC=(1.21e-05,3.54e-05) | ||d||_inf=4.44e-03| ||d||_l2=1.32e-02
# tau delta_c: 0.00780804235458798 ratio: 0.5834942316417612 miuy1: 0.01093849838448827 c1: 0.01874654073907625
# [iter=900] obj_s=nan PDE_obj_MSE=4.337e-04 data_lossmse=nanfeas_true=1.782e-09  station=3.858e-03 tau=4.576036e-01 alpha=2.96e-01 beta=3.60e-01 lam=1.00e-04 kkt_res=4.2e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(6.29e-05,9.00e-04) BCv=(4.69e-06,2.34e-05) BCd=(6.70e-06,1.75e-05) IC=(1.20e-05,3.43e-05) | ||d||_inf=3.86e-03| ||d||_l2=1.11e-02
# ...
# tau delta_c: 0.0034247324944726544 ratio: 0.43014180083868714 miuy1: 0.0025850652052235067 c1: 0.006009797699696161
# [iter=9720] obj_s=nan PDE_obj_MSE=3.893e-05 data_lossmse=nanfeas_true=2.752e-10  station=1.144e-03 tau=4.576036e-01 alpha=1.69e-01 beta=9.61e-02 lam=1.00e-04 kkt_res=1.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.37e-05,5.70e-04) BCv=(1.37e-06,4.31e-06) BCd=(1.57e-06,2.34e-06) IC=(4.34e-06,1.01e-05) | ||d||_inf=1.14e-03| ||d||_l2=4.78e-03
# tau delta_c: 0.0033428340398966713 ratio: 0.4348769574192064 miuy1: 0.0025723981980787583 c1: 0.00591523223797543
# [iter=9730] obj_s=nan PDE_obj_MSE=3.894e-05 data_lossmse=nanfeas_true=2.581e-10  station=7.773e-04 tau=4.576036e-01 alpha=3.63e-01 beta=9.60e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.47e-05,8.95e-04) BCv=(1.38e-06,4.24e-06) BCd=(1.57e-06,2.33e-06) IC=(4.32e-06,1.02e-05) | ||d||_inf=7.77e-04| ||d||_l2=3.24e-03
# tau delta_c: 0.004000751926367337 ratio: 0.39494166661184443 miuy1: 0.002611423636878372 c1: 0.006612175563245709
# [iter=9740] obj_s=nan PDE_obj_MSE=3.889e-05 data_lossmse=nanfeas_true=1.903e-10  station=9.778e-04 tau=4.576036e-01 alpha=2.48e-01 beta=9.60e-02 lam=1.00e-04 kkt_res=1.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.32e-05,5.10e-04) BCv=(1.37e-06,4.28e-06) BCd=(1.57e-06,2.26e-06) IC=(4.33e-06,1.01e-05) | ||d||_inf=9.78e-04| ||d||_l2=4.31e-03
# tau delta_c: 0.005466249998511981 ratio: 0.31928425738807076 miuy1: 0.002563900703655999 c1: 0.00803015070216798
# [iter=9750] obj_s=nan PDE_obj_MSE=3.955e-05 data_lossmse=nanfeas_true=5.201e-10  station=4.542e-04 tau=4.576036e-01 alpha=9.40e-01 beta=9.59e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(6.07e-05,1.28e-03) BCv=(1.37e-06,4.31e-06) BCd=(1.57e-06,2.27e-06) IC=(4.32e-06,1.00e-05) | ||d||_inf=4.54e-04| ||d||_l2=1.88e-03
# tau delta_c: 0.004412971893674662 ratio: 0.37111210613036405 miuy1: 0.0026041323258405584 c1: 0.007017104219515221
# [iter=9760] obj_s=nan PDE_obj_MSE=3.886e-05 data_lossmse=nanfeas_true=2.117e-10  station=1.570e-03 tau=4.576036e-01 alpha=1.27e-01 beta=9.59e-02 lam=1.00e-04 kkt_res=1.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.69e-05,6.40e-04) BCv=(1.38e-06,4.26e-06) BCd=(1.57e-06,2.26e-06) IC=(4.32e-06,1.01e-05) | ||d||_inf=1.57e-03| ||d||_l2=6.27e-03
# tau delta_c: 0.0035735145682592217 ratio: 0.4183735234630851 miuy1: 0.00257048800455422 c1: 0.006144002572813442
# [iter=9770] obj_s=nan PDE_obj_MSE=3.921e-05 data_lossmse=nanfeas_true=3.243e-10  station=4.984e-04 tau=4.576036e-01 alpha=9.39e-01 beta=9.58e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.23e-05,6.39e-04) BCv=(1.37e-06,4.25e-06) BCd=(1.57e-06,2.25e-06) IC=(4.32e-06,1.01e-05) | ||d||_inf=4.98e-04| ||d||_l2=1.92e-03
# tau delta_c: 0.0045566111307148915 ratio: 0.35993220179765 miuy1: 0.0025623396171781812 c1: 0.007118950747893073
# [iter=9780] obj_s=nan PDE_obj_MSE=3.903e-05 data_lossmse=nanfeas_true=1.079e-10  station=5.384e-04 tau=4.576036e-01 alpha=7.05e-01 beta=9.58e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.59e-05,9.69e-04) BCv=(1.37e-06,4.29e-06) BCd=(1.57e-06,2.27e-06) IC=(4.33e-06,1.01e-05) | ||d||_inf=5.38e-04| ||d||_l2=2.74e-03
# tau delta_c: 0.0031146171377165154 ratio: 0.45345950951547426 miuy1: 0.0025841685733939412 c1: 0.005698785711110457
# [iter=9790] obj_s=nan PDE_obj_MSE=3.881e-05 data_lossmse=nanfeas_true=2.229e-10  station=1.390e-03 tau=4.576036e-01 alpha=1.15e-01 beta=9.57e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.54e-05,4.39e-04) BCv=(1.37e-06,4.28e-06) BCd=(1.57e-06,2.37e-06) IC=(4.32e-06,1.00e-05) | ||d||_inf=1.39e-03| ||d||_l2=5.53e-03
# tau delta_c: 0.004761983805036556 ratio: 0.35128870852623467 miuy1: 0.0025786989726874336 c1: 0.00734068277772399
# [iter=9800] obj_s=nan PDE_obj_MSE=3.868e-05 data_lossmse=nanfeas_true=1.522e-10  station=9.833e-04 tau=4.576036e-01 alpha=2.47e-01 beta=9.56e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.72e-05,9.33e-04) BCv=(1.37e-06,4.32e-06) BCd=(1.57e-06,2.31e-06) IC=(4.33e-06,1.01e-05) | ||d||_inf=9.83e-04| ||d||_l2=4.67e-03
# tau delta_c: 0.0041220832307291184 ratio: 0.3843824142819135 miuy1: 0.002573767125658799 c1: 0.006695850356387918
# [iter=9810] obj_s=nan PDE_obj_MSE=3.888e-05 data_lossmse=nanfeas_true=2.774e-10  station=7.000e-04 tau=4.576036e-01 alpha=4.37e-01 beta=9.56e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.97e-05,6.88e-04) BCv=(1.37e-06,4.22e-06) BCd=(1.58e-06,2.23e-06) IC=(4.32e-06,1.02e-05) | ||d||_inf=7.00e-04| ||d||_l2=3.31e-03
# tau delta_c: 0.0026584123410440504 ratio: 0.4917772365350311 miuy1: 0.002572389055806981 c1: 0.005230801396851031
# [iter=9820] obj_s=nan PDE_obj_MSE=3.861e-05 data_lossmse=nanfeas_true=6.647e-11  station=8.339e-04 tau=4.576036e-01 alpha=2.24e-01 beta=9.55e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.38e-05,4.31e-04) BCv=(1.38e-06,4.21e-06) BCd=(1.57e-06,2.25e-06) IC=(4.34e-06,9.96e-06) | ||d||_inf=8.34e-04| ||d||_l2=3.66e-03
# tau delta_c: 0.005032199651124992 ratio: 0.3364181907214568 miuy1: 0.0025511903405266486 c1: 0.00758338999165164
# [iter=9830] obj_s=nan PDE_obj_MSE=3.857e-05 data_lossmse=nanfeas_true=4.942e-10  station=1.351e-04 tau=4.576036e-01 alpha=9.36e-01 beta=9.55e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.76e-05,7.09e-04) BCv=(1.38e-06,4.25e-06) BCd=(1.57e-06,2.32e-06) IC=(4.32e-06,9.95e-06) | ||d||_inf=1.35e-04| ||d||_l2=9.28e-04
# tau delta_c: 0.0036860904565830122 ratio: 0.4109701805914865 miuy1: 0.0025718108161988593 c1: 0.0062579012727818715
# [iter=9840] obj_s=nan PDE_obj_MSE=3.877e-05 data_lossmse=nanfeas_true=6.297e-10  station=7.575e-04 tau=4.576036e-01 alpha=4.36e-01 beta=9.54e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.69e-05,8.58e-04) BCv=(1.36e-06,4.31e-06) BCd=(1.57e-06,2.28e-06) IC=(4.33e-06,9.93e-06) | ||d||_inf=7.57e-04| ||d||_l2=3.19e-03
# tau delta_c: 0.0037260401936152605 ratio: 0.41221195850381953 miuy1: 0.002613047930959103 c1: 0.0063390881245743635
# [iter=9850] obj_s=nan PDE_obj_MSE=3.875e-05 data_lossmse=nanfeas_true=3.488e-10  station=1.929e-03 tau=4.576036e-01 alpha=6.48e-02 beta=9.53e-02 lam=1.00e-04 kkt_res=1.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.00e-05,4.50e-04) BCv=(1.38e-06,4.23e-06) BCd=(1.57e-06,2.34e-06) IC=(4.32e-06,1.01e-05) | ||d||_inf=1.93e-03| ||d||_l2=8.05e-03
# tau delta_c: 0.003486763432390229 ratio: 0.42244345174159514 miuy1: 0.0025503310181954385 c1: 0.0060370944505856675
# [iter=9860] obj_s=nan PDE_obj_MSE=3.907e-05 data_lossmse=nanfeas_true=5.279e-10  station=4.948e-04 tau=4.576036e-01 alpha=9.34e-01 beta=9.53e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.91e-05,4.51e-04) BCv=(1.37e-06,4.21e-06) BCd=(1.57e-06,2.36e-06) IC=(4.32e-06,1.00e-05) | ||d||_inf=4.95e-04| ||d||_l2=2.08e-03
# tau delta_c: 0.00337519176260771 ratio: 0.43012889207616484 miuy1: 0.0025475365801297745 c1: 0.005922728342737485
# [iter=9870] obj_s=nan PDE_obj_MSE=3.848e-05 data_lossmse=nanfeas_true=2.209e-10  station=1.155e-04 tau=4.576036e-01 alpha=9.33e-01 beta=9.52e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.95e-05,4.94e-04) BCv=(1.37e-06,4.28e-06) BCd=(1.57e-06,2.31e-06) IC=(4.32e-06,1.01e-05) | ||d||_inf=1.16e-04| ||d||_l2=8.71e-04
# tau delta_c: 0.0029261835723481105 ratio: 0.46475638494204957 miuy1: 0.002540828999172794 c1: 0.005467012571520905
# [iter=9880] obj_s=nan PDE_obj_MSE=3.848e-05 data_lossmse=nanfeas_true=2.562e-10  station=3.254e-04 tau=4.576036e-01 alpha=9.33e-01 beta=9.52e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.36e-05,3.73e-04) BCv=(1.37e-06,4.29e-06) BCd=(1.57e-06,2.27e-06) IC=(4.33e-06,1.01e-05) | ||d||_inf=3.25e-04| ||d||_l2=1.50e-03
# tau delta_c: 0.003804605609773155 ratio: 0.4048089974561596 miuy1: 0.002587637541605661 c1: 0.006392243151378816
# [iter=9890] obj_s=nan PDE_obj_MSE=3.845e-05 data_lossmse=nanfeas_true=1.632e-10  station=1.154e-03 tau=4.576036e-01 alpha=1.68e-01 beta=9.51e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.24e-05,5.77e-04) BCv=(1.37e-06,4.26e-06) BCd=(1.58e-06,2.36e-06) IC=(4.33e-06,9.99e-06) | ||d||_inf=1.15e-03| ||d||_l2=5.06e-03
# tau delta_c: 0.0038589759181360235 ratio: 0.4002848813740931 miuy1: 0.002575705813713385 c1: 0.006434681731849409
# [iter=9900] obj_s=nan PDE_obj_MSE=3.838e-05 data_lossmse=nanfeas_true=4.399e-10  station=9.303e-04 tau=4.576036e-01 alpha=2.70e-01 beta=9.51e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.63e-05,6.21e-04) BCv=(1.37e-06,4.19e-06) BCd=(1.58e-06,2.19e-06) IC=(4.33e-06,1.02e-05) | ||d||_inf=9.30e-04| ||d||_l2=4.00e-03
# tau delta_c: 0.00403979337453004 ratio: 0.3867287425775733 miuy1: 0.002547492961877202 c1: 0.006587286336407242
# [iter=9910] obj_s=nan PDE_obj_MSE=3.862e-05 data_lossmse=nanfeas_true=5.005e-10  station=2.296e-04 tau=4.576036e-01 alpha=9.31e-01 beta=9.50e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.80e-05,8.38e-04) BCv=(1.37e-06,4.34e-06) BCd=(1.57e-06,2.26e-06) IC=(4.32e-06,9.93e-06) | ||d||_inf=2.30e-04| ||d||_l2=1.18e-03
# tau delta_c: 0.004400882447960975 ratio: 0.3664248359808798 miuy1: 0.0025452270239503397 c1: 0.0069461094719113145
# [iter=9920] obj_s=nan PDE_obj_MSE=3.856e-05 data_lossmse=nanfeas_true=6.852e-10  station=2.529e-04 tau=4.576036e-01 alpha=9.31e-01 beta=9.50e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.05e-05,7.52e-04) BCv=(1.37e-06,4.23e-06) BCd=(1.57e-06,2.27e-06) IC=(4.33e-06,1.00e-05) | ||d||_inf=2.53e-04| ||d||_l2=1.51e-03
# tau delta_c: 0.004490698485811938 ratio: 0.3647272452141954 miuy1: 0.0025782312801530304 c1: 0.007068929765964968
# [iter=9930] obj_s=nan PDE_obj_MSE=3.833e-05 data_lossmse=nanfeas_true=4.528e-10  station=1.363e-03 tau=4.576036e-01 alpha=1.67e-01 beta=9.49e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.35e-05,9.09e-04) BCv=(1.38e-06,4.17e-06) BCd=(1.58e-06,2.29e-06) IC=(4.32e-06,1.04e-05) | ||d||_inf=1.36e-03| ||d||_l2=5.68e-03
# tau delta_c: 0.002800347342322991 ratio: 0.4784305036786485 miuy1: 0.0025687307231581046 c1: 0.005369078065481096
# [iter=9940] obj_s=nan PDE_obj_MSE=3.840e-05 data_lossmse=nanfeas_true=6.336e-10  station=1.241e-03 tau=4.576036e-01 alpha=1.04e-01 beta=9.48e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.08e-05,2.69e-04) BCv=(1.40e-06,4.18e-06) BCd=(1.58e-06,2.37e-06) IC=(4.31e-06,1.03e-05) | ||d||_inf=1.24e-03| ||d||_l2=5.57e-03
# tau delta_c: 0.004868424601706143 ratio: 0.3451943593608136 miuy1: 0.002566490890093602 c1: 0.007434915491799745
# [iter=9950] obj_s=nan PDE_obj_MSE=3.842e-05 data_lossmse=nanfeas_true=2.713e-10  station=8.236e-04 tau=4.576036e-01 alpha=4.77e-01 beta=9.48e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(4.54e-05,8.02e-04) BCv=(1.38e-06,4.20e-06) BCd=(1.58e-06,2.30e-06) IC=(4.32e-06,9.97e-06) | ||d||_inf=8.24e-04| ||d||_l2=3.47e-03
# tau delta_c: 0.0030896299593093247 ratio: 0.4537186511854898 miuy1: 0.0025661186142309535 c1: 0.005655748573540278
# [iter=9960] obj_s=nan PDE_obj_MSE=3.817e-05 data_lossmse=nanfeas_true=2.912e-10  station=9.711e-04 tau=4.576036e-01 alpha=2.02e-01 beta=9.47e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.38e-05,3.50e-04) BCv=(1.38e-06,4.22e-06) BCd=(1.58e-06,2.30e-06) IC=(4.32e-06,1.02e-05) | ||d||_inf=9.71e-04| ||d||_l2=4.19e-03
# tau delta_c: 0.00331395350299491 ratio: 0.4402871267297849 miuy1: 0.0026068563644512117 c1: 0.005920809867446122
# [iter=9970] obj_s=nan PDE_obj_MSE=3.838e-05 data_lossmse=nanfeas_true=3.244e-10  station=1.812e-03 tau=4.576036e-01 alpha=7.08e-02 beta=9.47e-02 lam=1.00e-04 kkt_res=1.0e-04 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.97e-05,5.48e-04) BCv=(1.37e-06,4.30e-06) BCd=(1.58e-06,2.28e-06) IC=(4.32e-06,9.99e-06) | ||d||_inf=1.81e-03| ||d||_l2=7.48e-03
# tau delta_c: 0.003407973731818729 ratio: 0.4273351498663223 miuy1: 0.0025431052125641906 c1: 0.005951078944382919
# [iter=9980] obj_s=nan PDE_obj_MSE=3.851e-05 data_lossmse=nanfeas_true=2.363e-10  station=3.499e-04 tau=4.576036e-01 alpha=9.27e-01 beta=9.46e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(2.72e-05,4.93e-04) BCv=(1.36e-06,4.28e-06) BCd=(1.58e-06,2.35e-06) IC=(4.32e-06,1.02e-05) | ||d||_inf=3.50e-04| ||d||_l2=1.68e-03
# tau delta_c: 0.0036544511333766296 ratio: 0.41190341207495074 miuy1: 0.0025595810654335024 c1: 0.006214032198810132
# [iter=9990] obj_s=nan PDE_obj_MSE=3.814e-05 data_lossmse=nanfeas_true=1.422e-10  station=8.815e-04 tau=4.576036e-01 alpha=2.95e-01 beta=9.46e-02 lam=1.00e-04 kkt_res=9.8e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.76e-05,8.50e-04) BCv=(1.37e-06,4.23e-06) BCd=(1.58e-06,2.28e-06) IC=(4.30e-06,9.85e-06) | ||d||_inf=8.82e-04| ||d||_l2=3.82e-03
# tau delta_c: 0.003929863658515749 ratio: 0.3970188499866102 miuy1: 0.002587526907389144 c1: 0.006517390565904894
# [iter=10000] obj_s=nan PDE_obj_MSE=3.812e-05 data_lossmse=nanfeas_true=1.890e-10  station=1.397e-03 tau=4.576036e-01 alpha=1.38e-01 beta=9.45e-02 lam=1.00e-04 kkt_res=9.9e-05 s=1.00e+00 | hold_data_K=10000 hold_con_K=10000 | jitter=gaussian sigx=1.0e-05 sigt=1.0e-05 clipk=2.0| RMS/max: PDE=(3.95e-05,8.04e-04) BCv=(1.38e-06,4.19e-06) BCd=(1.58e-06,2.31e-06) IC=(4.33e-06,1.04e-05) | ||d||_inf=1.40e-03| ||d||_l2=5.89e-03
# [done] elapsed=28184.20s
# Saved theta -> theta_star_pointwise_jitter_1e-5.npz
# [EVAL] full-grid MSE=1.441e-07, relL2=6.188e-04

# %%
pkill -9 -u $(whoami) python
